# %%
import pandas as pd
import numpy as np
import re
from datetime import datetime, timedelta
from sklearn.preprocessing import MinMaxScaler

import os
from dotenv import load_dotenv
import boto3
import io
import pymysql
import json

# %% [markdown]
# DB Connection

# %%
# from sshtunnel import SSHTunnelForwarder

# class SSHMySQLConnector:
#     def __init__(self):
#         self.ssh_host = None
#         self.ssh_username = None
#         self.ssh_password = None
#         self.db_username = None
#         self.db_password = None
#         self.db_name = None
#         self.tunnel = None
#         self.connection = None

#     def load_config_from_json(self, json_path):
#         try:
#             with open(json_path, 'r', encoding='utf-8') as f:
#                 config = json.load(f)
#                 self.ssh_host = config['ssh_host']
#                 self.ssh_username = config['ssh_username']
#                 self.ssh_password = config['ssh_password']
#                 self.db_username = config['db_username']
#                 self.db_password = config['db_password']
#                 self.db_name = config['db_name']
#         except Exception as e:
#             print("❌ 설정 JSON 로딩 실패:", e)


#     def connect(self):
#         try:
#             self.tunnel = SSHTunnelForwarder(
#                 (self.ssh_host, 22),
#                 ssh_username=self.ssh_username,
#                 ssh_password=self.ssh_password,
#                 remote_bind_address=('127.0.0.1', 3306),
#             )
#             self.tunnel.start()
            
#             self.connection = pymysql.connect(
#                 host='127.0.0.1',
#                 port=self.tunnel.local_bind_port,
#                 user=self.db_username,
#                 password=self.db_password,
#                 db=self.db_name,
#                 cursorclass=pymysql.cursors.DictCursor  # 이 줄 추가
#             )
#             print("✅ DB 접속 성공")
#         except Exception as e:
#             print("❌ SSH 또는 DB 연결 실패:", e)

#     def insert_query_with_lookup(self, table_name, data_list):
#         try:
#             with self.connection.cursor() as cursor:
#                 for data in data_list:
#                     # 1. op_member에서 uid, user_id 조회
#                     cursor.execute("""
#                         SELECT uid, user_id FROM op_member
#                         WHERE add1 = %s
#                         LIMIT 1
#                     """, (data['acnt_nm'],))
#                     result = cursor.fetchone()
#                     if result:
#                         data['member_uid'] = result['uid']
#                         data['user_id'] = result['user_id']
#                         # 향후에 ig_user_id가 추가가 된다면, 해당 부분도 확인해서 추가할 수 있게
#                         # data['ig_user_id'] = result['ig_user_id']
#                     else:
#                         data['member_uid'] = 0
#                         data['user_id'] = 'None'
#                         # data['ig_user_id'] = 'None'

#                     # 2. INSERT 쿼리 구성 및 실행
#                     columns = ', '.join(data.keys())
#                     placeholders = ', '.join([f"%({k})s" for k in data.keys()])
#                     insert_sql = f"INSERT INTO {table_name} ({columns}) VALUES ({placeholders})"
#                     cursor.execute(insert_sql, data)

#                     print(f"✅ inserted acnt_id: {data.get('acnt_id', 'N/A')}")

#             self.connection.commit()
#         except Exception as e:
#             self.connection.rollback()
#             print("❌ INSERT 실패:", e)

#     def close(self):
#         if self.connection:
#             self.connection.close()
#         if self.tunnel:
#             self.tunnel.stop()

# %%
# ssh = SSHMySQLConnector()
# ssh.load_config_from_json('C:/Users/ehddl/Desktop/업무/code/config/ssh_db_config.json')
# ssh.connect()

# # data_list = [
# #     {
# #         'activity_score': 0.18618008163528707,
# #         'follow_growth_rate': 1.2384506112322682,
# #         'follower_total_engagement': 0.9006925508419993,
# #         'follower_retention_rate': 4.84593837535013,
# #         'avg_post_efficiency': 1.4776093002849746,
# #         'acnt_id': '17841400070132367',
# #         'acnt_nm': 'gnuoyeatt',
# #         'influencer_scale_type': 'nano'
# #     }
# # ]

# # ssh.insert_query_with_lookup('op_mem_seller_score', data_list)

# %%
from sshtunnel import SSHTunnelForwarder

class SSHMySQLConnector:
    def __init__(self):
        self.ssh_host = None
        self.ssh_username = None
        self.ssh_password = None
        self.db_username = None
        self.db_password = None
        self.db_name = None
        self.tunnel = None
        self.connection = None

    def load_config_from_json(self, json_path):
        try:
            with open(json_path, 'r', encoding='utf-8') as f:
                config = json.load(f)
                self.ssh_host = config['ssh_host']
                self.ssh_username = config['ssh_username']
                self.ssh_password = config['ssh_password']
                self.db_username = config['db_username']
                self.db_password = config['db_password']
                self.db_name = config['db_name']
        except Exception as e:
            print("설정 JSON 로딩 실패:", e)

    def connect(self, insert=False):
        try:
            self.tunnel = SSHTunnelForwarder(
                (self.ssh_host, 22),
                ssh_username=self.ssh_username,
                ssh_password=self.ssh_password,
                remote_bind_address=('127.0.0.1', 3306),
            )
            self.tunnel.start()
            # insert 여부에 따라 cursorclass 설정
            connect_kwargs = {
                'host': '127.0.0.1',
                'port': self.tunnel.local_bind_port,
                'user': self.db_username,
                'password': self.db_password,
                'db': self.db_name,
            }
            if insert:
                connect_kwargs['cursorclass'] = pymysql.cursors.DictCursor
            self.connection = pymysql.connect(**connect_kwargs)
            print("DB 접속 성공")
        except Exception as e:
            print("SSH 또는 DB 연결 실패:", e)

    def execute_query(self, query):
        # 쿼리 실행 후 데이터를 DataFrame으로 반환
        return pd.read_sql_query(query, self.connection)

    def insert_query_with_lookup(self, table_name, data_list):
        try:
            with self.connection.cursor() as cursor:
                for data in data_list:
                    # 1. op_member에서 uid, user_id 조회
                    cursor.execute("""
                        SELECT uid, user_id, add1_connected FROM op_member
                        WHERE add1 = %s
                        LIMIT 1
                    """, (data['acnt_nm'],))
                    result = cursor.fetchone()
                    
                    if result:
                        data['member_uid'] = result['uid']
                        data['user_id'] = result['user_id']
                        data['is_connected'] = result['add1_connected']
                        # 향후에 ig_user_id가 추가가 된다면, 해당 부분도 확인해서 추가할 수 있게
                        # data['ig_user_id'] = result['ig_user_id']
                    else:
                        data['member_uid'] = 0
                        data['user_id'] = 'None'
                        data['is_connected'] = 'n'
                        # data['ig_user_id'] = 'None'
              

                    # 2. INSERT 쿼리 구성 및 실행
                    columns = ', '.join(data.keys())
                    placeholders = ', '.join([f"%({k})s" for k in data.keys()])
                    insert_sql = f"INSERT INTO {table_name} ({columns}) VALUES ({placeholders})"
                    print(insert_sql)
                    cursor.execute(insert_sql, data)

                    print(f"inserted acnt_id: {data.get('acnt_id', 'N/A')}")

            self.connection.commit()
        except Exception as e:
            self.connection.rollback()
            print("INSERT 실패:", e)
    
    def close(self):
        if self.connection:
            self.connection.close()
        if self.tunnel:
            self.tunnel.stop()

def sendQuery(query):
        ssh = SSHMySQLConnector()
        ssh.load_config_from_json('C:/Users/ehddl/Desktop/업무/code/config/ssh_db_config.json')
        ssh.connect()
        results = ssh.execute_query(query)
        # print(results)
        # print(results.head())
        ssh.close()

        return results
    
def get_all_infos(): 

    query_sales_info = """
        SELECT o.uid, o.add1, s.*
        FROM op_mem_seller_statistics s
        JOIN (
            SELECT member_uid, MAX(regdate) AS max_regdate
            FROM op_mem_seller_statistics
            GROUP BY member_uid
        ) latest ON s.member_uid = latest.member_uid AND s.regdate = latest.max_regdate
        JOIN op_member o ON o.uid = s.member_uid
        JOIN S3_RECENT_USER_INFO_MTR u ON o.add1 = u.acnt_nm
        ORDER BY s.uid DESC
    """
    sales_info = sendQuery(query_sales_info)

    query_seller_info = """
        SELECT
        o.user_id, o.ig_user_id, o.add1, s.interestcategory
        FROM op_member o
        left join op_mem_seller s on o.user_id=s.user_id
        where (o.ig_user_id != '' and o.ig_user_id is not null) or (o.add1 != '' and o.add1 is not null)
    """
    seller_info = sendQuery(query_seller_info)

    return sales_info, seller_info

# %%
sales_info, seller_info = get_all_infos()
# Out:
# DB 접속 성공
# DB 접속 성공

# %%
ssh = SSHMySQLConnector()
ssh.load_config_from_json('C:/Users/ehddl/Desktop/업무/code/config/ssh_db_config.json')
ssh.connect(True)
# Out:
# DB 접속 성공

# %% [markdown]
# Data Loading

# %%
# def load_s3_instagram_data():

#     load_dotenv()
#     aws_access_key = os.getenv("aws_accessKey")
#     aws_secret_key = os.getenv("aws_secretKey")
#     region_name='ap-northeast-2'

#     # S3 클라이언트 생성
#     client = boto3.client('s3', aws_access_key_id=aws_access_key, aws_secret_access_key=aws_secret_key, region_name=region_name)

#     today = datetime.now()
#     year, week, _ = today.isocalendar()

#     bucket_name = 'flexmatch-data'

#     table_list = ['RECENT_USER_INFO_MTR', 'TIME_SERIES_PROFILE_INFO', 'BY_USER_ID_MEDIA_DTL_INFO', 'BY_DATE_MEDIA_AGG_INFO']
#     df_by_table_list = {}

#     for table_name in table_list:
#         prefix = f'instagram-data/tables/{table_name}/year={year}/week=28/' # 이번주가 없어서 week를 따로 x
#         response = client.list_objects_v2(Bucket=bucket_name, Prefix=prefix)

#         if 'Contents' in response:
#             files = [content['Key'] for content in response['Contents'] if content['Key'].endswith('merged_data.parquet')]

#             if not files:
#                 print(f"[Info] No merged_data.parquet found for table: {table_name}")
#                 continue

#             # 각 파일 순회
#             for file_key in files:
#                 try:
#                     obj = client.get_object(Bucket=bucket_name, Key=file_key)
#                     df = pd.read_parquet(io.BytesIO(obj['Body'].read()))
#                     df_by_table_list[table_name] = df
#                     print(f"[Success] Loaded {file_key} for table {table_name}")
#                 except Exception as e:
#                     print(f"[Error] Failed to read {file_key} for table {table_name}: {e}")
#         else:
#             print(f"[Info] No files found under prefix: {prefix}")
        
#     return df_by_table_list

# df_by_table_list = load_s3_instagram_data()

# recent_user_info_mtr_2 = df_by_table_list['RECENT_USER_INFO_MTR']
# time_series_profile_info_2 = df_by_table_list['TIME_SERIES_PROFILE_INFO']
# by_user_id_media_dtl_info_2 = df_by_table_list['BY_USER_ID_MEDIA_DTL_INFO']
# by_date_media_agg_info_2 = df_by_table_list['BY_DATE_MEDIA_AGG_INFO']

# # recent_user_info_mtr = df_by_table_list['RECENT_USER_INFO_MTR']
# # time_series_profile_info = df_by_table_list['TIME_SERIES_PROFILE_INFO']
# # by_user_id_media_dtl_info = df_by_table_list['BY_USER_ID_MEDIA_DTL_INFO']
# # by_date_media_agg_info = df_by_table_list['BY_DATE_MEDIA_AGG_INFO']

# %%
def load_weekly_instagram_data(bucket_name, table_list, weeks_back=2, target_filename='merged_data.parquet'):
    # 환경 변수 로딩
    load_dotenv()
    aws_access_key = os.getenv("aws_accessKey")
    aws_secret_key = os.getenv("aws_secretKey")

    client = boto3.client(
        's3',
        aws_access_key_id=aws_access_key,
        aws_secret_access_key=aws_secret_key,
        region_name='ap-northeast-2'
    )

    # 주차 리스트 생성 (현재 주 포함하여 `weeks_back`만큼)
    today = datetime.now()
    week_year_pairs = [
        (today - timedelta(weeks=w)).isocalendar()[:2]
        for w in range(weeks_back)
    ]

    # 결과 저장용 딕셔너리 초기화
    merged_data_by_table = {table_name: {} for table_name in table_list}

    # 주차별로 데이터 로딩
    for year_val, week_val in week_year_pairs:
        for table_name in table_list:
            prefix = f'instagram-data/tables/{table_name}/year={year_val}/week={week_val}/'
            response = client.list_objects_v2(Bucket=bucket_name, Prefix=prefix)

            if 'Contents' not in response:
                print(f"[Info] No files found under prefix: {prefix}")
                continue

            target_files = [
                content['Key']
                for content in response['Contents']
                if content['Key'].endswith(target_filename)
            ]

            if not target_files:
                print(f"[Info] No {target_filename} found for {table_name} week={week_val}")
                continue

            for file_key in target_files:
                try:
                    obj = client.get_object(Bucket=bucket_name, Key=file_key)
                    df = pd.read_parquet(io.BytesIO(obj['Body'].read()))
                    merged_data_by_table[table_name][week_val] = df
                    print(f"[Success] Loaded {file_key} for table {table_name}, week {week_val}")
                except Exception as e:
                    print(f"[Error] Failed to read {file_key} for {table_name}, week {week_val}: {e}")

    recent_weeks_data = {}
    for table_name, week_data in merged_data_by_table.items():
        sorted_weeks = sorted(week_data.keys())
        if len(sorted_weeks) >= 2:
            prev_week, current_week = sorted_weeks[-2], sorted_weeks[-1]
            recent_weeks_data[table_name] = {
                'prev_week': week_data[prev_week],
                'current_week': week_data[current_week]
            }
        else:
            print(f"[Warning] Not enough data for table {table_name} to determine prev/current weeks.")

    
    return recent_weeks_data

# %%
bucket_name = 'flexmatch-data'
table_list = [
    'RECENT_USER_INFO_MTR',
    'TIME_SERIES_PROFILE_INFO',
    'BY_USER_ID_MEDIA_DTL_INFO',
    'BY_DATE_MEDIA_AGG_INFO'
]

merged_data_by_table = load_weekly_instagram_data(bucket_name, table_list)

recent_user_info_mtr = merged_data_by_table['RECENT_USER_INFO_MTR']['prev_week']
time_series_profile_info = merged_data_by_table['TIME_SERIES_PROFILE_INFO']['prev_week']
by_user_id_media_dtl_info = merged_data_by_table['BY_USER_ID_MEDIA_DTL_INFO']['prev_week']
by_date_media_agg_info = merged_data_by_table['BY_DATE_MEDIA_AGG_INFO']['prev_week']

recent_user_info_mtr_2 = merged_data_by_table['RECENT_USER_INFO_MTR']['current_week']
time_series_profile_info_2 = merged_data_by_table['TIME_SERIES_PROFILE_INFO']['current_week']
by_user_id_media_dtl_info_2 = merged_data_by_table['BY_USER_ID_MEDIA_DTL_INFO']['current_week']
by_date_media_agg_info_2 = merged_data_by_table['BY_DATE_MEDIA_AGG_INFO']['current_week']
# Out:
# [Success] Loaded instagram-data/tables/RECENT_USER_INFO_MTR/year=2025/week=29/merged_data.parquet for table RECENT_USER_INFO_MTR, week 29
# [Success] Loaded instagram-data/tables/TIME_SERIES_PROFILE_INFO/year=2025/week=29/merged_data.parquet for table TIME_SERIES_PROFILE_INFO, week 29
# [Success] Loaded instagram-data/tables/BY_USER_ID_MEDIA_DTL_INFO/year=2025/week=29/merged_data.parquet for table BY_USER_ID_MEDIA_DTL_INFO, week 29
# [Success] Loaded instagram-data/tables/BY_DATE_MEDIA_AGG_INFO/year=2025/week=29/merged_data.parquet for table BY_DATE_MEDIA_AGG_INFO, week 29
# [Success] Loaded instagram-data/tables/RECENT_USER_INFO_MTR/year=2025/week=28/merged_data.parquet for table RECENT_USER_INFO_MTR, week 28
# [Success] Loaded instagram-data/tables/TIME_SERIES_PROFILE_INFO/year=2025/week=28/merged_data.parquet for table TIME_SERIES_PROFILE_INFO, week 28
# [Success] Loaded instagram-data/tables/BY_USER_ID_MEDIA_DTL_INFO/year=2025/week=28/merged_data.parquet for table BY_USER_ID_MEDIA_DTL_INFO, week 28
# [Success] Loaded instagram-data/tables/BY_DATE_MEDIA_AGG_INFO/year=2025/week=28/merged_data.parquet for table BY_DATE_MEDIA_AGG_INFO, week 28

# %% [markdown]
# basic preprocessing

# %%
recent_user_info_mtr = recent_user_info_mtr.drop_duplicates(subset=['acnt_id', 'acnt_nm'])
time_series_profile_info = time_series_profile_info.drop_duplicates(subset=['base_ymd', 'acnt_id'])
by_user_id_media_dtl_info = by_user_id_media_dtl_info.drop_duplicates(subset=['acnt_id', 'media_id', 'media_cn'])
by_date_media_agg_info = by_date_media_agg_info.drop_duplicates(subset=['base_ymd', 'media_id'])

recent_user_info_mtr_2 = recent_user_info_mtr_2.drop_duplicates(subset=['acnt_id', 'acnt_nm'])
time_series_profile_info_2 = time_series_profile_info_2.drop_duplicates(subset=['base_ymd', 'acnt_id'])
by_user_id_media_dtl_info_2 = by_user_id_media_dtl_info_2.drop_duplicates(subset=['acnt_id', 'media_id', 'media_cn'])
by_date_media_agg_info_2 = by_date_media_agg_info_2.drop_duplicates(subset=['base_ymd', 'media_id'])

# %%
recent_user_info_mtr_2['acnt_id'] = recent_user_info_mtr_2['acnt_id'].astype(str)
time_series_profile_info_2['acnt_id'] = time_series_profile_info_2['acnt_id'].astype(str)

# %% [markdown]
# 가장 최근 데이터로 isin 해줘야 할 것 같음. 그래야 1주일 전, 후를 비교할 수 있기 때문임

# %%
# 각 acnt_id가 있는 전부 있는 경우만 가능, isin으로 제거
# 근데 전 주차에는 없는 유저가 생길수도 있음
# media 같은 경우에도 최근 25개만 일단 가져오고 있기 때문에 일주일 단위여도 없을수도 있음

# 이렇게 해야하는 이유는 timeseries 변수를 계산하려면 무조건 두 주차에 같은 아이디가 있어야 함
# 또한, user info랑 media info 같이 써야하는 경우에는 어짜피 한번 거르고 있을 듯
# -> 따라서, 굳이 필수적으로 하지는 않아도 될듯함

unique_user = recent_user_info_mtr['acnt_id'].unique()

time_series_profile_info = time_series_profile_info[time_series_profile_info['acnt_id'].isin(unique_user)]
by_user_id_media_dtl_info = by_user_id_media_dtl_info[by_user_id_media_dtl_info['acnt_id'].isin(unique_user)]
time_series_profile_info_2 = time_series_profile_info_2[time_series_profile_info_2['acnt_id'].isin(unique_user)]
by_user_id_media_dtl_info_2 = by_user_id_media_dtl_info_2[by_user_id_media_dtl_info_2['acnt_id'].isin(unique_user)]

unique_media = by_user_id_media_dtl_info_2['media_id'].unique()
by_date_media_agg_info_2 = by_date_media_agg_info_2[by_date_media_agg_info_2['media_id'].isin(unique_media)]

# %%
def influencer_scale_type(row):
    count = row['follower_cnt']
    if count < 1000:
        return 'nano'
    elif 1000 <= count <= 10000:
        return 'micro'
    elif 10000 < count <= 100000:
        return 'mid'
    elif 100000 < count <= 500000:
        return 'macro'
    else:
        return 'mega'

recent_user_info_mtr.loc[:, 'influencer_scale_type'] = recent_user_info_mtr.apply(influencer_scale_type, axis=1)
recent_user_info_mtr_2.loc[:,'influencer_scale_type'] = recent_user_info_mtr_2.apply(influencer_scale_type, axis=1)

# %% [markdown]
# create merged file

# %%
def create_merged_df(user_info_df, timeseries_df, timeseries_df_2, media_info_df, media_agg_df):
    media_engagement_merged_df = pd.merge(media_info_df, media_agg_df, on='media_id', how='outer')
    # print(len(media_engagement_merged_df['acnt_id'].unique()))

    ## 방법 1
    # 단 한개의 게시물이라도 like가 비공개인 influencer 제거
    # by_user_na_like_count = media_engagement_merged_df[media_engagement_merged_df['like_cnt'].isna()].groupby(['acnt_id'])['media_id'].count()
    # na_like_user = by_user_na_like_count[by_user_na_like_count > 0].index
    # media_engagement_merged_df = media_engagement_merged_df[~media_engagement_merged_df['acnt_id'].isin(na_like_user)].reset_index()

    ## 방법 2
    no_media_user = user_info_df[user_info_df['media_cnt'] == 0]['acnt_id'].to_list()
    media_engagement_merged_df = media_engagement_merged_df[~media_engagement_merged_df['acnt_id'].isin(no_media_user)].reset_index()

    media_engagement_merged_groupby_df = media_engagement_merged_df.groupby('acnt_id')[['like_cnt', 'cmnt_cnt']].mean()
    media_engagement_merged_groupby_df = np.ceil(media_engagement_merged_groupby_df)
    fillna_user = media_engagement_merged_groupby_df[media_engagement_merged_groupby_df['like_cnt'] > 1].index

    media_engagement_merged_df = media_engagement_merged_df[media_engagement_merged_df['acnt_id'].isin(fillna_user)].reset_index()

    engagement_cols = ['like_cnt', 'cmnt_cnt']
    for col in engagement_cols:
        media_engagement_merged_df[col] = media_engagement_merged_df.apply(
        lambda row: media_engagement_merged_groupby_df.at[row['acnt_id'], col] if pd.isna(row[col]) else row[col], axis=1)

    user_list = media_engagement_merged_df['acnt_id'].unique()
    media_list = media_engagement_merged_df['media_id'].unique()

    # merge하면서 제거된 리스트가 있기 때문에, 해당 부분 다시 삭제 후에 새로운 merge 파일 생성
    user_info = user_info_df[user_info_df['acnt_id'].isin(user_list)]
    timeseries = timeseries_df[timeseries_df['acnt_id'].isin(user_list)]
    timeseries_2 = timeseries_df_2[timeseries_df_2['acnt_id'].isin(user_list)]
    media_info = media_info_df[media_info_df['acnt_id'].isin(user_list)]
    media_agg = media_agg_df[media_agg_df['media_id'].isin(media_list)]

    all_merged_df_a = pd.merge(user_info, timeseries, on='acnt_id')
    all_merged_df_b = pd.merge(all_merged_df_a, media_info, on='acnt_id')
    all_merged_df = pd.merge(all_merged_df_b, media_agg, on='media_id')
    
    media_engagement_profile_merged_df = pd.merge(media_engagement_merged_df, user_info_df, on='acnt_id')
    time_series_merged_df = pd.merge(timeseries, timeseries_df_2, on='acnt_id')

    return user_info, timeseries, timeseries_2, media_info, media_agg, all_merged_df, media_engagement_merged_df, media_engagement_profile_merged_df, time_series_merged_df

# %%
user_info, timeseries, timeseries_2, media_info, media_agg, all_merged_df, media_engagement_merged_df, media_engagement_profile_merged_df, time_series_merged_df = create_merged_df(
                                                                                                                        recent_user_info_mtr_2,
                                                                                                                        time_series_profile_info,
                                                                                                                        time_series_profile_info_2,
                                                                                                                        by_user_id_media_dtl_info_2,
                                                                                                                        by_date_media_agg_info_2)

# %% [markdown]
# 크리에이터 활동성
#
# - 실제 게시물 업로드 날짜를 기준으로 계산할 수 있을 것 같음
# - 최근 25개의 게시물의 평균 게시 간격을 계산
# - 최근 25개의 게시물을 며칠에 걸쳐서 업로드 했는지에 대한 값을 계산

# %%
# media_dtl_2_copy = by_user_id_media_dtl_info_2.copy()
# media_dtl_2_copy = media_dtl_2_copy.drop_duplicates(subset=['acnt_id', 'media_id', 'media_cn'])
# media_dtl_2_copy['reg_dt'] = pd.to_datetime(media_dtl_2_copy['reg_dt'])
# media_dtl_2_copy = media_dtl_2_copy.sort_values(['acnt_id', 'reg_dt'])

# # 게시물 간격 계산
# media_dtl_2_copy['prev_reg_dt'] = media_dtl_2_copy.groupby('acnt_id')['reg_dt'].shift(1)
# media_dtl_2_copy['gap_days'] = (media_dtl_2_copy['reg_dt'] - media_dtl_2_copy['prev_reg_dt']).dt.days
# # media_dtl_2_copy

# # gap_days가 NaN인 첫 번째 포스트 제외 후 평균 간격 계산
# activity_df = media_dtl_2_copy.dropna(subset=['gap_days']).groupby('acnt_id')['gap_days'].mean().reset_index()
# activity_df.rename(columns={'gap_days': 'avg_upload_interval'}, inplace=True)

# # 활동성 점수 계산 (간격의 역수로 환산) -> 점수 정규화 (업로드 간격이 짧을수록 점수가 높아지도록 역수를 취해서 계산한 것)
# activity_df['activity_score'] = 100 / activity_df['avg_upload_interval']
# activity_df

# %%
def calculate_activity_score(recent_media_dtl_df): # 두 개의 테이블 중 가장 최근
    media_dtl_copy = recent_media_dtl_df.copy()
    media_dtl_copy = media_dtl_copy.drop_duplicates(subset=['acnt_id', 'media_id', 'media_cn'])
    media_dtl_copy['reg_dt'] = pd.to_datetime(media_dtl_copy['reg_dt'])
    media_dtl_copy = media_dtl_copy.sort_values(['acnt_id', 'reg_dt'])

    # 게시물 간격 계산
    media_dtl_copy['prev_reg_dt'] = media_dtl_copy.groupby('acnt_id')['reg_dt'].shift(1)
    media_dtl_copy['gap_days'] = (media_dtl_copy['reg_dt'] - media_dtl_copy['prev_reg_dt']).dt.days

    # gap_days가 NaN인 첫 번째 포스트 제외 후 평균 간격 계산
    activity_df = media_dtl_copy.dropna(subset=['gap_days']).groupby('acnt_id')['gap_days'].mean().reset_index()
    activity_df.rename(columns={'gap_days': 'avg_upload_interval'}, inplace=True)

    # 활동성 점수 계산 (간격의 역수로 환산) -> 점수 정규화 (업로드 간격이 짧을수록 점수가 높아지도록 역수를 취해서 계산한 것)
    activity_df['avg_upload_interval'] = activity_df['avg_upload_interval'].replace(0, 0.1)
    # activity_df['activity_score'] = activity_df['avg_upload_interval'] / 100
    ## 업로드 간격이 너무 짧은 유저의 경우 inf로 계산되는 것을 방지하기 위해서 scaling 진행
    # activity_df['activity_score'] = 100 / activity_df['avg_upload_interval']
    ## 너무 자주 올리면 오히려 게시물의 품질이 떨어질 수 있으므로 패널티를 주는 방식
    # activity_df['activity_score_penalty'] = 1 / (activity_df['avg_upload_interval'] + 1)
    activity_df['activity_score'] = (1 / activity_df['avg_upload_interval']) * 100

    return activity_df

# %%
activity_df = calculate_activity_score(media_info)

# %%
def check_inf(df):
    float_cols = df.select_dtypes(include=['float64', 'float32']).columns

    mask_inf = np.isinf(df[float_cols]).any(axis=1)
    mask_neginf = np.isneginf(df[float_cols]).any(axis=1)

    invalid_rows = df[mask_inf | mask_neginf]

    print(f"⚠️ inf / -inf 포함 행 개수: {len(invalid_rows)}개")
    display(invalid_rows)

# %%
check_inf(activity_df)
# Out:
# ⚠️ inf / -inf 포함 행 개수: 0개
# Empty DataFrame
# Columns: [acnt_id, avg_upload_interval, activity_score]
# Index: []

# %% [markdown]
# 트렌드지수 - 팔로워 순증감률 (follower_growth_rate)

# %%
# time_series_profile_info_2['acnt_id'] = time_series_profile_info_2['acnt_id'].astype(object)

# influencer_list = time_series_profile_info['acnt_id'].unique()
# time_series_profile_info_2[time_series_profile_info_2['acnt_id'].isin(influencer_list)]
# time_series_merged_df = pd.merge(time_series_profile_info, time_series_profile_info_2, on='acnt_id')

# time_series_merged_df['follow_growth_rate'] = ((time_series_merged_df['follower_cnt_y'] - time_series_merged_df['follower_cnt_x']) / (time_series_merged_df['follower_cnt_x'])) * 100
# time_series_merged_df[['acnt_id', 'follow_growth_rate']]

# %%
def calculate_follower_growth_rate(time_series_df, recent_time_series_df):
    time_series_df.loc[:, 'acnt_id'] = time_series_df['acnt_id'].astype(object)
    recent_time_series_df.loc[:, 'acnt_id'] = recent_time_series_df['acnt_id'].astype(object)

    influencer_list = time_series_df['acnt_id'].unique()
    recent_time_series_df = recent_time_series_df[recent_time_series_df['acnt_id'].isin(influencer_list)]
    time_series_merged_df = pd.merge(time_series_df, recent_time_series_df, on='acnt_id')

    time_series_merged_df['follow_growth_rate'] = ((time_series_merged_df['follower_cnt_y'] - time_series_merged_df['follower_cnt_x']) / (time_series_merged_df['follower_cnt_x'])) * 100
    # time_series_merged_df['follow_growth_rate'] = ((np.log1p(time_series_merged_df['follower_cnt_y']) - np.log1p(time_series_merged_df['follower_cnt_x'])) / np.log1p(time_series_merged_df['follower_cnt_x'])) * 100
    
    growth_rate_df = time_series_merged_df[['acnt_id', 'follow_growth_rate']]

    return growth_rate_df

# %%
growth_rate_df = calculate_follower_growth_rate(timeseries, timeseries_2)
growth_rate_df
# Out:
#                acnt_id  follow_growth_rate
# 0    17841401228916385            0.881543
# 1    17841433366211969           -0.036778
# 2    17841405869097470           -0.002018
# 3    17841406154606429            0.246305
# 4    17841400148093726           -0.013474
# ..                 ...                 ...
# 766  17841401571730009           -0.011767
# 767  17841401581354276           -0.076161
# 768  17841403266564062           -0.126141
# 769  17841431208327086           -0.053923
# 770  17841471290295933           -0.021124
#
# [771 rows x 2 columns]

# %% [markdown]
# ##### 팔로워 참여도
#
# - 26일 데이터를 기준으로 계산 진행
# - 단일 프소트 기준이 아닌 전체 포스트 평균을 측정
# - media_dtl & media_agg & user_data를 병합한 데이터
#
# ---------------------------------------------------------
#
# - 좋아요 비공개인 경우에는 각각의 중앙값으로 대체 -> 문제는 아예 없는 사람은 어떻게 해야하는건지...
# - estimated_total_engagement = avg_engagement_per_post * total_post_count
# - avg_engagement_per_post = like+comments / 25
# - total_post_count -> user_data

# %%
# media_engagement_merged_df = pd.merge(media_dtl, media_agg, on='media_id')


# # 해당 부분 수정 -> dic에 자동으로 median 값이 들어갈 수 있도록 수정
# media_engagement_merged_df.groupby(['acnt_id'])['like_cnt'].median()
# fillna_dict = {
#     '17841400591698216': 810,
#     '17841401506106699': 791,
#     '17841401839008777': 480,
#     '17841402936102997': 96,
#     '17841406083664639': 83,
#     '17841400361359004' : 0,
#     '17841401473518226' : 0
# }

# for acnt_id, default_like in fillna_dict.items():
#     condition = media_engagement_merged_df['acnt_id'] == acnt_id
#     media_engagement_merged_df.loc[condition, 'like_cnt'] = (
#         media_engagement_merged_df.loc[condition, 'like_cnt'].fillna(default_like)
#     )

# media_engagement_merged_df = pd.merge(media_engagement_merged_df, user_info_2,  on='acnt_id', how = 'left')
# media_engagement_merged_df_2 = media_engagement_merged_df[['acnt_id', 'media_id', 'follower_cnt', 'follow_cnt', 'like_cnt', 'cmnt_cnt', 'media_cnt']]

# engaged_df = media_engagement_merged_df_2.groupby(['acnt_id']).agg({
#     'like_cnt' : 'sum',
#     'cmnt_cnt' : 'sum',
#     'media_cnt': 'first',
#     'follower_cnt' : 'first',
#     'follow_cnt' : 'first'
# }).reset_index()

# engaged_df['avg_engagement_per_post'] = ((engaged_df['like_cnt'] + engaged_df['cmnt_cnt']) / 25)
# engaged_df['estimated_total_engagement'] = engaged_df['avg_engagement_per_post'] * engaged_df['media_cnt']
# engaged_df['follower_total_engagement'] = (engaged_df['estimated_total_engagement'] / engaged_df['follower_cnt']) * 100
# engaged_df

# %%
# def calculate_follower_engagement(media_engagement_profile_merged_df):
#     media_engagement_profile_merged_df_copy = media_engagement_profile_merged_df[['acnt_id', 'media_id', 'follower_cnt', 'follow_cnt', 'like_cnt', 'cmnt_cnt', 'media_cnt']]
    
#     engaged_df = media_engagement_profile_merged_df_copy.groupby(['acnt_id']).agg({
#         'like_cnt' : 'sum',
#         'cmnt_cnt' : 'sum',
#         'media_cnt': 'first',
#         'follower_cnt' : 'first',
#         'follow_cnt' : 'first'
#     }).reset_index()

#     # engaged_df['avg_engagement_per_post'] = ((engaged_df['like_cnt'] + engaged_df['cmnt_cnt']) / 25)
#     # engaged_df['estimated_total_engagement'] = engaged_df['avg_engagement_per_post'] * engaged_df['media_cnt']
#     # engaged_df['follower_total_engagement'] = (engaged_df['estimated_total_engagement'] / engaged_df['follower_cnt']) * 100

#     engaged_df['avg_engagement_per_post'] = ((engaged_df['like_cnt'] + engaged_df['cmnt_cnt']) / engaged_df['media_cnt']*engaged_df['follower_cnt'])
#     engaged_df['follower_total_engagement'] = engaged_df['avg_engagement_per_post'] * 100
    
#     follower_engagment_df = engaged_df

#     return follower_engagment_df

# %%
# follower_engagment_df = calculate_follower_engagement(media_engagement_profile_merged_df)

# %%
# check_inf(follower_engagment_df)

# %% [markdown]
# ##### 팔로워 충성도
#
# - user_info or time_series 데이터가 필요
# - 트렌드 지수는 time_series 데이터를 가지고 단순히 빼기를 진행했었음

# %%
# time_series_merged_df_copy = time_series_merged_df[['acnt_id', 'follower_cnt_x', 'follower_cnt_y']]

# time_series_merged_df_copy['follower_change'] = (time_series_merged_df_copy['follower_cnt_y'] - time_series_merged_df_copy['follower_cnt_x'])

# def estimate_new_follower(row):
#     if row['follower_change'] < 0:
#         return 0
#     else:
#         return row['follower_change']

# time_series_merged_df_copy['new_follower'] = time_series_merged_df_copy.apply(estimate_new_follower, axis=1)

# # 충성도 계산
# # time_series_merged_df_copy = time_series_merged_time_series_merged_df_copy_copy.copy()
# time_series_merged_df_copy['unfollowed'] = time_series_merged_df_copy['follower_cnt_x'] + time_series_merged_df_copy['new_follower'] - time_series_merged_df_copy['follower_cnt_y']
# time_series_merged_df_copy['follower_retention_rate'] = ((time_series_merged_df_copy['follower_cnt_x'] - time_series_merged_df_copy['unfollowed']) / time_series_merged_df_copy['follower_cnt_x']) * 100
# time_series_merged_df_copy['follower_retention_rate'] = time_series_merged_df_copy['follower_retention_rate'].round(2)

# time_series_merged_df_copy

# %%
# def estimate_loyalty(row):
#     if row['follower_change'] < 0:
#         return ((row['follower_cnt_x'] + row['follower_change']) / row['follower_cnt_x']) * 100
#     else:
#         return 100.0

# time_series_merged_df_copy['follower_loyalty'] = time_series_merged_df_copy.apply(estimate_loyalty, axis=1)
# time_series_merged_df_copy['follower_loyalty'] = time_series_merged_df_copy['follower_loyalty'].round(2)

# %%
def calculate_follower_loyalty(time_series_merged_df):
    time_series_merged_df_copy = time_series_merged_df[['acnt_id', 'follower_cnt_x', 'follower_cnt_y']].copy()

    time_series_merged_df_copy.loc[:, 'follower_change'] = (time_series_merged_df_copy['follower_cnt_y'] - time_series_merged_df_copy['follower_cnt_x'])

    def estimate_new_follower(row):
        if row['follower_change'] < 0:
            return 0
        else:
            return row['follower_change']

    time_series_merged_df_copy.loc[:, 'new_follower'] = time_series_merged_df_copy.apply(estimate_new_follower, axis=1)
    time_series_merged_df_copy.loc[:, 'unfollowed'] = time_series_merged_df_copy['follower_cnt_x'] + time_series_merged_df_copy['new_follower'] - time_series_merged_df_copy['follower_cnt_y']
    time_series_merged_df_copy.loc[:, 'follower_retention_rate'] = ((time_series_merged_df_copy['follower_cnt_x'] - time_series_merged_df_copy['unfollowed']) / time_series_merged_df_copy['follower_cnt_x']) * 100
    time_series_merged_df_copy.loc[:, 'follower_retention_rate'] = time_series_merged_df_copy['follower_retention_rate'].round(2)

    follower_loyalty_df = time_series_merged_df_copy

    return follower_loyalty_df

# %%
follower_loyalty_df = calculate_follower_loyalty(time_series_merged_df)
follower_loyalty_df
# Out:
#                acnt_id  follower_cnt_x  follower_cnt_y  follower_change  \
# 0    17841401228916385            1815            1831               16
# 1    17841433366211969            8157            8154               -3
# 2    17841405869097470           49565           49564               -1
# 3    17841406154606429            1218            1221                3
# 4    17841400148093726           14843           14841               -2
# ..                 ...             ...             ...              ...
# 766  17841401571730009           76484           76475               -9
# 767  17841401581354276           10504           10496               -8
# 768  17841403266564062           13477           13460              -17
# 769  17841431208327086          226250          226128             -122
# 770  17841471290295933            4734            4733               -1
#
#      new_follower  unfollowed  follower_retention_rate
# 0              16           0                   100.00
# 1               0           3                    99.96
# 2               0           1                   100.00
# 3               3           0                   100.00
# 4               0           2                    99.99
# ..            ...         ...                      ...
# 766             0           9                    99.99
# 767             0           8                    99.92
# 768             0          17                    99.87
# 769             0         122                    99.95
# 770             0           1                    99.98
#
# [771 rows x 7 columns]

# %%
check_inf(follower_loyalty_df)
# Out:
# ⚠️ inf / -inf 포함 행 개수: 0개
# Empty DataFrame
# Columns: [acnt_id, follower_cnt_x, follower_cnt_y, follower_change, new_follower, unfollowed, follower_retention_rate]
# Index: []

# %% [markdown]
# 콘텐츠 효율성 평가
#
# - 콘텐츠 1개당 팔로워 대비 반응량(like+comments)
# - media_agg & media_dtl & acnt_id가 필요 -> 전부 병합한 게 media_engagement_merged_df

# %%
# media_engagement_merged_df_3 = media_engagement_profile_merged_df.copy()
# # media_engagment_merged_df_2 == media_engagement_profile_merged_df 같은 df임
# # media_engagement_profile_merged_df_copy = media_engagement_merged_df_2.copy()


# media_engagement_merged_df_3['post_efficiency'] = ((media_engagement_merged_df_3['like_cnt'] + media_engagement_merged_df_3['cmnt_cnt']) / media_engagement_merged_df_3['follower_cnt']) * 100
# post_efficiency_df = media_engagement_merged_df_3.groupby('acnt_id')['post_efficiency'].mean().reset_index()
# post_efficiency_df.rename(columns={'post_efficiency': 'avg_post_efficiency'}, inplace=True)
# post_efficiency_df

# %%
def calculate_post_efficiency_df(media_engagement_profile_merged_df):
    media_engagement_profile_merged_df_copy = media_engagement_profile_merged_df.copy()

    media_engagement_profile_merged_df_copy['post_efficiency'] = ((media_engagement_profile_merged_df_copy['like_cnt'] + media_engagement_profile_merged_df_copy['cmnt_cnt']) / media_engagement_profile_merged_df_copy['follower_cnt']) * 100
    post_efficiency_df = media_engagement_profile_merged_df_copy.groupby('acnt_id')['post_efficiency'].mean().reset_index()
    post_efficiency_df.rename(columns={'post_efficiency': 'avg_post_efficiency'}, inplace=True)

    return post_efficiency_df

# %%
post_efficiency_df = calculate_post_efficiency_df(media_engagement_profile_merged_df)
post_efficiency_df
# Out:
#                acnt_id  avg_post_efficiency
# 0    17841400002751973             0.109729
# 1    17841400006499942             2.125723
# 2    17841400011995621             1.447646
# 3    17841400016295781             1.044368
# 4    17841400025364370             6.647955
# ..                 ...                  ...
# 766  17841472755802463            12.500000
# 767  17841473211163104             5.214865
# 768  17841473347851502             3.788905
# 769  17841473857435791            11.361474
# 770  17841474495202295             3.195944
#
# [771 rows x 2 columns]

# %%
check_inf(post_efficiency_df)
# Out:
# ⚠️ inf / -inf 포함 행 개수: 0개
# Empty DataFrame
# Columns: [acnt_id, avg_post_efficiency]
# Index: []

# %% [markdown]
# 광고효율성

# %%
def clean_acnt_nm(value):
    if pd.isnull(value):
        return None
    
    value = str(value)  # 혹시 모르니 문자열로 변환
    match = re.search(r'instagram\.com/([^/]+)', value)
    if match:
        return match.group(1)
    else:
        return value.strip()
    
seller_info['add1_cleaned'] = seller_info['add1'].apply(clean_acnt_nm)

# %%
db_merged_data = pd.merge(seller_info, sales_info, on='add1')

# %% [markdown]
# ##### not_connected_influencer_flexmatch_score

# %%
# def not_connected_user_flexmatch_score(activity_df, growth_rate_df, follower_engagement_df, follower_loyalty_df, post_efficiency_df):
#     # 크리에이터 활동성
#     creator_activity_score = activity_df[['acnt_id', 'activity_score']]
#     # 트렌드지수
#     creator_follow_growth_rate = growth_rate_df[['acnt_id', 'follow_growth_rate']]
#     # 팔로워 참여도
#     follower_engagement = follower_engagement_df[['acnt_id', 'follower_total_engagement']]
#     # 팔로워 충성도
#     follower_loyalty = follower_loyalty_df[['acnt_id', 'follower_retention_rate']]
#     # 콘텐츠 효율성
#     post_efficiency = post_efficiency_df[['acnt_id', 'avg_post_efficiency']]

#     # data_list
#     df_list = [creator_activity_score, creator_follow_growth_rate, follower_engagement, follower_loyalty, post_efficiency]

#     from functools import reduce

#     flexmatch_score = reduce(lambda left, right: pd.merge(left, right, on='acnt_id', how='left'), df_list)
#     user_info_nm = recent_user_info_mtr[['acnt_id', 'acnt_nm', 'influencer_scale_type']]
#     flexmatch_score = pd.merge(flexmatch_score, user_info_nm, on='acnt_id')
#     flexmatch_score = flexmatch_score[['acnt_id', 'acnt_nm', 'influencer_scale_type', 'activity_score', 'follow_growth_rate', 'follower_total_engagement', 'follower_retention_rate', 'avg_post_efficiency']]


#     not_connected_flexmatch_score_table = flexmatch_score.copy()
#     not_connected_flexmatch_score_table.dropna(inplace=True)
    
#     return not_connected_flexmatch_score_table

# %%
def not_connected_user_flexmatch_score(activity_df, growth_rate_df, follower_loyalty_df, post_efficiency_df):
    # 크리에이터 활동성
    creator_activity_score = activity_df[['acnt_id', 'activity_score']]
    # 트렌드지수
    creator_follow_growth_rate = growth_rate_df[['acnt_id', 'follow_growth_rate']]
    # 팔로워 참여도
    # follower_engagement = follower_engagement_df[['acnt_id', 'follower_total_engagement']]
    # 팔로워 충성도
    follower_loyalty = follower_loyalty_df[['acnt_id', 'follower_retention_rate']]
    # 콘텐츠 효율성
    post_efficiency = post_efficiency_df[['acnt_id', 'avg_post_efficiency']]

    # data_list
    df_list = [creator_activity_score, creator_follow_growth_rate, follower_loyalty, post_efficiency]

    from functools import reduce

    flexmatch_score = reduce(lambda left, right: pd.merge(left, right, on='acnt_id', how='left'), df_list)
    user_info_nm = recent_user_info_mtr[['acnt_id', 'acnt_nm', 'influencer_scale_type']]
    flexmatch_score = pd.merge(flexmatch_score, user_info_nm, on='acnt_id')
    flexmatch_score = flexmatch_score[['acnt_id', 'acnt_nm', 'influencer_scale_type', 'activity_score', 'follow_growth_rate', 'follower_retention_rate', 'avg_post_efficiency']]


    not_connected_flexmatch_score_table = flexmatch_score.copy()
    not_connected_flexmatch_score_table.dropna(inplace=True)
    
    return not_connected_flexmatch_score_table

# %%
not_connected_flexmatch_score_table = not_connected_user_flexmatch_score(activity_df, growth_rate_df, follower_loyalty_df, post_efficiency_df)
not_connected_flexmatch_score_table
# Out:
#                acnt_id        acnt_nm influencer_scale_type  activity_score  \
# 0    17841400002751973   licoco___jin                   mid      376.923077
# 1    17841400006499942       kim__us_                 macro       21.973094
# 2    17841400011995621      aaari_678                 micro       64.473684
# 3    17841400016295781      jihyolimm                   mid      119.512195
# 4    17841400025364370          9_5jw                 micro        4.454545
# ..                 ...            ...                   ...             ...
# 764  17841472755802463        huxa__0                  nano       24.210526
# 765  17841473211163104     mom._.room                   mid      144.117647
# 766  17841473347851502  hyepick_place                 micro       46.236559
# 767  17841473857435791     sesebonbon                 micro      245.000000
# 768  17841474495202295  susu_23.06.30                  nano       46.153846
#
#      follow_growth_rate  follower_retention_rate  avg_post_efficiency
# 0             -0.019637                    99.98             0.109729
# 1             -0.010515                    99.99             2.125723
# 2              0.000000                   100.00             1.447646
# 3              0.019318                   100.00             1.044368
# 4              0.321802                   100.00             6.647955
# ..                  ...                      ...                  ...
# 764            0.101010                   100.00            12.500000
# 765            0.881083                   100.00             5.214865
# 766           -0.348824                    99.65             3.788905
# 767            2.811736                   100.00            11.361474
# 768            0.431655                   100.00             3.195944
#
# [769 rows x 7 columns]

# %%
conn_list = seller_info[(seller_info['ig_user_id'].notnull()) & (seller_info['ig_user_id'] != '')]['ig_user_id'].to_list()
not_conn_user = seller_info[~seller_info['ig_user_id'].isin(conn_list)]
not_conn_user = not_conn_user[['add1', 'interestcategory']]

# %%
def clean_acnt_nm(value):
    if pd.isnull(value):
        return None
    
    value = str(value)  # 혹시 모르니 문자열로 변환
    match = re.search(r'instagram\.com/([^/]+)', value)
    if match:
        return match.group(1)
    else:
        return value.strip()
    
not_conn_user['acnt_nm'] = not_conn_user['add1'].apply(clean_acnt_nm)

# %%
not_connected_flexmatch_score_table = pd.merge(not_connected_flexmatch_score_table, not_conn_user, on='acnt_nm')
not_connected_flexmatch_score_table['interestcategory'] = not_connected_flexmatch_score_table['interestcategory'].fillna('뷰티')

# %%
not_connected_flexmatch_score_table['interestcategory'] = not_connected_flexmatch_score_table['interestcategory'].apply(
    lambda x: '뷰티' if pd.isna(x) or (isinstance(x, str) and x.strip() == '') else x)

# %%
category_map = {
            'BABY/KIDS': '베이비/키즈',
            'BEAUTY': '뷰티',
            'FASHION': '패션',
            'FOOD': '푸드',
            'HEALTHY': '헬시',
            'HOME/LIVING': '홈/리빙',
            'SERVICE': '서비스',
            'SPORT': '스포츠',
            'TEST 카테고리.. TEST': '뷰티'
        }

for k, v in category_map.items():
    not_connected_flexmatch_score_table['interestcategory'] = not_connected_flexmatch_score_table['interestcategory'].str.replace(k, v)

# %%
not_connected_flexmatch_score_table = not_connected_flexmatch_score_table.drop_duplicates(subset=['acnt_id', 'acnt_nm'])

# %%
not_connected_flexmatch_score_table['influencer_scale_type'].value_counts()
# Out:
# influencer_scale_type
# micro    281
# mid      226
# nano     122
# macro     40
# Name: count, dtype: int64

# %%
not_connected_flexmatch_score_table[(not_connected_flexmatch_score_table['influencer_scale_type'] == 'macro') & (not_connected_flexmatch_score_table['interestcategory']=='뷰티')]
# Out:
#                acnt_id        acnt_nm influencer_scale_type  activity_score  \
# 1    17841400006499942       kim__us_                 macro       21.973094
# 74   17841400580612199       jogood72                 macro      306.250000
# 138  17841401061482770      mina_lavu                 macro      136.111111
# 141  17841401086862436    julietmira5                 macro       12.727273
# 158  17841401272625523       oing0307                 macro      108.888889
# 217  17841401717699486       cocoalla                 macro      100.000000
# 242  17841401942858884     my_floria_                 macro       37.404580
# 246  17841401954250938    raonjenanim                 macro       94.230769
# 252  17841402028598497     stylecooca                 macro       29.878049
# 263  17841402128645157      icanddoit                 macro     1633.333333
# 267  17841402158404026        tedseon                 macro      116.666667
# 269  17841402171767176  stylish_tasty                 macro       11.556604
# 296  17841402372145724        dri1117                 macro       87.500000
# 355  17841404452754986     sylove7100                 macro      102.083333
# 410  17841407300151686      2905_home                 macro      288.235294
# 460  17841416105095031    best_namnam                 macro       18.702290
# 492  17841431208327086         vv_vid                 macro      100.000000
# 502  17841437781952670        neuel_s                 macro      119.512195
# 562  17841448810667457        gum0070                 macro        9.589041
# 647  17841462888085401     mr___choon                 macro       72.058824
#
#      follow_growth_rate  follower_retention_rate  avg_post_efficiency  \
# 1             -0.010515                    99.99             2.125723
# 74            -0.033206                    99.97             0.969374
# 138           -0.014898                    99.99             1.557299
# 141           -0.098106                    99.90             0.768209
# 158           -0.014178                    99.99             1.255131
# 217           -0.010504                    99.99             0.988080
# 242           -0.135664                    99.86             1.958459
# 246           -0.018580                    99.98             1.298520
# 252           -0.019436                    99.98             1.285600
# 263            0.196795                   100.00             0.428311
# 267           -0.018123                    99.98             1.147556
# 269           -0.016907                    99.98             0.004483
# 296           -0.013895                    99.99             1.637835
# 355           -0.010051                    99.99             0.746198
# 410            0.449019                   100.00             0.662095
# 460           -0.035116                    99.96             1.376547
# 492           -0.053923                    99.95             0.659122
# 502           -0.003566                   100.00             0.037218
# 562           -0.039678                    99.96             2.057000
# 647           -0.096386                    99.90             4.056621
#
#                                          add1 interestcategory
# 1         https://www.instagram.com/kim__us_/               뷰티
# 74         https://www.instagram.com/jogood72               뷰티
# 138        http://www.instagram.com/mina_lavu               뷰티
# 141    https://www.instagram.com/julietmira5/               뷰티
# 158       https://www.instagram.com/oing0307/               뷰티
# 217                                  cocoalla               뷰티
# 242      https://www.instagram.com/my_floria_               뷰티
# 246                               raonjenanim               뷰티
# 252                                stylecooca               뷰티
# 263      https://www.instagram.com/icanddoit/               뷰티
# 267        https://www.instagram.com/tedseon/               뷰티
# 269   https://www.instagram.com/stylish_tasty               뷰티
# 296         https://www.instagram.com/dri1117               뷰티
# 355      https://www.instagram.com/sylove7100               뷰티
# 410      https://www.instagram.com/2905_home/               뷰티
# 460    https://www.instagram.com/best_namnam/               뷰티
# 492          https://www.instagram.com/vv_vid               뷰티
# 502         https://www.instagram.com/neuel_s               뷰티
# 562         https://www.instagram.com/gum0070               뷰티
# 647  https://www.instagram.com/mr___choon/pro               뷰티
# 2025-07-19 04:00:28,263| ERROR   | Socket exception: 현재 연결은 원격 호스트에 의해 강제로 끊겼습니다 (10054)

# %%
# from sklearn.preprocessing import MinMaxScaler
# import pandas as pd
# import numpy as np

# def normalize_influencer_scores(influencer_scale_names, influencer_scale_df_list, reverse_columns=None, feature_range=(0, 5)):

#     if reverse_columns is None:
#         reverse_columns = []

#     normalized_df_dict = {}

#     for name, df in zip(influencer_scale_names, influencer_scale_df_list):
#         cleaned = df.copy()

#         # 무한대 및 NaN 제거
#         float_cols = cleaned.select_dtypes(include='float64').columns
#         cleaned[float_cols] = cleaned[float_cols].replace([np.inf, -np.inf], np.nan)
#         cleaned = cleaned.dropna(subset=float_cols)

#         if cleaned.empty:
#             continue

#         norm_df = pd.DataFrame(index=cleaned.index)
#         for col in float_cols:
#             scaler = MinMaxScaler(feature_range=feature_range)
#             norm_col = scaler.fit_transform(cleaned[[col]])
#             if col in reverse_columns:
#                 norm_df[col] = feature_range[1] - norm_col.ravel()
#             else:
#                 norm_df[col] = norm_col.ravel()

#         # ID 및 이름, 스케일 타입 추가
#         norm_df['acnt_id'] = cleaned['acnt_id'].values
#         norm_df['acnt_nm'] = cleaned['acnt_nm'].values
#         norm_df['influencer_scale_type'] = name

#         normalized_df_dict[name] = norm_df

#     normalized_all_df = pd.concat(normalized_df_dict.values(), ignore_index=True)
#     normalized_all_dic = normalized_all_df.to_dict(orient='index')

#     return normalized_all_df, normalized_all_dic

# %%
# def normalize_influencer_scores(
#     influencer_scale_names, 
#     influencer_scale_df_list, 
#     reverse_columns=None, 
#     log_columns=None, 
#     feature_range=(0, 5)
# ):
#     if reverse_columns is None:
#         reverse_columns = []
#     if log_columns is None:
#         log_columns = []

#     normalized_df_dict = {}

#     for name, df in zip(influencer_scale_names, influencer_scale_df_list):
#         cleaned = df.copy()

#         # 무한대 및 NaN 제거
#         float_cols = cleaned.select_dtypes(include='float64').columns
#         cleaned[float_cols] = cleaned[float_cols].replace([np.inf, -np.inf], np.nan)
#         cleaned = cleaned.dropna(subset=float_cols)

#         if cleaned.empty:
#             continue

#         norm_df = pd.DataFrame(index=cleaned.index)
#         for col in float_cols:
#             col_data = cleaned[col]
#             if col in log_columns:
#                 col_data = np.log1p(col_data)
#             scaler = MinMaxScaler(feature_range=feature_range)
#             norm_col = scaler.fit_transform(col_data.values.reshape(-1, 1))
#             if col in reverse_columns:
#                 norm_df[col] = feature_range[1] - norm_col.ravel()
#             else:
#                 norm_df[col] = norm_col.ravel()

#         norm_df['acnt_id'] = cleaned['acnt_id'].values
#         norm_df['acnt_nm'] = cleaned['acnt_nm'].values
#         norm_df['influencer_scale_type'] = name

#         normalized_df_dict[name] = norm_df

#     normalized_all_df = pd.concat(normalized_df_dict.values(), ignore_index=True)
#     normalized_all_dic = normalized_all_df.to_dict(orient='index')

#     return normalized_all_df, normalized_all_dic

# %%
nano = not_connected_flexmatch_score_table[not_connected_flexmatch_score_table['influencer_scale_type']=='nano']
micro = not_connected_flexmatch_score_table[not_connected_flexmatch_score_table['influencer_scale_type']=='micro']
mid = not_connected_flexmatch_score_table[not_connected_flexmatch_score_table['influencer_scale_type']=='mid']
macro = not_connected_flexmatch_score_table[not_connected_flexmatch_score_table['influencer_scale_type']=='macro']
mega = not_connected_flexmatch_score_table[not_connected_flexmatch_score_table['influencer_scale_type']=='mega']

# %%
def normalize_influencer_scores(
    influencer_scale_names, 
    influencer_scale_df_list, 
    reverse_columns=None, 
    log_columns=None, 
    feature_range=(1, 5)
):
    if reverse_columns is None:
        reverse_columns = []
    if log_columns is None:
        log_columns = []

    normalized_df_list = []

    for name, df in zip(influencer_scale_names, influencer_scale_df_list):
        cleaned = df.copy()

        # 무한대 및 NaN 제거
        float_cols = cleaned.select_dtypes(include='float64').columns
        cleaned[float_cols] = cleaned[float_cols].replace([np.inf, -np.inf], np.nan)
        cleaned = cleaned.dropna(subset=float_cols)

        if cleaned.empty:
            continue

        # 관심 카테고리 첫 번째 값 추출
        if 'interestcategory' in cleaned.columns:
            cleaned['main_interest_category'] = cleaned['interestcategory'].apply(
                lambda x: str(x).split('@')[0] if pd.notnull(x) else '뷰티'
            )
        else:
            cleaned['main_interest_category'] = '뷰티'

        # (관심카테고리, 스케일타입) 조합별 그룹화
        cleaned['influencer_scale_type'] = name  # 확실히 넣어두기
        grouped = cleaned.groupby(['main_interest_category', 'influencer_scale_type'])

        for (category, scale_type), group in grouped:
            norm_df = pd.DataFrame(index=group.index)

            # 그룹 내 인원 수 체크
            if len(group) == 1:
                # 1명인 경우 모든 점수를 1.0으로 고정
                for col in float_cols:
                    norm_df.loc[group.index, col] = 3.0
            else:
                # 여러명인 경우 정규화 진행
                for col in float_cols:
                    col_data = group[col]
                    if col in log_columns:
                        col_data = np.log1p(col_data)

                    max_val = col_data.max()
                    min_val = col_data.min()

                    if max_val == min_val:
                        # 모든 값이 동일하면 1.0 고정
                        norm_df.loc[group.index, col] = 3.0
                    else:
                        scaler = MinMaxScaler(feature_range=feature_range)
                        norm_col = scaler.fit_transform(col_data.values.reshape(-1, 1))
                        if col in reverse_columns:
                            norm_df[col] = feature_range[1] - norm_col.ravel()
                        else:
                            norm_df[col] = norm_col.ravel()

            # 공통 컬럼 복사
            norm_df['acnt_id'] = group['acnt_id'].values
            norm_df['acnt_nm'] = group['acnt_nm'].values
            norm_df['influencer_scale_type'] = scale_type
            norm_df['main_interest_category'] = category

            normalized_df_list.append(norm_df)

    normalized_all_df = pd.concat(normalized_df_list, ignore_index=True)
    normalized_all_dic = normalized_all_df.to_dict(orient='index')

    return normalized_all_df, normalized_all_dic

# %%
influencer_scale_names=['nano', 'micro', 'mid', 'macro', 'mega']
influencer_scale_df_list=[nano, micro, mid, macro, mega]

normalized_df, normalized_all_dic = normalize_influencer_scores(influencer_scale_names, influencer_scale_df_list, reverse_columns='activity_score')

# %%
normalized_all_dic
# Out:
# {0: {'activity_score': 3.945442851133671,
#   'follow_growth_rate': 1.1115702479338843,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.1747744338040107,
#   'acnt_id': '17841400127762252',
#   'acnt_nm': 'hwaaaaa_a',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  1: {'activity_score': 3.8760731406223075,
#   'follow_growth_rate': 1.0704470190636197,
#   'follower_retention_rate': 3.5416666666666856,
#   'avg_post_efficiency': 1.1047268795196188,
#   'acnt_id': '17841400166779874',
#   'acnt_nm': 'lihanian',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  2: {'activity_score': 3.1849683940247844,
#   'follow_growth_rate': 1.0918985965743593,
#   'follower_retention_rate': 4.291666666666686,
#   'avg_post_efficiency': 1.0768264561808514,
#   'acnt_id': '17841400204233993',
#   'acnt_nm': 'j_solha',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  3: {'activity_score': 3.8110999202103306,
#   'follow_growth_rate': 1.1115702479338843,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.1116952307554486,
#   'acnt_id': '17841400297953515',
#   'acnt_nm': 'j.yyyyyul',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  4: {'activity_score': 2.9203639029017374,
#   'follow_growth_rate': 1.1349945235487404,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.0183160983233999,
#   'acnt_id': '17841400336698050',
#   'acnt_nm': 'hnpiano',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  5: {'activity_score': 2.878481239365989,
#   'follow_growth_rate': 1.1115702479338843,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.0819762469383976,
#   'acnt_id': '17841400483419781',
#   'acnt_nm': 'hyeryeon_yoon',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  6: {'activity_score': 3.896806918343589,
#   'follow_growth_rate': 1.1115702479338843,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.2231564960250196,
#   'acnt_id': '17841400588709226',
#   'acnt_nm': 'seul90',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  7: {'activity_score': 3.8727730783508796,
#   'follow_growth_rate': 1.1517031238153006,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.0487086813164532,
#   'acnt_id': '17841400697997803',
#   'acnt_nm': 'cchaaeee',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  8: {'activity_score': 3.8336062038226606,
#   'follow_growth_rate': 1.2294014525419483,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.511383636271018,
#   'acnt_id': '17841400718160676',
#   'acnt_nm': 'bbongslim',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  9: {'activity_score': 0.0,
#   'follow_growth_rate': 1.2155389578821763,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.1783287906851048,
#   'acnt_id': '17841400802104441',
#   'acnt_nm': 'huizhenzhen_',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  10: {'activity_score': 2.2452153667054713,
#   'follow_growth_rate': 1.2248254834309555,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.0836500414978683,
#   'acnt_id': '17841400836205318',
#   'acnt_nm': 'naveraint',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  11: {'activity_score': 3.6492931980708465,
#   'follow_growth_rate': 1.1115702479338843,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.0989263269695224,
#   'acnt_id': '17841400874732512',
#   'acnt_nm': 'andyjeon317',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  12: {'activity_score': 0.17431796325353055,
#   'follow_growth_rate': 1.1343096032091247,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.0289410568345774,
#   'acnt_id': '17841401028212046',
#   'acnt_nm': 'kevinkim911',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  13: {'activity_score': 3.6826283792523604,
#   'follow_growth_rate': 1.1343540160123966,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.0528781000186087,
#   'acnt_id': '17841401080128294',
#   'acnt_nm': 'yeonwoo_0523',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  14: {'activity_score': 3.991104960296755,
#   'follow_growth_rate': 1.1414047473103506,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.423141209120039,
#   'acnt_id': '17841401293139137',
#   'acnt_nm': '_movingday',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  15: {'activity_score': 3.991104960296755,
#   'follow_growth_rate': 1.1414047473103506,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.423141209120039,
#   'acnt_id': '17841401293139137',
#   'acnt_nm': '_movingday',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  16: {'activity_score': 3.991104960296755,
#   'follow_growth_rate': 1.1414047473103506,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.423141209120039,
#   'acnt_id': '17841401293139137',
#   'acnt_nm': '_movingday',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  17: {'activity_score': 3.991104960296755,
#   'follow_growth_rate': 1.1414047473103506,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.423141209120039,
#   'acnt_id': '17841401293139137',
#   'acnt_nm': '_movingday',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  18: {'activity_score': 3.991104960296755,
#   'follow_growth_rate': 1.1414047473103506,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.423141209120039,
#   'acnt_id': '17841401293139137',
#   'acnt_nm': '_movingday',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  19: {'activity_score': 3.991104960296755,
#   'follow_growth_rate': 1.1414047473103506,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.423141209120039,
#   'acnt_id': '17841401293139137',
#   'acnt_nm': '_movingday',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  20: {'activity_score': 3.991104960296755,
#   'follow_growth_rate': 1.1414047473103506,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.423141209120039,
#   'acnt_id': '17841401293139137',
#   'acnt_nm': '_movingday',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  21: {'activity_score': 3.991104960296755,
#   'follow_growth_rate': 1.1414047473103506,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.423141209120039,
#   'acnt_id': '17841401293139137',
#   'acnt_nm': '_movingday',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  22: {'activity_score': 3.991104960296755,
#   'follow_growth_rate': 1.1414047473103506,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.423141209120039,
#   'acnt_id': '17841401293139137',
#   'acnt_nm': '_movingday',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  23: {'activity_score': 3.657899252814122,
#   'follow_growth_rate': 1.1115702479338843,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.0757388017283618,
#   'acnt_id': '17841401374507119',
#   'acnt_nm': 'yeeeee_jini',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  24: {'activity_score': 3.818805834299263,
#   'follow_growth_rate': 1.1115702479338843,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.0775816867223054,
#   'acnt_id': '17841401443052146',
#   'acnt_nm': 'kyounghye0517',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  25: {'activity_score': 3.949391354962798,
#   'follow_growth_rate': 1.1239275458747724,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.2258339253600665,
#   'acnt_id': '17841401466497996',
#   'acnt_nm': '__ssomsom_',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  26: {'activity_score': 3.7865735351183547,
#   'follow_growth_rate': 1.1115702479338843,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.1370481218160657,
#   'acnt_id': '17841401530775838',
#   'acnt_nm': 'touritst_genie',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  27: {'activity_score': 3.773915490795584,
#   'follow_growth_rate': 1.1700135808807697,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.3000870645779734,
#   'acnt_id': '17841401629705047',
#   'acnt_nm': 'soulvoice1987',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  28: {'activity_score': 3.9063902967141786,
#   'follow_growth_rate': 1.1353043054236063,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.1213245566486425,
#   'acnt_id': '17841401639140025',
#   'acnt_nm': 'summerkim__',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  29: {'activity_score': 3.9153782353356865,
#   'follow_growth_rate': 1.1115702479338843,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.3677322733943864,
#   'acnt_id': '17841401661602499',
#   'acnt_nm': 'uuuuuuu_jung',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  30: {'activity_score': 3.8175633952523156,
#   'follow_growth_rate': 1.1115702479338843,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.1147605181094944,
#   'acnt_id': '17841401674757443',
#   'acnt_nm': 'ou_ra27',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  31: {'activity_score': 3.940777887227247,
#   'follow_growth_rate': 1.1115702479338843,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.174682583495135,
#   'acnt_id': '17841401681942874',
#   'acnt_nm': 'dangeenea',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  32: {'activity_score': 3.9833813452206095,
#   'follow_growth_rate': 1.077361188531543,
#   'follower_retention_rate': 3.7916666666666288,
#   'avg_post_efficiency': 1.7245098793665443,
#   'acnt_id': '17841401738522234',
#   'acnt_nm': 'eunchong326',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  33: {'activity_score': 3.7082725766527473,
#   'follow_growth_rate': 1.1115702479338843,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.0626536631545933,
#   'acnt_id': '17841401784692335',
#   'acnt_nm': 'totoro0550',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  34: {'activity_score': 3.9572133973555426,
#   'follow_growth_rate': 1.077260573650948,
#   'follower_retention_rate': 3.7916666666666288,
#   'avg_post_efficiency': 1.3908533115986461,
#   'acnt_id': '17841401850643757',
#   'acnt_nm': 'michelle_ynoh',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  35: {'activity_score': 3.9104287496672008,
#   'follow_growth_rate': 1.0785241027321892,
#   'follower_retention_rate': 3.8333333333333144,
#   'avg_post_efficiency': 1.0387821673755548,
#   'acnt_id': '17841402048303273',
#   'acnt_nm': 'vvipsvip',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  36: {'activity_score': 1.336437718277066,
#   'follow_growth_rate': 1.0852674536696265,
#   'follower_retention_rate': 4.041666666666629,
#   'avg_post_efficiency': 1.009295042829482,
#   'acnt_id': '17841402059097583',
#   'acnt_nm': 'zenyaluiah',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  37: {'activity_score': 3.8818494418163345,
#   'follow_growth_rate': 1.0964597696227465,
#   'follower_retention_rate': 4.458333333333371,
#   'avg_post_efficiency': 1.0410580073122513,
#   'acnt_id': '17841402265949784',
#   'acnt_nm': 'soro_1217',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  38: {'activity_score': 3.988622352718535,
#   'follow_growth_rate': 1.198531935679772,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.2695689666973538,
#   'acnt_id': '17841402353151092',
#   'acnt_nm': 'hey_lilly_',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  39: {'activity_score': 3.902007936575376,
#   'follow_growth_rate': 1.1115702479338843,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.119376876243073,
#   'acnt_id': '17841402652660371',
#   'acnt_nm': 'ykl0422',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  40: {'activity_score': 3.8545677348201703,
#   'follow_growth_rate': 1.1717006049245975,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.3063613212617011,
#   'acnt_id': '17841403690842921',
#   'acnt_nm': 'jisoocori',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  41: {'activity_score': 3.975251633692748,
#   'follow_growth_rate': 1.125261901990455,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.1759205450218593,
#   'acnt_id': '17841404264105604',
#   'acnt_nm': 'jeehyonny',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  42: {'activity_score': 2.7121824282681644,
#   'follow_growth_rate': 1.086750483558994,
#   'follower_retention_rate': 4.125,
#   'avg_post_efficiency': 1.0059678213510057,
#   'acnt_id': '17841404867713313',
#   'acnt_nm': 'znzl5689',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  43: {'activity_score': 3.880358638155342,
#   'follow_growth_rate': 1.0818875780707842,
#   'follower_retention_rate': 3.9583333333333144,
#   'avg_post_efficiency': 1.2339892520759084,
#   'acnt_id': '17841405446581360',
#   'acnt_nm': 'imsujini88',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  44: {'activity_score': 3.949928419695471,
#   'follow_growth_rate': 1.1115702479338843,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.0308952756091891,
#   'acnt_id': '17841405735233010',
#   'acnt_nm': 'flex_h.y',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  45: {'activity_score': 3.914774152252114,
#   'follow_growth_rate': 1.0404404353960894,
#   'follower_retention_rate': 2.4583333333333144,
#   'avg_post_efficiency': 1.1976474600483358,
#   'acnt_id': '17841406001951671',
#   'acnt_nm': 'gukja98',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  46: {'activity_score': 3.972044008168637,
#   'follow_growth_rate': 1.0716889171434625,
#   'follower_retention_rate': 3.5833333333333144,
#   'avg_post_efficiency': 4.999999999999999,
#   'acnt_id': '17841406281775348',
#   'acnt_nm': 'snr_1345',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  47: {'activity_score': 3.915077161875765,
#   'follow_growth_rate': 1.1115702479338843,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.1063170298438398,
#   'acnt_id': '17841406696060527',
#   'acnt_nm': 'euni_j_',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  48: {'activity_score': 2.6928222681702083,
#   'follow_growth_rate': 1.0976498550267264,
#   'follower_retention_rate': 4.5,
#   'avg_post_efficiency': 1.1029802041366945,
#   'acnt_id': '17841406919372473',
#   'acnt_nm': '12styles',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  49: {'activity_score': 3.9741783168583242,
#   'follow_growth_rate': 1.1873188794676397,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 2.2997014263417803,
#   'acnt_id': '17841407102497168',
#   'acnt_nm': 'ohana.yyy',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  50: {'activity_score': 3.8758715672271347,
#   'follow_growth_rate': 1.320344999722669,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.263793219364636,
#   'acnt_id': '17841407376200009',
#   'acnt_nm': 'sh851029',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  51: {'activity_score': 3.9581502259412416,
#   'follow_growth_rate': 1.1115702479338843,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.5807688073823503,
#   'acnt_id': '17841411649994165',
#   'acnt_nm': 'seungje69',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  52: {'activity_score': 3.7201167961220634,
#   'follow_growth_rate': 1.1461853495843244,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.0054950183800306,
#   'acnt_id': '17841413644545926',
#   'acnt_nm': 'love1iveuny',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  53: {'activity_score': 3.6671454273316906,
#   'follow_growth_rate': 1.1115702479338843,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.15381286149048,
#   'acnt_id': '17841415107014253',
#   'acnt_nm': 'hongsyn',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  54: {'activity_score': 3.9035518965502805,
#   'follow_growth_rate': 1.0793011213607215,
#   'follower_retention_rate': 3.8333333333333144,
#   'avg_post_efficiency': 1.0448717682036766,
#   'acnt_id': '17841416663433806',
#   'acnt_nm': 'wwwtable',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  55: {'activity_score': 3.952111540430235,
#   'follow_growth_rate': 1.0976664466750066,
#   'follower_retention_rate': 4.5,
#   'avg_post_efficiency': 1.6001252032682922,
#   'acnt_id': '17841421332213883',
#   'acnt_nm': 'mini_loggg',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  56: {'activity_score': 3.7702755141637563,
#   'follow_growth_rate': 1.0771593651722373,
#   'follower_retention_rate': 3.7916666666666288,
#   'avg_post_efficiency': 1.1418082670061853,
#   'acnt_id': '17841430430382691',
#   'acnt_nm': 'b_ri_27',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  57: {'activity_score': 3.934626542294123,
#   'follow_growth_rate': 1.1115702479338843,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.714303694217329,
#   'acnt_id': '17841431248109362',
#   'acnt_nm': 'woo.ah.___',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  58: {'activity_score': 3.9992754236947583,
#   'follow_growth_rate': 1.1115702479338843,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 2.5233897585619265,
#   'acnt_id': '17841436038328892',
#   'acnt_nm': 'mingoorigudi',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  59: {'activity_score': 3.939811232676691,
#   'follow_growth_rate': 1.1115702479338843,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.053692295587431,
#   'acnt_id': '17841437265150835',
#   'acnt_nm': 'yam.made',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  60: {'activity_score': 3.9448829945636414,
#   'follow_growth_rate': 1.1115702479338843,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.1001721573838907,
#   'acnt_id': '17841438292231131',
#   'acnt_nm': 'charmin.grl',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  61: {'activity_score': 3.6789577637964186,
#   'follow_growth_rate': 1.139747275122769,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.1283790166390626,
#   'acnt_id': '17841439136122865',
#   'acnt_nm': 'cat._.0620',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  62: {'activity_score': 3.952662615713481,
#   'follow_growth_rate': 1.1115702479338843,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.2643469676329193,
#   'acnt_id': '17841439791628421',
#   'acnt_nm': 'kkochang_cos',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  63: {'activity_score': 3.952129309945372,
#   'follow_growth_rate': 1.1251661561578916,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 3.164568397549185,
#   'acnt_id': '17841440869702644',
#   'acnt_nm': '_08080822_',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  64: {'activity_score': 1.6881318546657682,
#   'follow_growth_rate': 1.1115702479338843,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.294057793602216,
#   'acnt_id': '17841443737382400',
#   'acnt_nm': 'kan__jung',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  65: {'activity_score': 3.42128055878929,
#   'follow_growth_rate': 1.0696087757892858,
#   'follower_retention_rate': 3.5,
#   'avg_post_efficiency': 1.3183948022009384,
#   'acnt_id': '17841445132536071',
#   'acnt_nm': 'smh_pomy1004',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  66: {'activity_score': 3.9476745179295314,
#   'follow_growth_rate': 1.1115702479338843,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.2080761885502798,
#   'acnt_id': '17841445166422975',
#   'acnt_nm': 'zoayo_o_o',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  67: {'activity_score': 3.8393615374780463,
#   'follow_growth_rate': 1.1115702479338843,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.0280200315644716,
#   'acnt_id': '17841445643835132',
#   'acnt_nm': 'zeppetto81',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  68: {'activity_score': 3.9748399699623893,
#   'follow_growth_rate': 1.1115702479338843,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.4713437204665991,
#   'acnt_id': '17841445666937156',
#   'acnt_nm': '__moggu__',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  69: {'activity_score': 3.881108373717411,
#   'follow_growth_rate': 1.0747130938858642,
#   'follower_retention_rate': 3.6666666666666856,
#   'avg_post_efficiency': 1.0999188742955341,
#   'acnt_id': '17841445793838858',
#   'acnt_nm': 'h_yubari',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  70: {'activity_score': 3.9463096623981375,
#   'follow_growth_rate': 1.1115702479338843,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 2.2387940569076057,
#   'acnt_id': '17841446006782306',
#   'acnt_nm': 'foto_nly',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  71: {'activity_score': 3.756577082033817,
#   'follow_growth_rate': 1.1115702479338843,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.1209464628005332,
#   'acnt_id': '17841448271359564',
#   'acnt_nm': 'soulmate.0817',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  72: {'activity_score': 3.9451174565733487,
#   'follow_growth_rate': 1.0976332237329305,
#   'follower_retention_rate': 4.5,
#   'avg_post_efficiency': 1.4866965454244496,
#   'acnt_id': '17841448917513240',
#   'acnt_nm': 'gini_mukmuk',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  73: {'activity_score': 4.0,
#   'follow_growth_rate': 1.5602352193261284,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.0996296426126313,
#   'acnt_id': '17841449481118331',
#   'acnt_nm': 'april_plus2',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  74: {'activity_score': 3.9096466131291807,
#   'follow_growth_rate': 1.1115702479338843,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.581576284562094,
#   'acnt_id': '17841450345136721',
#   'acnt_nm': '____yulbro____',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  75: {'activity_score': 3.848355327447465,
#   'follow_growth_rate': 1.1471351542027817,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.1549101329044202,
#   'acnt_id': '17841451635925488',
#   'acnt_nm': 'nanangmanssi',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  76: {'activity_score': 3.94313301572084,
#   'follow_growth_rate': 1.1115702479338843,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.462134870184678,
#   'acnt_id': '17841451732700545',
#   'acnt_nm': '172cm.dam',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  77: {'activity_score': 3.8413038416763676,
#   'follow_growth_rate': 1.0311199772014819,
#   'follower_retention_rate': 2.125,
#   'avg_post_efficiency': 2.0154321765320615,
#   'acnt_id': '17841452448927260',
#   'acnt_nm': 'daylog_c',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  78: {'activity_score': 3.8413038416763676,
#   'follow_growth_rate': 1.0311199772014819,
#   'follower_retention_rate': 2.125,
#   'avg_post_efficiency': 2.0154321765320615,
#   'acnt_id': '17841452448927260',
#   'acnt_nm': 'daylog_c',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  79: {'activity_score': 3.9211963821975466,
#   'follow_growth_rate': 1.5436179981634526,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.277500822213645,
#   'acnt_id': '17841452550656938',
#   'acnt_nm': 'bab_soooni_',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  80: {'activity_score': 3.8738217732547224,
#   'follow_growth_rate': 1.1115702479338843,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.1009672559106216,
#   'acnt_id': '17841454351752346',
#   'acnt_nm': 'rareyul',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  81: {'activity_score': 3.9175286705374566,
#   'follow_growth_rate': 1.1693192046477374,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.3023850325213477,
#   'acnt_id': '17841455470832799',
#   'acnt_nm': '9853du',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  82: {'activity_score': 3.836700846795414,
#   'follow_growth_rate': 1.1115702479338843,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.3126671580603269,
#   'acnt_id': '17841457700514314',
#   'acnt_nm': 'hi_kooing',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  83: {'activity_score': 3.859927280656779,
#   'follow_growth_rate': 1.1115702479338843,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.265926219007456,
#   'acnt_id': '17841458338153275',
#   'acnt_nm': 'lumisaga_mucin',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  84: {'activity_score': 3.800524151694318,
#   'follow_growth_rate': 1.1468128136625801,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.9361586076212722,
#   'acnt_id': '17841460040181185',
#   'acnt_nm': 'kkudam_',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  85: {'activity_score': 3.622449604803627,
#   'follow_growth_rate': 1.5169277896550626,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.2181389358840358,
#   'acnt_id': '17841460588103672',
#   'acnt_nm': 'yujiwon628',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  86: {'activity_score': 3.872110427407284,
#   'follow_growth_rate': 1.1115702479338843,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.205885841412944,
#   'acnt_id': '17841463336185919',
#   'acnt_nm': 'urizip_ganghazi',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  87: {'activity_score': 3.915801477750588,
#   'follow_growth_rate': 1.1115702479338843,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.1651750214721062,
#   'acnt_id': '17841463893430301',
#   'acnt_nm': 'mukyuding_',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  88: {'activity_score': 3.772050719143861,
#   'follow_growth_rate': 1.1115702479338843,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.2162682255825197,
#   'acnt_id': '17841464003665583',
#   'acnt_nm': 'velyoung2m',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  89: {'activity_score': 2.8092466322966905,
#   'follow_growth_rate': 1.3935882299518663,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.027855387256914,
#   'acnt_id': '17841464134128386',
#   'acnt_nm': 'it.tem___',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  90: {'activity_score': 3.643667886246466,
#   'follow_growth_rate': 1.0950938506793668,
#   'follower_retention_rate': 4.416666666666686,
#   'avg_post_efficiency': 1.0,
#   'acnt_id': '17841465781097624',
#   'acnt_nm': 'acong_mommy',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  91: {'activity_score': 3.928782375029541,
#   'follow_growth_rate': 1.1115702479338843,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.8885160422094622,
#   'acnt_id': '17841466998593596',
#   'acnt_nm': 'nao_yim',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  92: {'activity_score': 3.874170528419655,
#   'follow_growth_rate': 1.1746258655349564,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.2503479979931758,
#   'acnt_id': '17841467034456062',
#   'acnt_nm': 'hongsue_',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  93: {'activity_score': 3.6047035703986925,
#   'follow_growth_rate': 0.9999999999999999,
#   'follower_retention_rate': 1.0,
#   'avg_post_efficiency': 1.1968060881375715,
#   'acnt_id': '17841467078397304',
#   'acnt_nm': 'hyunnn138_',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  94: {'activity_score': 3.752156042859519,
#   'follow_growth_rate': 1.0894768970698723,
#   'follower_retention_rate': 4.208333333333314,
#   'avg_post_efficiency': 1.0675409748044242,
#   'acnt_id': '17841467436798662',
#   'acnt_nm': 'i_am_foodist',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  95: {'activity_score': 3.4251748143922165,
#   'follow_growth_rate': 1.0644853266172412,
#   'follower_retention_rate': 3.3333333333333144,
#   'avg_post_efficiency': 1.2862758668019125,
#   'acnt_id': '17841467581724114',
#   'acnt_nm': 'kooney2024',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  96: {'activity_score': 3.7692998503242974,
#   'follow_growth_rate': 1.7047205490965123,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.8873286886088865,
#   'acnt_id': '17841470993682107',
#   'acnt_nm': 'hi_losy',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  97: {'activity_score': 3.3138200565441545,
#   'follow_growth_rate': 5.0,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.2863475729885376,
#   'acnt_id': '17841472657326131',
#   'acnt_nm': 'min_of_travel',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  98: {'activity_score': 3.1784978699996165,
#   'follow_growth_rate': 1.1619240145074023,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.106235872272737,
#   'acnt_id': '17841474495202295',
#   'acnt_nm': 'susu_23.06.30',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '뷰티'},
#  99: {'activity_score': 3.3374367888858476,
#   'follow_growth_rate': 4.383303643259396,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 2.1106235220062706,
#   'acnt_id': '17841400070132367',
#   'acnt_nm': 'gnuoyeatt',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '패션'},
#  100: {'activity_score': 1.5861389488469277,
#   'follow_growth_rate': 4.295405500843567,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.0834583823828807,
#   'acnt_id': '17841400290013501',
#   'acnt_nm': 'niica_bini',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '패션'},
#  101: {'activity_score': 3.424855505329151,
#   'follow_growth_rate': 3.4025974025974026,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.3062619879228086,
#   'acnt_id': '17841400532714000',
#   'acnt_nm': '2sarada90',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '패션'},
#  102: {'activity_score': 3.7539283507753956,
#   'follow_growth_rate': 3.9043282693537362,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.269357060087277,
#   'acnt_id': '17841400582114307',
#   'acnt_nm': 'hhyun_jjin',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '패션'},
#  103: {'activity_score': 3.859671388878703,
#   'follow_growth_rate': 3.4025974025974026,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.4833302197790152,
#   'acnt_id': '17841400584148660',
#   'acnt_nm': 'jungseungmi_',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '패션'},
#  104: {'activity_score': 3.859671388878703,
#   'follow_growth_rate': 3.4025974025974026,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.4833302197790152,
#   'acnt_id': '17841400584148660',
#   'acnt_nm': 'jungseungmi_',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '패션'},
#  105: {'activity_score': 3.955201833753706,
#   'follow_growth_rate': 4.559229420286171,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 2.0412232250647335,
#   'acnt_id': '17841400590387514',
#   'acnt_nm': 'kay.kwon.kr',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '패션'},
#  106: {'activity_score': 2.8197710653289834,
#   'follow_growth_rate': 3.0261394656299117,
#   'follower_retention_rate': 4.358024691358082,
#   'avg_post_efficiency': 1.0544716745541067,
#   'acnt_id': '17841400593366620',
#   'acnt_nm': 'attraction_sa',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '패션'},
#  107: {'activity_score': 2.8197710653289834,
#   'follow_growth_rate': 3.0261394656299117,
#   'follower_retention_rate': 4.358024691358082,
#   'avg_post_efficiency': 1.0544716745541067,
#   'acnt_id': '17841400593366620',
#   'acnt_nm': 'attraction_sa',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '패션'},
#  108: {'activity_score': 3.2803800851779745,
#   'follow_growth_rate': 4.418128263489088,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.4289265428833882,
#   'acnt_id': '17841400872018393',
#   'acnt_nm': 'jiseon_37',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '패션'},
#  109: {'activity_score': 0.0,
#   'follow_growth_rate': 3.4025974025974026,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.0,
#   'acnt_id': '17841401615883791',
#   'acnt_nm': 'rinaseong',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '패션'},
#  110: {'activity_score': 3.7663130117566928,
#   'follow_growth_rate': 3.049948857824753,
#   'follower_retention_rate': 4.407407407407391,
#   'avg_post_efficiency': 2.15945898703544,
#   'acnt_id': '17841404564270314',
#   'acnt_nm': 'c.yeon.e',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '패션'},
#  111: {'activity_score': 3.8105673696822477,
#   'follow_growth_rate': 3.4025974025974026,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.2953164790557086,
#   'acnt_id': '17841405960290513',
#   'acnt_nm': 'kjnon1026',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '패션'},
#  112: {'activity_score': 3.8673809301207838,
#   'follow_growth_rate': 3.8003355997972417,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.0692834467302927,
#   'acnt_id': '17841406480562531',
#   'acnt_nm': 'gayoungmood',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '패션'},
#  113: {'activity_score': 3.6631075035792167,
#   'follow_growth_rate': 2.918139237811369,
#   'follower_retention_rate': 4.20987654320993,
#   'avg_post_efficiency': 1.6346846365707401,
#   'acnt_id': '17841411461566186',
#   'acnt_nm': 'dbbibbi',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '패션'},
#  114: {'activity_score': 3.6631075035792167,
#   'follow_growth_rate': 2.918139237811369,
#   'follower_retention_rate': 4.20987654320993,
#   'avg_post_efficiency': 1.6346846365707401,
#   'acnt_id': '17841411461566186',
#   'acnt_nm': 'dbbibbi',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '패션'},
#  115: {'activity_score': 2.8464673754983485,
#   'follow_growth_rate': 5.0,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.3307911978431184,
#   'acnt_id': '17841412336851729',
#   'acnt_nm': 'naegyeong2',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '패션'},
#  116: {'activity_score': 3.3234048488994214,
#   'follow_growth_rate': 3.4025974025974026,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.1252450445850657,
#   'acnt_id': '17841412467476265',
#   'acnt_nm': 'yayasoraya1218',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '패션'},
#  117: {'activity_score': 4.0,
#   'follow_growth_rate': 2.1342734518700186,
#   'follower_retention_rate': 2.8765432098765586,
#   'avg_post_efficiency': 2.481764297656012,
#   'acnt_id': '17841427906920555',
#   'acnt_nm': 'jangeunyeong4486',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '패션'},
#  118: {'activity_score': 3.952112982001476,
#   'follow_growth_rate': 3.4025974025974026,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 2.531188737523353,
#   'acnt_id': '17841439225730933',
#   'acnt_nm': 'review_ddook',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '패션'},
#  119: {'activity_score': 3.997532599792119,
#   'follow_growth_rate': 1.0,
#   'follower_retention_rate': 1.0,
#   'avg_post_efficiency': 1.9072477117607114,
#   'acnt_id': '17841444317992419',
#   'acnt_nm': 'sayhello_0123',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '패션'},
#  120: {'activity_score': 3.8120824110353997,
#   'follow_growth_rate': 4.279509807699719,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.864811011018535,
#   'acnt_id': '17841445706534901',
#   'acnt_nm': 'gimpo_market',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '패션'},
#  121: {'activity_score': 0.0,
#   'follow_growth_rate': 2.252716155439891,
#   'follower_retention_rate': 3.074074074074133,
#   'avg_post_efficiency': 1.0976206361653444,
#   'acnt_id': '17841449913495321',
#   'acnt_nm': 'goneemama',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '패션'},
#  122: {'activity_score': 3.649346769155553,
#   'follow_growth_rate': 2.723242274966413,
#   'follower_retention_rate': 3.864197530864203,
#   'avg_post_efficiency': 2.111752914148185,
#   'acnt_id': '17841452740446247',
#   'acnt_nm': '_pila_sun_',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '패션'},
#  123: {'activity_score': 1.8795966637122246,
#   'follow_growth_rate': 4.761307657859382,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 2.449083654103728,
#   'acnt_id': '17841458883844033',
#   'acnt_nm': 'poemyeony',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '패션'},
#  124: {'activity_score': 3.973552437810681,
#   'follow_growth_rate': 3.4025974025974026,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 2.9370421248401035,
#   'acnt_id': '17841461261981850',
#   'acnt_nm': 'doromi___',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '패션'},
#  125: {'activity_score': 3.946891342170697,
#   'follow_growth_rate': 1.3645320197044337,
#   'follower_retention_rate': 1.5925925925926663,
#   'avg_post_efficiency': 5.0,
#   'acnt_id': '17841466979796967',
#   'acnt_nm': 'iseolriem',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '패션'},
#  126: {'activity_score': 2.5914995482086196,
#   'follow_growth_rate': 3.701101928374656,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 2.165175969649356,
#   'acnt_id': '17841472755802463',
#   'acnt_nm': 'huxa__0',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '패션'},
#  127: {'activity_score': 4.0,
#   'follow_growth_rate': 2.3825762924128107,
#   'follower_retention_rate': 3.0,
#   'avg_post_efficiency': 1.0,
#   'acnt_id': '17841418240434019',
#   'acnt_nm': '1209_1124',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '푸드'},
#  128: {'activity_score': 3.671350435047478,
#   'follow_growth_rate': 1.0,
#   'follower_retention_rate': 3.0,
#   'avg_post_efficiency': 5.0,
#   'acnt_id': '17841469380767019',
#   'acnt_nm': '_bbo_iing',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '푸드'},
#  129: {'activity_score': 3.671350435047478,
#   'follow_growth_rate': 1.0,
#   'follower_retention_rate': 3.0,
#   'avg_post_efficiency': 5.0,
#   'acnt_id': '17841469380767019',
#   'acnt_nm': '_bbo_iing',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '푸드'},
#  130: {'activity_score': 0.0,
#   'follow_growth_rate': 5.0,
#   'follower_retention_rate': 3.0,
#   'avg_post_efficiency': 1.1362434000666053,
#   'acnt_id': '17841469588134780',
#   'acnt_nm': 'review.cat',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '푸드'},
#  131: {'activity_score': 3.9832930061066945,
#   'follow_growth_rate': 4.573587907716786,
#   'follower_retention_rate': 4.571428571428555,
#   'avg_post_efficiency': 4.255959267316607,
#   'acnt_id': '17841404564270314',
#   'acnt_nm': 'c.yeon.e',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '홈/리빙'},
#  132: {'activity_score': 4.0,
#   'follow_growth_rate': 5.0,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 4.999999999999999,
#   'acnt_id': '17841404803263661',
#   'acnt_nm': 'xoxojinam',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '홈/리빙'},
#  133: {'activity_score': 3.7459691004476103,
#   'follow_growth_rate': 5.0,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.8777437346773604,
#   'acnt_id': '17841408084939632',
#   'acnt_nm': 'sweet_potato36',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '홈/리빙'},
#  134: {'activity_score': 3.7299978527572226,
#   'follow_growth_rate': 1.0,
#   'follower_retention_rate': 1.0,
#   'avg_post_efficiency': 1.0,
#   'acnt_id': '17841455388870972',
#   'acnt_nm': 'elie0723',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '홈/리빙'},
#  135: {'activity_score': 0.0,
#   'follow_growth_rate': 5.0,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.85570503347182,
#   'acnt_id': '17841466835485122',
#   'acnt_nm': 'kikikiki_eun',
#   'influencer_scale_type': 'nano',
#   'main_interest_category': '홈/리빙'},
#  136: {'activity_score': 3.0,
#   'follow_growth_rate': 3.0,
#   'follower_retention_rate': 3.0,
#   'avg_post_efficiency': 3.0,
#   'acnt_id': '17841454147699373',
#   'acnt_nm': '230111love',
#   'influencer_scale_type': 'micro',
#   'main_interest_category': '베이비/키즈'},
#  137: {'activity_score': 3.9876540236805136,
#   'follow_growth_rate': 1.1602285619984736,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.510350293749853,
#   'acnt_id': '17841400025364370',
#   'acnt_nm': '9_5jw',
#   'influencer_scale_type': 'micro',
#   'main_interest_category': '뷰티'},
#  138: {'activity_score': 3.948123620309051,
#   'follow_growth_rate': 1.1028366227369826,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.057667204604066,
#   'acnt_id': '17841400079187566',
#   'acnt_nm': 'jjjjeong_2',
#   'influencer_scale_type': 'micro',
#   'main_interest_category': '뷰티'},
#  139: {'activity_score': 3.9923861374070615,
#   'follow_growth_rate': 1.0974358974358975,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.3483742546488673,
#   'acnt_id': '17841400082069836',
#   'acnt_nm': '1___ykkk',
#   'influencer_scale_type': 'micro',
#   'main_interest_category': '뷰티'},
#  140: {'activity_score': 3.7001541088758385,
#   'follow_growth_rate': 1.1128854782061435,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.1832909455118634,
#   'acnt_id': '17841400098010697',
#   'acnt_nm': 'hyyye.r',
#   'influencer_scale_type': 'micro',
#   'main_interest_category': '뷰티'},
#  141: {'activity_score': 3.938427306227628,
#   'follow_growth_rate': 1.0974358974358975,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.1320073200067087,
#   'acnt_id': '17841400187194180',
#   'acnt_nm': 'j.o.a.r.a',
#   'influencer_scale_type': 'micro',
#   'main_interest_category': '뷰티'},
#  142: {'activity_score': 3.9941222378308474,
#   'follow_growth_rate': 1.0796915926349089,
#   'follower_retention_rate': 4.279999999999973,
#   'avg_post_efficiency': 1.2798696325912982,
#   'acnt_id': '17841400190627741',
#   'acnt_nm': 'by__miinchae',
#   'influencer_scale_type': 'micro',
#   'main_interest_category': '뷰티'},
#  143: {'activity_score': 3.7735099337748346,
#   'follow_growth_rate': 1.105812296024788,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.185231484610773,
#   'acnt_id': '17841400228562323',
#   'acnt_nm': 'subin_mam',
#   'influencer_scale_type': 'micro',
#   'main_interest_category': '뷰티'},
#  144: {'activity_score': 3.899586800249052,
#   'follow_growth_rate': 1.1026630124942476,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.0848636588953275,
#   'acnt_id': '17841400286702933',
#   'acnt_nm': 'hwasu0220',
#   'influencer_scale_type': 'micro',
#   'main_interest_category': '뷰티'},
#  145: {'activity_score': 3.9762612656126457,
#   'follow_growth_rate': 1.0863532655656851,
#   'follower_retention_rate': 4.519999999999982,
#   'avg_post_efficiency': 1.0574585884002996,
#   'acnt_id': '17841400290385517',
#   'acnt_nm': 'mchan_lee',
#   'influencer_scale_type': 'micro',
#   'main_interest_category': '뷰티'},
#  146: {'activity_score': 3.3864832739004926,
#   'follow_growth_rate': 1.101435245768101,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.0031913594223527,
#   'acnt_id': '17841400321488131',
#   'acnt_nm': 'hello_minvely',
#   'influencer_scale_type': 'micro',
#   'main_interest_category': '뷰티'},
#  147: {'activity_score': 3.9541329408879076,
#   'follow_growth_rate': 1.0933558513276236,
#   'follower_retention_rate': 4.840000000000032,
#   'avg_post_efficiency': 1.02179708129512,
#   'acnt_id': '17841400330502606',
#   'acnt_nm': 'hsb12211',
#   'influencer_scale_type': 'micro',
#   'main_interest_category': '뷰티'},
#  148: {'activity_score': 3.763269743995256,
#   'follow_growth_rate': 1.1643943893300486,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.0348451019687606,
#   'acnt_id': '17841400331610291',
#   'acnt_nm': 'ssong_e.y',
#   'influencer_scale_type': 'micro',
#   'main_interest_category': '뷰티'},
#  149: {'activity_score': 3.711137868753763,
#   'follow_growth_rate': 1.103652151183212,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.2088450727187043,
#   'acnt_id': '17841400385794614',
#   'acnt_nm': '76minary',
#   'influencer_scale_type': 'micro',
#   'main_interest_category': '뷰티'},
#  150: {'activity_score': 3.735393671817513,
#   'follow_growth_rate': 1.0846990694249181,
#   'follower_retention_rate': 4.440000000000055,
#   'avg_post_efficiency': 1.14283081380714,
#   'acnt_id': '17841400397474567',
#   'acnt_nm': 'yoomyang',
#   'influencer_scale_type': 'micro',
#   'main_interest_category': '뷰티'},
#  151: {'activity_score': 2.6681383370125094,
#   'follow_growth_rate': 1.0974358974358975,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.0162066819891837,
#   'acnt_id': '17841400475050030',
#   'acnt_nm': '49lauren',
#   'influencer_scale_type': 'micro',
#   'main_interest_category': '뷰티'},
#  152: {'activity_score': 3.935504047093451,
#   'follow_growth_rate': 1.0974358974358975,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.0304613478045976,
#   'acnt_id': '17841400584001516',
#   'acnt_nm': 'tiana_1228',
#   'influencer_scale_type': 'micro',
#   'main_interest_category': '뷰티'},
#  153: {'activity_score': 3.56953642384106,
#   'follow_growth_rate': 1.0911697379905474,
#   'follower_retention_rate': 4.759999999999991,
#   'avg_post_efficiency': 1.0478455265889963,
#   'acnt_id': '17841400600051722',
#   'acnt_nm': 'p1000h',
#   'influencer_scale_type': 'micro',
#   'main_interest_category': '뷰티'},
#  154: {'activity_score': 3.7887564385577632,
#   'follow_growth_rate': 1.121645352166444,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.0203816609339185,
#   'acnt_id': '17841400611875418',
#   'acnt_nm': 'cafe.flex',
#   'influencer_scale_type': 'micro',
#   'main_interest_category': '뷰티'},
#  155: {'activity_score': 3.8388520971302427,
#   'follow_growth_rate': 1.0974358974358975,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.0468163954405585,
#   'acnt_id': '17841400642634136',
#   'acnt_nm': 'earth_trip',
#   'influencer_scale_type': 'micro',
#   'main_interest_category': '뷰티'},
#  156: {'activity_score': 3.982516447681033,
#   'follow_growth_rate': 1.0785159034027814,
#   'follower_retention_rate': 4.2000000000000455,
#   'avg_post_efficiency': 1.3420705654095897,
#   'acnt_id': '17841400656677541',
#   'acnt_nm': 'ninesea_',
#   'influencer_scale_type': 'micro',
#   'main_interest_category': '뷰티'},
#  157: {'activity_score': 3.9877981175601005,
#   'follow_growth_rate': 1.0974358974358975,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.2638693152550773,
#   'acnt_id': '17841400680176427',
#   'acnt_nm': 'hyunjjomi',
#   'influencer_scale_type': 'micro',
#   'main_interest_category': '뷰티'},
#  158: {'activity_score': 3.9681461650462637,
#   'follow_growth_rate': 1.092969699103826,
#   'follower_retention_rate': 4.840000000000032,
#   'avg_post_efficiency': 1.0377472924265139,
#   'acnt_id': '17841400688613479',
#   'acnt_nm': 'jindorf7',
#   'influencer_scale_type': 'micro',
#   'main_interest_category': '뷰티'},
#  159: {'activity_score': 3.980277601378935,
#   'follow_growth_rate': 1.0974358974358975,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.4690608598084218,
#   'acnt_id': '17841400694192158',
#   'acnt_nm': 'naayeon16',
#   'influencer_scale_type': 'micro',
#   'main_interest_category': '뷰티'},
#  160: {'activity_score': 3.97426888418879,
#   'follow_growth_rate': 1.0788345432768693,
#   'follower_retention_rate': 4.2000000000000455,
#   'avg_post_efficiency': 2.095017608731861,
#   'acnt_id': '17841400726275578',
#   'acnt_nm': 'daugng',
#   'influencer_scale_type': 'micro',
#   'main_interest_category': '뷰티'},
#  161: {'activity_score': 3.987759102971765,
# ...
#   'acnt_id': '17841401926975682',
#   'acnt_nm': 'yum0.0',
#   'influencer_scale_type': 'mid',
#   'main_interest_category': '홈/리빙'},
#  642: {'activity_score': 3.9174816495110103,
#   'follow_growth_rate': 1.9878671444699803,
#   'follower_retention_rate': 4.428571428571331,
#   'avg_post_efficiency': 1.0467964305717505,
#   'acnt_id': '17841401959713516',
#   'acnt_nm': 'taeim3',
#   'influencer_scale_type': 'mid',
#   'main_interest_category': '홈/리빙'},
#  643: {'activity_score': 3.9880583889239243,
#   'follow_growth_rate': 2.109168699593351,
#   'follower_retention_rate': 4.85714285714289,
#   'avg_post_efficiency': 1.0,
#   'acnt_id': '17841404035899279',
#   'acnt_nm': 'baesurin_',
#   'influencer_scale_type': 'mid',
#   'main_interest_category': '홈/리빙'},
#  644: {'activity_score': 3.440751078406496,
#   'follow_growth_rate': 5.0,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.5063634537637465,
#   'acnt_id': '17841405643705489',
#   'acnt_nm': 'unijeni',
#   'influencer_scale_type': 'mid',
#   'main_interest_category': '홈/리빙'},
#  645: {'activity_score': 3.933114448212139,
#   'follow_growth_rate': 2.060926141939901,
#   'follower_retention_rate': 4.714285714285779,
#   'avg_post_efficiency': 1.084435570140661,
#   'acnt_id': '17841406890931545',
#   'acnt_nm': 'emsmcy',
#   'influencer_scale_type': 'mid',
#   'main_interest_category': '홈/리빙'},
#  646: {'activity_score': 3.9810343055942927,
#   'follow_growth_rate': 2.0339664461885265,
#   'follower_retention_rate': 4.714285714285779,
#   'avg_post_efficiency': 1.0565567169302936,
#   'acnt_id': '17841418505172230',
#   'acnt_nm': 'ko_a.ra',
#   'influencer_scale_type': 'mid',
#   'main_interest_category': '홈/리빙'},
#  647: {'activity_score': 3.921928911210469,
#   'follow_growth_rate': 2.028474898368857,
#   'follower_retention_rate': 4.571428571428669,
#   'avg_post_efficiency': 1.4887106539554162,
#   'acnt_id': '17841438518782201',
#   'acnt_nm': 'seandy.zip',
#   'influencer_scale_type': 'mid',
#   'main_interest_category': '홈/리빙'},
#  648: {'activity_score': 3.8906954501981144,
#   'follow_growth_rate': 2.4696965344343287,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 5.0,
#   'acnt_id': '17841454076298818',
#   'acnt_nm': 'ipsae_camping',
#   'influencer_scale_type': 'mid',
#   'main_interest_category': '홈/리빙'},
#  649: {'activity_score': 3.9519737838544895,
#   'follow_growth_rate': 2.131598998160281,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.1506094094946682,
#   'acnt_id': '17841467159743263',
#   'acnt_nm': 'thirty_life_93',
#   'influencer_scale_type': 'mid',
#   'main_interest_category': '홈/리빙'},
#  650: {'activity_score': 3.921928911210469,
#   'follow_growth_rate': 1.0,
#   'follower_retention_rate': 1.0,
#   'avg_post_efficiency': 2.3687791764240815,
#   'acnt_id': '17841469363262587',
#   'acnt_nm': 'comet_life_all',
#   'influencer_scale_type': 'mid',
#   'main_interest_category': '홈/리빙'},
#  651: {'activity_score': 3.9694926026623354,
#   'follow_growth_rate': 1.8561831788229515,
#   'follower_retention_rate': 4.714285714285779,
#   'avg_post_efficiency': 3.0939468896020292,
#   'acnt_id': '17841400006499942',
#   'acnt_nm': 'kim__us_',
#   'influencer_scale_type': 'macro',
#   'main_interest_category': '뷰티'},
#  652: {'activity_score': 3.269192913385827,
#   'follow_growth_rate': 1.700950773568117,
#   'follower_retention_rate': 4.142857142857338,
#   'avg_post_efficiency': 1.952476028979056,
#   'acnt_id': '17841400580612199',
#   'acnt_nm': 'jogood72',
#   'influencer_scale_type': 'macro',
#   'main_interest_category': '뷰티'},
#  653: {'activity_score': 3.688320209973753,
#   'follow_growth_rate': 1.8262020708700824,
#   'follower_retention_rate': 4.714285714285779,
#   'avg_post_efficiency': 2.532836536251817,
#   'acnt_id': '17841401061482770',
#   'acnt_nm': 'mina_lavu',
#   'influencer_scale_type': 'macro',
#   'main_interest_category': '뷰티'},
#  654: {'activity_score': 3.99226914817466,
#   'follow_growth_rate': 1.2569474079229193,
#   'follower_retention_rate': 2.1428571428573377,
#   'avg_post_efficiency': 1.753899355355384,
#   'acnt_id': '17841401086862436',
#   'acnt_nm': 'julietmira5',
#   'influencer_scale_type': 'macro',
#   'main_interest_category': '뷰티'},
#  655: {'activity_score': 3.7553805774278217,
#   'follow_growth_rate': 1.8311265294704937,
#   'follower_retention_rate': 4.714285714285779,
#   'avg_post_efficiency': 2.2345557224099055,
#   'acnt_id': '17841401272625523',
#   'acnt_nm': 'oing0307',
#   'influencer_scale_type': 'macro',
#   'main_interest_category': '뷰티'},
#  656: {'activity_score': 3.7772778402699663,
#   'follow_growth_rate': 1.856256895090954,
#   'follower_retention_rate': 4.714285714285779,
#   'avg_post_efficiency': 1.9709413790078718,
#   'acnt_id': '17841401717699486',
#   'acnt_nm': 'cocoalla',
#   'influencer_scale_type': 'macro',
#   'main_interest_category': '뷰티'},
#  657: {'activity_score': 3.931478030894993,
#   'follow_growth_rate': 0.9999999999999999,
#   'follower_retention_rate': 1.0,
#   'avg_post_efficiency': 2.928834846512143,
#   'acnt_id': '17841401942858884',
#   'acnt_nm': 'my_floria_',
#   'influencer_scale_type': 'macro',
#   'main_interest_category': '뷰티'},
#  658: {'activity_score': 3.931478030894993,
#   'follow_growth_rate': 0.9999999999999999,
#   'follower_retention_rate': 1.0,
#   'avg_post_efficiency': 2.928834846512143,
#   'acnt_id': '17841401942858884',
#   'acnt_nm': 'my_floria_',
#   'influencer_scale_type': 'macro',
#   'main_interest_category': '뷰티'},
#  659: {'activity_score': 3.791490006056935,
#   'follow_growth_rate': 1.8010083377137451,
#   'follower_retention_rate': 4.4285714285715585,
#   'avg_post_efficiency': 2.2773869226494305,
#   'acnt_id': '17841401954250938',
#   'acnt_nm': 'raonjenanim',
#   'influencer_scale_type': 'macro',
#   'main_interest_category': '뷰티'},
#  660: {'activity_score': 3.9500192049164586,
#   'follow_growth_rate': 1.7951504182520264,
#   'follower_retention_rate': 4.4285714285715585,
#   'avg_post_efficiency': 2.264632728909807,
#   'acnt_id': '17841402028598497',
#   'acnt_nm': 'stylecooca',
#   'influencer_scale_type': 'macro',
#   'main_interest_category': '뷰티'},
#  661: {'activity_score': 0.0,
#   'follow_growth_rate': 3.2744564444814115,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.4183743357304104,
#   'acnt_id': '17841402128645157',
#   'acnt_nm': 'icanddoit',
#   'influencer_scale_type': 'macro',
#   'main_interest_category': '뷰티'},
#  662: {'activity_score': 3.736220472440945,
#   'follow_growth_rate': 1.8041364351683287,
#   'follower_retention_rate': 4.4285714285715585,
#   'avg_post_efficiency': 2.1283654553740714,
#   'acnt_id': '17841402158404026',
#   'acnt_nm': 'tedseon',
#   'influencer_scale_type': 'macro',
#   'main_interest_category': '뷰티'},
#  663: {'activity_score': 3.9951530233249146,
#   'follow_growth_rate': 1.812456798951159,
#   'follower_retention_rate': 4.4285714285715585,
#   'avg_post_efficiency': 1.0,
#   'acnt_id': '17841402171767176',
#   'acnt_nm': 'stylish_tasty',
#   'influencer_scale_type': 'macro',
#   'main_interest_category': '뷰티'},
#  664: {'activity_score': 3.8080708661417324,
#   'follow_growth_rate': 1.8330627279410208,
#   'follower_retention_rate': 4.714285714285779,
#   'avg_post_efficiency': 2.6123354620613073,
#   'acnt_id': '17841402372145724',
#   'acnt_nm': 'dri1117',
#   'influencer_scale_type': 'macro',
#   'main_interest_category': '뷰티'},
#  665: {'activity_score': 3.7721456692913384,
#   'follow_growth_rate': 1.8593617011613752,
#   'follower_retention_rate': 4.714285714285779,
#   'avg_post_efficiency': 1.7321716017107212,
#   'acnt_id': '17841404452754986',
#   'acnt_nm': 'sylove7100',
#   'influencer_scale_type': 'macro',
#   'main_interest_category': '뷰티'},
#  666: {'activity_score': 3.3135710977304305,
#   'follow_growth_rate': 5.0,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.6491499694161602,
#   'acnt_id': '17841407300151686',
#   'acnt_nm': '2905_home',
#   'influencer_scale_type': 'macro',
#   'main_interest_category': '뷰티'},
#  667: {'activity_score': 3.3135710977304305,
#   'follow_growth_rate': 5.0,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.6491499694161602,
#   'acnt_id': '17841407300151686',
#   'acnt_nm': '2905_home',
#   'influencer_scale_type': 'macro',
#   'main_interest_category': '뷰티'},
#  668: {'activity_score': 3.977550039069544,
#   'follow_growth_rate': 1.687879228401617,
#   'follower_retention_rate': 3.8571428571426623,
#   'avg_post_efficiency': 2.354409590808795,
#   'acnt_id': '17841416105095031',
#   'acnt_nm': 'best_namnam',
#   'influencer_scale_type': 'macro',
#   'main_interest_category': '뷰티'},
#  669: {'activity_score': 3.7772778402699663,
#   'follow_growth_rate': 1.5592186375268926,
#   'follower_retention_rate': 3.5714285714288962,
#   'avg_post_efficiency': 1.646215878427936,
#   'acnt_id': '17841431208327086',
#   'acnt_nm': 'vv_vid',
#   'influencer_scale_type': 'macro',
#   'main_interest_category': '뷰티'},
#  670: {'activity_score': 3.729210677933551,
#   'follow_growth_rate': 1.9037211280608384,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.0323130642956317,
#   'acnt_id': '17841437781952670',
#   'acnt_nm': 'neuel_s',
#   'influencer_scale_type': 'macro',
#   'main_interest_category': '뷰티'},
#  671: {'activity_score': 4.0,
#   'follow_growth_rate': 1.6566708902901084,
#   'follower_retention_rate': 3.8571428571426623,
#   'avg_post_efficiency': 3.0261079415662584,
#   'acnt_id': '17841448810667457',
#   'acnt_nm': 'gum0070',
#   'influencer_scale_type': 'macro',
#   'main_interest_category': '뷰티'},
#  672: {'activity_score': 3.8461093098656782,
#   'follow_growth_rate': 1.268713298468065,
#   'follower_retention_rate': 2.1428571428573377,
#   'avg_post_efficiency': 5.0,
#   'acnt_id': '17841462888085401',
#   'acnt_nm': 'mr___choon',
#   'influencer_scale_type': 'macro',
#   'main_interest_category': '뷰티'},
#  673: {'activity_score': 3.0,
#   'follow_growth_rate': 3.0,
#   'follower_retention_rate': 3.0,
#   'avg_post_efficiency': 3.0,
#   'acnt_id': '17841423469631536',
#   'acnt_nm': 'goodlovelov',
#   'influencer_scale_type': 'macro',
#   'main_interest_category': '서비스'},
#  674: {'activity_score': 3.668179646440516,
#   'follow_growth_rate': 2.8773525373557587,
#   'follower_retention_rate': 4.555555555554747,
#   'avg_post_efficiency': 2.2544582256417365,
#   'acnt_id': '17841400313840086',
#   'acnt_nm': 'blondierona',
#   'influencer_scale_type': 'macro',
#   'main_interest_category': '패션'},
#  675: {'activity_score': 3.270425226946966,
#   'follow_growth_rate': 3.5837100198859746,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 4.868287132099507,
#   'acnt_id': '17841400361359004',
#   'acnt_nm': 's_h_j_',
#   'influencer_scale_type': 'macro',
#   'main_interest_category': '패션'},
#  676: {'activity_score': 1.7788461538461533,
#   'follow_growth_rate': 2.5798023817606186,
#   'follower_retention_rate': 4.111111111111313,
#   'avg_post_efficiency': 1.0,
#   'acnt_id': '17841400417546279',
#   'acnt_nm': 'yooojung4',
#   'influencer_scale_type': 'macro',
#   'main_interest_category': '패션'},
#  677: {'activity_score': 3.5029585798816565,
#   'follow_growth_rate': 3.087574306720206,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.557998445798292,
#   'acnt_id': '17841400591698216',
#   'acnt_nm': 'tingkerhee',
#   'influencer_scale_type': 'macro',
#   'main_interest_category': '패션'},
#  678: {'activity_score': 3.907521050378193,
#   'follow_growth_rate': 1.9576541469990392,
#   'follower_retention_rate': 2.7777777777773736,
#   'avg_post_efficiency': 4.999999999999999,
#   'acnt_id': '17841401131460799',
#   'acnt_nm': 'jeje9e',
#   'influencer_scale_type': 'macro',
#   'main_interest_category': '패션'},
#  679: {'activity_score': 3.83433022673529,
#   'follow_growth_rate': 2.896108525985273,
#   'follower_retention_rate': 4.555555555554747,
#   'avg_post_efficiency': 2.7736553172842404,
#   'acnt_id': '17841401500840763',
#   'acnt_nm': 'maycoco__',
#   'influencer_scale_type': 'macro',
#   'main_interest_category': '패션'},
#  680: {'activity_score': 3.872318158032444,
#   'follow_growth_rate': 2.8277079406492818,
#   'follower_retention_rate': 4.555555555554747,
#   'avg_post_efficiency': 2.0760762106723796,
#   'acnt_id': '17841401566082143',
#   'acnt_nm': 'raon45',
#   'influencer_scale_type': 'macro',
#   'main_interest_category': '패션'},
#  681: {'activity_score': 3.3754924320962054,
#   'follow_growth_rate': 1.0,
#   'follower_retention_rate': 1.0,
#   'avg_post_efficiency': 1.9376863917646516,
#   'acnt_id': '17841402891598966',
#   'acnt_nm': 'khyunee_',
#   'influencer_scale_type': 'macro',
#   'main_interest_category': '패션'},
#  682: {'activity_score': 3.3754924320962054,
#   'follow_growth_rate': 1.0,
#   'follower_retention_rate': 1.0,
#   'avg_post_efficiency': 1.9376863917646516,
#   'acnt_id': '17841402891598966',
#   'acnt_nm': 'khyunee_',
#   'influencer_scale_type': 'macro',
#   'main_interest_category': '패션'},
#  683: {'activity_score': 4.0,
#   'follow_growth_rate': 1.6010894367963895,
#   'follower_retention_rate': 2.33333333333303,
#   'avg_post_efficiency': 1.3895200517606279,
#   'acnt_id': '17841403843676453',
#   'acnt_nm': 'lily_ujoo',
#   'influencer_scale_type': 'macro',
#   'main_interest_category': '패션'},
#  684: {'activity_score': 3.388278388278388,
#   'follow_growth_rate': 4.005025853077019,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 3.71321875469412,
#   'acnt_id': '17841404754372434',
#   'acnt_nm': 'bora_sunny_',
#   'influencer_scale_type': 'macro',
#   'main_interest_category': '패션'},
#  685: {'activity_score': 3.388278388278388,
#   'follow_growth_rate': 4.005025853077019,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 3.71321875469412,
#   'acnt_id': '17841404754372434',
#   'acnt_nm': 'bora_sunny_',
#   'influencer_scale_type': 'macro',
#   'main_interest_category': '패션'},
#  686: {'activity_score': 0.0,
#   'follow_growth_rate': 5.0,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 2.303949413885335,
#   'acnt_id': '17841406889980629',
#   'acnt_nm': 'lilycoco__',
#   'influencer_scale_type': 'macro',
#   'main_interest_category': '패션'},
#  687: {'activity_score': 3.0,
#   'follow_growth_rate': 3.0,
#   'follower_retention_rate': 3.0,
#   'avg_post_efficiency': 3.0,
#   'acnt_id': '17841401506106699',
#   'acnt_nm': 'siwolbubu_hyun',
#   'influencer_scale_type': 'macro',
#   'main_interest_category': '푸드'},
#  688: {'activity_score': 3.968745511781325,
#   'follow_growth_rate': 1.3025399141735114,
#   'follower_retention_rate': 1.6666666666669698,
#   'avg_post_efficiency': 3.9019455732514974,
#   'acnt_id': '17841401175130753',
#   'acnt_nm': 'csheep',
#   'influencer_scale_type': 'macro',
#   'main_interest_category': '홈/리빙'},
#  689: {'activity_score': 4.0,
#   'follow_growth_rate': 5.0,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 5.000000000000001,
#   'acnt_id': '17841401400610794',
#   'acnt_nm': 'sun',
#   'influencer_scale_type': 'macro',
#   'main_interest_category': '홈/리빙'},
#  690: {'activity_score': 8.881784197001252e-16,
#   'follow_growth_rate': 2.3975631791477614,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.0,
#   'acnt_id': '17841401409523807',
#   'acnt_nm': 'daitsoall',
#   'influencer_scale_type': 'macro',
#   'main_interest_category': '홈/리빙'},
#  691: {'activity_score': 3.871811128339795,
#   'follow_growth_rate': 1.9104560960027297,
#   'follower_retention_rate': 3.66666666666697,
#   'avg_post_efficiency': 2.0235582509746894,
#   'acnt_id': '17841401478098195',
#   'acnt_nm': 'aquilina0113',
#   'influencer_scale_type': 'macro',
#   'main_interest_category': '홈/리빙'},
#  692: {'activity_score': 3.8889525168437897,
#   'follow_growth_rate': 2.2752270067422975,
#   'follower_retention_rate': 4.33333333333303,
#   'avg_post_efficiency': 2.435336390118284,
#   'acnt_id': '17841401844782267',
#   'acnt_nm': 'real2sseul',
#   'influencer_scale_type': 'macro',
#   'main_interest_category': '홈/리빙'},
#  693: {'activity_score': 1.334726913188363,
#   'follow_growth_rate': 1.0,
#   'follower_retention_rate': 1.0,
#   'avg_post_efficiency': 1.7873466527133488,
#   'acnt_id': '17841402337428788',
#   'acnt_nm': 'jjun2_mam',
#   'influencer_scale_type': 'macro',
#   'main_interest_category': '홈/리빙'},
#  694: {'activity_score': 2.5481150160868737,
#   'follow_growth_rate': 2.2031570873079223,
#   'follower_retention_rate': 4.33333333333303,
#   'avg_post_efficiency': 1.2398088391769613,
#   'acnt_id': '17841402997201103',
#   'acnt_nm': 'eunyi486',
#   'influencer_scale_type': 'macro',
#   'main_interest_category': '홈/리빙'}}

# %%
len(list(normalized_all_dic.keys()))
# Out:
# 695

# %%
ssh.insert_query_with_lookup('op_mem_seller_score', list(normalized_all_dic.values()))
# Out:
# ✅ inserted acnt_id: 17841400587197476
# ✅ inserted acnt_id: 17841400588709226
# ✅ inserted acnt_id: 17841400773895438
# ✅ inserted acnt_id: 17841401080128294
# ✅ inserted acnt_id: 17841401374507119
# ✅ inserted acnt_id: 17841401530775838
# ✅ inserted acnt_id: 17841401629705047
# ✅ inserted acnt_id: 17841401639140025
# ✅ inserted acnt_id: 17841401661602499
# ✅ inserted acnt_id: 17841401784692335
# ✅ inserted acnt_id: 17841401829633534
# ✅ inserted acnt_id: 17841402048303273
# ✅ inserted acnt_id: 17841402059097583
# ✅ inserted acnt_id: 17841402265949784
# ✅ inserted acnt_id: 17841402652660371
# ✅ inserted acnt_id: 17841403918276288
# ✅ inserted acnt_id: 17841404803263661
# ✅ inserted acnt_id: 17841404867713313
# ✅ inserted acnt_id: 17841406281775348
# ✅ inserted acnt_id: 17841407376200009
# ✅ inserted acnt_id: 17841408084939632
# ✅ inserted acnt_id: 17841411649994165
# ✅ inserted acnt_id: 17841412467476265
# ✅ inserted acnt_id: 17841416663433806
# ✅ inserted acnt_id: 17841431248109362
# ✅ inserted acnt_id: 17841437265150835
# ✅ inserted acnt_id: 17841445132536071
# ✅ inserted acnt_id: 17841445166422975
# ✅ inserted acnt_id: 17841445643835132
# ✅ inserted acnt_id: 17841445756322288
# ✅ inserted acnt_id: 17841448271359564
# ✅ inserted acnt_id: 17841449982443435
# ✅ inserted acnt_id: 17841460588103672
# ✅ inserted acnt_id: 17841463336185919
# ✅ inserted acnt_id: 17841464003665583
# ✅ inserted acnt_id: 17841464546823475
# ✅ inserted acnt_id: 17841474495202295
# ✅ inserted acnt_id: 17841400207803324
# ✅ inserted acnt_id: 17841400228562323
# ✅ inserted acnt_id: 17841400260808355
# ✅ inserted acnt_id: 17841400331610291
# ✅ inserted acnt_id: 17841400393557813
# ✅ inserted acnt_id: 17841400397474567
# ✅ inserted acnt_id: 17841400584001516
# ✅ inserted acnt_id: 17841400741475317
# ✅ inserted acnt_id: 17841400788733911
# ✅ inserted acnt_id: 17841400847520703
# ✅ inserted acnt_id: 17841400987507569
# ✅ inserted acnt_id: 17841401130847234
# ✅ inserted acnt_id: 17841401155466552
# ✅ inserted acnt_id: 17841401207230048
# ✅ inserted acnt_id: 17841401828073811
# ✅ inserted acnt_id: 17841401849932428
# ✅ inserted acnt_id: 17841401866805925
# ✅ inserted acnt_id: 17841402099160722
# ✅ inserted acnt_id: 17841402102624080
# ✅ inserted acnt_id: 17841402217096445
# ✅ inserted acnt_id: 17841402992067481
# ✅ inserted acnt_id: 17841403010500034
# ✅ inserted acnt_id: 17841403149767140
# ✅ inserted acnt_id: 17841403193273551
# ✅ inserted acnt_id: 17841403245207523
# ✅ inserted acnt_id: 17841404225590969
# ✅ inserted acnt_id: 17841406247356662
# ✅ inserted acnt_id: 17841406277150184
# ✅ inserted acnt_id: 17841407325633359
# ✅ inserted acnt_id: 17841407484079801
# ✅ inserted acnt_id: 17841407744795642
# ✅ inserted acnt_id: 17841408034660403
# ✅ inserted acnt_id: 17841409110284916
# ✅ inserted acnt_id: 17841416451104402
# ✅ inserted acnt_id: 17841420643724984
# ✅ inserted acnt_id: 17841422295117996
# ✅ inserted acnt_id: 17841425122174352
# ✅ inserted acnt_id: 17841425136266507
# ✅ inserted acnt_id: 17841428565011638
# ✅ inserted acnt_id: 17841430916245881
# ✅ inserted acnt_id: 17841434185690601
# ✅ inserted acnt_id: 17841438021613345
# ✅ inserted acnt_id: 17841439727391508
# ✅ inserted acnt_id: 17841440499771771
# ✅ inserted acnt_id: 17841445908145098
# ✅ inserted acnt_id: 17841446792244911
# ✅ inserted acnt_id: 17841446872061061
# ✅ inserted acnt_id: 17841448658481026
# ✅ inserted acnt_id: 17841451947574168
# ✅ inserted acnt_id: 17841452444445850
# ✅ inserted acnt_id: 17841452557069952
# ✅ inserted acnt_id: 17841452674987093
# ✅ inserted acnt_id: 17841454745213673
# ✅ inserted acnt_id: 17841455344835442
# ✅ inserted acnt_id: 17841457823458915
# ✅ inserted acnt_id: 17841458400102283
# ✅ inserted acnt_id: 17841458745843420
# ✅ inserted acnt_id: 17841459202587740
# ✅ inserted acnt_id: 17841462766662071
# ✅ inserted acnt_id: 17841464040869476
# ✅ inserted acnt_id: 17841464210842845
# ✅ inserted acnt_id: 17841467095436954
# ✅ inserted acnt_id: 17841467636476654
# ✅ inserted acnt_id: 17841471290295933
# ✅ inserted acnt_id: 17841473857435791
# ✅ inserted acnt_id: 17841400141093921
# ✅ inserted acnt_id: 17841400161867480
# ✅ inserted acnt_id: 17841400213155737
# ✅ inserted acnt_id: 17841400328449426
# ✅ inserted acnt_id: 17841400421674292
# ✅ inserted acnt_id: 17841400530652036
# ✅ inserted acnt_id: 17841400536962805
# ✅ inserted acnt_id: 17841400677092417
# ✅ inserted acnt_id: 17841400784072284
# ✅ inserted acnt_id: 17841400815487261
# ✅ inserted acnt_id: 17841400859114230
# ✅ inserted acnt_id: 17841400917436891
# ✅ inserted acnt_id: 17841400918051812
# ✅ inserted acnt_id: 17841400978217439
# ✅ inserted acnt_id: 17841401029158025
# ✅ inserted acnt_id: 17841401092222560
# ✅ inserted acnt_id: 17841401211771114
# ✅ inserted acnt_id: 17841401301316101
# ✅ inserted acnt_id: 17841401311746253
# ✅ inserted acnt_id: 17841401366408281
# ✅ inserted acnt_id: 17841401394689456
# ✅ inserted acnt_id: 17841401424029959
# ✅ inserted acnt_id: 17841401424154210
# ✅ inserted acnt_id: 17841401526880784
# ✅ inserted acnt_id: 17841401571730009
# ✅ inserted acnt_id: 17841401581354276
# ✅ inserted acnt_id: 17841401614497126
# ✅ inserted acnt_id: 17841401714788385
# ✅ inserted acnt_id: 17841401800033959
# ✅ inserted acnt_id: 17841401837605088
# ✅ inserted acnt_id: 17841401926975682
# ✅ inserted acnt_id: 17841401935860270
# ✅ inserted acnt_id: 17841401945182913
# ✅ inserted acnt_id: 17841401959713516
# ✅ inserted acnt_id: 17841402125099488
# ✅ inserted acnt_id: 17841402189386396
# ✅ inserted acnt_id: 17841402536605041
# ✅ inserted acnt_id: 17841402599777713
# ✅ inserted acnt_id: 17841403266564062
# ✅ inserted acnt_id: 17841403458875665
# ✅ inserted acnt_id: 17841404031482825
# ✅ inserted acnt_id: 17841404036630544
# ✅ inserted acnt_id: 17841404776831282
# ✅ inserted acnt_id: 17841405643705489
# ✅ inserted acnt_id: 17841405943979868
# ✅ inserted acnt_id: 17841406130271904
# ✅ inserted acnt_id: 17841406718947821
# ✅ inserted acnt_id: 17841407608097154
# ✅ inserted acnt_id: 17841408670217255
# ✅ inserted acnt_id: 17841409132515581
# ✅ inserted acnt_id: 17841409196470651
# ✅ inserted acnt_id: 17841424904746312
# ✅ inserted acnt_id: 17841435293870150
# ✅ inserted acnt_id: 17841443943990104
# ✅ inserted acnt_id: 17841445592295805
# ✅ inserted acnt_id: 17841456831877987
# ✅ inserted acnt_id: 17841459094129560
# ✅ inserted acnt_id: 17841465078082022
# ✅ inserted acnt_id: 17841467159743263
# ✅ inserted acnt_id: 17841468103686024
# ✅ inserted acnt_id: 17841400417546279
# ✅ inserted acnt_id: 17841400591698216
# ✅ inserted acnt_id: 17841401045868840
# ✅ inserted acnt_id: 17841401400610794
# ✅ inserted acnt_id: 17841401506106699
# ✅ inserted acnt_id: 17841402028598497
# ✅ inserted acnt_id: 17841402158404026
# ✅ inserted acnt_id: 17841402171767176
# ✅ inserted acnt_id: 17841404452754986
# ✅ inserted acnt_id: 17841431208327086
# 2025-07-18 04:00:31,515| ERROR   | Socket exception: 현재 연결은 원격 호스트에 의해 강제로 끊겼습니다 (10054)

# %% [markdown]
# ##### 크리에이터 광고 효율성

# %%
revenue_dic = {
    'acnt_nm' : ['s_h_j_', 'siwolbubu_hyun', 'bong_camper83', 'binwoos', 'seojinii_', 'tingkerhee'],
    'sell_type' : ['flexmatch', 'other', 'flexmatch', 'flexmatch', 'other', 'other'],
    'total_revenue' : [6906000, 10937105, 7233100, 8759000, 7939664, 38449720],
    'total_order_cnt' : [84, 132, 122, 88, 89, 471]
    }

revenue_df = pd.DataFrame(revenue_dic)
revenue_merged_df = pd.merge(media_engagement_merged_df, revenue_df, on='acnt_nm', how='left')
revenue_merged_df = revenue_merged_df[['acnt_id', 'acnt_nm', 'follower_cnt', 'follow_cnt', 'media_cnt', 'sell_type', 'total_revenue', 'total_order_cnt', 'media_id', 'like_cnt', 'cmnt_cnt']]
revenue_merged_df

revenue_merged_df['post_efficiency'] = ((revenue_merged_df['like_cnt'] + revenue_merged_df['cmnt_cnt']) / revenue_merged_df['follower_cnt']) * 100
revenue_df_total = revenue_merged_df.groupby(['acnt_id', 'acnt_nm']).agg({
    'post_efficiency' : 'mean',
    'total_order_cnt' : 'first'
}).dropna()

revenue_df_total['advertisement_efficiency'] = (revenue_df_total['total_order_cnt'] / revenue_df_total['post_efficiency']) 
revenue_df_total.sort_values(by='advertisement_efficiency', ascending=False)

revenue_merged_df['engagement_per_post'] = ((revenue_merged_df['like_cnt'] + revenue_merged_df['cmnt_cnt']) / 25)
revenue_df_total = revenue_merged_df.groupby(['acnt_id', 'acnt_nm']).agg({
    'engagement_per_post' : 'mean',
    'total_revenue' : 'first',
    'total_order_cnt' : 'first'
}).dropna()

# 팔로워를 생각하지 않고, 25개의 콘텐츠 단위당 반응 비율을 계산
revenue_df_total['advertisement_efficiency'] = (revenue_df_total['total_order_cnt'] / revenue_df_total['engagement_per_post'] * 25) * 100
revenue_df_total.sort_values(by='advertisement_efficiency', ascending=False)
# Out:
#           acnt_nm  sell_type  total_revenue  total_order_cnt
# 0          s_h_j_  flexmatch        6906000               84
# 1  siwolbubu_hyun      other       10937105              132
# 2   bong_camper83  flexmatch        7233100              122
# 3         binwoos  flexmatch        8759000               88
# 4       seojinii_      other        7939664               89
# 5      tingkerhee      other       38449720              471

# %% [markdown]
# 콘텐츠 효율성이 아닌 팔로워 참여도를 기준으로 계산했을 때

# %%
engaged_df_2 = engaged_df.copy()
revenue_merged_df_2 = revenue_merged_df.groupby(['acnt_id', 'acnt_nm'])[['total_revenue', 'total_order_cnt']].first().dropna().reset_index()
revenue_df_total_2 = pd.merge(engaged_df_2, revenue_merged_df_2, on='acnt_id')

revenue_df_total_2['advertisement_efficiency'] = revenue_df_total_2['total_order_cnt'] / revenue_df_total_2['follower_total_engagement']
revenue_df_total_2[['acnt_id', 'acnt_nm', 'total_revenue', 'total_order_cnt', 'follower_total_engagement', 'advertisement_efficiency']].sort_values(by='advertisement_efficiency', ascending=False)

# %% [markdown]
# table merged

# %%
# 크리에이터 활동성
creator_activity_score = activity_df[['acnt_id', 'avg_upload_interval']]

# %%
# 트렌드지수
creator_follow_growth_rate = time_series_merged_df[['acnt_id', 'follow_growth_rate']]

# %%
# 팔로워 참여도
follower_engagement = engaged_df[['acnt_id', 'follower_total_engagement']]

# %%
# 팔로워 충성도
follower_loyalty = time_series_merged_df_copy[['acnt_id', 'follower_retention_rate']]

# %%
# 콘텐츠 효율성
post_efficiency = post_efficiency_df.copy()

# %%
# 광고효율성
revenue_df_total = revenue_df_total.reset_index()
advertisement_efficiency = revenue_df_total[['acnt_id', 'advertisement_efficiency']]

# %%
df_list = [creator_activity_score, creator_follow_growth_rate, follower_engagement, follower_loyalty, post_efficiency, advertisement_efficiency]

# %%
from functools import reduce

flexmatch_score = reduce(lambda left, right: pd.merge(left, right, on='acnt_id', how='left'), df_list)

# %%
user_info_nm = user_info_2[['acnt_id', 'acnt_nm']]
flexmatch_score = pd.merge(flexmatch_score, user_info_nm, on='acnt_id')

# %%
flexmatch_score = flexmatch_score[['acnt_id', 'acnt_nm', 'avg_upload_interval', 'follow_growth_rate', 'follower_total_engagement', 'follower_retention_rate', 'avg_post_efficiency', 'advertisement_efficiency']]
flexmatch_score.rename(columns={
    'avg_upload_interval' : '크리에이터 활동성',
    'follow_growth_rate' : '트렌드지수(팔로워순증가량)', 
    'follower_total_engagement' : '콘텐츠 참여도' ,
    'follower_retention_rate' : '팔로워 충성도',
    'avg_post_efficiency' : '콘텐츠 효율성',
    'advertisement_efficiency' : '광고 효율성'
}, inplace=True)

# %%
flexmatch_score_2 = flexmatch_score.copy()
flexmatch_score_2.dropna(inplace=True)

# %%
flexmatch_score_2
# Out:
#               acnt_id         acnt_nm  크리에이터 활동성  트렌드지수(팔로워순증가량)      콘텐츠 참여도  \
# 0   17841400361359004          s_h_j_   1.166667        0.057866   110.188904
# 1   17841400561503844         binwoos   0.500000       -0.014956   626.642600
# 2   17841400591698216      tingkerhee   2.416667       -0.018509  2065.579146
# 4   17841401506106699  siwolbubu_hyun   0.958333       -0.075045  2094.996055
# 6   17841402936102997       seojinii_   2.875000       -0.002312   166.809026
# 10  17841453615191128   bong_camper83   1.500000        0.281793  2526.578680
#
#     팔로워 충성도   콘텐츠 효율성       광고 효율성
# 0    100.00  0.045178  1859.316062
# 1     99.99  0.169730   518.470975
# 2     99.98  0.483403   974.343202
# 4     99.92  0.556736   237.096389
# 6    100.00  0.240359   370.279723
# 10   100.00  2.506526    48.672935

# %%
# from sklearn.preprocessing import MinMaxScaler

# columns = flexmatch_score_2.select_dtypes(include='float64').columns
# minmax = MinMaxScaler(feature_range=(0, 5))
# flexmatch_score_norm = minmax.fit_transform(flexmatch_score_2[columns])

# flexmatch_score_norm_df = pd.DataFrame(flexmatch_score_norm, columns=columns, index=flexmatch_score_2.index)
# flexmatch_score_norm_df['acnt_id'] = flexmatch_score_2['acnt_id']
# flexmatch_score_norm_df['acnt_nm'] = flexmatch_score_2['acnt_nm']

# flexmatch_score_norm_df['avg_upload_interval'] = 5 - flexmatch_score_norm_df['avg_upload_interval']
# flexmatch_score_norm_df

# %%
from sklearn.preprocessing import MinMaxScaler

columns = flexmatch_score_2.select_dtypes(include='float64').columns
minmax = MinMaxScaler(feature_range=(0, 5))
flexmatch_score_norm = minmax.fit_transform(flexmatch_score_2[columns])

flexmatch_score_norm_df = pd.DataFrame(flexmatch_score_norm, columns=columns, index=flexmatch_score_2.index)
flexmatch_score_norm_df['acnt_id'] = flexmatch_score_2['acnt_id']
flexmatch_score_norm_df['acnt_nm'] = flexmatch_score_2['acnt_nm']

flexmatch_score_norm_df['크리에이터 활동성'] = 5 - flexmatch_score_norm_df['크리에이터 활동성']
flexmatch_score_norm_df

# 지금 이거 정규화 할 때는 그냥 이사람들을 전부 다 합쳐서 함께 정규화를 진행해서 그런데, 원래라면은 팔로워를 기준으로 뭐 메가 인플루언서, 마이크로 인플루언서 이런식으로 기준을 나눠서 정규화를 해야 조금 더 정확한 값이 될 것 같음.
# Out:
#     크리에이터 활동성  트렌드지수(팔로워순증가량)   콘텐츠 참여도  팔로워 충성도   콘텐츠 효율성    광고 효율성  \
# 0    3.596491        1.862339  0.000000    5.000  0.000000  5.000000
# 1    5.000000        0.841960  1.068647    4.375  0.253016  1.297324
# 2    0.964912        0.792182  4.046099    3.750  0.890213  2.556192
# 4    4.035088        0.000000  4.106968    0.000  1.039182  0.520322
# 6    0.000000        1.019133  0.117159    5.000  0.396492  0.888101
# 10   2.894737        5.000000  5.000000    5.000  5.000000  0.000000
#
#               acnt_id         acnt_nm
# 0   17841400361359004          s_h_j_
# 1   17841400561503844         binwoos
# 2   17841400591698216      tingkerhee
# 4   17841401506106699  siwolbubu_hyun
# 6   17841402936102997       seojinii_
# 10  17841453615191128   bong_camper83

# %%
# flexmatch_score_norm_df.to_csv("flexmatch_score_test.csv")
