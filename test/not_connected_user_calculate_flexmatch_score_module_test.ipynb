# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from sklearn.preprocessing import MinMaxScaler

import os
from dotenv import load_dotenv
import boto3
import io
import pymysql
import json

# %% [markdown]
# DB Connection

# %%
from sshtunnel import SSHTunnelForwarder

class SSHMySQLConnector:
    def __init__(self):
        self.ssh_host = None
        self.ssh_username = None
        self.ssh_password = None
        self.db_username = None
        self.db_password = None
        self.db_name = None
        self.tunnel = None
        self.connection = None

    def load_config_from_json(self, json_path):
        try:
            with open(json_path, 'r', encoding='utf-8') as f:
                config = json.load(f)
                self.ssh_host = config['ssh_host']
                self.ssh_username = config['ssh_username']
                self.ssh_password = config['ssh_password']
                self.db_username = config['db_username']
                self.db_password = config['db_password']
                self.db_name = config['db_name']
        except Exception as e:
            print("❌ 설정 JSON 로딩 실패:", e)


    def connect(self):
        try:
            self.tunnel = SSHTunnelForwarder(
                (self.ssh_host, 22),
                ssh_username=self.ssh_username,
                ssh_password=self.ssh_password,
                remote_bind_address=('127.0.0.1', 3306),
            )
            self.tunnel.start()
            
            self.connection = pymysql.connect(
                host='127.0.0.1',
                port=self.tunnel.local_bind_port,
                user=self.db_username,
                password=self.db_password,
                db=self.db_name,
                cursorclass=pymysql.cursors.DictCursor  # 이 줄 추가
            )
            print("✅ DB 접속 성공")
        except Exception as e:
            print("❌ SSH 또는 DB 연결 실패:", e)

    def insert_query_with_lookup(self, table_name, data_list):
        try:
            with self.connection.cursor() as cursor:
                for data in data_list:
                    # 1. op_member에서 uid, user_id 조회
                    cursor.execute("""
                        SELECT uid, user_id FROM op_member
                        WHERE add1 = %s
                        LIMIT 1
                    """, (data['acnt_nm'],))
                    result = cursor.fetchone()
                    if result:
                        data['member_uid'] = result['uid']
                        data['user_id'] = result['user_id']
                        # 향후에 ig_user_id가 추가가 된다면, 해당 부분도 확인해서 추가할 수 있게
                        # data['ig_user_id'] = result['ig_user_id']
                    else:
                        data['member_uid'] = 0
                        data['user_id'] = 'None'
                        # data['ig_user_id'] = 'None'

                    # 2. INSERT 쿼리 구성 및 실행
                    columns = ', '.join(data.keys())
                    placeholders = ', '.join([f"%({k})s" for k in data.keys()])
                    insert_sql = f"INSERT INTO {table_name} ({columns}) VALUES ({placeholders})"
                    cursor.execute(insert_sql, data)

                    print(f"✅ inserted acnt_id: {data.get('acnt_id', 'N/A')}")

            self.connection.commit()
        except Exception as e:
            self.connection.rollback()
            print("❌ INSERT 실패:", e)

    def close(self):
        if self.connection:
            self.connection.close()
        if self.tunnel:
            self.tunnel.stop()

# %%
ssh = SSHMySQLConnector()
ssh.load_config_from_json('C:/Users/ehddl/Desktop/업무/code/config/ssh_db_config.json')
ssh.connect()

# data_list = [
#     {
#         'activity_score': 0.18618008163528707,
#         'follow_growth_rate': 1.2384506112322682,
#         'follower_total_engagement': 0.9006925508419993,
#         'follower_retention_rate': 4.84593837535013,
#         'avg_post_efficiency': 1.4776093002849746,
#         'acnt_id': '17841400070132367',
#         'acnt_nm': 'gnuoyeatt',
#         'influencer_scale_type': 'nano'
#     }
# ]

# ssh.insert_query_with_lookup('op_mem_seller_score', data_list)
# Out:
# ✅ DB 접속 성공

# %% [markdown]
# Data Loading

# %%
def load_s3_instagram_data():

    load_dotenv()
    aws_access_key = os.getenv("aws_accessKey")
    aws_secret_key = os.getenv("aws_secretKey")
    region_name='ap-northeast-2'

    # S3 클라이언트 생성
    client = boto3.client('s3', aws_access_key_id=aws_access_key, aws_secret_access_key=aws_secret_key, region_name=region_name)

    today = datetime.now()
    year, week, _ = today.isocalendar()

    bucket_name = 'flexmatch-data'

    table_list = ['RECENT_USER_INFO_MTR', 'TIME_SERIES_PROFILE_INFO', 'BY_USER_ID_MEDIA_DTL_INFO', 'BY_DATE_MEDIA_AGG_INFO']
    df_by_table_list = {}

    for table_name in table_list:
        prefix = f'instagram-data/tables/{table_name}/year={year}/week=28/' # 이번주가 없어서 week를 따로 x
        response = client.list_objects_v2(Bucket=bucket_name, Prefix=prefix)

        if 'Contents' in response:
            files = [content['Key'] for content in response['Contents'] if content['Key'].endswith('merged_data.parquet')]

            if not files:
                print(f"[Info] No merged_data.parquet found for table: {table_name}")
                continue

            # 각 파일 순회
            for file_key in files:
                try:
                    obj = client.get_object(Bucket=bucket_name, Key=file_key)
                    df = pd.read_parquet(io.BytesIO(obj['Body'].read()))
                    df_by_table_list[table_name] = df
                    print(f"[Success] Loaded {file_key} for table {table_name}")
                except Exception as e:
                    print(f"[Error] Failed to read {file_key} for table {table_name}: {e}")
        else:
            print(f"[Info] No files found under prefix: {prefix}")
        
    return df_by_table_list

df_by_table_list = load_s3_instagram_data()

recent_user_info_mtr_2 = df_by_table_list['RECENT_USER_INFO_MTR']
time_series_profile_info_2 = df_by_table_list['TIME_SERIES_PROFILE_INFO']
by_user_id_media_dtl_info_2 = df_by_table_list['BY_USER_ID_MEDIA_DTL_INFO']
by_date_media_agg_info_2 = df_by_table_list['BY_DATE_MEDIA_AGG_INFO']

# recent_user_info_mtr = df_by_table_list['RECENT_USER_INFO_MTR']
# time_series_profile_info = df_by_table_list['TIME_SERIES_PROFILE_INFO']
# by_user_id_media_dtl_info = df_by_table_list['BY_USER_ID_MEDIA_DTL_INFO']
# by_date_media_agg_info = df_by_table_list['BY_DATE_MEDIA_AGG_INFO']
# Out:
# [Success] Loaded instagram-data/tables/RECENT_USER_INFO_MTR/year=2025/week=28/merged_data.parquet for table RECENT_USER_INFO_MTR
# [Success] Loaded instagram-data/tables/TIME_SERIES_PROFILE_INFO/year=2025/week=28/merged_data.parquet for table TIME_SERIES_PROFILE_INFO
# [Success] Loaded instagram-data/tables/BY_USER_ID_MEDIA_DTL_INFO/year=2025/week=28/merged_data.parquet for table BY_USER_ID_MEDIA_DTL_INFO
# [Success] Loaded instagram-data/tables/BY_DATE_MEDIA_AGG_INFO/year=2025/week=28/merged_data.parquet for table BY_DATE_MEDIA_AGG_INFO

# %%
def load_weekly_instagram_data(bucket_name, table_list, weeks_back=2, target_filename='merged_data.parquet'):
    # 환경 변수 로딩
    load_dotenv()
    aws_access_key = os.getenv("aws_accessKey")
    aws_secret_key = os.getenv("aws_secretKey")

    client = boto3.client(
        's3',
        aws_access_key_id=aws_access_key,
        aws_secret_access_key=aws_secret_key,
        region_name='ap-northeast-2'
    )

    # 주차 리스트 생성 (현재 주 포함하여 `weeks_back`만큼)
    today = datetime.now()
    week_year_pairs = [
        (today - timedelta(weeks=w)).isocalendar()[:2]
        for w in range(weeks_back)
    ]

    # 결과 저장용 딕셔너리 초기화
    merged_data_by_table = {table_name: {} for table_name in table_list}

    # 주차별로 데이터 로딩
    for year_val, week_val in week_year_pairs:
        for table_name in table_list:
            prefix = f'instagram-data/tables/{table_name}/year={year_val}/week={week_val}/'
            response = client.list_objects_v2(Bucket=bucket_name, Prefix=prefix)

            if 'Contents' not in response:
                print(f"[Info] No files found under prefix: {prefix}")
                continue

            target_files = [
                content['Key']
                for content in response['Contents']
                if content['Key'].endswith(target_filename)
            ]

            if not target_files:
                print(f"[Info] No {target_filename} found for {table_name} week={week_val}")
                continue

            for file_key in target_files:
                try:
                    obj = client.get_object(Bucket=bucket_name, Key=file_key)
                    df = pd.read_parquet(io.BytesIO(obj['Body'].read()))
                    merged_data_by_table[table_name][week_val] = df
                    print(f"[Success] Loaded {file_key} for table {table_name}, week {week_val}")
                except Exception as e:
                    print(f"[Error] Failed to read {file_key} for {table_name}, week {week_val}: {e}")

    recent_weeks_data = {}
    for table_name, week_data in merged_data_by_table.items():
        sorted_weeks = sorted(week_data.keys())
        if len(sorted_weeks) >= 2:
            prev_week, current_week = sorted_weeks[-2], sorted_weeks[-1]
            recent_weeks_data[table_name] = {
                'prev_week': week_data[prev_week],
                'current_week': week_data[current_week]
            }
        else:
            print(f"[Warning] Not enough data for table {table_name} to determine prev/current weeks.")

    
    return merged_data_by_table

# %%
bucket_name = 'flexmatch-data'
table_list = [
    'RECENT_USER_INFO_MTR',
    'TIME_SERIES_PROFILE_INFO',
    'BY_USER_ID_MEDIA_DTL_INFO',
    'BY_DATE_MEDIA_AGG_INFO'
]

merged_data_by_table = load_weekly_instagram_data(bucket_name, table_list)

# 예시 접근
user_info_this_week = merged_data_by_table['RECENT_USER_INFO_MTR']['current_week']
user_info_last_week = merged_data_by_table['RECENT_USER_INFO_MTR']['prev_week']

# %% [markdown]
# basic preprocessing

# %%
recent_user_info_mtr = recent_user_info_mtr.drop_duplicates(subset=['acnt_id', 'acnt_nm'])
time_series_profile_info = time_series_profile_info.drop_duplicates(subset=['base_ymd', 'acnt_id'])
by_user_id_media_dtl_info = by_user_id_media_dtl_info.drop_duplicates(subset=['acnt_id', 'media_id', 'media_cn'])
by_date_media_agg_info = by_date_media_agg_info.drop_duplicates(subset=['base_ymd', 'media_id'])

recent_user_info_mtr_2 = recent_user_info_mtr_2.drop_duplicates(subset=['acnt_id', 'acnt_nm'])
time_series_profile_info_2 = time_series_profile_info_2.drop_duplicates(subset=['base_ymd', 'acnt_id'])
by_user_id_media_dtl_info_2 = by_user_id_media_dtl_info_2.drop_duplicates(subset=['acnt_id', 'media_id', 'media_cn'])
by_date_media_agg_info_2 = by_date_media_agg_info_2.drop_duplicates(subset=['base_ymd', 'media_id'])

# %% [markdown]
# 가장 최근 데이터로 isin 해줘야 할 것 같음. 그래야 1주일 전, 후를 비교할 수 있기 때문임

# %%
# 각 acnt_id가 있는 전부 있는 경우만 가능, isin으로 제거
# 근데 전 주차에는 없는 유저가 생길수도 있음
# media 같은 경우에도 최근 25개만 일단 가져오고 있기 때문에 일주일 단위여도 없을수도 있음

# 이렇게 해야하는 이유는 timeseries 변수를 계산하려면 무조건 두 주차에 같은 아이디가 있어야 함
# 또한, user info랑 media info 같이 써야하는 경우에는 어짜피 한번 거르고 있을 듯
# -> 따라서, 굳이 필수적으로 하지는 않아도 될듯함

unique_user = recent_user_info_mtr['acnt_id'].unique()

time_series_profile_info = time_series_profile_info[time_series_profile_info['acnt_id'].isin(unique_user)]
by_user_id_media_dtl_info = by_user_id_media_dtl_info[by_user_id_media_dtl_info['acnt_id'].isin(unique_user)]
time_series_profile_info_2 = time_series_profile_info_2[time_series_profile_info_2['acnt_id'].isin(unique_user)]
by_user_id_media_dtl_info_2 = by_user_id_media_dtl_info_2[by_user_id_media_dtl_info_2['acnt_id'].isin(unique_user)]

unique_media = by_user_id_media_dtl_info_2['media_id'].unique()
by_date_media_agg_info_2 = by_date_media_agg_info_2[by_date_media_agg_info_2['media_id'].isin(unique_media)]

# %%
def influencer_scale_type(row):
    count = row['follower_cnt']
    if count < 1000:
        return 'nano'
    elif 1000 <= count <= 10000:
        return 'micro'
    elif 10000 < count <= 100000:
        return 'mid'
    elif 100000 < count <= 500000:
        return 'macro'
    else:
        return 'mega'

recent_user_info_mtr.loc[:, 'influencer_scale_type'] = recent_user_info_mtr.apply(influencer_scale_type, axis=1)
recent_user_info_mtr_2.loc[:,'influencer_scale_type'] = recent_user_info_mtr_2.apply(influencer_scale_type, axis=1)

# %% [markdown]
# create merged file

# %%
# all_merged_df_a = pd.merge(recent_user_info_mtr, time_series_profile_info, on='acnt_id', how='left')
# all_merged_df_b = pd.merge(all_merged_df_a, by_user_id_media_dtl_info, on='acnt_id')

# all_merged_df = pd.merge(all_merged_df_b, by_date_media_agg_info, on='media_id')

# media_engagement_merged_df = pd.merge(by_user_id_media_dtl_info, by_date_media_agg_info, on='media_id')
# media_engagement_profile_merged_df = pd.merge(media_engagement_merged_df, recent_user_info_mtr, on='acnt_id', how='left')
# time_series_merged_df = pd.merge(time_series_profile_info, time_series_profile_info_2, on='acnt_id')

# %%
# def create_merged_df(user_info_df, timeseries_df, timeseries_df_2, media_info_df, media_agg_df):
#     all_merged_df_a = pd.merge(user_info_df, timeseries_df, on='acnt_id', how='left')
#     all_merged_df_b = pd.merge(all_merged_df_a, media_info_df, on='acnt_id')
#     all_merged_df = pd.merge(all_merged_df_b, media_agg_df, on='media_id')

#     media_engagement_merged_df = pd.merge(media_info_df, media_agg_df, on='media_id')

#     # 절반 이상의 게시물의 like가 비공개인 influencer 제거
#     by_user_na_like_count = media_engagement_merged_df[media_engagement_merged_df['like_cnt'].isna()].groupby(['acnt_id'])['media_id'].count()
#     na_like_user = by_user_na_like_count[by_user_na_like_count > 13].index
#     print(len(na_like_user))
#     media_engagement_merged_df = media_engagement_merged_df[~media_engagement_merged_df['acnt_id'].isin(na_like_user)].reset_index()

#     # fillna 함수 정의
#     like_medians = media_engagement_merged_df.groupby(['acnt_id'])['like_cnt'].median()
#     comments_medians = media_engagement_merged_df.groupby(['acnt_id'])['cmnt_cnt'].median()

#     def fillna_like(row):
#         if pd.notna(row['like_cnt']):
#             return row['like_cnt']
#         median = like_medians.get(row['acnt_id'])
#         return median if pd.notna(median) else 0

#     def fillna_comment(row):
#         if pd.notna(row['cmnt_cnt']):
#             return row['cmnt_cnt']
#         median = comments_medians.get(row['acnt_id'])
#         return median if pd.notna(median) else 0

#     media_engagement_merged_df['like_cnt'] = media_engagement_merged_df.apply(fillna_like, axis=1)
#     media_engagement_merged_df['cmnt_cnt'] = media_engagement_merged_df.apply(fillna_comment, axis=1)

    
#     media_engagement_profile_merged_df = pd.merge(media_engagement_merged_df, user_info_df, on='acnt_id', how='left')
#     time_series_merged_df = pd.merge(timeseries_df, timeseries_df_2, on='acnt_id')

#     return all_merged_df, media_engagement_merged_df, media_engagement_profile_merged_df, time_series_merged_df

# %%
def create_merged_df(user_info_df, timeseries_df, timeseries_df_2, media_info_df, media_agg_df):
    media_engagement_merged_df = pd.merge(media_info_df, media_agg_df, on='media_id', how='outer')
    # print(len(media_engagement_merged_df['acnt_id'].unique()))

    ## 방법 1
    # 단 한개의 게시물이라도 like가 비공개인 influencer 제거
    # by_user_na_like_count = media_engagement_merged_df[media_engagement_merged_df['like_cnt'].isna()].groupby(['acnt_id'])['media_id'].count()
    # na_like_user = by_user_na_like_count[by_user_na_like_count > 0].index
    # media_engagement_merged_df = media_engagement_merged_df[~media_engagement_merged_df['acnt_id'].isin(na_like_user)].reset_index()

    ## 방법 2
    no_media_user = user_info_df[user_info_df['media_cnt'] == 0]['acnt_id'].to_list()
    media_engagement_merged_df = media_engagement_merged_df[~media_engagement_merged_df['acnt_id'].isin(no_media_user)].reset_index()

    media_engagement_merged_groupby_df = media_engagement_merged_df.groupby('acnt_id')[['like_cnt', 'cmnt_cnt']].mean()
    media_engagement_merged_groupby_df = np.ceil(media_engagement_merged_groupby_df)
    fillna_user = media_engagement_merged_groupby_df[media_engagement_merged_groupby_df['like_cnt'] > 1].index

    media_engagement_merged_df = media_engagement_merged_df[media_engagement_merged_df['acnt_id'].isin(fillna_user)].reset_index()

    engagement_cols = ['like_cnt', 'cmnt_cnt']
    for col in engagement_cols:
        media_engagement_merged_df[col] = media_engagement_merged_df.apply(
        lambda row: media_engagement_merged_groupby_df.at[row['acnt_id'], col] if pd.isna(row[col]) else row[col], axis=1)

    user_list = media_engagement_merged_df['acnt_id'].unique()
    media_list = media_engagement_merged_df['media_id'].unique()

    # merge하면서 제거된 리스트가 있기 때문에, 해당 부분 다시 삭제 후에 새로운 merge 파일 생성
    user_info = user_info_df[user_info_df['acnt_id'].isin(user_list)]
    timeseries = timeseries_df[timeseries_df['acnt_id'].isin(user_list)]
    timeseries_2 = timeseries_df_2[timeseries_df_2['acnt_id'].isin(user_list)]
    media_info = media_info_df[media_info_df['acnt_id'].isin(user_list)]
    media_agg = media_agg_df[media_agg_df['media_id'].isin(media_list)]

    all_merged_df_a = pd.merge(user_info, timeseries, on='acnt_id')
    all_merged_df_b = pd.merge(all_merged_df_a, media_info, on='acnt_id')
    all_merged_df = pd.merge(all_merged_df_b, media_agg, on='media_id')
    
    media_engagement_profile_merged_df = pd.merge(media_engagement_merged_df, user_info_df, on='acnt_id')
    time_series_merged_df = pd.merge(timeseries, timeseries_df_2, on='acnt_id')

    return user_info, timeseries, timeseries_2, media_info, media_agg, all_merged_df, media_engagement_merged_df, media_engagement_profile_merged_df, time_series_merged_df

# %%
user_info, timeseries, timeseries_2, media_info, media_agg, all_merged_df, media_engagement_merged_df, media_engagement_profile_merged_df, time_series_merged_df = create_merged_df(
                                                                                                                        recent_user_info_mtr_2,
                                                                                                                        time_series_profile_info,
                                                                                                                        time_series_profile_info_2,
                                                                                                                        by_user_id_media_dtl_info_2,
                                                                                                                        by_date_media_agg_info_2)

# %% [markdown]
# 크리에이터 활동성
#
# - 실제 게시물 업로드 날짜를 기준으로 계산할 수 있을 것 같음
# - 최근 25개의 게시물의 평균 게시 간격을 계산
# - 최근 25개의 게시물을 며칠에 걸쳐서 업로드 했는지에 대한 값을 계산

# %%
# media_dtl_2_copy = by_user_id_media_dtl_info_2.copy()
# media_dtl_2_copy = media_dtl_2_copy.drop_duplicates(subset=['acnt_id', 'media_id', 'media_cn'])
# media_dtl_2_copy['reg_dt'] = pd.to_datetime(media_dtl_2_copy['reg_dt'])
# media_dtl_2_copy = media_dtl_2_copy.sort_values(['acnt_id', 'reg_dt'])

# # 게시물 간격 계산
# media_dtl_2_copy['prev_reg_dt'] = media_dtl_2_copy.groupby('acnt_id')['reg_dt'].shift(1)
# media_dtl_2_copy['gap_days'] = (media_dtl_2_copy['reg_dt'] - media_dtl_2_copy['prev_reg_dt']).dt.days
# # media_dtl_2_copy

# # gap_days가 NaN인 첫 번째 포스트 제외 후 평균 간격 계산
# activity_df = media_dtl_2_copy.dropna(subset=['gap_days']).groupby('acnt_id')['gap_days'].mean().reset_index()
# activity_df.rename(columns={'gap_days': 'avg_upload_interval'}, inplace=True)

# # 활동성 점수 계산 (간격의 역수로 환산) -> 점수 정규화 (업로드 간격이 짧을수록 점수가 높아지도록 역수를 취해서 계산한 것)
# activity_df['activity_score'] = 100 / activity_df['avg_upload_interval']
# activity_df

# %%
def calculate_activity_score(recent_media_dtl_df): # 두 개의 테이블 중 가장 최근
    media_dtl_copy = recent_media_dtl_df.copy()
    media_dtl_copy = media_dtl_copy.drop_duplicates(subset=['acnt_id', 'media_id', 'media_cn'])
    media_dtl_copy['reg_dt'] = pd.to_datetime(media_dtl_copy['reg_dt'])
    media_dtl_copy = media_dtl_copy.sort_values(['acnt_id', 'reg_dt'])

    # 게시물 간격 계산
    media_dtl_copy['prev_reg_dt'] = media_dtl_copy.groupby('acnt_id')['reg_dt'].shift(1)
    media_dtl_copy['gap_days'] = (media_dtl_copy['reg_dt'] - media_dtl_copy['prev_reg_dt']).dt.days

    # gap_days가 NaN인 첫 번째 포스트 제외 후 평균 간격 계산
    activity_df = media_dtl_copy.dropna(subset=['gap_days']).groupby('acnt_id')['gap_days'].mean().reset_index()
    activity_df.rename(columns={'gap_days': 'avg_upload_interval'}, inplace=True)

    # 활동성 점수 계산 (간격의 역수로 환산) -> 점수 정규화 (업로드 간격이 짧을수록 점수가 높아지도록 역수를 취해서 계산한 것)
    # 업로드 간격이 너무 짧은 유저의 경우 inf로 계산되는 것을 방지하기 위해서 scaling 진행
    activity_df['avg_upload_interval'] = activity_df['avg_upload_interval'].replace(0, 0.1)
    activity_df['activity_score'] = activity_df['avg_upload_interval'] / 100
    # activity_df['activity_score'] = 100 / activity_df['avg_upload_interval']

    return activity_df

# %%
activity_df = calculate_activity_score(media_info)

# %%
activity_df
# Out:
#                acnt_id  avg_upload_interval  activity_score
# 0    17841400006499942             4.632653        0.046327
# 1    17841400011995621             1.489796        0.014898
# 2    17841400016295781             0.795918        0.007959
# 3    17841400025364370            22.448980        0.224490
# 4    17841400028316253             2.040816        0.020408
# ..                 ...                  ...             ...
# 757  17841472755802463             4.130435        0.041304
# 758  17841473211163104             0.591837        0.005918
# 759  17841473347851502             2.256410        0.022564
# 760  17841473857435791             0.530612        0.005306
# 761  17841474495202295             2.166667        0.021667
#
# [762 rows x 3 columns]

# %%
def check_inf(df):
    float_cols = df.select_dtypes(include=['float64', 'float32']).columns

    mask_inf = np.isinf(df[float_cols]).any(axis=1)
    mask_neginf = np.isneginf(df[float_cols]).any(axis=1)

    invalid_rows = df[mask_inf | mask_neginf]

    print(f"⚠️ inf / -inf 포함 행 개수: {len(invalid_rows)}개")
    display(invalid_rows)

# %%
check_inf(activity_df)
# Out:
# ⚠️ inf / -inf 포함 행 개수: 0개
# Empty DataFrame
# Columns: [acnt_id, avg_upload_interval, activity_score]
# Index: []

# %% [markdown]
# 트렌드지수 - 팔로워 순증감률 (follower_growth_rate)

# %%
# time_series_profile_info_2['acnt_id'] = time_series_profile_info_2['acnt_id'].astype(object)

# influencer_list = time_series_profile_info['acnt_id'].unique()
# time_series_profile_info_2[time_series_profile_info_2['acnt_id'].isin(influencer_list)]
# time_series_merged_df = pd.merge(time_series_profile_info, time_series_profile_info_2, on='acnt_id')

# time_series_merged_df['follow_growth_rate'] = ((time_series_merged_df['follower_cnt_y'] - time_series_merged_df['follower_cnt_x']) / (time_series_merged_df['follower_cnt_x'])) * 100
# time_series_merged_df[['acnt_id', 'follow_growth_rate']]

# %%
def calculate_follower_growth_rate(time_series_df, recent_time_series_df):
    time_series_df.loc[:, 'acnt_id'] = time_series_df['acnt_id'].astype(object)
    recent_time_series_df.loc[:, 'acnt_id'] = recent_time_series_df['acnt_id'].astype(object)

    influencer_list = time_series_df['acnt_id'].unique()
    recent_time_series_df = recent_time_series_df[recent_time_series_df['acnt_id'].isin(influencer_list)]
    time_series_merged_df = pd.merge(time_series_df, recent_time_series_df, on='acnt_id')

    time_series_merged_df['follow_growth_rate'] = ((time_series_merged_df['follower_cnt_y'] - time_series_merged_df['follower_cnt_x']) / (time_series_merged_df['follower_cnt_x'])) * 100
    growth_rate_df = time_series_merged_df[['acnt_id', 'follow_growth_rate']]

    return growth_rate_df

# %%
growth_rate_df = calculate_follower_growth_rate(timeseries, timeseries_2)

# %%
growth_rate_df
# Out:
#                acnt_id  follow_growth_rate
# 0    17841407273326102            0.144928
# 1    17841401640546975            0.459348
# 2    17841401745190066            0.221595
# 3    17841405733424155           -0.044360
# 4    17841400385794614            0.127592
# ..                 ...                 ...
# 759  17841400149037869            0.445434
# 760  17841463079367585            0.608614
# 761  17841402057001317           -0.210637
# 762  17841407102497168            0.983607
# 763  17841441205793391            0.640000
#
# [764 rows x 2 columns]

# %% [markdown]
# ##### 팔로워 참여도
#
# - 26일 데이터를 기준으로 계산 진행
# - 단일 프소트 기준이 아닌 전체 포스트 평균을 측정
# - media_dtl & media_agg & user_data를 병합한 데이터
#
# ---------------------------------------------------------
#
# - 좋아요 비공개인 경우에는 각각의 중앙값으로 대체 -> 문제는 아예 없는 사람은 어떻게 해야하는건지...
# - estimated_total_engagement = avg_engagement_per_post * total_post_count
# - avg_engagement_per_post = like+comments / 25
# - total_post_count -> user_data

# %%
# media_engagement_merged_df = pd.merge(media_dtl, media_agg, on='media_id')


# # 해당 부분 수정 -> dic에 자동으로 median 값이 들어갈 수 있도록 수정
# media_engagement_merged_df.groupby(['acnt_id'])['like_cnt'].median()
# fillna_dict = {
#     '17841400591698216': 810,
#     '17841401506106699': 791,
#     '17841401839008777': 480,
#     '17841402936102997': 96,
#     '17841406083664639': 83,
#     '17841400361359004' : 0,
#     '17841401473518226' : 0
# }

# for acnt_id, default_like in fillna_dict.items():
#     condition = media_engagement_merged_df['acnt_id'] == acnt_id
#     media_engagement_merged_df.loc[condition, 'like_cnt'] = (
#         media_engagement_merged_df.loc[condition, 'like_cnt'].fillna(default_like)
#     )

# media_engagement_merged_df = pd.merge(media_engagement_merged_df, user_info_2,  on='acnt_id', how = 'left')
# media_engagement_merged_df_2 = media_engagement_merged_df[['acnt_id', 'media_id', 'follower_cnt', 'follow_cnt', 'like_cnt', 'cmnt_cnt', 'media_cnt']]

# engaged_df = media_engagement_merged_df_2.groupby(['acnt_id']).agg({
#     'like_cnt' : 'sum',
#     'cmnt_cnt' : 'sum',
#     'media_cnt': 'first',
#     'follower_cnt' : 'first',
#     'follow_cnt' : 'first'
# }).reset_index()

# engaged_df['avg_engagement_per_post'] = ((engaged_df['like_cnt'] + engaged_df['cmnt_cnt']) / 25)
# engaged_df['estimated_total_engagement'] = engaged_df['avg_engagement_per_post'] * engaged_df['media_cnt']
# engaged_df['follower_total_engagement'] = (engaged_df['estimated_total_engagement'] / engaged_df['follower_cnt']) * 100
# engaged_df

# %%
def calculate_follower_engagement(media_engagement_profile_merged_df):
    media_engagement_profile_merged_df_copy = media_engagement_profile_merged_df[['acnt_id', 'media_id', 'follower_cnt', 'follow_cnt', 'like_cnt', 'cmnt_cnt', 'media_cnt']]
    
    engaged_df = media_engagement_profile_merged_df_copy.groupby(['acnt_id']).agg({
        'like_cnt' : 'sum',
        'cmnt_cnt' : 'sum',
        'media_cnt': 'first',
        'follower_cnt' : 'first',
        'follow_cnt' : 'first'
    }).reset_index()

    # engaged_df['avg_engagement_per_post'] = ((engaged_df['like_cnt'] + engaged_df['cmnt_cnt']) / 25)
    # engaged_df['estimated_total_engagement'] = engaged_df['avg_engagement_per_post'] * engaged_df['media_cnt']
    # engaged_df['follower_total_engagement'] = (engaged_df['estimated_total_engagement'] / engaged_df['follower_cnt']) * 100

    engaged_df['avg_engagement_per_post'] = ((engaged_df['like_cnt'] + engaged_df['cmnt_cnt']) / engaged_df['media_cnt']*engaged_df['follower_cnt'])
    engaged_df['follower_total_engagement'] = engaged_df['avg_engagement_per_post'] * 100
    
    follower_engagment_df = engaged_df

    return follower_engagment_df

# %%
follower_engagment_df = calculate_follower_engagement(media_engagement_profile_merged_df)

# %%
check_inf(follower_engagment_df)
# Out:
# ⚠️ inf / -inf 포함 행 개수: 0개
# Empty DataFrame
# Columns: [acnt_id, like_cnt, cmnt_cnt, media_cnt, follower_cnt, follow_cnt, avg_engagement_per_post, follower_total_engagement]
# Index: []

# %% [markdown]
# ##### 팔로워 충성도
#
# - user_info or time_series 데이터가 필요
# - 트렌드 지수는 time_series 데이터를 가지고 단순히 빼기를 진행했었음

# %%
# time_series_merged_df_copy = time_series_merged_df[['acnt_id', 'follower_cnt_x', 'follower_cnt_y']]

# time_series_merged_df_copy['follower_change'] = (time_series_merged_df_copy['follower_cnt_y'] - time_series_merged_df_copy['follower_cnt_x'])

# def estimate_new_follower(row):
#     if row['follower_change'] < 0:
#         return 0
#     else:
#         return row['follower_change']

# time_series_merged_df_copy['new_follower'] = time_series_merged_df_copy.apply(estimate_new_follower, axis=1)

# # 충성도 계산
# # time_series_merged_df_copy = time_series_merged_time_series_merged_df_copy_copy.copy()
# time_series_merged_df_copy['unfollowed'] = time_series_merged_df_copy['follower_cnt_x'] + time_series_merged_df_copy['new_follower'] - time_series_merged_df_copy['follower_cnt_y']
# time_series_merged_df_copy['follower_retention_rate'] = ((time_series_merged_df_copy['follower_cnt_x'] - time_series_merged_df_copy['unfollowed']) / time_series_merged_df_copy['follower_cnt_x']) * 100
# time_series_merged_df_copy['follower_retention_rate'] = time_series_merged_df_copy['follower_retention_rate'].round(2)

# time_series_merged_df_copy

# %%
# def estimate_loyalty(row):
#     if row['follower_change'] < 0:
#         return ((row['follower_cnt_x'] + row['follower_change']) / row['follower_cnt_x']) * 100
#     else:
#         return 100.0

# time_series_merged_df_copy['follower_loyalty'] = time_series_merged_df_copy.apply(estimate_loyalty, axis=1)
# time_series_merged_df_copy['follower_loyalty'] = time_series_merged_df_copy['follower_loyalty'].round(2)

# %%
def calculate_follower_loyalty(time_series_merged_df):
    time_series_merged_df_copy = time_series_merged_df[['acnt_id', 'follower_cnt_x', 'follower_cnt_y']].copy()

    time_series_merged_df_copy.loc[:, 'follower_change'] = (time_series_merged_df_copy['follower_cnt_y'] - time_series_merged_df_copy['follower_cnt_x'])

    def estimate_new_follower(row):
        if row['follower_change'] < 0:
            return 0
        else:
            return row['follower_change']

    time_series_merged_df_copy.loc[:, 'new_follower'] = time_series_merged_df_copy.apply(estimate_new_follower, axis=1)
    time_series_merged_df_copy.loc[:, 'unfollowed'] = time_series_merged_df_copy['follower_cnt_x'] + time_series_merged_df_copy['new_follower'] - time_series_merged_df_copy['follower_cnt_y']
    time_series_merged_df_copy.loc[:, 'follower_retention_rate'] = ((time_series_merged_df_copy['follower_cnt_x'] - time_series_merged_df_copy['unfollowed']) / time_series_merged_df_copy['follower_cnt_x']) * 100
    time_series_merged_df_copy.loc[:, 'follower_retention_rate'] = time_series_merged_df_copy['follower_retention_rate'].round(2)

    follower_loyalty_df = time_series_merged_df_copy

    return follower_loyalty_df

# %%
follower_loyalty_df = calculate_follower_loyalty(time_series_merged_df)
follower_loyalty_df
# Out:
#                acnt_id  follower_cnt_x  follower_cnt_y  follower_change  \
# 0    17841407273326102            1380            1382                2
# 1    17841401640546975            2177            2187               10
# 2    17841401745190066           14892           14925               33
# 3    17841405733424155           49594           49572              -22
# 4    17841400385794614            3135            3139                4
# ..                 ...             ...             ...              ...
# 759  17841400149037869            1347            1353                6
# 760  17841463079367585            2136            2149               13
# 761  17841402057001317            5697            5685              -12
# 762  17841407102497168             305             308                3
# 763  17841441205793391            1250            1258                8
#
#      new_follower  unfollowed  follower_retention_rate
# 0               2           0                   100.00
# 1              10           0                   100.00
# 2              33           0                   100.00
# 3               0          22                    99.96
# 4               4           0                   100.00
# ..            ...         ...                      ...
# 759             6           0                   100.00
# 760            13           0                   100.00
# 761             0          12                    99.79
# 762             3           0                   100.00
# 763             8           0                   100.00
#
# [764 rows x 7 columns]

# %%
check_inf(follower_loyalty_df)
# Out:
# ⚠️ inf / -inf 포함 행 개수: 0개
# Empty DataFrame
# Columns: [acnt_id, follower_cnt_x, follower_cnt_y, follower_change, new_follower, unfollowed, follower_retention_rate]
# Index: []

# %% [markdown]
# 콘텐츠 효율성 평가
#
# - 콘텐츠 1개당 팔로워 대비 반응량(like+comments)
# - media_agg & media_dtl & acnt_id가 필요 -> 전부 병합한 게 media_engagement_merged_df

# %%
# media_engagement_merged_df_3 = media_engagement_profile_merged_df.copy()
# # media_engagment_merged_df_2 == media_engagement_profile_merged_df 같은 df임
# # media_engagement_profile_merged_df_copy = media_engagement_merged_df_2.copy()


# media_engagement_merged_df_3['post_efficiency'] = ((media_engagement_merged_df_3['like_cnt'] + media_engagement_merged_df_3['cmnt_cnt']) / media_engagement_merged_df_3['follower_cnt']) * 100
# post_efficiency_df = media_engagement_merged_df_3.groupby('acnt_id')['post_efficiency'].mean().reset_index()
# post_efficiency_df.rename(columns={'post_efficiency': 'avg_post_efficiency'}, inplace=True)
# post_efficiency_df

# %%
def calculate_post_efficiency_df(media_engagement_profile_merged_df):
    media_engagement_profile_merged_df_copy = media_engagement_profile_merged_df.copy()

    media_engagement_profile_merged_df_copy['post_efficiency'] = ((media_engagement_profile_merged_df_copy['like_cnt'] + media_engagement_profile_merged_df_copy['cmnt_cnt']) / media_engagement_profile_merged_df_copy['follower_cnt']) * 100
    post_efficiency_df = media_engagement_profile_merged_df_copy.groupby('acnt_id')['post_efficiency'].mean().reset_index()
    post_efficiency_df.rename(columns={'post_efficiency': 'avg_post_efficiency'}, inplace=True)

    return post_efficiency_df

# %%
post_efficiency_df = calculate_post_efficiency_df(media_engagement_profile_merged_df)

# %%
check_inf(post_efficiency_df)
# Out:
# ⚠️ inf / -inf 포함 행 개수: 0개
# Empty DataFrame
# Columns: [acnt_id, avg_post_efficiency]
# Index: []

# %% [markdown]
# 광고효율성

# %% [markdown]
# ##### not_connected_influencer_flexmatch_score

# %%
# # 크리에이터 활동성
# creator_activity_score = activity_df[['acnt_id', 'activity_score']]
# # 트렌드지수
# creator_follow_growth_rate = growth_rate_df[['acnt_id', 'follow_growth_rate']]
# # 팔로워 참여도
# follower_engagement = follower_engagment_df[['acnt_id', 'follower_total_engagement']]
# # 팔로워 충성도
# follower_loyalty = follower_loyalty_df[['acnt_id', 'follower_retention_rate']]
# # 콘텐츠 효율성
# post_efficiency = post_efficiency_df[['acnt_id', 'avg_post_efficiency']]

# # data_list
# df_list = [creator_activity_score, creator_follow_growth_rate, follower_engagement, follower_loyalty, post_efficiency]

# from functools import reduce

# flexmatch_score = reduce(lambda left, right: pd.merge(left, right, on='acnt_id', how='left'), df_list)
# user_info_nm = recent_user_info_mtr[['acnt_id', 'acnt_nm', 'influencer_scale_type']]
# # user_info_nm
# flexmatch_score = pd.merge(flexmatch_score, user_info_nm, on='acnt_id')
# flexmatch_score = flexmatch_score[['acnt_id', 'acnt_nm', 'activity_score', 'follow_growth_rate', 'follower_total_engagement', 'follower_retention_rate', 'avg_post_efficiency']]

# flexmatch_score.rename(columns={
#     'avg_upload_interval' : '크리에이터 활동성',
#     'follow_growth_rate' : '트렌드지수(팔로워순증가량)', 
#     'follower_total_engagement' : '콘텐츠 참여도' ,
#     'follower_retention_rate' : '팔로워 충성도',
#     'avg_post_efficiency' : '콘텐츠 효율성',
# }, inplace=True)

# flexmatch_score_2 = flexmatch_score.copy()
# flexmatch_score_2.dropna(inplace=True)
# flexmatch_score_2

# %%
def not_connected_user_flexmatch_score(activity_df, growth_rate_df, follower_engagement_df, follower_loyalty_df, post_efficiency_df):
    # 크리에이터 활동성
    creator_activity_score = activity_df[['acnt_id', 'activity_score']]
    # 트렌드지수
    creator_follow_growth_rate = growth_rate_df[['acnt_id', 'follow_growth_rate']]
    # 팔로워 참여도
    follower_engagement = follower_engagement_df[['acnt_id', 'follower_total_engagement']]
    # 팔로워 충성도
    follower_loyalty = follower_loyalty_df[['acnt_id', 'follower_retention_rate']]
    # 콘텐츠 효율성
    post_efficiency = post_efficiency_df[['acnt_id', 'avg_post_efficiency']]

    # data_list
    df_list = [creator_activity_score, creator_follow_growth_rate, follower_engagement, follower_loyalty, post_efficiency]

    from functools import reduce

    flexmatch_score = reduce(lambda left, right: pd.merge(left, right, on='acnt_id', how='left'), df_list)
    user_info_nm = recent_user_info_mtr[['acnt_id', 'acnt_nm', 'influencer_scale_type']]
    flexmatch_score = pd.merge(flexmatch_score, user_info_nm, on='acnt_id')
    flexmatch_score = flexmatch_score[['acnt_id', 'acnt_nm', 'influencer_scale_type', 'activity_score', 'follow_growth_rate', 'follower_total_engagement', 'follower_retention_rate', 'avg_post_efficiency']]


    not_connected_flexmatch_score_table = flexmatch_score.copy()
    not_connected_flexmatch_score_table.dropna(inplace=True)
    
    return not_connected_flexmatch_score_table

# %%
not_connected_flexmatch_score_table = not_connected_user_flexmatch_score(activity_df, growth_rate_df, follower_engagment_df, follower_loyalty_df, post_efficiency_df)
not_connected_flexmatch_score_table
# Out:
#                acnt_id        acnt_nm influencer_scale_type  activity_score  \
# 0    17841400006499942       kim__us_                 macro        0.046327
# 1    17841400011995621      aaari_678                 micro        0.014898
# 2    17841400016295781      jihyolimm                   mid        0.007959
# 3    17841400025364370          9_5jw                 micro        0.224490
# 4    17841400028316253      o_mango_l                 micro        0.020408
# ..                 ...            ...                   ...             ...
# 757  17841472755802463        huxa__0                  nano        0.041304
# 758  17841473211163104     mom._.room                   mid        0.005918
# 759  17841473347851502  hyepick_place                 micro        0.022564
# 760  17841473857435791     sesebonbon                 micro        0.005306
# 761  17841474495202295  susu_23.06.30                  nano        0.021667
#
#      follow_growth_rate  follower_total_engagement  follower_retention_rate  \
# 0             -0.027714               5.991792e+09                    99.97
# 1              0.140746               1.156609e+05                   100.00
# 2              2.073298               1.466264e+08                   100.00
# 3              0.000000               5.152235e+06                   100.00
# 4              1.080580               7.138825e+06                   100.00
# ..                  ...                        ...                      ...
# 757            0.405680               1.279683e+07                   100.00
# 758            5.108650               1.709889e+09                   100.00
# 759           -1.605403               2.957149e+08                    98.39
# 760            8.632138               2.024489e+07                   100.00
# 761            0.433526               1.832273e+06                   100.00
#
#      avg_post_efficiency
# 0               2.115871
# 1               1.446240
# 2               1.065379
# 3               6.669348
# 4               5.794136
# ..                   ...
# 757            12.512626
# 758             8.392283
# 759             3.744233
# 760            10.135697
# 761             3.209740
#
# [762 rows x 8 columns]

# %%
not_connected_flexmatch_score_table['influencer_scale_type'].value_counts()
# Out:
# influencer_scale_type
# micro    321
# mid      251
# nano     143
# macro     46
# mega       1
# Name: count, dtype: int64

# %%
nano = not_connected_flexmatch_score_table[not_connected_flexmatch_score_table['influencer_scale_type']=='nano']
micro = not_connected_flexmatch_score_table[not_connected_flexmatch_score_table['influencer_scale_type']=='micro']
mid = not_connected_flexmatch_score_table[not_connected_flexmatch_score_table['influencer_scale_type']=='mid']
macro = not_connected_flexmatch_score_table[not_connected_flexmatch_score_table['influencer_scale_type']=='macro']
mega = not_connected_flexmatch_score_table[not_connected_flexmatch_score_table['influencer_scale_type']=='mega']

# %%
# influencer_scale_df_list = [nano, micro, mid, macro, mega]


# for df in influencer_scale_df_list :
#     columns = df.select_dtypes(include='float64').columns
#     cleaned = df[columns].replace([np.inf, -np.inf], np.nan).dropna()
#     minmax = MinMaxScaler(feature_range=(0, 5))
#     flexmatch_score_norm = minmax.fit_transform(cleaned[columns])

#     flexmatch_score_norm_df = pd.DataFrame(flexmatch_score_norm, columns=columns, index=cleaned.index)
#     flexmatch_score_norm_df['acnt_id'] = df['acnt_id']
#     flexmatch_score_norm_df['acnt_nm'] = df['acnt_nm']

#     flexmatch_score_norm_df['크리에이터 활동성'] = 5 - flexmatch_score_norm_df['크리에이터 활동성']

# %%
# influencer_scale_df_list = [nano, micro, mid, macro, mega]
# normalized_df_list = []

# # 높을수록 안 좋은 지표
# reverse_columns = []  

# for df in influencer_scale_df_list:
#     cleaned = df.copy()

#     # 무한대 및 NaN 제거
#     float_cols = cleaned.select_dtypes(include='float64').columns
#     cleaned[float_cols] = cleaned[float_cols].replace([np.inf, -np.inf], np.nan)
#     cleaned = cleaned.dropna(subset=float_cols)

#     if cleaned.empty:
#         continue

#     # 개별 컬럼 정규화 (0~5 스케일)
#     norm_df = pd.DataFrame(index=cleaned.index)
#     for col in float_cols:
#         scaler = MinMaxScaler(feature_range=(0, 5))
#         norm_col = scaler.fit_transform(cleaned[[col]])
#         # norm_df[col] = 5 - norm_col.ravel() if col in reverse_columns else norm_col.ravel()
#         norm_df[col] = norm_col.ravel() if col in reverse_columns else norm_col.ravel()

#     # ID 및 이름 붙이기
#     norm_df['acnt_id'] = cleaned['acnt_id'].values
#     norm_df['acnt_nm'] = cleaned['acnt_nm'].values

#     normalized_df_list.append(norm_df)

# %%
# influencer_scale_names = ['nano', 'micro', 'mid', 'macro', 'mega']
# influencer_scale_df_list = [nano, micro, mid, macro, mega]
# normalized_df_dict = {}
# # normalized_df_list = []

# reverse_columns = []

# for name, df in zip(influencer_scale_names, influencer_scale_df_list):
#     cleaned = df.copy()

#     # 무한대 및 NaN 제거
#     float_cols = cleaned.select_dtypes(include='float64').columns
#     cleaned[float_cols] = cleaned[float_cols].replace([np.inf, -np.inf], np.nan)
#     cleaned = cleaned.dropna(subset=float_cols)

#     if cleaned.empty:
#         continue

#     norm_df = pd.DataFrame(index=cleaned.index)
#     for col in float_cols:
#         scaler = MinMaxScaler(feature_range=(0, 5))
#         norm_col = scaler.fit_transform(cleaned[[col]])
#         # norm_df[col] = 5 - norm_col.ravel() if col in reverse_columns else norm_col.ravel()
#         norm_df[col] = norm_col.ravel() if col in reverse_columns else norm_col.ravel()

#     # ID 및 이름 붙이기
#     norm_df['acnt_id'] = cleaned['acnt_id'].values
#     norm_df['acnt_nm'] = cleaned['acnt_nm'].values
#     norm_df['influencer_scale_type'] = name

#     # 딕셔너리에 저장
#     normalized_df_dict[name] = norm_df

# normalized_all_df = pd.concat(normalized_df_dict, ignore_index=True)
# normalized_all_dic = normalized_all_df.to_dict(orient='index')

# %%
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
import numpy as np

def normalize_influencer_scores(influencer_scale_names, influencer_scale_df_list, reverse_columns=None, feature_range=(0, 5)):

    if reverse_columns is None:
        reverse_columns = []

    normalized_df_dict = {}

    for name, df in zip(influencer_scale_names, influencer_scale_df_list):
        cleaned = df.copy()

        # 무한대 및 NaN 제거
        float_cols = cleaned.select_dtypes(include='float64').columns
        cleaned[float_cols] = cleaned[float_cols].replace([np.inf, -np.inf], np.nan)
        cleaned = cleaned.dropna(subset=float_cols)

        if cleaned.empty:
            continue

        norm_df = pd.DataFrame(index=cleaned.index)
        for col in float_cols:
            scaler = MinMaxScaler(feature_range=feature_range)
            norm_col = scaler.fit_transform(cleaned[[col]])
            if col in reverse_columns:
                norm_df[col] = feature_range[1] - norm_col.ravel()
            else:
                norm_df[col] = norm_col.ravel()

        # ID 및 이름, 스케일 타입 추가
        norm_df['acnt_id'] = cleaned['acnt_id'].values
        norm_df['acnt_nm'] = cleaned['acnt_nm'].values
        norm_df['influencer_scale_type'] = name

        normalized_df_dict[name] = norm_df

    normalized_all_df = pd.concat(normalized_df_dict.values(), ignore_index=True)
    normalized_all_dic = normalized_all_df.to_dict(orient='index')

    return normalized_all_df, normalized_all_dic

# %%
influencer_scale_names=['nano', 'micro', 'mid', 'macro', 'mega']
influencer_scale_df_list=[nano, micro, mid, macro, mega]

normalized_df, normalized_all_dic = normalize_influencer_scores(influencer_scale_names, influencer_scale_df_list, reverse_columns='activity_score')

# %%
normalized_all_dic
# Out:
# {0: {'activity_score': 4.837181044957473,
#   'follow_growth_rate': 0.9514551667255803,
#   'follower_total_engagement': 0.29737001397663027,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.5200913683034994,
#   'acnt_id': '17841400070132367',
#   'acnt_nm': 'gnuoyeatt',
#   'influencer_scale_type': 'nano'},
#  1: {'activity_score': 4.997974888618874,
#   'follow_growth_rate': 0.9793221751284218,
#   'follower_total_engagement': 0.005078808721981036,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.0614662641850769,
#   'acnt_id': '17841400111322589',
#   'acnt_nm': 'seon4123',
#   'influencer_scale_type': 'nano'},
#  2: {'activity_score': 4.441879303361685,
#   'follow_growth_rate': 0.8497609548487679,
#   'follower_total_engagement': 0.06812031355176908,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.21914030544789478,
#   'acnt_id': '17841400127762252',
#   'acnt_nm': 'hwaaaaa_a',
#   'influencer_scale_type': 'nano'},
#  3: {'activity_score': 4.733090319967598,
#   'follow_growth_rate': 0.7993577918972467,
#   'follower_total_engagement': 0.051206882551819335,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.13061455502777478,
#   'acnt_id': '17841400166779874',
#   'acnt_nm': 'lihanian',
#   'influencer_scale_type': 'nano'},
#  4: {'activity_score': 4.958282705548805,
#   'follow_growth_rate': 0.8111247135637379,
#   'follower_total_engagement': 0.00172028300150196,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.09615845163775678,
#   'acnt_id': '17841400204233993',
#   'acnt_nm': 'j_solha',
#   'influencer_scale_type': 'nano'},
#  5: {'activity_score': 4.944106925880924,
#   'follow_growth_rate': 0.6688236270117803,
#   'follower_total_engagement': 0.008935313862219192,
#   'follower_retention_rate': 4.332344213649833,
#   'avg_post_efficiency': 0.06071140446234353,
#   'acnt_id': '17841400290013501',
#   'acnt_nm': 'niica_bini',
#   'influencer_scale_type': 'nano'},
#  6: {'activity_score': 4.775212636695018,
#   'follow_growth_rate': 0.8230201034271459,
#   'follower_total_engagement': 0.030875104412953144,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.1442552533189538,
#   'acnt_id': '17841400297953515',
#   'acnt_nm': 'j.yyyyyul',
#   'influencer_scale_type': 'nano'},
#  7: {'activity_score': 4.967598217901984,
#   'follow_growth_rate': 0.7263656232325277,
#   'follower_total_engagement': 0.0015749976236356634,
#   'follower_retention_rate': 4.703264094955472,
#   'avg_post_efficiency': 0.018763453299990004,
#   'acnt_id': '17841400336698050',
#   'acnt_nm': 'hnpiano',
#   'influencer_scale_type': 'nano'},
#  8: {'activity_score': 4.9696233292831105,
#   'follow_growth_rate': 0.7458870683615387,
#   'follower_total_engagement': 0.004604824422715624,
#   'follower_retention_rate': 4.821958456973277,
#   'avg_post_efficiency': 0.10217728556446844,
#   'acnt_id': '17841400483419781',
#   'acnt_nm': 'hyeryeon_yoon',
#   'influencer_scale_type': 'nano'},
#  9: {'activity_score': 4.82057513163224,
#   'follow_growth_rate': 0.8584742641851505,
#   'follower_total_engagement': 0.01248868813412879,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.15975982618038173,
#   'acnt_id': '17841400532714000',
#   'acnt_nm': '2sarada90',
#   'influencer_scale_type': 'nano'},
#  10: {'activity_score': 4.6569461320372625,
#   'follow_growth_rate': 0.7723577235772358,
#   'follower_total_engagement': 0.03277026605614941,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.14342168240290057,
#   'acnt_id': '17841400582114307',
#   'acnt_nm': 'hhyun_jjin',
#   'influencer_scale_type': 'nano'},
#  11: {'activity_score': 4.51559335763467,
#   'follow_growth_rate': 0.8462709540829018,
#   'follower_total_engagement': 0.01715386917653325,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.23981297955492958,
#   'acnt_id': '17841400584148660',
#   'acnt_nm': 'jungseungmi_',
#   'influencer_scale_type': 'nano'},
#  12: {'activity_score': 4.22680403672202,
#   'follow_growth_rate': 0.810166715458635,
#   'follower_total_engagement': 0.16895947236913683,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.2792823653470488,
#   'acnt_id': '17841400587197476',
#   'acnt_nm': 'sm1112',
#   'influencer_scale_type': 'nano'},
#  13: {'activity_score': 4.683677602268125,
#   'follow_growth_rate': 0.7723577235772358,
#   'follower_total_engagement': 0.007554692173748805,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.2794593327670675,
#   'acnt_id': '17841400588709226',
#   'acnt_nm': 'seul90',
#   'influencer_scale_type': 'nano'},
#  14: {'activity_score': 4.229242608343458,
#   'follow_growth_rate': 1.0911085301329204,
#   'follower_total_engagement': 0.04816342002642316,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.4922171897662314,
#   'acnt_id': '17841400590387514',
#   'acnt_nm': 'kay.kwon.kr',
#   'influencer_scale_type': 'nano'},
#  15: {'activity_score': 4.90481976508708,
#   'follow_growth_rate': 0.6849844060442054,
#   'follower_total_engagement': 0.010507950649180076,
#   'follower_retention_rate': 4.436201780415416,
#   'avg_post_efficiency': 0.046461958951127175,
#   'acnt_id': '17841400593366620',
#   'acnt_nm': 'attraction_sa',
#   'influencer_scale_type': 'nano'},
#  16: {'activity_score': 4.739570676387201,
#   'follow_growth_rate': 0.7460689972633648,
#   'follower_total_engagement': 0.017817397027122442,
#   'follower_retention_rate': 4.8367952522254996,
#   'avg_post_efficiency': 0.05755653352392492,
#   'acnt_id': '17841400697997803',
#   'acnt_nm': 'cchaaeee',
#   'influencer_scale_type': 'nano'},
#  17: {'activity_score': 4.791413527744026,
#   'follow_growth_rate': 0.8888554802879428,
#   'follower_total_engagement': 0.020123151355009854,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.6280175602744028,
#   'acnt_id': '17841400718160676',
#   'acnt_nm': 'bbongslim',
#   'influencer_scale_type': 'nano'},
#  18: {'activity_score': 4.671121911705144,
#   'follow_growth_rate': 0.7400336981237016,
#   'follower_total_engagement': 0.002481315763589992,
#   'follower_retention_rate': 4.792284866468833,
#   'avg_post_efficiency': 0.10380155327146756,
#   'acnt_id': '17841400773895438',
#   'acnt_nm': 'ychlodel',
#   'influencer_scale_type': 'nano'},
#  19: {'activity_score': 4.9833940866747675,
#   'follow_growth_rate': 3.067363530778165,
#   'follower_total_engagement': 0.004638739088407195,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.2218699122952393,
#   'acnt_id': '17841400802104441',
#   'acnt_nm': 'huizhenzhen_',
#   'influencer_scale_type': 'nano'},
#  20: {'activity_score': 4.97974888618874,
#   'follow_growth_rate': 0.7723577235772358,
#   'follower_total_engagement': 0.00013457507713710717,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.05774819820296475,
#   'acnt_id': '17841400836205318',
#   'acnt_nm': 'naveraint',
#   'influencer_scale_type': 'nano'},
#  21: {'activity_score': 4.85176184690158,
#   'follow_growth_rate': 0.8118586841142569,
#   'follower_total_engagement': 0.010626582152858341,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.21462169448142712,
#   'acnt_id': '17841400872018393',
#   'acnt_nm': 'jiseon_37',
#   'influencer_scale_type': 'nano'},
#  22: {'activity_score': 4.901984609153503,
#   'follow_growth_rate': 0.8211876343687449,
#   'follower_total_engagement': 0.011483063369244446,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.12404369633644928,
#   'acnt_id': '17841400874732512',
#   'acnt_nm': 'andyjeon317',
#   'influencer_scale_type': 'nano'},
#  23: {'activity_score': 0.3274605103280681,
#   'follow_growth_rate': 0.7233714736903429,
#   'follower_total_engagement': 0.3757124854818697,
#   'follower_retention_rate': 4.688427299703278,
#   'avg_post_efficiency': 0.2676872369431338,
#   'acnt_id': '17841400971163589',
#   'acnt_nm': 'ga.hye.on',
#   'influencer_scale_type': 'nano'},
#  24: {'activity_score': 4.991899554475496,
#   'follow_growth_rate': 0.8171820557491289,
#   'follower_total_engagement': 0.0004227626580387732,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.03586635549884493,
#   'acnt_id': '17841401028212046',
#   'acnt_nm': 'kevinkim911',
#   'influencer_scale_type': 'nano'},
#  25: {'activity_score': 4.773997569866343,
#   'follow_growth_rate': 0.7723577235772358,
#   'follower_total_engagement': 0.0016877231365284126,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.18810115935148294,
#   'acnt_id': '17841401032620068',
#   'acnt_nm': 'insunkwak',
#   'influencer_scale_type': 'nano'},
#  26: {'activity_score': 4.901579586877278,
#   'follow_growth_rate': 0.7723577235772358,
#   'follower_total_engagement': 0.003335130728819076,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.06870880591881108,
#   'acnt_id': '17841401080128294',
#   'acnt_nm': 'yeonwoo_0523',
#   'influencer_scale_type': 'nano'},
#  27: {'activity_score': 3.039189396796134,
#   'follow_growth_rate': 0.8312040263259776,
#   'follower_total_engagement': 0.12427618728092897,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.5315374429256551,
#   'acnt_id': '17841401293139137',
#   'acnt_nm': '_movingday',
#   'influencer_scale_type': 'nano'},
#  28: {'activity_score': 4.899554475496152,
#   'follow_growth_rate': 0.7177147281676898,
#   'follower_total_engagement': 0.015521024977008082,
#   'follower_retention_rate': 4.643916913946583,
#   'avg_post_efficiency': 0.09486582253207328,
#   'acnt_id': '17841401374507119',
#   'acnt_nm': 'yeeeee_jini',
#   'influencer_scale_type': 'nano'},
#  29: {'activity_score': 4.813689752936411,
#   'follow_growth_rate': 0.7723577235772358,
#   'follower_total_engagement': 0.0008861272110837799,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.09728227808980329,
#   'acnt_id': '17841401443052146',
#   'acnt_nm': 'kyounghye0517',
#   'influencer_scale_type': 'nano'},
#  30: {'activity_score': 4.745240988254354,
#   'follow_growth_rate': 0.828676884490142,
#   'follower_total_engagement': 0.07398051164232683,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.36210026411817425,
#   'acnt_id': '17841401486674215',
#   'acnt_nm': 'minhee0216',
#   'influencer_scale_type': 'nano'},
#  31: {'activity_score': 4.840826245443499,
#   'follow_growth_rate': 0.7723577235772358,
#   'follower_total_engagement': 0.005350853176201733,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.17183992454105398,
#   'acnt_id': '17841401530775838',
#   'acnt_nm': 'touritst_genie',
#   'influencer_scale_type': 'nano'},
#  32: {'activity_score': 4.972053462940462,
#   'follow_growth_rate': 0.7165181662244151,
#   'follower_total_engagement': 0.004898753487033564,
#   'follower_retention_rate': 4.643916913946583,
#   'avg_post_efficiency': 0.022145006947246255,
#   'acnt_id': '17841401615883791',
#   'acnt_nm': 'rinaseong',
#   'influencer_scale_type': 'nano'},
#  33: {'activity_score': 4.718623980840685,
#   'follow_growth_rate': 0.7953768389954998,
#   'follower_total_engagement': 0.5350656352140357,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.38083092275055097,
#   'acnt_id': '17841401629705047',
#   'acnt_nm': 'soulvoice1987',
#   'influencer_scale_type': 'nano'},
#  34: {'activity_score': 4.654110976103686,
#   'follow_growth_rate': 0.7025299606806558,
#   'follower_total_engagement': 0.03973266973269555,
#   'follower_retention_rate': 4.554896142433222,
#   'avg_post_efficiency': 0.1533557607297906,
#   'acnt_id': '17841401639140025',
#   'acnt_nm': 'summerkim__',
#   'influencer_scale_type': 'nano'},
#  35: {'activity_score': 4.62089914945322,
#   'follow_growth_rate': 0.7111575687185443,
#   'follower_total_engagement': 0.0640303139608931,
#   'follower_retention_rate': 4.599406528189917,
#   'avg_post_efficiency': 0.4610663997478691,
#   'acnt_id': '17841401661602499',
#   'acnt_nm': 'uuuuuuu_jung',
#   'influencer_scale_type': 'nano'},
#  36: {'activity_score': 4.817334953422439,
#   'follow_growth_rate': 0.7723577235772358,
#   'follower_total_engagement': 0.01621993441378448,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.14926703208461298,
#   'acnt_id': '17841401674757443',
#   'acnt_nm': 'ou_ra27',
#   'influencer_scale_type': 'nano'},
#  37: {'activity_score': 4.479951397326853,
#   'follow_growth_rate': 0.7046584372291258,
#   'follower_total_engagement': 0.004175594901531763,
#   'follower_retention_rate': 4.569732937685444,
#   'avg_post_efficiency': 0.21902514564649103,
#   'acnt_id': '17841401681942874',
#   'acnt_nm': 'dangeenea',
#   'influencer_scale_type': 'nano'},
#  38: {'activity_score': 3.623565546105036,
#   'follow_growth_rate': 0.8398578943772631,
#   'follower_total_engagement': 0.16528924056130626,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.9053452237344305,
#   'acnt_id': '17841401738522234',
#   'acnt_nm': 'eunchong326',
#   'influencer_scale_type': 'nano'},
#  39: {'activity_score': 4.882543539894694,
#   'follow_growth_rate': 0.8636104395693204,
#   'follower_total_engagement': 0.0015289957556946499,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.07786301597419397,
#   'acnt_id': '17841401784692335',
#   'acnt_nm': 'totoro0550',
#   'influencer_scale_type': 'nano'},
#  40: {'activity_score': 4.315512353179425,
#   'follow_growth_rate': 0.7723577235772358,
#   'follower_total_engagement': 0.04335838255924567,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.48858842905304845,
#   'acnt_id': '17841401850643757',
#   'acnt_nm': 'michelle_ynoh',
#   'influencer_scale_type': 'nano'},
#  41: {'activity_score': 5.0,
#   'follow_growth_rate': 0.7723577235772358,
#   'follower_total_engagement': 0.0,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.003985240850071316,
#   'acnt_id': '17841401921070593',
#   'acnt_nm': 'hi_angsoo',
#   'influencer_scale_type': 'nano'},
#  42: {'activity_score': 4.655731065208586,
#   'follow_growth_rate': 0.7075270510574355,
#   'follower_total_engagement': 0.001045623263065557,
#   'follower_retention_rate': 4.584569732937666,
#   'avg_post_efficiency': 0.04947972092111155,
#   'acnt_id': '17841402048303273',
#   'acnt_nm': 'vvipsvip',
#   'influencer_scale_type': 'nano'},
#  43: {'activity_score': 4.989064398541919,
#   'follow_growth_rate': 0.7207265468123104,
#   'follower_total_engagement': 0.0017377542906407088,
#   'follower_retention_rate': 4.6735905044510275,
#   'avg_post_efficiency': 0.0021166602269841912,
#   'acnt_id': '17841402059097583',
#   'acnt_nm': 'zenyaluiah',
#   'influencer_scale_type': 'nano'},
#  44: {'activity_score': 4.720939651680842,
#   'follow_growth_rate': 0.8021243358625915,
#   'follower_total_engagement': 0.00620353097315143,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.051411909907087355,
#   'acnt_id': '17841402265949784',
#   'acnt_nm': 'soro_1217',
#   'influencer_scale_type': 'nano'},
#  45: {'activity_score': 4.677197245848522,
#   'follow_growth_rate': 0.9762287978209732,
#   'follower_total_engagement': 0.005345415459383274,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.14376846934180784,
#   'acnt_id': '17841402652660371',
#   'acnt_nm': 'ykl0422',
#   'influencer_scale_type': 'nano'},
#  46: {'activity_score': 4.840016200891049,
#   'follow_growth_rate': 0.841276816886573,
#   'follower_total_engagement': 0.007354609358120568,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.05216304441570744,
#   'acnt_id': '17841403245207523',
#   'acnt_nm': 'soulruka',
#   'influencer_scale_type': 'nano'},
#  47: {'activity_score': 4.770352369380316,
#   'follow_growth_rate': 0.6546651180797523,
#   'follower_total_engagement': 0.004217053731696621,
#   'follower_retention_rate': 4.243323442136472,
#   'avg_post_efficiency': 0.3861451840855603,
#   'acnt_id': '17841403690842921',
#   'acnt_nm': 'jisoocori',
#   'influencer_scale_type': 'nano'},
#  48: {'activity_score': 4.258824235332943,
#   'follow_growth_rate': 0.7723577235772358,
#   'follower_total_engagement': 0.051674535523540684,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.05020096303874816,
#   'acnt_id': '17841403918276288',
#   'acnt_nm': 'suhhahi',
#   'influencer_scale_type': 'nano'},
#  49: {'activity_score': 4.644795463750507,
#   'follow_growth_rate': 0.8824299445461052,
#   'follower_total_engagement': 0.10001604436104367,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.5427754678429525,
#   'acnt_id': '17841404564270314',
#   'acnt_nm': 'c.yeon.e',
#   'influencer_scale_type': 'nano'},
#  50: {'activity_score': 4.634669906844876,
#   'follow_growth_rate': 0.8964120915340428,
#   'follower_total_engagement': 0.028279473938430603,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.6545382550873424,
#   'acnt_id': '17841404803263661',
#   'acnt_nm': 'xoxojinam',
#   'influencer_scale_type': 'nano'},
#  51: {'activity_score': 4.974483596597813,
#   'follow_growth_rate': 0.7723577235772358,
#   'follower_total_engagement': 0.0005888186285349546,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.008404233788571391,
#   'acnt_id': '17841404867713313',
#   'acnt_nm': 'znzl5689',
#   'influencer_scale_type': 'nano'},
#  52: {'activity_score': 4.724179829890644,
#   'follow_growth_rate': 0.8309037900874635,
#   'follower_total_engagement': 0.00629662158842208,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.2923883206281207,
#   'acnt_id': '17841405446581360',
#   'acnt_nm': 'imsujini88',
#   'influencer_scale_type': 'nano'},
#  53: {'activity_score': 4.399630417172944,
#   'follow_growth_rate': 0.8476038156166105,
#   'follower_total_engagement': 0.027535312712333476,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.038747931304742814,
#   'acnt_id': '17841405735233010',
#   'acnt_nm': 'flex_h.y',
#   'influencer_scale_type': 'nano'},
#  54: {'activity_score': 4.593357634669907,
#   'follow_growth_rate': 0.662810907004399,
#   'follower_total_engagement': 0.004131500061217501,
#   'follower_retention_rate': 4.2878338278931665,
#   'avg_post_efficiency': 0.1548377374717793,
#   'acnt_id': '17841405960290513',
#   'acnt_nm': 'kjnon1026',
#   'influencer_scale_type': 'nano'},
#  55: {'activity_score': 4.6233292831105715,
#   'follow_growth_rate': 0.9131556258595014,
#   'follower_total_engagement': 0.0028314375311476857,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.2473366624986057,
#   'acnt_id': '17841406001951671',
#   'acnt_nm': 'gukja98',
#   'influencer_scale_type': 'nano'},
#  56: {'activity_score': 3.4350276765222088,
#   'follow_growth_rate': 0.6705836301315182,
#   'follower_total_engagement': 0.7840623027171476,
#   'follower_retention_rate': 4.3471810089020835,
#   'avg_post_efficiency': 0.7606401150153463,
#   'acnt_id': '17841406191877812',
#   'acnt_nm': 'hwangj_',
#   'influencer_scale_type': 'nano'},
#  57: {'activity_score': 4.017807013868522,
#   'follow_growth_rate': 0.7331938019526465,
#   'follower_total_engagement': 5.0,
#   'follower_retention_rate': 4.747774480712167,
#   'avg_post_efficiency': 4.999999999999999,
#   'acnt_id': '17841406281775348',
#   'acnt_nm': 'snr_1345',
#   'influencer_scale_type': 'nano'},
#  58: {'activity_score': 4.500607533414338,
#   'follow_growth_rate': 0.7107468294241907,
#   'follower_total_engagement': 0.005298000889235177,
#   'follower_retention_rate': 4.599406528189917,
#   'avg_post_efficiency': 0.05327603476917417,
#   'acnt_id': '17841406480562531',
#   'acnt_nm': 'gayoungmood',
#   'influencer_scale_type': 'nano'},
#  59: {'activity_score': 4.645605508302957,
#   'follow_growth_rate': 0.8739066530994007,
#   'follower_total_engagement': 0.002839896090968814,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.13330998934797406,
#   'acnt_id': '17841406696060527',
#   'acnt_nm': 'euni_j_',
#   'influencer_scale_type': 'nano'},
#  60: {'activity_score': 4.976913730255164,
#   'follow_growth_rate': 0.8272621687255833,
#   'follower_total_engagement': 0.0031945017500619117,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.1303385722198143,
#   'acnt_id': '17841406919372473',
#   'acnt_nm': '12styles',
#   'influencer_scale_type': 'nano'},
#  61: {'activity_score': 3.9844195686081885,
#   'follow_growth_rate': 0.99809599969536,
#   'follower_total_engagement': 0.2453713374366921,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.6542899964810678,
#   'acnt_id': '17841407102497168',
#   'acnt_nm': 'ohana.yyy',
#   'influencer_scale_type': 'nano'},
#  62: {'activity_score': 4.3831510733090315,
#   'follow_growth_rate': 2.3645866328793157,
#   'follower_total_engagement': 0.04118543004999439,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.22486245262584573,
#   'acnt_id': '17841407376200009',
#   'acnt_nm': 'sh851029',
#   'influencer_scale_type': 'nano'},
#  63: {'activity_score': 4.572701498582422,
#   'follow_growth_rate': 0.5951371979246544,
#   'follower_total_engagement': 0.012694215692074406,
#   'follower_retention_rate': 3.857566765578639,
#   'avg_post_efficiency': 0.30388331935930724,
#   'acnt_id': '17841407941247313',
#   'acnt_nm': 'itsmejoyelfin',
#   'influencer_scale_type': 'nano'},
#  64: {'activity_score': 4.745240988254354,
#   'follow_growth_rate': 0.8104807436304073,
#   'follower_total_engagement': 0.012138208932422814,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.1878651679041084,
#   'acnt_id': '17841408084939632',
#   'acnt_nm': 'sweet_potato36',
#   'influencer_scale_type': 'nano'},
#  65: {'activity_score': 4.731065208586473,
#   'follow_growth_rate': 0.6973575337994276,
#   'follower_total_engagement': 0.11432323036630217,
#   'follower_retention_rate': 4.5103857566765555,
#   'avg_post_efficiency': 0.3312231752569512,
#   'acnt_id': '17841411461566186',
#   'acnt_nm': 'dbbibbi',
#   'influencer_scale_type': 'nano'},
#  66: {'activity_score': 4.3029566626164435,
#   'follow_growth_rate': 0.8112561270891159,
#   'follower_total_engagement': 0.1588230695550925,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.7281666985505646,
#   'acnt_id': '17841411649994165',
#   'acnt_nm': 'seungje69',
#   'influencer_scale_type': 'nano'},
#  67: {'activity_score': 4.879708383961118,
#   'follow_growth_rate': 0.8970863000555471,
#   'follower_total_engagement': 0.018649509701989017,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.17751575528173225,
#   'acnt_id': '17841412336851729',
#   'acnt_nm': 'naegyeong2',
#   'influencer_scale_type': 'nano'},
#  68: {'activity_score': 4.843661401377076,
#   'follow_growth_rate': 0.7415522765007132,
#   'follower_total_engagement': 0.0021280525747437197,
#   'follower_retention_rate': 4.807121661721055,
#   'avg_post_efficiency': 0.07835827019182962,
#   'acnt_id': '17841412467476265',
#   'acnt_nm': 'yayasoraya1218',
#   'influencer_scale_type': 'nano'},
#  69: {'activity_score': 4.896807367883494,
#   'follow_growth_rate': 0.7723577235772358,
#   'follower_total_engagement': 0.028347513414491602,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.19285916895214852,
#   'acnt_id': '17841415107014253',
#   'acnt_nm': 'hongsyn',
#   'influencer_scale_type': 'nano'},
#  70: {'activity_score': 4.6634264884568655,
#   'follow_growth_rate': 0.7723577235772358,
#   'follower_total_engagement': 0.011910250596852608,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.05081446860325654,
#   'acnt_id': '17841416663433806',
#   'acnt_nm': 'wwwtable',
#   'influencer_scale_type': 'nano'},
#  71: {'activity_score': 4.932361279870393,
#   'follow_growth_rate': 0.7723577235772358,
#   'follower_total_engagement': 0.001922532480411937,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.023242259390440487,
#   'acnt_id': '17841418240434019',
#   'acnt_nm': '1209_1124',
#   'influencer_scale_type': 'nano'},
#  72: {'activity_score': 4.3766707168894285,
#   'follow_growth_rate': 0.8547143912997571,
#   'follower_total_engagement': 0.5862549907852701,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.7516340050087387,
#   'acnt_id': '17841421332213883',
#   'acnt_nm': 'mini_loggg',
#   'influencer_scale_type': 'nano'},
#  73: {'activity_score': 3.9341957925332953,
#   'follow_growth_rate': 1.071706307125183,
#   'follower_total_engagement': 0.05856613462859213,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.685380521716493,
#   'acnt_id': '17841427906920555',
#   'acnt_nm': 'jangeunyeong4486',
#   'influencer_scale_type': 'nano'},
#  74: {'activity_score': 4.85176184690158,
#   'follow_growth_rate': 0.8402573036719378,
#   'follower_total_engagement': 0.025476333490610577,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.17699649069695628,
#   'acnt_id': '17841430430382691',
#   'acnt_nm': 'b_ri_27',
#   'influencer_scale_type': 'nano'},
#  75: {'activity_score': 4.517618469015796,
#   'follow_growth_rate': 1.0392188639494369,
#   'follower_total_engagement': 0.02504746928177359,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.897119574219363,
#   'acnt_id': '17841431248109362',
#   'acnt_nm': 'woo.ah.___',
#   'influencer_scale_type': 'nano'},
#  76: {'activity_score': 4.7833130822195224,
#   'follow_growth_rate': 0.7723577235772358,
#   'follower_total_engagement': 0.007806251688223704,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.13895065097225082,
#   'acnt_id': '17841436609182687',
#   'acnt_nm': 'lovesome_nini',
#   'influencer_scale_type': 'nano'},
#  77: {'activity_score': 4.546960082804555,
#   'follow_growth_rate': 0.7482505197200832,
#   'follower_total_engagement': 0.11548491441163679,
#   'follower_retention_rate': 4.8367952522254996,
#   'avg_post_efficiency': 0.07352249196285622,
#   'acnt_id': '17841437265150835',
#   'acnt_nm': 'yam.made',
#   'influencer_scale_type': 'nano'},
#  78: {'activity_score': 4.446739570676387,
#   'follow_growth_rate': 0.7723577235772358,
#   'follower_total_engagement': 0.09465418507984795,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.12560568981102416,
#   'acnt_id': '17841438292231131',
#   'acnt_nm': 'charmin.grl',
#   'influencer_scale_type': 'nano'},
#  79: {'activity_score': 4.899149453219927,
#   'follow_growth_rate': 1.0529207806922638,
#   'follower_total_engagement': 0.0033116271032574353,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.1594513435837009,
#   'acnt_id': '17841439136122865',
#   'acnt_nm': 'cat._.0620',
#   'influencer_scale_type': 'nano'},
#  80: {'activity_score': 4.265615369714899,
#   'follow_growth_rate': 0.7723577235772358,
#   'follower_total_engagement': 0.25986883574733943,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.725329449510561,
#   'acnt_id': '17841439225730933',
#   'acnt_nm': 'review_ddook',
#   'influencer_scale_type': 'nano'},
#  81: {'activity_score': 0.0,
#   'follow_growth_rate': 0.8186280019482223,
#   'follower_total_engagement': 0.361020204272174,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.0652083392800484,
#   'acnt_id': '17841439266326958',
#   'acnt_nm': 'eunoia_sz1',
#   'influencer_scale_type': 'nano'},
#  82: {'activity_score': 4.370595382746051,
#   'follow_growth_rate': 0.7723577235772358,
#   'follower_total_engagement': 0.015402813404164481,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.33144428496892697,
#   'acnt_id': '17841439791628421',
#   'acnt_nm': 'kkochang_cos',
#   'influencer_scale_type': 'nano'},
#  83: {'activity_score': 4.376476643715404,
#   'follow_growth_rate': 0.7189854955027956,
#   'follower_total_engagement': 2.7314447990431296,
#   'follower_retention_rate': 4.658753709198805,
#   'avg_post_efficiency': 2.7170712005142903,
#   'acnt_id': '17841440869702644',
#   'acnt_nm': '_08080822_',
#   'influencer_scale_type': 'nano'},
#  84: {'activity_score': 4.985824220332118,
#   'follow_growth_rate': 0.7723577235772358,
#   'follower_total_engagement': 0.004832688523734585,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.3680566541603053,
#   'acnt_id': '17841443737382400',
#   'acnt_nm': 'kan__jung',
#   'influencer_scale_type': 'nano'},
#  85: {'activity_score': 3.956194309437019,
#   'follow_growth_rate': 1.1516975264203646,
#   'follower_total_engagement': 0.010115145038412413,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.4231721712151291,
#   'acnt_id': '17841444317992419',
#   'acnt_nm': 'sayhello_0123',
#   'influencer_scale_type': 'nano'},
#  86: {'activity_score': 4.940461725394897,
#   'follow_growth_rate': 1.1073950676941597,
#   'follower_total_engagement': 0.010519168646590187,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.39742213370423396,
#   'acnt_id': '17841445132536071',
#   'acnt_nm': 'smh_pomy1004',
#   'influencer_scale_type': 'nano'},
#  87: {'activity_score': 4.421628189550425,
#   'follow_growth_rate': 0.8077199085880359,
#   'follower_total_engagement': 0.14053474864544976,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.26089327840926047,
#   'acnt_id': '17841445166422975',
#   'acnt_nm': 'zoayo_o_o',
#   'influencer_scale_type': 'nano'},
#  88: {'activity_score': 4.657351154313488,
#   'follow_growth_rate': 0.7986464498911067,
#   'follower_total_engagement': 0.06900709901039902,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.25172833523471916,
#   'acnt_id': '17841445316242409',
#   'acnt_nm': 'cafe_mjj',
#   'influencer_scale_type': 'nano'},
#  89: {'activity_score': 4.744025921425679,
#   'follow_growth_rate': 0.7723577235772358,
#   'follower_total_engagement': 0.0030350488432473502,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.29158967500504634,
#   'acnt_id': '17841445530983804',
#   'acnt_nm': 'lucystory03',
#   'influencer_scale_type': 'nano'},
#  90: {'activity_score': 4.791008505467801,
#   'follow_growth_rate': 0.5548216281079534,
#   'follower_total_engagement': 0.001960691483222829,
#   'follower_retention_rate': 3.590504451038555,
#   'avg_post_efficiency': 0.03514301655562217,
#   'acnt_id': '17841445643835132',
#   'acnt_nm': 'zeppetto81',
#   'influencer_scale_type': 'nano'},
#  91: {'activity_score': 3.9649039392818777,
#   'follow_growth_rate': 0.7723577235772358,
#   'follower_total_engagement': 0.005060591866212774,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.5909720452928312,
#   'acnt_id': '17841445666937156',
#   'acnt_nm': '__moggu__',
#   'influencer_scale_type': 'nano'},
#  92: {'activity_score': 4.591332523288781,
#   'follow_growth_rate': 0.909372995648933,
#   'follower_total_engagement': 0.05895596467017834,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.4121787512792053,
#   'acnt_id': '17841445706534901',
#   'acnt_nm': 'gimpo_market',
#   'influencer_scale_type': 'nano'},
#  93: {'activity_score': 3.9622721749696233,
#   'follow_growth_rate': 1.0791766817591781,
#   'follower_total_engagement': 0.29594217105871246,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.315912579657904,
#   'acnt_id': '17841445756322288',
#   'acnt_nm': 'sxxngmi__',
#   'influencer_scale_type': 'nano'},
#  94: {'activity_score': 4.722559740785743,
#   'follow_growth_rate': 0.7000740761063403,
#   'follower_total_engagement': 0.013876054570485935,
#   'follower_retention_rate': 4.540059347181,
#   'avg_post_efficiency': 0.11827661617546613,
#   'acnt_id': '17841445793838858',
#   'acnt_nm': 'h_yubari',
#   'influencer_scale_type': 'nano'},
#  95: {'activity_score': 4.434183880113406,
#   'follow_growth_rate': 0.8220331739495502,
#   'follower_total_engagement': 0.4648966393701377,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.5528002943779233,
#   'acnt_id': '17841446006782306',
#   'acnt_nm': 'foto_nly',
#   'influencer_scale_type': 'nano'},
#  96: {'activity_score': 4.850546780072904,
#   'follow_growth_rate': 0.6614878778187367,
#   'follower_total_engagement': 0.0029861438405307072,
#   'follower_retention_rate': 4.2878338278931665,
#   'avg_post_efficiency': 0.14992902919850123,
#   'acnt_id': '17841448271359564',
#   'acnt_nm': 'soulmate.0817',
#   'influencer_scale_type': 'nano'},
#  97: {'activity_score': 3.3639125151883356,
#   'follow_growth_rate': 1.248280586821668,
#   'follower_total_engagement': 0.15895997024001718,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.5122037205446016,
#   'acnt_id': '17841448463686887',
#   'acnt_nm': 'fortune_hoya',
#   'influencer_scale_type': 'nano'},
#  98: {'activity_score': 4.444714459295261,
#   'follow_growth_rate': 0.7449710194340265,
#   'follower_total_engagement': 0.49519816939592554,
#   'follower_retention_rate': 4.821958456973277,
#   'avg_post_efficiency': 0.6093757309142036,
#   'acnt_id': '17841448917513240',
#   'acnt_nm': 'gini_mukmuk',
#   'influencer_scale_type': 'nano'},
#  99: {'activity_score': 1.1652490886998788,
#   'follow_growth_rate': 3.7658435590567083,
#   'follower_total_engagement': 0.0005359667081562262,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.13006061410658945,
#   'acnt_id': '17841449481118331',
#   'acnt_nm': 'april_plus2',
#   'influencer_scale_type': 'nano'},
#  100: {'activity_score': 4.972458485216687,
#   'follow_growth_rate': 0.7723577235772358,
#   'follower_total_engagement': 0.000760450145758579,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.06357423857789629,
#   'acnt_id': '17841449913495321',
#   'acnt_nm': 'goneemama',
#   'influencer_scale_type': 'nano'},
#  101: {'activity_score': 4.611735520453625,
#   'follow_growth_rate': 0.7723577235772358,
#   'follower_total_engagement': 0.44032841921025706,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.0628115842420738,
#   'acnt_id': '17841449982443435',
#   'acnt_nm': 'soli_beem',
#   'influencer_scale_type': 'nano'},
#  102: {'activity_score': 4.64277035236938,
#   'follow_growth_rate': 0.7396186963703751,
#   'follower_total_engagement': 0.13454923118386453,
#   'follower_retention_rate': 4.792284866468833,
#   'avg_post_efficiency': 0.7294326228906814,
#   'acnt_id': '17841450345136721',
#   'acnt_nm': '____yulbro____',
#   'influencer_scale_type': 'nano'},
#  103: {'activity_score': 4.902389631429728,
#   'follow_growth_rate': 1.6420441347270616,
#   'follower_total_engagement': 0.10392621347978621,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.7063307147078338,
#   'acnt_id': '17841450806092688',
#   'acnt_nm': 'iam.seun9a',
#   'influencer_scale_type': 'nano'},
#  104: {'activity_score': 4.77926285945727,
#   'follow_growth_rate': 0.7026007081607941,
#   'follower_total_engagement': 0.00896093748371714,
#   'follower_retention_rate': 4.554896142433222,
#   'avg_post_efficiency': 0.19485326367957193,
#   'acnt_id': '17841451635925488',
#   'acnt_nm': 'nanangmanssi',
#   'influencer_scale_type': 'nano'},
#  105: {'activity_score': 4.461401377075739,
#   'follow_growth_rate': 0.9384905121026391,
#   'follower_total_engagement': 0.8826195983839193,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.5764554343180318,
#   'acnt_id': '17841451732700545',
#   'acnt_nm': '172cm.dam',
#   'influencer_scale_type': 'nano'},
#  106: {'activity_score': 4.6318347509113,
#   'follow_growth_rate': 0.6934915446356231,
#   'follower_total_engagement': 0.15001179305863238,
#   'follower_retention_rate': 4.495548961424305,
#   'avg_post_efficiency': 1.275925455094801,
#   'acnt_id': '17841452448927260',
#   'acnt_nm': 'daylog_c',
#   'influencer_scale_type': 'nano'},
#  107: {'activity_score': 4.595787768327258,
#   'follow_growth_rate': 1.6550522648083623,
#   'follower_total_engagement': 0.000657457486169667,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.36114087093437997,
#   'acnt_id': '17841452550656938',
#   'acnt_nm': 'bab_soooni_',
#   'influencer_scale_type': 'nano'},
#  108: {'activity_score': 4.733900364520048,
#   'follow_growth_rate': 0.825238041715506,
#   'follower_total_engagement': 0.04989999089413366,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.5207615504093559,
#   'acnt_id': '17841452740446247',
#   'acnt_nm': '_pila_sun_',
#   'influencer_scale_type': 'nano'},
#  109: {'activity_score': 4.885446199540975,
#   'follow_growth_rate': 1.1098585775773724,
#   'follower_total_engagement': 0.009185134285714418,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.2378547282770076,
#   'acnt_id': '17841453655907894',
#   'acnt_nm': 'ninetys_90z',
#   'influencer_scale_type': 'nano'},
#  110: {'activity_score': 4.703928716079385,
#   'follow_growth_rate': 0.8423274128211665,
#   'follower_total_engagement': 0.011970825532214032,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.00552731970964546,
#   'acnt_id': '17841453878324566',
#   'acnt_nm': 'heesoo5985',
#   'influencer_scale_type': 'nano'},
#  111: {'activity_score': 4.737545565006076,
#   'follow_growth_rate': 1.18463421588878,
#   'follower_total_engagement': 0.0025726966314835033,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.12660256602794298,
#   'acnt_id': '17841454351752346',
#   'acnt_nm': 'rareyul',
#   'influencer_scale_type': 'nano'},
#  112: {'activity_score': 4.746434161987017,
#   'follow_growth_rate': 0.0,
#   'follower_total_engagement': 0.0680484633019058,
#   'follower_retention_rate': 0.0,
#   'avg_post_efficiency': 0.05734203524939158,
#   'acnt_id': '17841455388870972',
#   'acnt_nm': 'elie0723',
#   'influencer_scale_type': 'nano'},
#  113: {'activity_score': 4.611988659376266,
#   'follow_growth_rate': 0.3267255280042399,
#   'follower_total_engagement': 0.019900418293170512,
#   'follower_retention_rate': 2.12166172106825,
#   'avg_post_efficiency': 0.3810549556415987,
#   'acnt_id': '17841455470832799',
#   'acnt_nm': '9853du',
#   'influencer_scale_type': 'nano'},
#  114: {'activity_score': 4.794248683677602,
#   'follow_growth_rate': 0.7204345152695224,
#   'follower_total_engagement': 0.07969819741570187,
#   'follower_retention_rate': 4.658753709198805,
#   'avg_post_efficiency': 0.3920270266224918,
#   'acnt_id': '17841457700514314',
#   'acnt_nm': 'hi_kooing',
#   'influencer_scale_type': 'nano'},
#  115: {'activity_score': 4.762069663831511,
#   'follow_growth_rate': 0.7723577235772358,
#   'follower_total_engagement': 0.021664196183823356,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.3334243139626733,
#   'acnt_id': '17841458338153275',
#   'acnt_nm': 'lumisaga_mucin',
#   'influencer_scale_type': 'nano'},
#  116: {'activity_score': 4.866747671121912,
#   'follow_growth_rate': 0.7723577235772358,
#   'follower_total_engagement': 0.5131076279800365,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.5588543390931562,
#   'acnt_id': '17841458346986749',
#   'acnt_nm': 'meok_santa',
#   'influencer_scale_type': 'nano'},
#  117: {'activity_score': 4.9372215471850955,
#   'follow_growth_rate': 1.1477091406428082,
#   'follower_total_engagement': 0.12169495538163758,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.719241960798048,
#   'acnt_id': '17841458883844033',
#   'acnt_nm': 'poemyeony',
#   'influencer_scale_type': 'nano'},
#  118: {'activity_score': 4.401321845428772,
#   'follow_growth_rate': 3.6411149825783973,
#   'follower_total_engagement': 0.001160047762524189,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.055944503058133,
#   'acnt_id': '17841459626202227',
#   'acnt_nm': 'meowmoue',
#   'influencer_scale_type': 'nano'},
#  119: {'activity_score': 4.830109574945541,
#   'follow_growth_rate': 0.7032310426374487,
#   'follower_total_engagement': 0.20203246176331568,
#   'follower_retention_rate': 4.554896142433222,
#   'avg_post_efficiency': 1.1769655105271293,
#   'acnt_id': '17841460040181185',
#   'acnt_nm': 'kkudam_',
#   'influencer_scale_type': 'nano'},
#  120: {'activity_score': 4.909680032401782,
#   'follow_growth_rate': 0.7723577235772358,
#   'follower_total_engagement': 0.009132414276116009,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.23945882557839007,
#   'acnt_id': '17841460588103672',
#   'acnt_nm': 'yujiwon628',
#   'influencer_scale_type': 'nano'},
#  121: {'activity_score': 4.01349035735427,
#   'follow_growth_rate': 0.6668402152001816,
#   'follower_total_engagement': 0.30096821757295766,
#   'follower_retention_rate': 4.317507418397639,
#   'avg_post_efficiency': 1.0233828844312194,
#   'acnt_id': '17841461261981850',
#   'acnt_nm': 'doromi___',
#   'influencer_scale_type': 'nano'},
#  122: {'activity_score': 4.740834345889024,
#   'follow_growth_rate': 0.9649456234822088,
#   'follower_total_engagement': 0.22151727891652953,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.25483359818910817,
#   'acnt_id': '17841463336185919',
#   'acnt_nm': 'urizip_ganghazi',
#   'influencer_scale_type': 'nano'},
#  123: {'activity_score': 4.619177804779262,
#   'follow_growth_rate': 0.7723577235772358,
#   'follower_total_engagement': 0.0012013492605298856,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.2071047833982971,
#   'acnt_id': '17841463893430301',
#   'acnt_nm': 'mukyuding_',
#   'influencer_scale_type': 'nano'},
#  124: {'activity_score': 4.850643633225914,
#   'follow_growth_rate': 0.8511336666161693,
#   'follower_total_engagement': 0.3344430523434345,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.2709489892330895,
#   'acnt_id': '17841464003665583',
#   'acnt_nm': 'velyoung2m',
#   'influencer_scale_type': 'nano'},
#  125: {'activity_score': 4.971445929526124,
#   'follow_growth_rate': 2.2201417608301584,
#   'follower_total_engagement': 0.01431001629305606,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.03598882101305312,
#   'acnt_id': '17841464134128386',
#   'acnt_nm': 'it.tem___',
#   'influencer_scale_type': 'nano'},
#  126: {'activity_score': 4.847306601863102,
#   'follow_growth_rate': 0.8059595655567515,
#   'follower_total_engagement': 0.5004155878124676,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.050262737190786,
#   'acnt_id': '17841464546823475',
#   'acnt_nm': 'suhyun_mungo',
#   'influencer_scale_type': 'nano'},
#  127: {'activity_score': 4.866747671121912,
#   'follow_growth_rate': 0.7723577235772358,
#   'follower_total_engagement': 0.027449913653064463,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.32960931588950115,
#   'acnt_id': '17841465775699880',
#   'acnt_nm': 'beauty_dohyi',
#   'influencer_scale_type': 'nano'},
#  128: {'activity_score': 4.903511231579276,
#   'follow_growth_rate': 0.7723577235772358,
#   'follower_total_engagement': 0.0061878505920370105,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.0,
#   'acnt_id': '17841465781097624',
#   'acnt_nm': 'acong_mommy',
#   'influencer_scale_type': 'nano'},
#  129: {'activity_score': 4.954232482786553,
#   'follow_growth_rate': 0.7723577235772358,
#   'follower_total_engagement': 0.000871012406118827,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.18501570063945308,
#   'acnt_id': '17841466835485122',
#   'acnt_nm': 'kikikiki_eun',
#   'influencer_scale_type': 'nano'},
#  130: {'activity_score': 4.604293236127987,
#   'follow_growth_rate': 0.931733126855078,
#   'follower_total_engagement': 0.06651059258261005,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 2.026193645649384,
#   'acnt_id': '17841466979796967',
#   'acnt_nm': 'iseolriem',
#   'influencer_scale_type': 'nano'},
#  131: {'activity_score': 4.5575965501632005,
#   'follow_growth_rate': 0.8057153661237609,
#   'follower_total_engagement': 0.8631414302888866,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.1601620666768013,
#   'acnt_id': '17841466998593596',
#   'acnt_nm': 'nao_yim',
#   'influencer_scale_type': 'nano'},
#  132: {'activity_score': 4.736865127582017,
#   'follow_growth_rate': 1.4755628455608072,
#   'follower_total_engagement': 0.06841808725846737,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.3128686376577555,
#   'acnt_id': '17841467034456062',
#   'acnt_nm': 'hongsue_',
#   'influencer_scale_type': 'nano'},
#  133: {'activity_score': 4.924665856622115,
#   'follow_growth_rate': 0.7967726789729903,
#   'follower_total_engagement': 0.3701850723936227,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.2494129528361007,
#   'acnt_id': '17841467078397304',
#   'acnt_nm': 'hyunnn138_',
#   'influencer_scale_type': 'nano'},
#  134: {'activity_score': 4.952207371405427,
#   'follow_growth_rate': 1.0467605918295209,
#   'follower_total_engagement': 0.011898989039809358,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.046693012964464556,
#   'acnt_id': '17841467085828788',
#   'acnt_nm': 'ingyuking2',
#   'influencer_scale_type': 'nano'},
#  135: {'activity_score': 4.862292426083434,
#   'follow_growth_rate': 1.1703356092190154,
#   'follower_total_engagement': 0.01997931524523065,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.08283621252941918,
#   'acnt_id': '17841467436798662',
#   'acnt_nm': 'i_am_foodist',
#   'influencer_scale_type': 'nano'},
#  136: {'activity_score': 4.940056703118672,
#   'follow_growth_rate': 0.8187683566854447,
#   'follower_total_engagement': 0.14851379688814628,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.35700707598680886,
#   'acnt_id': '17841467581724114',
#   'acnt_nm': 'kooney2024',
#   'influencer_scale_type': 'nano'},
#  137: {'activity_score': 4.950497277350254,
#   'follow_growth_rate': 0.74783843076526,
#   'follower_total_engagement': 1.7870933562528781,
#   'follower_retention_rate': 4.8367952522254996,
#   'avg_post_efficiency': 1.023827500201744,
#   'acnt_id': '17841469380767019',
#   'acnt_nm': '_bbo_iing',
#   'influencer_scale_type': 'nano'},
#  138: {'activity_score': 4.989064398541919,
#   'follow_growth_rate': 1.0994369360049216,
#   'follower_total_engagement': 0.006163981583725312,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.0566647622283406,
#   'acnt_id': '17841469588134780',
#   'acnt_nm': 'review.cat',
#   'influencer_scale_type': 'nano'},
#  139: {'activity_score': 4.852369380315918,
#   'follow_growth_rate': 0.7723577235772358,
#   'follower_total_engagement': 0.006332962937865594,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.1695301083793965,
#   'acnt_id': '17841470993682107',
#   'acnt_nm': 'hi_losy',
#   'influencer_scale_type': 'nano'},
#  140: {'activity_score': 4.943045488191506,
#   'follow_growth_rate': 4.999999999999999,
#   'follower_total_engagement': 0.0008741919297348239,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.283908713985714,
#   'acnt_id': '17841472657326131',
#   'acnt_nm': 'min_of_travel',
#   'influencer_scale_type': 'nano'},
#  141: {'activity_score': 4.919242080053533,
#   'follow_growth_rate': 0.8654614074393424,
#   'follower_total_engagement': 0.883260729083934,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.5465652709586193,
#   'acnt_id': '17841472755802463',
#   'acnt_nm': 'huxa__0',
#   'influencer_scale_type': 'nano'},
#  142: {'activity_score': 4.958215201836101,
#   'follow_growth_rate': 0.8718521949876806,
#   'follower_total_engagement': 0.12642634345344209,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.13382030395204436,
#   'acnt_id': '17841474495202295',
#   'acnt_nm': 'susu_23.06.30',
#   'influencer_scale_type': 'nano'},
#  143: {'activity_score': 4.958660851226994,
#   'follow_growth_rate': 0.3483929044465239,
#   'follower_total_engagement': 0.00011238661691666024,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.1003375871811406,
#   'acnt_id': '17841400011995621',
#   'acnt_nm': 'aaari_678',
#   'influencer_scale_type': 'micro'},
#  144: {'activity_score': 4.3433665644171775,
#   'follow_growth_rate': 0.3203111699962251,
#   'follower_total_engagement': 0.006011815483598393,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.47095632143197935,
#   'acnt_id': '17841400025364370',
#   'acnt_nm': '9_5jw',
#   'influencer_scale_type': 'micro'},
#  145: {'activity_score': 4.942484662576687,
#   'follow_growth_rate': 0.5359093581539296,
#   'follower_total_engagement': 0.008338744037792058,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.40885340571756207,
#   'acnt_id': '17841400028316253',
#   'acnt_nm': 'o_mango_l',
#   'influencer_scale_type': 'micro'},
#  146: {'activity_score': 4.900546395705521,
#   'follow_growth_rate': 0.3495113594774212,
#   'follower_total_engagement': 0.00032303826808528807,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.060170434249841476,
#   'acnt_id': '17841400039750009',
#   'acnt_nm': 'bichon.mayo',
#   'influencer_scale_type': 'micro'},
#  147: {'activity_score': 3.560460179086972,
#   'follow_growth_rate': 0.30498699770211046,
#   'follower_total_engagement': 0.0009988099307019957,
#   'follower_retention_rate': 4.751552795031046,
#   'avg_post_efficiency': 0.032258447074435904,
#   'acnt_id': '17841400041215173',
#   'acnt_nm': 'bbbiiinnn111',
#   'influencer_scale_type': 'micro'},
#  148: {'activity_score': 4.8250575153374236,
#   'follow_growth_rate': 0.2817298146678934,
#   'follower_total_engagement': 0.0009719195574018226,
#   'follower_retention_rate': 4.409937888198726,
#   'avg_post_efficiency': 0.05294224587914513,
#   'acnt_id': '17841400079187566',
#   'acnt_nm': 'jjjjeong_2',
#   'influencer_scale_type': 'micro'},
#  149: {'activity_score': 4.028829562883436,
#   'follow_growth_rate': 0.3363627165182985,
#   'follower_total_engagement': 0.0012352531073947758,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.3277482482297288,
#   'acnt_id': '17841400082069836',
#   'acnt_nm': '1___ykkk',
#   'influencer_scale_type': 'micro'},
#  150: {'activity_score': 4.9730396855828225,
#   'follow_growth_rate': 0.34403539392837407,
# ...
#   'follower_retention_rate': 1.462882096069876,
#   'avg_post_efficiency': 0.030881569736430838,
#   'acnt_id': '17841468103686024',
#   'acnt_nm': 'twinkling.travel',
#   'influencer_scale_type': 'mid'},
#  713: {'activity_score': 4.748344370860927,
#   'follow_growth_rate': 0.09569815822144906,
#   'follower_total_engagement': 0.5500847848039228,
#   'follower_retention_rate': 4.1048034934497935,
#   'avg_post_efficiency': 0.9243459344650465,
#   'acnt_id': '17841469363262587',
#   'acnt_nm': 'comet_life_all',
#   'influencer_scale_type': 'mid'},
#  714: {'activity_score': 4.93023408301095,
#   'follow_growth_rate': 0.3750514600318132,
#   'follower_total_engagement': 0.2383414203831871,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.3859153342338522,
#   'acnt_id': '17841473211163104',
#   'acnt_nm': 'mom._.room',
#   'influencer_scale_type': 'mid'},
#  715: {'activity_score': 4.704966541600588,
#   'follow_growth_rate': 2.4011754169204655,
#   'follower_total_engagement': 0.4375953639009223,
#   'follower_retention_rate': 4.905660377358515,
#   'avg_post_efficiency': 2.832838400829658,
#   'acnt_id': '17841400006499942',
#   'acnt_nm': 'kim__us_',
#   'influencer_scale_type': 'macro'},
#  716: {'activity_score': 4.701050168259003,
#   'follow_growth_rate': 3.0589555955535643,
#   'follower_total_engagement': 0.10051182933240126,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.1790884334046048,
#   'acnt_id': '17841400214059012',
#   'acnt_nm': 'lovelink_8',
#   'influencer_scale_type': 'macro'},
#  717: {'activity_score': 4.886425173094032,
#   'follow_growth_rate': 2.4000331683794727,
#   'follower_total_engagement': 0.02534219209126827,
#   'follower_retention_rate': 4.905660377358515,
#   'avg_post_efficiency': 1.3896853813167591,
#   'acnt_id': '17841400313840086',
#   'acnt_nm': 'blondierona',
#   'influencer_scale_type': 'macro'},
#  718: {'activity_score': 4.94386531543728,
#   'follow_growth_rate': 2.6591214130708387,
#   'follower_total_engagement': 0.3657799743292513,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 3.8898127858779077,
#   'acnt_id': '17841400361359004',
#   'acnt_nm': 's_h_j_',
#   'influencer_scale_type': 'macro'},
#  719: {'activity_score': 4.9778072177310175,
#   'follow_growth_rate': 2.3994043072094193,
#   'follower_total_engagement': 0.0,
#   'follower_retention_rate': 4.905660377358515,
#   'avg_post_efficiency': 0.06022086445434721,
#   'acnt_id': '17841400417546279',
#   'acnt_nm': 'yooojung4',
#   'influencer_scale_type': 'macro'},
#  720: {'activity_score': 4.976501759950489,
#   'follow_growth_rate': 2.2345444284825673,
#   'follower_total_engagement': 0.0031254807105783548,
#   'follower_retention_rate': 4.559748427672957,
#   'avg_post_efficiency': 1.31490670271806,
#   'acnt_id': '17841400580612199',
#   'acnt_nm': 'jogood72',
#   'influencer_scale_type': 'macro'},
#  721: {'activity_score': 4.896868835338259,
#   'follow_growth_rate': 2.400942071244948,
#   'follower_total_engagement': 0.010756181406760294,
#   'follower_retention_rate': 4.905660377358515,
#   'avg_post_efficiency': 0.6398111371729557,
#   'acnt_id': '17841400591698216',
#   'acnt_nm': 'tingkerhee',
#   'influencer_scale_type': 'macro'},
#  722: {'activity_score': 4.9490871465593935,
#   'follow_growth_rate': 2.3269594038191146,
#   'follower_total_engagement': 0.007227346576975043,
#   'follower_retention_rate': 4.748427672955984,
#   'avg_post_efficiency': 0.5060228533040251,
#   'acnt_id': '17841401045868840',
#   'acnt_nm': 'soo_pple',
#   'influencer_scale_type': 'macro'},
#  723: {'activity_score': 4.9595308088036205,
#   'follow_growth_rate': 2.4101711322664587,
#   'follower_total_engagement': 0.04445202433856216,
#   'follower_retention_rate': 4.93710691823901,
#   'avg_post_efficiency': 2.077764914483143,
#   'acnt_id': '17841401061482770',
#   'acnt_nm': 'mina_lavu',
#   'influencer_scale_type': 'macro'},
#  724: {'activity_score': 4.526118825668201,
#   'follow_growth_rate': 2.2583018165799693,
#   'follower_total_engagement': 0.07274556044624479,
#   'follower_retention_rate': 4.622641509433947,
#   'avg_post_efficiency': 1.013326519798992,
#   'acnt_id': '17841401086862436',
#   'acnt_nm': 'julietmira5',
#   'influencer_scale_type': 'macro'},
#  725: {'activity_score': 4.690606506014776,
#   'follow_growth_rate': 2.3025536636907593,
#   'follower_total_engagement': 0.257034237500471,
#   'follower_retention_rate': 4.716981132075489,
#   'avg_post_efficiency': 4.411620127504806,
#   'acnt_id': '17841401131460799',
#   'acnt_nm': 'jeje9e',
#   'influencer_scale_type': 'macro'},
#  726: {'activity_score': 4.411238540981704,
#   'follow_growth_rate': 2.0093012060237125,
#   'follower_total_engagement': 0.15599861173189106,
#   'follower_retention_rate': 4.119496855345915,
#   'avg_post_efficiency': 3.625738154043523,
#   'acnt_id': '17841401175130753',
#   'acnt_nm': 'csheep',
#   'influencer_scale_type': 'macro'},
#  727: {'activity_score': 4.9386434843151665,
#   'follow_growth_rate': 0.4942110677222764,
#   'follower_total_engagement': 0.011314992311581841,
#   'follower_retention_rate': 1.0062893081761217,
#   'avg_post_efficiency': 1.6691513396646576,
#   'acnt_id': '17841401272625523',
#   'acnt_nm': 'oing0307',
#   'influencer_scale_type': 'macro'},
#  728: {'activity_score': 4.77546126174912,
#   'follow_growth_rate': 2.2093881872523915,
#   'follower_total_engagement': 0.004849229200657625,
#   'follower_retention_rate': 4.5283018867924625,
#   'avg_post_efficiency': 0.7770053511291641,
#   'acnt_id': '17841401306554824',
#   'acnt_nm': 'han_yejjin',
#   'influencer_scale_type': 'macro'},
#  729: {'activity_score': 0.0,
#   'follow_growth_rate': 2.913840203478514,
#   'follower_total_engagement': 3.851019051367504,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 4.919887814297787,
#   'acnt_id': '17841401400610794',
#   'acnt_nm': 'sun',
#   'influencer_scale_type': 'macro'},
#  730: {'activity_score': 4.994778168877887,
#   'follow_growth_rate': 0.0,
#   'follower_total_engagement': 0.0028702952397838856,
#   'follower_retention_rate': 0.0,
#   'avg_post_efficiency': 0.1650535581291533,
#   'acnt_id': '17841401409523807',
#   'acnt_nm': 'daitsoall',
#   'influencer_scale_type': 'macro'},
#  731: {'activity_score': 4.843345066336595,
#   'follow_growth_rate': 2.364644085140236,
#   'follower_total_engagement': 0.040470934554112103,
#   'follower_retention_rate': 4.842767295597525,
#   'avg_post_efficiency': 1.3817399608095307,
#   'acnt_id': '17841401478098195',
#   'acnt_nm': 'aquilina0113',
#   'influencer_scale_type': 'macro'},
#  732: {'activity_score': 4.795043128457046,
#   'follow_growth_rate': 2.466021512351012,
#   'follower_total_engagement': 1.7812241695453754,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.9713649899987817,
#   'acnt_id': '17841401500840763',
#   'acnt_nm': 'maycoco__',
#   'influencer_scale_type': 'macro'},
#  733: {'activity_score': 4.966058097706262,
#   'follow_growth_rate': 2.493444549361056,
#   'follower_total_engagement': 0.04381411364610644,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.9130099378865503,
#   'acnt_id': '17841401506106699',
#   'acnt_nm': 'siwolbubu_hyun',
#   'influencer_scale_type': 'macro'},
#  734: {'activity_score': 4.754573937260666,
#   'follow_growth_rate': 2.363287704713069,
#   'follower_total_engagement': 0.015197160208164374,
#   'follower_retention_rate': 4.842767295597525,
#   'avg_post_efficiency': 1.2174929760107738,
#   'acnt_id': '17841401566082143',
#   'acnt_nm': 'raon45',
#   'influencer_scale_type': 'macro'},
#  735: {'activity_score': 4.9386434843151665,
#   'follow_growth_rate': 2.408983619317998,
#   'follower_total_engagement': 0.01870671230364731,
#   'follower_retention_rate': 4.93710691823901,
#   'avg_post_efficiency': 1.3214134231850874,
#   'acnt_id': '17841401717699486',
#   'acnt_nm': 'cocoalla',
#   'influencer_scale_type': 'macro'},
#  736: {'activity_score': 4.9464762309983366,
#   'follow_growth_rate': 5.0,
#   'follower_total_engagement': 0.11110332133881919,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.9662693807309235,
#   'acnt_id': '17841401789715737',
#   'acnt_nm': '0.bbo.0',
#   'influencer_scale_type': 'macro'},
#  737: {'activity_score': 4.812014079603914,
#   'follow_growth_rate': 2.2752560385398377,
#   'follower_total_engagement': 0.0269104284044552,
#   'follower_retention_rate': 4.654088050314499,
#   'avg_post_efficiency': 1.8406640415071,
#   'acnt_id': '17841401844782267',
#   'acnt_nm': 'real2sseul',
#   'influencer_scale_type': 'macro'},
#  738: {'activity_score': 4.924283448729354,
#   'follow_growth_rate': 2.271439837340788,
#   'follower_total_engagement': 0.03408403936766124,
#   'follower_retention_rate': 4.654088050314499,
#   'avg_post_efficiency': 0.547231330962622,
#   'acnt_id': '17841401890726499',
#   'acnt_nm': 'rose_vine_',
#   'influencer_scale_type': 'macro'},
#  739: {'activity_score': 4.828985030750784,
#   'follow_growth_rate': 2.756505206834683,
#   'follower_total_engagement': 5.0,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 2.6718652473364406,
#   'acnt_id': '17841401942858884',
#   'acnt_nm': 'my_floria_',
#   'influencer_scale_type': 'macro'},
#  740: {'activity_score': 4.932116195412525,
#   'follow_growth_rate': 2.040033503527714,
#   'follower_total_engagement': 0.015595179722748502,
#   'follower_retention_rate': 4.182389937106905,
#   'avg_post_efficiency': 1.668860686228065,
#   'acnt_id': '17841401954250938',
#   'acnt_nm': 'raonjenanim',
#   'influencer_scale_type': 'macro'},
#  741: {'activity_score': 4.78329400843229,
#   'follow_growth_rate': 2.374794009652284,
#   'follower_total_engagement': 0.0948849708798421,
#   'follower_retention_rate': 4.8742138364779635,
#   'avg_post_efficiency': 1.7411716569855191,
#   'acnt_id': '17841402028598497',
#   'acnt_nm': 'stylecooca',
#   'influencer_scale_type': 'macro'},
#  742: {'activity_score': 5.0,
#   'follow_growth_rate': 2.98388360340983,
#   'follower_total_engagement': 0.0024676198096328095,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.47654869757131463,
#   'acnt_id': '17841402128645157',
#   'acnt_nm': 'icanddoit',
#   'influencer_scale_type': 'macro'},
#  743: {'activity_score': 4.9464762309983366,
#   'follow_growth_rate': 2.4261115948889587,
#   'follower_total_engagement': 0.01990081404315848,
#   'follower_retention_rate': 4.968553459119505,
#   'avg_post_efficiency': 1.7420538856206753,
#   'acnt_id': '17841402158404026',
#   'acnt_nm': 'tedseon',
#   'influencer_scale_type': 'macro'},
#  744: {'activity_score': 4.447791358836499,
#   'follow_growth_rate': 2.3866656465765876,
#   'follower_total_engagement': 0.0029931751209050696,
#   'follower_retention_rate': 4.8742138364779635,
#   'avg_post_efficiency': 0.0,
#   'acnt_id': '17841402171767176',
#   'acnt_nm': 'stylish_tasty',
#   'influencer_scale_type': 'macro'},
#  745: {'activity_score': 4.9934727110973585,
#   'follow_growth_rate': 2.4058786574874724,
#   'follower_total_engagement': 0.059084983325419886,
#   'follower_retention_rate': 4.93710691823901,
#   'avg_post_efficiency': 1.1145928306579291,
#   'acnt_id': '17841402337428788',
#   'acnt_nm': 'jjun2_mam',
#   'influencer_scale_type': 'macro'},
#  746: {'activity_score': 4.919061617607241,
#   'follow_growth_rate': 2.420645374005418,
#   'follower_total_engagement': 0.21345174844179687,
#   'follower_retention_rate': 4.93710691823901,
#   'avg_post_efficiency': 1.0225035599252075,
#   'acnt_id': '17841402891598966',
#   'acnt_nm': 'khyunee_',
#   'influencer_scale_type': 'macro'},
#  747: {'activity_score': 4.99216725331683,
#   'follow_growth_rate': 0.1264704005744064,
#   'follower_total_engagement': 0.011066912565380583,
#   'follower_retention_rate': 0.2515723270440162,
#   'avg_post_efficiency': 0.43550409404188933,
#   'acnt_id': '17841402997201103',
#   'acnt_nm': 'eunyi486',
#   'influencer_scale_type': 'macro'},
#  748: {'activity_score': 4.681468301551077,
#   'follow_growth_rate': 2.24910515857811,
#   'follower_total_engagement': 0.016421072157695803,
#   'follower_retention_rate': 4.591194968553509,
#   'avg_post_efficiency': 0.39819403299118716,
#   'acnt_id': '17841403843676453',
#   'acnt_nm': 'lily_ujoo',
#   'influencer_scale_type': 'macro'},
#  749: {'activity_score': 4.934727110973581,
#   'follow_growth_rate': 2.4062510847714016,
#   'follower_total_engagement': 0.012773000927845604,
#   'follower_retention_rate': 4.93710691823901,
#   'avg_post_efficiency': 0.979182060798373,
#   'acnt_id': '17841404452754986',
#   'acnt_nm': 'sylove7100',
#   'influencer_scale_type': 'macro'},
#  750: {'activity_score': 4.933421653193053,
#   'follow_growth_rate': 2.3782282710827896,
#   'follower_total_engagement': 0.05005033892186807,
#   'follower_retention_rate': 4.8742138364779635,
#   'avg_post_efficiency': 2.997215447638583,
#   'acnt_id': '17841404754372434',
#   'acnt_nm': 'bora_sunny_',
#   'influencer_scale_type': 'macro'},
#  751: {'activity_score': 4.960836266584149,
#   'follow_growth_rate': 2.3880684552785283,
#   'follower_total_engagement': 0.004525994869481692,
#   'follower_retention_rate': 4.8742138364779635,
#   'avg_post_efficiency': 0.4402978390268351,
#   'acnt_id': '17841404773656443',
#   'acnt_nm': 'honeyzam',
#   'influencer_scale_type': 'macro'},
#  752: {'activity_score': 4.989556337755773,
#   'follow_growth_rate': 2.2575941352026154,
#   'follower_total_engagement': 0.11168690863990947,
#   'follower_retention_rate': 4.622641509433947,
#   'avg_post_efficiency': 1.4191772101732296,
#   'acnt_id': '17841406889980629',
#   'acnt_nm': 'lilycoco__',
#   'influencer_scale_type': 'macro'},
#  753: {'activity_score': 4.968669013267319,
#   'follow_growth_rate': 2.373957708934632,
#   'follower_total_engagement': 0.03744337213231222,
#   'follower_retention_rate': 4.842767295597525,
#   'avg_post_efficiency': 0.840644277311175,
#   'acnt_id': '17841407300151686',
#   'acnt_nm': '2905_home',
#   'influencer_scale_type': 'macro'},
#  754: {'activity_score': 4.865537848605578,
#   'follow_growth_rate': 2.2009131454889936,
#   'follower_total_engagement': 0.036672643298883506,
#   'follower_retention_rate': 4.496855345911968,
#   'avg_post_efficiency': 1.1398809902720037,
#   'acnt_id': '17841416067859418',
#   'acnt_nm': 'dae_2l',
#   'influencer_scale_type': 'macro'},
#  755: {'activity_score': 4.660580977062623,
#   'follow_growth_rate': 2.4063254377774697,
#   'follower_total_engagement': 0.6407496380842457,
#   'follower_retention_rate': 4.93710691823901,
#   'avg_post_efficiency': 1.8347333515781878,
#   'acnt_id': '17841416105095031',
#   'acnt_nm': 'best_namnam',
#   'influencer_scale_type': 'macro'},
#  756: {'activity_score': 4.50262058561869,
#   'follow_growth_rate': 2.33254477852797,
#   'follower_total_engagement': 0.3390087797978274,
#   'follower_retention_rate': 4.7798742138365355,
#   'avg_post_efficiency': 2.953482611340737,
#   'acnt_id': '17841423469631536',
#   'acnt_nm': 'goodlovelov',
#   'influencer_scale_type': 'macro'},
#  757: {'activity_score': 4.93603256875411,
#   'follow_growth_rate': 2.2150198805743275,
#   'follower_total_engagement': 0.0906826000305747,
#   'follower_retention_rate': 4.5283018867924625,
#   'avg_post_efficiency': 0.8056680526903087,
#   'acnt_id': '17841431208327086',
#   'acnt_nm': 'vv_vid',
#   'influencer_scale_type': 'macro'},
#  758: {'activity_score': 4.9595308088036205,
#   'follow_growth_rate': 2.4477528805501403,
#   'follower_total_engagement': 0.0007508910090395578,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.04480385386261198,
#   'acnt_id': '17841437781952670',
#   'acnt_nm': 'neuel_s',
#   'influencer_scale_type': 'macro'},
#  759: {'activity_score': 4.37468572312691,
#   'follow_growth_rate': 2.013753109274805,
#   'follower_total_engagement': 0.46570069847937545,
#   'follower_retention_rate': 4.119496855345915,
#   'avg_post_efficiency': 2.747173476649892,
#   'acnt_id': '17841448810667457',
#   'acnt_nm': 'gum0070',
#   'influencer_scale_type': 'macro'},
#  760: {'activity_score': 4.8994797508993155,
#   'follow_growth_rate': 1.9676198753940903,
#   'follower_total_engagement': 0.2425875036403754,
#   'follower_retention_rate': 4.02515723270443,
#   'avg_post_efficiency': 5.0,
#   'acnt_id': '17841462888085401',
#   'acnt_nm': 'mr___choon',
#   'influencer_scale_type': 'macro'},
#  761: {'activity_score': 5.0,
#   'follow_growth_rate': 0.0,
#   'follower_total_engagement': 0.0,
#   'follower_retention_rate': 0.0,
#   'avg_post_efficiency': 0.0,
#   'acnt_id': '17841400290105756',
#   'acnt_nm': 'reel',
#   'influencer_scale_type': 'mega'}}

# %%
len(list(normalized_all_dic.keys()))
# Out:
# 762

# %%
ssh.insert_query_with_lookup('op_mem_seller_score', list(normalized_all_dic.values()))
# Out:
# ✅ inserted acnt_id: 17841400070132367
# ✅ inserted acnt_id: 17841400111322589
# ✅ inserted acnt_id: 17841400127762252
# ✅ inserted acnt_id: 17841400166779874
# ✅ inserted acnt_id: 17841400204233993
# ✅ inserted acnt_id: 17841400290013501
# ✅ inserted acnt_id: 17841400297953515
# ✅ inserted acnt_id: 17841400336698050
# ✅ inserted acnt_id: 17841400483419781
# ✅ inserted acnt_id: 17841400532714000
# ✅ inserted acnt_id: 17841400582114307
# ✅ inserted acnt_id: 17841400584148660
# ✅ inserted acnt_id: 17841400587197476
# ✅ inserted acnt_id: 17841400588709226
# ✅ inserted acnt_id: 17841400590387514
# ✅ inserted acnt_id: 17841400593366620
# ✅ inserted acnt_id: 17841400697997803
# ✅ inserted acnt_id: 17841400718160676
# ✅ inserted acnt_id: 17841400773895438
# ✅ inserted acnt_id: 17841400802104441
# ✅ inserted acnt_id: 17841400836205318
# ✅ inserted acnt_id: 17841400872018393
# ✅ inserted acnt_id: 17841400874732512
# ✅ inserted acnt_id: 17841400971163589
# ✅ inserted acnt_id: 17841401028212046
# ✅ inserted acnt_id: 17841401032620068
# ✅ inserted acnt_id: 17841401080128294
# ✅ inserted acnt_id: 17841401293139137
# ✅ inserted acnt_id: 17841401374507119
# ✅ inserted acnt_id: 17841401443052146
# ✅ inserted acnt_id: 17841401486674215
# ✅ inserted acnt_id: 17841401530775838
# ✅ inserted acnt_id: 17841401615883791
# ✅ inserted acnt_id: 17841401629705047
# ✅ inserted acnt_id: 17841401500840763
# ✅ inserted acnt_id: 17841401506106699
# ✅ inserted acnt_id: 17841401566082143
# ✅ inserted acnt_id: 17841401717699486
# ✅ inserted acnt_id: 17841401789715737
# ✅ inserted acnt_id: 17841401844782267
# ✅ inserted acnt_id: 17841401890726499
# ✅ inserted acnt_id: 17841401942858884
# ✅ inserted acnt_id: 17841401954250938
# ✅ inserted acnt_id: 17841402028598497
# ✅ inserted acnt_id: 17841402128645157
# ✅ inserted acnt_id: 17841402158404026
# ✅ inserted acnt_id: 17841402171767176
# ✅ inserted acnt_id: 17841402337428788
# ✅ inserted acnt_id: 17841402891598966
# ✅ inserted acnt_id: 17841402997201103
# ✅ inserted acnt_id: 17841403843676453
# ✅ inserted acnt_id: 17841404452754986
# ✅ inserted acnt_id: 17841404754372434
# ✅ inserted acnt_id: 17841404773656443
# ✅ inserted acnt_id: 17841406889980629
# ✅ inserted acnt_id: 17841407300151686
# ✅ inserted acnt_id: 17841416067859418
# ✅ inserted acnt_id: 17841416105095031
# ✅ inserted acnt_id: 17841423469631536
# ✅ inserted acnt_id: 17841431208327086
# ✅ inserted acnt_id: 17841437781952670
# ✅ inserted acnt_id: 17841448810667457
# ✅ inserted acnt_id: 17841462888085401
# ✅ inserted acnt_id: 17841400290105756

# %% [markdown]
# ##### 크리에이터 광고 효율성

# %%
revenue_dic = {
    'acnt_nm' : ['s_h_j_', 'siwolbubu_hyun', 'bong_camper83', 'binwoos', 'seojinii_', 'tingkerhee'],
    'sell_type' : ['flexmatch', 'other', 'flexmatch', 'flexmatch', 'other', 'other'],
    'total_revenue' : [6906000, 10937105, 7233100, 8759000, 7939664, 38449720],
    'total_order_cnt' : [84, 132, 122, 88, 89, 471]
    }

revenue_df = pd.DataFrame(revenue_dic)
revenue_merged_df = pd.merge(media_engagement_merged_df, revenue_df, on='acnt_nm', how='left')
revenue_merged_df = revenue_merged_df[['acnt_id', 'acnt_nm', 'follower_cnt', 'follow_cnt', 'media_cnt', 'sell_type', 'total_revenue', 'total_order_cnt', 'media_id', 'like_cnt', 'cmnt_cnt']]
revenue_merged_df

revenue_merged_df['post_efficiency'] = ((revenue_merged_df['like_cnt'] + revenue_merged_df['cmnt_cnt']) / revenue_merged_df['follower_cnt']) * 100
revenue_df_total = revenue_merged_df.groupby(['acnt_id', 'acnt_nm']).agg({
    'post_efficiency' : 'mean',
    'total_order_cnt' : 'first'
}).dropna()

revenue_df_total['advertisement_efficiency'] = (revenue_df_total['total_order_cnt'] / revenue_df_total['post_efficiency']) 
revenue_df_total.sort_values(by='advertisement_efficiency', ascending=False)

revenue_merged_df['engagement_per_post'] = ((revenue_merged_df['like_cnt'] + revenue_merged_df['cmnt_cnt']) / 25)
revenue_df_total = revenue_merged_df.groupby(['acnt_id', 'acnt_nm']).agg({
    'engagement_per_post' : 'mean',
    'total_revenue' : 'first',
    'total_order_cnt' : 'first'
}).dropna()

# 팔로워를 생각하지 않고, 25개의 콘텐츠 단위당 반응 비율을 계산
revenue_df_total['advertisement_efficiency'] = (revenue_df_total['total_order_cnt'] / revenue_df_total['engagement_per_post'] * 25) * 100
revenue_df_total.sort_values(by='advertisement_efficiency', ascending=False)
# Out:
#           acnt_nm  sell_type  total_revenue  total_order_cnt
# 0          s_h_j_  flexmatch        6906000               84
# 1  siwolbubu_hyun      other       10937105              132
# 2   bong_camper83  flexmatch        7233100              122
# 3         binwoos  flexmatch        8759000               88
# 4       seojinii_      other        7939664               89
# 5      tingkerhee      other       38449720              471

# %% [markdown]
# 콘텐츠 효율성이 아닌 팔로워 참여도를 기준으로 계산했을 때

# %%
engaged_df_2 = engaged_df.copy()
revenue_merged_df_2 = revenue_merged_df.groupby(['acnt_id', 'acnt_nm'])[['total_revenue', 'total_order_cnt']].first().dropna().reset_index()
revenue_df_total_2 = pd.merge(engaged_df_2, revenue_merged_df_2, on='acnt_id')

revenue_df_total_2['advertisement_efficiency'] = revenue_df_total_2['total_order_cnt'] / revenue_df_total_2['follower_total_engagement']
revenue_df_total_2[['acnt_id', 'acnt_nm', 'total_revenue', 'total_order_cnt', 'follower_total_engagement', 'advertisement_efficiency']].sort_values(by='advertisement_efficiency', ascending=False)

# %% [markdown]
# table merged

# %%
# 크리에이터 활동성
creator_activity_score = activity_df[['acnt_id', 'avg_upload_interval']]

# %%
# 트렌드지수
creator_follow_growth_rate = time_series_merged_df[['acnt_id', 'follow_growth_rate']]

# %%
# 팔로워 참여도
follower_engagement = engaged_df[['acnt_id', 'follower_total_engagement']]

# %%
# 팔로워 충성도
follower_loyalty = time_series_merged_df_copy[['acnt_id', 'follower_retention_rate']]

# %%
# 콘텐츠 효율성
post_efficiency = post_efficiency_df.copy()

# %%
# 광고효율성
revenue_df_total = revenue_df_total.reset_index()
advertisement_efficiency = revenue_df_total[['acnt_id', 'advertisement_efficiency']]

# %%
df_list = [creator_activity_score, creator_follow_growth_rate, follower_engagement, follower_loyalty, post_efficiency, advertisement_efficiency]

# %%
from functools import reduce

flexmatch_score = reduce(lambda left, right: pd.merge(left, right, on='acnt_id', how='left'), df_list)

# %%
user_info_nm = user_info_2[['acnt_id', 'acnt_nm']]
flexmatch_score = pd.merge(flexmatch_score, user_info_nm, on='acnt_id')

# %%
flexmatch_score = flexmatch_score[['acnt_id', 'acnt_nm', 'avg_upload_interval', 'follow_growth_rate', 'follower_total_engagement', 'follower_retention_rate', 'avg_post_efficiency', 'advertisement_efficiency']]
flexmatch_score.rename(columns={
    'avg_upload_interval' : '크리에이터 활동성',
    'follow_growth_rate' : '트렌드지수(팔로워순증가량)', 
    'follower_total_engagement' : '콘텐츠 참여도' ,
    'follower_retention_rate' : '팔로워 충성도',
    'avg_post_efficiency' : '콘텐츠 효율성',
    'advertisement_efficiency' : '광고 효율성'
}, inplace=True)

# %%
flexmatch_score_2 = flexmatch_score.copy()
flexmatch_score_2.dropna(inplace=True)

# %%
flexmatch_score_2
# Out:
#               acnt_id         acnt_nm  크리에이터 활동성  트렌드지수(팔로워순증가량)      콘텐츠 참여도  \
# 0   17841400361359004          s_h_j_   1.166667        0.057866   110.188904
# 1   17841400561503844         binwoos   0.500000       -0.014956   626.642600
# 2   17841400591698216      tingkerhee   2.416667       -0.018509  2065.579146
# 4   17841401506106699  siwolbubu_hyun   0.958333       -0.075045  2094.996055
# 6   17841402936102997       seojinii_   2.875000       -0.002312   166.809026
# 10  17841453615191128   bong_camper83   1.500000        0.281793  2526.578680
#
#     팔로워 충성도   콘텐츠 효율성       광고 효율성
# 0    100.00  0.045178  1859.316062
# 1     99.99  0.169730   518.470975
# 2     99.98  0.483403   974.343202
# 4     99.92  0.556736   237.096389
# 6    100.00  0.240359   370.279723
# 10   100.00  2.506526    48.672935

# %%
# from sklearn.preprocessing import MinMaxScaler

# columns = flexmatch_score_2.select_dtypes(include='float64').columns
# minmax = MinMaxScaler(feature_range=(0, 5))
# flexmatch_score_norm = minmax.fit_transform(flexmatch_score_2[columns])

# flexmatch_score_norm_df = pd.DataFrame(flexmatch_score_norm, columns=columns, index=flexmatch_score_2.index)
# flexmatch_score_norm_df['acnt_id'] = flexmatch_score_2['acnt_id']
# flexmatch_score_norm_df['acnt_nm'] = flexmatch_score_2['acnt_nm']

# flexmatch_score_norm_df['avg_upload_interval'] = 5 - flexmatch_score_norm_df['avg_upload_interval']
# flexmatch_score_norm_df

# %%
from sklearn.preprocessing import MinMaxScaler

columns = flexmatch_score_2.select_dtypes(include='float64').columns
minmax = MinMaxScaler(feature_range=(0, 5))
flexmatch_score_norm = minmax.fit_transform(flexmatch_score_2[columns])

flexmatch_score_norm_df = pd.DataFrame(flexmatch_score_norm, columns=columns, index=flexmatch_score_2.index)
flexmatch_score_norm_df['acnt_id'] = flexmatch_score_2['acnt_id']
flexmatch_score_norm_df['acnt_nm'] = flexmatch_score_2['acnt_nm']

flexmatch_score_norm_df['크리에이터 활동성'] = 5 - flexmatch_score_norm_df['크리에이터 활동성']
flexmatch_score_norm_df

# 지금 이거 정규화 할 때는 그냥 이사람들을 전부 다 합쳐서 함께 정규화를 진행해서 그런데, 원래라면은 팔로워를 기준으로 뭐 메가 인플루언서, 마이크로 인플루언서 이런식으로 기준을 나눠서 정규화를 해야 조금 더 정확한 값이 될 것 같음.
# Out:
#     크리에이터 활동성  트렌드지수(팔로워순증가량)   콘텐츠 참여도  팔로워 충성도   콘텐츠 효율성    광고 효율성  \
# 0    3.596491        1.862339  0.000000    5.000  0.000000  5.000000
# 1    5.000000        0.841960  1.068647    4.375  0.253016  1.297324
# 2    0.964912        0.792182  4.046099    3.750  0.890213  2.556192
# 4    4.035088        0.000000  4.106968    0.000  1.039182  0.520322
# 6    0.000000        1.019133  0.117159    5.000  0.396492  0.888101
# 10   2.894737        5.000000  5.000000    5.000  5.000000  0.000000
#
#               acnt_id         acnt_nm
# 0   17841400361359004          s_h_j_
# 1   17841400561503844         binwoos
# 2   17841400591698216      tingkerhee
# 4   17841401506106699  siwolbubu_hyun
# 6   17841402936102997       seojinii_
# 10  17841453615191128   bong_camper83

# %%
# flexmatch_score_norm_df.to_csv("flexmatch_score_test.csv")
