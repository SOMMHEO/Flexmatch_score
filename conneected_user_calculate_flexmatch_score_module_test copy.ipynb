# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from sklearn.preprocessing import MinMaxScaler

import os
from dotenv import load_dotenv
import boto3
import io
import pymysql
import json

# %% [markdown]
# DB Connection

# %%
from sshtunnel import SSHTunnelForwarder

class SSHMySQLConnector:
    def __init__(self):
        self.ssh_host = None
        self.ssh_username = None
        self.ssh_password = None
        self.db_username = None
        self.db_password = None
        self.db_name = None
        self.tunnel = None
        self.connection = None

    def load_config_from_json(self, json_path):
        try:
            with open(json_path, 'r', encoding='utf-8') as f:
                config = json.load(f)
                self.ssh_host = config['ssh_host']
                self.ssh_username = config['ssh_username']
                self.ssh_password = config['ssh_password']
                self.db_username = config['db_username']
                self.db_password = config['db_password']
                self.db_name = config['db_name']
        except Exception as e:
            print("❌ 설정 JSON 로딩 실패:", e)


    def connect(self):
        try:
            self.tunnel = SSHTunnelForwarder(
                (self.ssh_host, 22),
                ssh_username=self.ssh_username,
                ssh_password=self.ssh_password,
                remote_bind_address=('127.0.0.1', 3306),
            )
            self.tunnel.start()
            
            self.connection = pymysql.connect(
                host='127.0.0.1',
                port=self.tunnel.local_bind_port,
                user=self.db_username,
                password=self.db_password,
                db=self.db_name,
                cursorclass=pymysql.cursors.DictCursor  # 이 줄 추가
            )
            print("✅ DB 접속 성공")
        except Exception as e:
            print("❌ SSH 또는 DB 연결 실패:", e)

    def insert_query_with_lookup(self, table_name, data_list):
        try:
            with self.connection.cursor() as cursor:
                for data in data_list:
                    # 1. op_member에서 uid, user_id 조회
                    cursor.execute("""
                        SELECT uid, user_id FROM op_member
                        WHERE add1 = %s
                        LIMIT 1
                    """, (data['acnt_nm'],))
                    result = cursor.fetchone()
                    if result:
                        data['member_uid'] = result['uid']
                        data['user_id'] = result['user_id']
                        # 향후에 ig_user_id가 추가가 된다면, 해당 부분도 확인해서 추가할 수 있게
                        # data['ig_user_id'] = result['ig_user_id']
                    else:
                        data['member_uid'] = 0
                        data['user_id'] = 'None'
                        # data['ig_user_id'] = 'None'

                    # 2. INSERT 쿼리 구성 및 실행
                    columns = ', '.join(data.keys())
                    placeholders = ', '.join([f"%({k})s" for k in data.keys()])
                    insert_sql = f"INSERT INTO {table_name} ({columns}) VALUES ({placeholders})"
                    cursor.execute(insert_sql, data)

                    print(f"✅ inserted acnt_id: {data.get('acnt_id', 'N/A')}")

            self.connection.commit()
        except Exception as e:
            self.connection.rollback()
            print("❌ INSERT 실패:", e)

    def close(self):
        if self.connection:
            self.connection.close()
        if self.tunnel:
            self.tunnel.stop()

# %%
ssh = SSHMySQLConnector()
ssh.load_config_from_json('C:/Users/ehddl/Desktop/업무/code/config/ssh_db_config.json')
ssh.connect()

# data_list = [
#     {
#         'activity_score': 0.18618008163528707,
#         'trend_score': 1.2384506112322682,
#         'follower_total_engagement': 0.9006925508419993,
#         'follower_retention_rate': 4.84593837535013,
#         'avg_post_efficiency': 1.4776093002849746,
#         'acnt_id': '17841400070132367',
#         'acnt_nm': 'gnuoyeatt',
#         'influencer_scale_type': 'nano'
#     }
# ]

# ssh.insert_query_with_lookup('op_mem_seller_score', data_list)
# Out:
# ✅ DB 접속 성공

# %% [markdown]
# Data Loading

# %%
def load_s3_instagram_data():

    load_dotenv()
    aws_access_key = os.getenv("aws_accessKey")
    aws_secret_key = os.getenv("aws_secretKey")
    region_name='ap-northeast-2'

    # S3 클라이언트 생성
    client = boto3.client('s3', aws_access_key_id=aws_access_key, aws_secret_access_key=aws_secret_key, region_name=region_name)

    today = datetime.now()
    year, week, _ = today.isocalendar()

    bucket_name = 'flexmatch-data'

    table_list = ['RECENT_USER_INFO_MTR', 'TIME_SERIES_PROFILE_INFO', 'BY_USER_ID_MEDIA_DTL_INFO', 'BY_DATE_MEDIA_AGG_INFO']
    df_by_table_list = {}

    for table_name in table_list:
        prefix = f'instagram-data/tables/{table_name}/year={year}/week=25/' # 이번주가 없어서 week를 따로 x
        response = client.list_objects_v2(Bucket=bucket_name, Prefix=prefix)

        if 'Contents' in response:
            files = [content['Key'] for content in response['Contents'] if content['Key'].endswith('merged_data.parquet')]

            if not files:
                print(f"[Info] No merged_data.parquet found for table: {table_name}")
                continue

            # 각 파일 순회
            for file_key in files:
                try:
                    obj = client.get_object(Bucket=bucket_name, Key=file_key)
                    df = pd.read_parquet(io.BytesIO(obj['Body'].read()))
                    df_by_table_list[table_name] = df
                    print(f"[Success] Loaded {file_key} for table {table_name}")
                except Exception as e:
                    print(f"[Error] Failed to read {file_key} for table {table_name}: {e}")
        else:
            print(f"[Info] No files found under prefix: {prefix}")
        
    return df_by_table_list

df_by_table_list = load_s3_instagram_data()

# recent_user_info_mtr_2 = df_by_table_list['RECENT_USER_INFO_MTR']
# time_series_profile_info_2 = df_by_table_list['TIME_SERIES_PROFILE_INFO']
# by_user_id_media_dtl_info_2 = df_by_table_list['BY_USER_ID_MEDIA_DTL_INFO']
# by_date_media_agg_info_2 = df_by_table_list['BY_DATE_MEDIA_AGG_INFO']

recent_user_info_mtr = df_by_table_list['RECENT_USER_INFO_MTR']
time_series_profile_info = df_by_table_list['TIME_SERIES_PROFILE_INFO']
by_user_id_media_dtl_info = df_by_table_list['BY_USER_ID_MEDIA_DTL_INFO']
by_date_media_agg_info = df_by_table_list['BY_DATE_MEDIA_AGG_INFO']
# Out:
# [Success] Loaded instagram-data/tables/RECENT_USER_INFO_MTR/year=2025/week=25/merged_data.parquet for table RECENT_USER_INFO_MTR
# [Success] Loaded instagram-data/tables/TIME_SERIES_PROFILE_INFO/year=2025/week=25/merged_data.parquet for table TIME_SERIES_PROFILE_INFO
# [Success] Loaded instagram-data/tables/BY_USER_ID_MEDIA_DTL_INFO/year=2025/week=25/merged_data.parquet for table BY_USER_ID_MEDIA_DTL_INFO
# [Success] Loaded instagram-data/tables/BY_DATE_MEDIA_AGG_INFO/year=2025/week=25/merged_data.parquet for table BY_DATE_MEDIA_AGG_INFO

# %%
def load_weekly_instagram_data(bucket_name, table_list, weeks_back=2, target_filename='merged_data.parquet'):
    # 환경 변수 로딩
    load_dotenv()
    aws_access_key = os.getenv("aws_accessKey")
    aws_secret_key = os.getenv("aws_secretKey")

    client = boto3.client(
        's3',
        aws_access_key_id=aws_access_key,
        aws_secret_access_key=aws_secret_key,
        region_name='ap-northeast-2'
    )

    # 주차 리스트 생성 
    today = datetime.now()
    weekday = today.weekday()
    # week_year_pairs = [
    #     (today - timedelta(weeks=w)).isocalendar()[:2]
    #     for w in range(weeks_back)
    # ]
    
    # 주차 리스트 생성 (이번 주 제외, 저번주 & 저저번주만)
    if weekday <= 2:
        # 월~수
        week_year_pairs = week_year_pairs = [
        (today - timedelta(weeks=2)).isocalendar()[:2],  # 저저번주
        (today - timedelta(weeks=1)).isocalendar()[:2],  # 저번주
        ]
    else:
        weeks_year_pairs = [
            (today - timedelta(weeks=1)).isocalendar()[:2],
            today.isocalendar()[:2]
        ]

    # 결과 저장용 딕셔너리 초기화
    merged_data_by_table = {table_name: {} for table_name in table_list}

    # 주차별로 데이터 로딩
    for year_val, week_val in week_year_pairs:
        for table_name in table_list:
            prefix = f'instagram-data/tables/{table_name}/year={year_val}/week={week_val}/'
            response = client.list_objects_v2(Bucket=bucket_name, Prefix=prefix)

            if 'Contents' not in response:
                print(f"[Info] No files found under prefix: {prefix}")
                continue

            target_files = [
                content['Key']
                for content in response['Contents']
                if content['Key'].endswith(target_filename)
            ]

            if not target_files:
                print(f"[Info] No {target_filename} found for {table_name} week={week_val}")
                continue

            for file_key in target_files:
                try:
                    obj = client.get_object(Bucket=bucket_name, Key=file_key)
                    df = pd.read_parquet(io.BytesIO(obj['Body'].read()))
                    merged_data_by_table[table_name][week_val] = df
                    print(f"[Success] Loaded {file_key} for table {table_name}, week {week_val}")
                except Exception as e:
                    print(f"[Error] Failed to read {file_key} for {table_name}, week {week_val}: {e}")

    recent_weeks_data = {}
    for table_name, week_data in merged_data_by_table.items():
        sorted_weeks = sorted(week_data.keys())
        if len(sorted_weeks) >= 2:
            prev_week, current_week = sorted_weeks[-2], sorted_weeks[-1]
            # print(prev_week, current_week)
            recent_weeks_data[table_name] = {
                'prev_week': week_data[prev_week],
                'current_week': week_data[current_week]
            }
        else:
            print(f"[Warning] Not enough data for table {table_name} to determine prev/current weeks.")

    
    return recent_weeks_data

# %%
bucket_name = 'flexmatch-data'
table_list = [
    'RECENT_USER_INFO_MTR',
    'TIME_SERIES_PROFILE_INFO',
    'BY_USER_ID_MEDIA_DTL_INFO',
    'BY_DATE_MEDIA_AGG_INFO',
    'CONN_PROFILE_INSIGHT_DTL',
    'CONN_MEDIA_INSIGHT'
]

merged_data_by_table = load_weekly_instagram_data(bucket_name, table_list)
# Out:
# [Success] Loaded instagram-data/tables/RECENT_USER_INFO_MTR/year=2025/week=25/merged_data.parquet for table RECENT_USER_INFO_MTR, week 25
# [Success] Loaded instagram-data/tables/TIME_SERIES_PROFILE_INFO/year=2025/week=25/merged_data.parquet for table TIME_SERIES_PROFILE_INFO, week 25
# [Success] Loaded instagram-data/tables/BY_USER_ID_MEDIA_DTL_INFO/year=2025/week=25/merged_data.parquet for table BY_USER_ID_MEDIA_DTL_INFO, week 25
# [Success] Loaded instagram-data/tables/BY_DATE_MEDIA_AGG_INFO/year=2025/week=25/merged_data.parquet for table BY_DATE_MEDIA_AGG_INFO, week 25
# [Success] Loaded instagram-data/tables/CONN_PROFILE_INSIGHT_DTL/year=2025/week=25/merged_data.parquet for table CONN_PROFILE_INSIGHT_DTL, week 25
# [Success] Loaded instagram-data/tables/CONN_MEDIA_INSIGHT/year=2025/week=25/merged_data.parquet for table CONN_MEDIA_INSIGHT, week 25
# [Success] Loaded instagram-data/tables/RECENT_USER_INFO_MTR/year=2025/week=26/merged_data.parquet for table RECENT_USER_INFO_MTR, week 26
# [Success] Loaded instagram-data/tables/TIME_SERIES_PROFILE_INFO/year=2025/week=26/merged_data.parquet for table TIME_SERIES_PROFILE_INFO, week 26
# [Success] Loaded instagram-data/tables/BY_USER_ID_MEDIA_DTL_INFO/year=2025/week=26/merged_data.parquet for table BY_USER_ID_MEDIA_DTL_INFO, week 26
# [Success] Loaded instagram-data/tables/BY_DATE_MEDIA_AGG_INFO/year=2025/week=26/merged_data.parquet for table BY_DATE_MEDIA_AGG_INFO, week 26
# [Success] Loaded instagram-data/tables/CONN_PROFILE_INSIGHT_DTL/year=2025/week=26/merged_data.parquet for table CONN_PROFILE_INSIGHT_DTL, week 26
# [Success] Loaded instagram-data/tables/CONN_MEDIA_INSIGHT/year=2025/week=26/merged_data.parquet for table CONN_MEDIA_INSIGHT, week 26

# %%
recent_user_info_mtr = merged_data_by_table['RECENT_USER_INFO_MTR']['prev_week']
time_series_profile_info = merged_data_by_table['TIME_SERIES_PROFILE_INFO']['prev_week']
by_user_id_media_dtl_info = merged_data_by_table['BY_USER_ID_MEDIA_DTL_INFO']['prev_week']
by_date_media_agg_info = merged_data_by_table['BY_DATE_MEDIA_AGG_INFO']['prev_week']

recent_user_info_mtr_2 = merged_data_by_table['RECENT_USER_INFO_MTR']['current_week']
time_series_profile_info_2 = merged_data_by_table['TIME_SERIES_PROFILE_INFO']['current_week']
by_user_id_media_dtl_info_2 = merged_data_by_table['BY_USER_ID_MEDIA_DTL_INFO']['current_week']
by_date_media_agg_info_2 = merged_data_by_table['BY_DATE_MEDIA_AGG_INFO']['current_week']

conn_profile_insight = merged_data_by_table['CONN_PROFILE_INSIGHT_DTL']['prev_week']
conn_profile_insight_2 = merged_data_by_table['CONN_PROFILE_INSIGHT_DTL']['current_week']

conn_media_insight = merged_data_by_table['CONN_MEDIA_INSIGHT']['prev_week']
conn_media_insight_2 = merged_data_by_table['CONN_MEDIA_INSIGHT']['current_week']

# %% [markdown]
# basic preprocessing

# %%
# recent_user_info_mtr = recent_user_info_mtr.drop_duplicates(subset=['acnt_id', 'acnt_nm'])
# time_series_profile_info = time_series_profile_info.drop_duplicates(subset=['base_ymd', 'acnt_id'])
# by_user_id_media_dtl_info = by_user_id_media_dtl_info.drop_duplicates(subset=['acnt_id', 'media_id', 'media_cn'])
# by_date_media_agg_info = by_date_media_agg_info.drop_duplicates(subset=['base_ymd', 'media_id'])

# recent_user_info_mtr_2 = recent_user_info_mtr_2.drop_duplicates(subset=['acnt_id', 'acnt_nm'])
# time_series_profile_info_2 = time_series_profile_info_2.drop_duplicates(subset=['base_ymd', 'acnt_id'])
# by_user_id_media_dtl_info_2 = by_user_id_media_dtl_info_2.drop_duplicates(subset=['acnt_id', 'media_id', 'media_cn'])
# by_date_media_agg_info_2 = by_date_media_agg_info_2.drop_duplicates(subset=['base_ymd', 'media_id'])

# conn_profile_insight = conn_profile_insight.drop_duplicates(subset=['acnt_id', 'acnt_nm'])
# conn_media_insight = conn_media_insight.drop_duplicates(subset=['acnt_id', 'acnt_nm', 'media_id'])

# conn_profile_insight_2 = conn_profile_insight_2.drop_duplicates(subset=['acnt_id', 'acnt_nm'])
# conn_media_insight_2 = conn_media_insight_2.drop_duplicates(subset=['acnt_id', 'acnt_nm', 'media_id'])

# %% [markdown]
# 가장 최근 데이터로 isin 해줘야 할 것 같음. 그래야 1주일 전, 후를 비교할 수 있기 때문임

# %%
# 각 acnt_id가 있는 전부 있는 경우만 가능, isin으로 제거
# 근데 전 주차에는 없는 유저가 생길수도 있음
# media 같은 경우에도 최근 25개만 일단 가져오고 있기 때문에 일주일 단위여도 없을수도 있음

# 이렇게 해야하는 이유는 timeseries 변수를 계산하려면 무조건 두 주차에 같은 아이디가 있어야 함
# 또한, user info랑 media info 같이 써야하는 경우에는 어짜피 한번 거르고 있을 듯
# -> 따라서, 굳이 필수적으로 하지는 않아도 될듯함

# unique_user = recent_user_info_mtr['acnt_id'].unique()
c_unique_user = recent_user_info_mtr_2[recent_user_info_mtr_2['acnt_conn_yn']=='Y']['acnt_id'].to_list()
# print(len(c_unique_user))

c_recent_user_info_mtr_2 = recent_user_info_mtr_2[recent_user_info_mtr_2['acnt_id'].isin(c_unique_user)]

c_time_series_profile_info = time_series_profile_info[time_series_profile_info['acnt_id'].isin(c_unique_user)]
c_time_series_profile_info_2 = time_series_profile_info_2[time_series_profile_info_2['acnt_id'].isin(c_unique_user)]

# by_user_id_media_dtl_info = by_user_id_media_dtl_info[by_user_id_media_dtl_info['acnt_id'].isin(c_unique_user)]
c_by_user_id_media_dtl_info_2 = by_user_id_media_dtl_info_2[by_user_id_media_dtl_info_2['acnt_id'].isin(c_unique_user)]

unique_media = c_by_user_id_media_dtl_info_2['media_id'].unique()
# connected_user 같은 경우에는 conn_media_insight 안에 있는 게 media_agg랑 동일하기 때문에 해당 부분을 쓰면 당장은 문제가 없음
# c_by_date_media_agg_info_2 = by_date_media_agg_info_2[by_date_media_agg_info_2['media_id'].isin(unique_media)]
conn_media_insight_2 = conn_media_insight_2[conn_media_insight_2['media_id'].isin(unique_media)]

# %%
def influencer_scale_type(row):
    count = row['follower_cnt']
    if count < 1000:
        return 'nano'
    elif 1000 <= count <= 10000:
        return 'micro'
    elif 10000 < count <= 100000:
        return 'mid'
    elif 100000 < count <= 500000:
        return 'macro'
    else:
        return 'mega'

# recent_user_info_mtr.loc[:, 'influencer_scale_type'] = recent_user_info_mtr.apply(influencer_scale_type, axis=1)
c_recent_user_info_mtr_2.loc[:,'influencer_scale_type'] = c_recent_user_info_mtr_2.apply(influencer_scale_type, axis=1)

# %%
# c_recent_user_info_mtr_2

# %%
# conn_media_insight_2[conn_media_insight_2['acnt_id']=='17841450980480576'].head()

# %%
# # by_user_id_media_dtl_info_2[by_user_id_media_dtl_info_2['acnt_id']=='17841450980480576'] # 17850258761802532
# by_date_media_agg_info_2[by_date_media_agg_info_2['media_id']=='17850258761802532']

# %%
# conn_profile_insight_2[conn_profile_insight_2['acnt_id']=='17841450980480576']

# %% [markdown]
# create merged file

# %%
def create_merged_df(user_info_df, timeseries_df, timeseries_df_2, media_info_df, media_insight): # media_agg, profile_insight X
    media_engagement_merged_df = pd.merge(media_info_df, media_insight, on='media_id', how='outer')
    # print(len(media_engagement_merged_df['acnt_id'].unique()))

    # 단 한개의 게시물이라도 like가 비공개인 influencer 제거
    # by_user_na_like_count = media_engagement_merged_df[media_engagement_merged_df['like_cnt'].isna()].groupby(['acnt_id'])['media_id'].count()
    # na_like_user = by_user_na_like_count[by_user_na_like_count > 0].index
    # # print(len(na_like_user))
    # media_engagement_merged_df = media_engagement_merged_df[~media_engagement_merged_df['acnt_id'].isin(na_like_user)].reset_index()

    user_list = media_engagement_merged_df['acnt_id'].unique()
    # print(len(user_list))
    media_list = media_engagement_merged_df['media_id'].unique()

    # merge하면서 제거된 리스트가 있기 때문에, 해당 부분 다시 삭제 후에 새로운 merge 파일 생성
    user_info = user_info_df[user_info_df['acnt_id'].isin(user_list)]
    timeseries = timeseries_df[timeseries_df['acnt_id'].isin(user_list)]
    timeseries_2 = timeseries_df_2[timeseries_df_2['acnt_id'].isin(user_list)]
    media_info = media_info_df[media_info_df['acnt_id'].isin(user_list)]

    media_insight_info = media_insight[media_insight['media_id'].isin(media_list)]

    all_merged_df_a = pd.merge(user_info, timeseries, on='acnt_id')
    all_merged_df_b = pd.merge(all_merged_df_a, media_info, on='acnt_id')
    all_merged_df = pd.merge(all_merged_df_b, media_insight_info, on='media_id')
    
    media_engagement_profile_merged_df = pd.merge(media_engagement_merged_df, user_info_df, on='acnt_id')
    time_series_merged_df = pd.merge(timeseries, timeseries_df_2, on='acnt_id')

    return user_info, timeseries, timeseries_2, media_info, media_insight_info, all_merged_df, media_engagement_merged_df, media_engagement_profile_merged_df, time_series_merged_df

# %%
user_info, timeseries, timeseries_2, media_info, media_agg, all_merged_df, media_engagement_merged_df, media_engagement_profile_merged_df, time_series_merged_df = create_merged_df(
                                                                                                                        c_recent_user_info_mtr_2,
                                                                                                                        c_time_series_profile_info,
                                                                                                                        c_time_series_profile_info_2,
                                                                                                                        c_by_user_id_media_dtl_info_2,
                                                                                                                        conn_media_insight_2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\ehddl\anaconda3\envs\pysaprk_env\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'acnt_id'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[220], line 1
# ----> 1 user_info, timeseries, timeseries_2, media_info, media_agg, all_merged_df, media_engagement_merged_df, media_engagement_profile_merged_df, time_series_merged_df = create_merged_df(
#       2                                                                                                                         c_recent_user_info_mtr_2,
#       3                                                                                                                         c_time_series_profile_info,
#       4                                                                                                                         c_time_series_profile_info_2,
#       5                                                                                                                         c_by_user_id_media_dtl_info_2,
#       6                                                                                                                         conn_media_insight_2)
#
# Cell In[219], line 11, in create_merged_df(user_info_df, timeseries_df, timeseries_df_2, media_info_df, media_insight)
#       2 media_engagement_merged_df = pd.merge(media_info_df, media_insight, on='media_id', how='outer')
#       3 # print(len(media_engagement_merged_df['acnt_id'].unique()))
#       4
#       5 # 단 한개의 게시물이라도 like가 비공개인 influencer 제거
#    (...)
#       8 # # print(len(na_like_user))
#       9 # media_engagement_merged_df = media_engagement_merged_df[~media_engagement_merged_df['acnt_id'].isin(na_like_user)].reset_index()
# ---> 11 user_list = media_engagement_merged_df['acnt_id'].unique()
#      12 # print(len(user_list))
#      13 media_list = media_engagement_merged_df['media_id'].unique()
#
# File c:\Users\ehddl\anaconda3\envs\pysaprk_env\lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\ehddl\anaconda3\envs\pysaprk_env\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'acnt_id'

# %%
media_engagement_merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 337 entries, 0 to 336
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   acnt_id             337 non-null    object
#  1   media_id            337 non-null    object
#  2   media_type_nm       337 non-null    object
#  3   reels_feed_type_nm  337 non-null    object
#  4   media_url_addr      337 non-null    object
#  5   media_unq_url_addr  337 non-null    object
#  6   tmnl_url_addr       39 non-null     object
#  7   reg_dt              337 non-null    object
#  8   media_cn            274 non-null    object
#  9   acnt_conn_yn        337 non-null    object
#  10  feed_share_yn       31 non-null     object
#  11  cmnt_actvtn_yn      337 non-null    object
#  12  base_ymd            0 non-null      object
#  13  cmnt_cnt            0 non-null      float64
#  14  like_cnt            0 non-null      float64
#  15  created_dt          0 non-null      datetime64[us]
# dtypes: datetime64[us](1), float64(2), object(13)
# memory usage: 42.2+ KB

# %%
media_engagement_merged_df[media_engagement_merged_df['acnt_id']=='17841450980480576']
# Out:
#                acnt_id           media_id   media_type_nm reels_feed_type_nm  \
# 5    17841450980480576  17845632434762696  CAROUSEL_ALBUM               FEED
# 15   17841450980480576  17850258761802532  CAROUSEL_ALBUM               FEED
# 21   17841450980480576  17856317744695367  CAROUSEL_ALBUM               FEED
# 23   17841450980480576  17857189607706657  CAROUSEL_ALBUM               FEED
# 28   17841450980480576  17859119504684701  CAROUSEL_ALBUM               FEED
# ..                 ...                ...             ...                ...
# 313  17841450980480576  18229115269104698  CAROUSEL_ALBUM               FEED
# 314  17841450980480576  18237946321160191  CAROUSEL_ALBUM               FEED
# 315  17841450980480576  18240952645111314  CAROUSEL_ALBUM               FEED
# 319  17841450980480576  18295822177054619  CAROUSEL_ALBUM               FEED
# 321  17841450980480576  18298442902062498  CAROUSEL_ALBUM               FEED
#
#                                         media_url_addr  \
# 5    https://scontent-nrt1-2.cdninstagram.com/v/t51...
# 15   https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 21   https://scontent-nrt1-2.cdninstagram.com/v/t51...
# 23   https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 28   https://scontent-nrt1-2.cdninstagram.com/v/t51...
# ..                                                 ...
# 313  https://scontent-nrt1-1.cdninstagram.com/v/t51...
# 314  https://scontent-nrt1-2.cdninstagram.com/v/t51...
# 315  https://scontent-nrt1-2.cdninstagram.com/v/t51...
# 319  https://scontent-nrt1-2.cdninstagram.com/v/t51...
# 321  https://scontent-nrt1-1.cdninstagram.com/v/t51...
#
#                            media_unq_url_addr tmnl_url_addr  \
# 5    https://www.instagram.com/p/CcFHLyjJym7/          None
# 15   https://www.instagram.com/p/CgqtlLjJ9Z9/          None
# 21   https://www.instagram.com/p/CZoOOpFpPUP/          None
# 23   https://www.instagram.com/p/CdiBqPup5KM/          None
# 28   https://www.instagram.com/p/Ca3xraepfP3/          None
# ..                                        ...           ...
# 313  https://www.instagram.com/p/Cb4ZC0qJaBM/          None
# 314  https://www.instagram.com/p/CqhrVJVy91h/          None
# 315  https://www.instagram.com/p/CeqHzhOJBAv/          None
# 319  https://www.instagram.com/p/Cdadlu6J4Mc/          None
# 321  https://www.instagram.com/p/CdzzPlZpE01/          None
#
#                        reg_dt  \
# 5    2022-04-08T06:23:29+0000
# 15   2022-07-31T06:56:29+0000
# 21   2022-02-06T08:04:17+0000
# 23   2022-05-14T08:24:35+0000
# 28   2022-03-09T05:34:03+0000
# ..                        ...
# 313  2022-04-03T07:49:25+0000
# 314  2023-04-02T07:57:35+0000
# 315  2022-06-11T08:23:36+0000
# 319  2022-05-11T09:54:43+0000
# 321  2022-05-21T06:04:56+0000
#
#                                               media_cn acnt_conn_yn  \
# 5    #34\n🔵 🧊🧊🧊🧊🧊\n클라임 어스 첫 방문\n시설 훌륭하네\n남색 어렵다\n클라...            Y
# 15   #64회차 \n⚫️⚫️❌️🔴🔴🔴🔴🔴🔴\n손상원 클라이밍짐 강남점 오픈런!\n처음 만...            Y
# 21   .\n🧊🧊🧊🧊🧊 좋다 좀 늘긴했어ㅎㅎ\n🟢 다이노라서 재밌다\n🔵 이거 진짜 깨고 ...            Y
# 23   #45회차\n🔵🔵🔵🔵🔵🔵\n웨어하우스짐 첫 방문\n깔끔하고 문제도 재밌고 사장님도 ...            Y
# 28   .\n오랜만에 양재 더클라임\n🔵x2 다이노\n참교육만 엄청 당했다\n우연히 만난\...            Y
# ..                                                 ...          ...
# 313  #33\n🟣 물보라든 꿀보라든 보라!!\n❌️ 기세를 몰아 다른 보라 도전했지만 탑...            Y
# 314  04/02 미금 더볼더\n❌️🧊🧊🧊🧊\n클라이밍 1일차~\n4달만에 @_p.ark ...            Y
# 315  #53회차\n🟢🟢❌️🟢🟢🟢\n비블럭 강남은 참 재밌다\n오버행 하나 못깬거 너무 아...            Y
# 319  #44회차\nDD❌️EE\n내 인생 첫 클라이밍했던 곳\n앞으로 내 주암장이 될 곳...            Y
# 321  #48회차\n🪨1110⭕️/⚪️10?0❌️/🟤9??⭕️/🍑820⭕️/🟣7?0⭕️\n...            Y
#
#     feed_share_yn cmnt_actvtn_yn base_ymd  cmnt_cnt  like_cnt created_dt
# 5            None           true      NaN       NaN       NaN        NaT
# 15           None           true      NaN       NaN       NaN        NaT
# 21           None           true      NaN       NaN       NaN        NaT
# 23           None           true      NaN       NaN       NaN        NaT
# 28           None           true      NaN       NaN       NaN        NaT
# ..            ...            ...      ...       ...       ...        ...
# 313          None           true      NaN       NaN       NaN        NaT
# 314          None           true      NaN       NaN       NaN        NaT
# 315          None           true      NaN       NaN       NaN        NaT
# 319          None           true      NaN       NaN       NaN        NaT
# 321          None           true      NaN       NaN       NaN        NaT
#
# [100 rows x 16 columns]

# %% [markdown]
# 크리에이터 활동성
#
# - 실제 게시물 업로드 날짜를 기준으로 계산할 수 있을 것 같음
# - 최근 25개의 게시물의 평균 게시 간격을 계산
# - 최근 25개의 게시물을 며칠에 걸쳐서 업로드 했는지에 대한 값을 계산

# %%
media_dtl_2_copy = by_user_id_media_dtl_info_2.copy()
media_dtl_2_copy = media_dtl_2_copy.drop_duplicates(subset=['acnt_id', 'media_id', 'media_cn'])
media_dtl_2_copy['reg_dt'] = pd.to_datetime(media_dtl_2_copy['reg_dt'])
media_dtl_2_copy = media_dtl_2_copy.sort_values(['acnt_id', 'reg_dt'])

# 게시물 간격 계산
media_dtl_2_copy['prev_reg_dt'] = media_dtl_2_copy.groupby('acnt_id')['reg_dt'].shift(1)
media_dtl_2_copy['gap_days'] = (media_dtl_2_copy['reg_dt'] - media_dtl_2_copy['prev_reg_dt']).dt.days
# media_dtl_2_copy

# gap_days가 NaN인 첫 번째 포스트 제외 후 평균 간격 계산
activity_df = media_dtl_2_copy.dropna(subset=['gap_days']).groupby('acnt_id')['gap_days'].mean().reset_index()
activity_df.rename(columns={'gap_days': 'avg_upload_interval'}, inplace=True)

# 활동성 점수 계산 (간격의 역수로 환산) -> 점수 정규화 (업로드 간격이 짧을수록 점수가 높아지도록 역수를 취해서 계산한 것)
activity_df['activity_score'] = 100 / activity_df['avg_upload_interval']
activity_df
# Out:
#                acnt_id  avg_upload_interval  activity_score
# 0    17841400002751973             0.333333      300.000000
# 1    17841400006499942             3.166667       31.578947
# 2    17841400011995621             2.291667       43.636364
# 3    17841400016295781             0.541667      184.615385
# 4    17841400025364370            26.416667        3.785489
# ..                 ...                  ...             ...
# 716  17841473332885823             2.750000       36.363636
# 717  17841473347851502             2.208333       45.283019
# 718  17841473857435791             0.500000      200.000000
# 719  17841474152637635             3.500000       28.571429
# 720  17841474495202295             2.000000       50.000000
#
# [721 rows x 3 columns]

# %%
def calculate_activity_score(recent_media_dtl_df): # 두 개의 테이블 중 가장 최근
    media_dtl_copy = recent_media_dtl_df.copy()
    media_dtl_copy = media_dtl_copy.drop_duplicates(subset=['acnt_id', 'media_id', 'media_cn'])
    media_dtl_copy['reg_dt'] = pd.to_datetime(media_dtl_copy['reg_dt'])
    media_dtl_copy = media_dtl_copy.sort_values(['acnt_id', 'reg_dt'])

    # 게시물 간격 계산
    media_dtl_copy['prev_reg_dt'] = media_dtl_copy.groupby('acnt_id')['reg_dt'].shift(1)
    media_dtl_copy['gap_days'] = (media_dtl_copy['reg_dt'] - media_dtl_copy['prev_reg_dt']).dt.days

    # gap_days가 NaN인 첫 번째 포스트 제외 후 평균 간격 계산
    activity_df = media_dtl_copy.dropna(subset=['gap_days']).groupby('acnt_id')['gap_days'].mean().reset_index()
    activity_df.rename(columns={'gap_days': 'avg_upload_interval'}, inplace=True)

    # 활동성 점수 계산 (간격의 역수로 환산) -> 점수 정규화 (업로드 간격이 짧을수록 점수가 높아지도록 역수를 취해서 계산한 것)
    # 업로드 간격이 너무 짧은 유저의 경우 inf로 계산되는 것을 방지하기 위해서 scaling 진행
    activity_df['avg_upload_interval'] = activity_df['avg_upload_interval'].replace(0, 0.1)
    activity_df['activity_score'] = 100 / activity_df['avg_upload_interval']
    
    return activity_df

# %%
activity_df = calculate_activity_score(media_info)

# %%
activity_df
# Out:
#              acnt_id  avg_upload_interval  activity_score
# 0  17841400337192059          1044.000000        0.095785
# 1  17841400360358101           120.000000        0.833333
# 2  17841400624415491            21.545455        4.641350
# 3  17841409045873013           292.000000        0.342466
# 4  17841449549923448             3.070707       32.565789
# 5  17841450980480576            12.070707        8.284519
# 6  17841470887323678             0.100000     1000.000000

# %%
def check_inf(df):
    float_cols = df.select_dtypes(include=['float64', 'float32']).columns

    mask_inf = np.isinf(df[float_cols]).any(axis=1)
    mask_neginf = np.isneginf(df[float_cols]).any(axis=1)

    invalid_rows = df[mask_inf | mask_neginf]

    print(f"⚠️ inf / -inf 포함 행 개수: {len(invalid_rows)}개")
    display(invalid_rows)

# %%
check_inf(activity_df)
# Out:
# ⚠️ inf / -inf 포함 행 개수: 0개
# Empty DataFrame
# Columns: [acnt_id, avg_upload_interval, activity_score]
# Index: []

# %% [markdown]
# 트렌드지수 - 팔로워 순증감률 (follower_growth_rate)

# %%
# time_series_profile_info_2['acnt_id'] = time_series_profile_info_2['acnt_id'].astype(object)

# influencer_list = time_series_profile_info['acnt_id'].unique()
# time_series_profile_info_2[time_series_profile_info_2['acnt_id'].isin(influencer_list)]
# time_series_merged_df = pd.merge(time_series_profile_info, time_series_profile_info_2, on='acnt_id')

# time_series_merged_df['trend_score'] = ((time_series_merged_df['follower_cnt_y'] - time_series_merged_df['follower_cnt_x']) / (time_series_merged_df['follower_cnt_x'])) * 100
# time_series_merged_df[['acnt_id', 'trend_score']]

# %%
def calculate_follower_growth_rate(time_series_df, recent_time_series_df):
    time_series_df.loc[:, 'acnt_id'] = time_series_df['acnt_id'].astype(object)
    recent_time_series_df.loc[:, 'acnt_id'] = recent_time_series_df['acnt_id'].astype(object)

    influencer_list = time_series_df['acnt_id'].unique()
    recent_time_series_df = recent_time_series_df[recent_time_series_df['acnt_id'].isin(influencer_list)]
    time_series_merged_df = pd.merge(time_series_df, recent_time_series_df, on='acnt_id')

    time_series_merged_df['trend_score'] = ((time_series_merged_df['follower_cnt_y'] - time_series_merged_df['follower_cnt_x']) / (time_series_merged_df['follower_cnt_x'])) * 100
    growth_rate_df = time_series_merged_df[['acnt_id', 'trend_score']]

    return growth_rate_df

# %%
growth_rate_df = calculate_follower_growth_rate(timeseries, timeseries_2)

# %%
growth_rate_df
# Out:
#              acnt_id  trend_score
# 0  17841449549923448    -0.184290
# 1  17841400624415491     0.000000
# 2  17841450980480576     0.000000
# 3  17841400337192059     0.000000
# 4  17841400360358101     2.419355
# 5  17841409045873013     0.952381
# 6  17841470887323678     1.250000

# %% [markdown]
# ##### 팔로워 참여도
#
# - estimated_total_engagement = avg_engagement_per_post * total_post_count
# - avg_engagement_per_post = like+comments / 25
#   -> 25개가 아니라 비즈니스 연동 계정 같은 경우 max 100임. 이거 어케 나눠줘야 할지? (id별 goupby해서 개수를 알아야 할 듯)
# - total_post_count -> user_data

# %%
def calculate_follower_engagement(media_engagement_profile_merged_df):
    media_engagement_profile_merged_df_copy = media_engagement_profile_merged_df[['acnt_id', 'media_id', 'follower_cnt', 'follow_cnt', 'like_cnt', 'cmnt_cnt', 'media_cnt']]
    
    engaged_df = media_engagement_profile_merged_df_copy.groupby(['acnt_id']).agg({
        'like_cnt' : 'sum',
        'cmnt_cnt' : 'sum',
        'media_cnt': 'first',
        'follower_cnt' : 'first',
        'follow_cnt' : 'first'
    }).reset_index()

    engaged_df['avg_engagement_per_post'] = ((engaged_df['like_cnt'] + engaged_df['cmnt_cnt']) / 25)
    engaged_df['estimated_total_engagement'] = engaged_df['avg_engagement_per_post'] * engaged_df['media_cnt']
    engaged_df['follower_total_engagement'] = (engaged_df['estimated_total_engagement'] / engaged_df['follower_cnt']) * 100
    
    follower_engagment_df = engaged_df

    return follower_engagment_df

# %%
follower_engagment_df = calculate_follower_engagement(media_engagement_profile_merged_df)

# %%
check_inf(follower_engagment_df)
# Out:
# ⚠️ inf / -inf 포함 행 개수: 0개
# Empty DataFrame
# Columns: [acnt_id, like_cnt, cmnt_cnt, media_cnt, follower_cnt, follow_cnt, avg_engagement_per_post, estimated_total_engagement, follower_total_engagement]
# Index: []

# %% [markdown]
# ##### 팔로워 충성도
#
# - user_info or time_series 데이터가 필요
# - 트렌드 지수는 time_series 데이터를 가지고 단순히 빼기를 진행했었음

# %%
# time_series_merged_df_copy = time_series_merged_df[['acnt_id', 'follower_cnt_x', 'follower_cnt_y']]

# time_series_merged_df_copy['follower_change'] = (time_series_merged_df_copy['follower_cnt_y'] - time_series_merged_df_copy['follower_cnt_x'])

# def estimate_new_follower(row):
#     if row['follower_change'] < 0:
#         return 0
#     else:
#         return row['follower_change']

# time_series_merged_df_copy['new_follower'] = time_series_merged_df_copy.apply(estimate_new_follower, axis=1)

# # 충성도 계산
# # time_series_merged_df_copy = time_series_merged_time_series_merged_df_copy_copy.copy()
# time_series_merged_df_copy['unfollowed'] = time_series_merged_df_copy['follower_cnt_x'] + time_series_merged_df_copy['new_follower'] - time_series_merged_df_copy['follower_cnt_y']
# time_series_merged_df_copy['follower_retention_rate'] = ((time_series_merged_df_copy['follower_cnt_x'] - time_series_merged_df_copy['unfollowed']) / time_series_merged_df_copy['follower_cnt_x']) * 100
# time_series_merged_df_copy['follower_retention_rate'] = time_series_merged_df_copy['follower_retention_rate'].round(2)

# time_series_merged_df_copy

# %%
# def estimate_loyalty(row):
#     if row['follower_change'] < 0:
#         return ((row['follower_cnt_x'] + row['follower_change']) / row['follower_cnt_x']) * 100
#     else:
#         return 100.0

# time_series_merged_df_copy['follower_loyalty'] = time_series_merged_df_copy.apply(estimate_loyalty, axis=1)
# time_series_merged_df_copy['follower_loyalty'] = time_series_merged_df_copy['follower_loyalty'].round(2)

# %%
def calculate_follower_loyalty(time_series_merged_df):
    time_series_merged_df_copy = time_series_merged_df[['acnt_id', 'follower_cnt_x', 'follower_cnt_y']].copy()

    time_series_merged_df_copy.loc[:, 'follower_change'] = (time_series_merged_df_copy['follower_cnt_y'] - time_series_merged_df_copy['follower_cnt_x'])

    def estimate_new_follower(row):
        if row['follower_change'] < 0:
            return 0
        else:
            return row['follower_change']

    time_series_merged_df_copy.loc[:, 'new_follower'] = time_series_merged_df_copy.apply(estimate_new_follower, axis=1)
    time_series_merged_df_copy.loc[:, 'unfollowed'] = time_series_merged_df_copy['follower_cnt_x'] + time_series_merged_df_copy['new_follower'] - time_series_merged_df_copy['follower_cnt_y']
    time_series_merged_df_copy.loc[:, 'follower_retention_rate'] = ((time_series_merged_df_copy['follower_cnt_x'] - time_series_merged_df_copy['unfollowed']) / time_series_merged_df_copy['follower_cnt_x']) * 100
    time_series_merged_df_copy.loc[:, 'follower_retention_rate'] = time_series_merged_df_copy['follower_retention_rate'].round(2)

    follower_loyalty_df = time_series_merged_df_copy

    return follower_loyalty_df

# %%
follower_loyalty_df = calculate_follower_loyalty(time_series_merged_df)
follower_loyalty_df
# Out:
#                acnt_id  follower_cnt_x  follower_cnt_y  follower_change  \
# 0    17841472095454621            2348            2424               76
# 1    17841459031207937            2119            2119                0
# 2    17841458105192949            1269            1271                2
# 3    17841400305959659           12337           12319              -18
# 4    17841418684451303           21360           20696             -664
# ..                 ...             ...             ...              ...
# 357  17841401900622950           24985           24944              -41
# 358  17841402240386451            1437            1436               -1
# 359  17841411620779046            1069            1065               -4
# 360  17841400875316568            1267            1266               -1
# 361  17841400254814022           21260           21259               -1
#
#      new_follower  unfollowed  follower_retention_rate
# 0              76           0                   100.00
# 1               0           0                   100.00
# 2               2           0                   100.00
# 3               0          18                    99.85
# 4               0         664                    96.89
# ..            ...         ...                      ...
# 357             0          41                    99.84
# 358             0           1                    99.93
# 359             0           4                    99.63
# 360             0           1                    99.92
# 361             0           1                   100.00
#
# [362 rows x 7 columns]

# %%
check_inf(follower_loyalty_df)
# Out:
# ⚠️ inf / -inf 포함 행 개수: 0개
# Empty DataFrame
# Columns: [acnt_id, follower_cnt_x, follower_cnt_y, follower_change, new_follower, unfollowed, follower_retention_rate]
# Index: []

# %% [markdown]
# 콘텐츠 효율성 평가
#
# - 콘텐츠 1개당 팔로워 대비 반응량(like+comments)
# - media_agg & media_dtl & acnt_id가 필요 -> 전부 병합한 게 media_engagement_merged_df

# %%
# media_engagement_merged_df_3 = media_engagement_profile_merged_df.copy()
# # media_engagment_merged_df_2 == media_engagement_profile_merged_df 같은 df임
# # media_engagement_profile_merged_df_copy = media_engagement_merged_df_2.copy()


# media_engagement_merged_df_3['post_efficiency'] = ((media_engagement_merged_df_3['like_cnt'] + media_engagement_merged_df_3['cmnt_cnt']) / media_engagement_merged_df_3['follower_cnt']) * 100
# post_efficiency_df = media_engagement_merged_df_3.groupby('acnt_id')['post_efficiency'].mean().reset_index()
# post_efficiency_df.rename(columns={'post_efficiency': 'avg_post_efficiency'}, inplace=True)
# post_efficiency_df

# %%
def calculate_post_efficiency_df(media_engagement_profile_merged_df):
    media_engagement_profile_merged_df_copy = media_engagement_profile_merged_df.copy()

    media_engagement_profile_merged_df_copy['post_efficiency'] = ((media_engagement_profile_merged_df_copy['like_cnt'] + media_engagement_profile_merged_df_copy['cmnt_cnt']) / media_engagement_profile_merged_df_copy['follower_cnt']) * 100
    post_efficiency_df = media_engagement_profile_merged_df_copy.groupby('acnt_id')['post_efficiency'].mean().reset_index()
    post_efficiency_df.rename(columns={'post_efficiency': 'avg_post_efficiency'}, inplace=True)

    return post_efficiency_df

# %%
post_efficiency_df = calculate_post_efficiency_df(media_engagement_profile_merged_df)

# %%
check_inf(post_efficiency_df)
# Out:
# ⚠️ inf / -inf 포함 행 개수: 0개
# Empty DataFrame
# Columns: [acnt_id, avg_post_efficiency]
# Index: []

# %% [markdown]
# ##### not_connected_influencer_flexmatch_score

# %%
# # 크리에이터 활동성
# creator_activity_score = activity_df[['acnt_id', 'activity_score']]
# # 트렌드지수
# creator_trend_score = growth_rate_df[['acnt_id', 'trend_score']]
# # 팔로워 참여도
# follower_engagement = follower_engagment_df[['acnt_id', 'follower_total_engagement']]
# # 팔로워 충성도
# follower_loyalty = follower_loyalty_df[['acnt_id', 'follower_retention_rate']]
# # 콘텐츠 효율성
# post_efficiency = post_efficiency_df[['acnt_id', 'avg_post_efficiency']]

# # data_list
# df_list = [creator_activity_score, creator_trend_score, follower_engagement, follower_loyalty, post_efficiency]

# from functools import reduce

# flexmatch_score = reduce(lambda left, right: pd.merge(left, right, on='acnt_id', how='left'), df_list)
# user_info_nm = recent_user_info_mtr[['acnt_id', 'acnt_nm', 'influencer_scale_type']]
# # user_info_nm
# flexmatch_score = pd.merge(flexmatch_score, user_info_nm, on='acnt_id')
# flexmatch_score = flexmatch_score[['acnt_id', 'acnt_nm', 'activity_score', 'trend_score', 'follower_total_engagement', 'follower_retention_rate', 'avg_post_efficiency']]

# flexmatch_score.rename(columns={
#     'avg_upload_interval' : '크리에이터 활동성',
#     'trend_score' : '트렌드지수(팔로워순증가량)', 
#     'follower_total_engagement' : '콘텐츠 참여도' ,
#     'follower_retention_rate' : '팔로워 충성도',
#     'avg_post_efficiency' : '콘텐츠 효율성',
# }, inplace=True)

# flexmatch_score_2 = flexmatch_score.copy()
# flexmatch_score_2.dropna(inplace=True)
# flexmatch_score_2

# %%
def not_connected_user_flexmatch_score(activity_df, growth_rate_df, follower_engagement_df, follower_loyalty_df, post_efficiency_df):
    # 크리에이터 활동성
    creator_activity_score = activity_df[['acnt_id', 'activity_score']]
    # 트렌드지수
    creator_trend_score = growth_rate_df[['acnt_id', 'trend_score']]
    # 팔로워 참여도
    follower_engagement = follower_engagement_df[['acnt_id', 'follower_total_engagement']]
    # 팔로워 충성도
    follower_loyalty = follower_loyalty_df[['acnt_id', 'follower_retention_rate']]
    # 콘텐츠 효율성
    post_efficiency = post_efficiency_df[['acnt_id', 'avg_post_efficiency']]

    # data_list
    df_list = [creator_activity_score, creator_trend_score, follower_engagement, follower_loyalty, post_efficiency]

    from functools import reduce

    flexmatch_score = reduce(lambda left, right: pd.merge(left, right, on='acnt_id', how='left'), df_list)
    user_info_nm = recent_user_info_mtr[['acnt_id', 'acnt_nm', 'influencer_scale_type']]
    flexmatch_score = pd.merge(flexmatch_score, user_info_nm, on='acnt_id')
    flexmatch_score = flexmatch_score[['acnt_id', 'acnt_nm', 'influencer_scale_type', 'activity_score', 'trend_score', 'follower_total_engagement', 'follower_retention_rate', 'avg_post_efficiency']]

    # flexmatch_score.rename(columns={
    #     'activity_score' : '크리에이터 활동성',
    #     'trend_score' : '팔로워순증감률', 
    #     'follower_total_engagement' : '콘텐츠 참여도' ,
    #     'follower_retention_rate' : '팔로워 충성도',
    #     'avg_post_efficiency' : '콘텐츠 효율성',
    # }, inplace=True)

    not_connected_flexmatch_score_table = flexmatch_score.copy()
    not_connected_flexmatch_score_table.dropna(inplace=True)
    
    return not_connected_flexmatch_score_table

# %%
not_connected_flexmatch_score_table = not_connected_user_flexmatch_score(activity_df, growth_rate_df, follower_engagment_df, follower_loyalty_df, post_efficiency_df)
not_connected_flexmatch_score_table
# Out:
#                acnt_id        acnt_nm influencer_scale_type  activity_score  \
# 0    17841400016295781      jihyolimm                   mid      184.615385
# 1    17841400038455668        kos9803                   mid       11.940299
# 2    17841400064417438     jjosworlds                   mid      141.176471
# 3    17841400070132367      gnuoyeatt                  nano       12.371134
# 4    17841400079187566     jjjjeong_2                 micro       16.666667
# ..                 ...            ...                   ...             ...
# 355  17841472245916641    bella_haus_                 micro       20.183486
# 356  17841473211163104     mom._.room                   mid      200.000000
# 357  17841473347851502  hyepick_place                 micro       45.283019
# 358  17841473857435791     sesebonbon                 micro      200.000000
# 359  17841474152637635     _samelee47                  nano       28.571429
#
#      trend_score  follower_total_engagement  follower_retention_rate  \
# 0       0.000000                 603.536863                   100.00
# 1      -0.020737                 290.415000                    99.98
# 2      -0.404967                2484.457250                    99.60
# 3      -0.110375                1464.088398                    99.89
# 4      -0.110041                 466.945745                    99.89
# ..           ...                        ...                      ...
# 355    39.187956                 345.354310                   100.00
# 356    17.509025                 595.526882                   100.00
# 357    -0.882292                 109.016651                    99.12
# 358     7.234432                 347.076923                   100.00
# 359     0.000000                  10.000000                   100.00
#
#      avg_post_efficiency
# 0               1.221735
# 1               0.335352
# 2               1.274734
# 3              13.812155
# 4               0.782154
# ..                   ...
# 355            16.321092
# 356            12.946237
# 357             3.633888
# 358             8.676923
# 359            10.000000
#
# [360 rows x 8 columns]

# %%
not_connected_flexmatch_score_table[not_connected_flexmatch_score_table['acnt_id']=='17841400111322589']
# Out:
#              acnt_id   acnt_nm influencer_scale_type  activity_score  \
# 6  17841400111322589  seon4123                  nano      266.666667
#
#    trend_score  follower_total_engagement  follower_retention_rate  \
# 6    -0.206186                1053.487603                    99.79
#
#    avg_post_efficiency
# 6             1.024793

# %%
not_connected_flexmatch_score_table[not_connected_flexmatch_score_table['acnt_id']=='17841400070132367']
# Out:
#              acnt_id    acnt_nm influencer_scale_type  activity_score  \
# 3  17841400070132367  gnuoyeatt                  nano       12.371134
#
#    trend_score  follower_total_engagement  follower_retention_rate  \
# 3    -0.110375                1464.088398                    99.89
#
#    avg_post_efficiency
# 3            13.812155

# %%
not_connected_flexmatch_score_table['influencer_scale_type'].value_counts()
# Out:
# influencer_scale_type
# micro    146
# mid      105
# nano      93
# macro     15
# mega       1
# Name: count, dtype: int64

# %%
nano = not_connected_flexmatch_score_table[not_connected_flexmatch_score_table['influencer_scale_type']=='nano']
micro = not_connected_flexmatch_score_table[not_connected_flexmatch_score_table['influencer_scale_type']=='micro']
mid = not_connected_flexmatch_score_table[not_connected_flexmatch_score_table['influencer_scale_type']=='mid']
macro = not_connected_flexmatch_score_table[not_connected_flexmatch_score_table['influencer_scale_type']=='macro']
mega = not_connected_flexmatch_score_table[not_connected_flexmatch_score_table['influencer_scale_type']=='mega']

# %%
# influencer_scale_df_list = [nano, micro, mid, macro, mega]


# for df in influencer_scale_df_list :
#     columns = df.select_dtypes(include='float64').columns
#     cleaned = df[columns].replace([np.inf, -np.inf], np.nan).dropna()
#     minmax = MinMaxScaler(feature_range=(0, 5))
#     flexmatch_score_norm = minmax.fit_transform(cleaned[columns])

#     flexmatch_score_norm_df = pd.DataFrame(flexmatch_score_norm, columns=columns, index=cleaned.index)
#     flexmatch_score_norm_df['acnt_id'] = df['acnt_id']
#     flexmatch_score_norm_df['acnt_nm'] = df['acnt_nm']

#     flexmatch_score_norm_df['크리에이터 활동성'] = 5 - flexmatch_score_norm_df['크리에이터 활동성']

# %%
influencer_scale_df_list = [nano, micro, mid, macro, mega]
normalized_df_list = []

# 높을수록 안 좋은 지표
reverse_columns = []  

for df in influencer_scale_df_list:
    cleaned = df.copy()

    # 무한대 및 NaN 제거
    float_cols = cleaned.select_dtypes(include='float64').columns
    cleaned[float_cols] = cleaned[float_cols].replace([np.inf, -np.inf], np.nan)
    cleaned = cleaned.dropna(subset=float_cols)

    if cleaned.empty:
        continue

    # 개별 컬럼 정규화 (0~5 스케일)
    norm_df = pd.DataFrame(index=cleaned.index)
    for col in float_cols:
        scaler = MinMaxScaler(feature_range=(0, 5))
        norm_col = scaler.fit_transform(cleaned[[col]])
        # norm_df[col] = 5 - norm_col.ravel() if col in reverse_columns else norm_col.ravel()
        norm_df[col] = norm_col.ravel() if col in reverse_columns else norm_col.ravel()

    # ID 및 이름 붙이기
    norm_df['acnt_id'] = cleaned['acnt_id'].values
    norm_df['acnt_nm'] = cleaned['acnt_nm'].values

    normalized_df_list.append(norm_df)

# %%
influencer_scale_names = ['nano', 'micro', 'mid', 'macro', 'mega']
influencer_scale_df_list = [nano, micro, mid, macro, mega]
normalized_df_dict = {}
# normalized_df_list = []

reverse_columns = []

for name, df in zip(influencer_scale_names, influencer_scale_df_list):
    cleaned = df.copy()

    # 무한대 및 NaN 제거
    float_cols = cleaned.select_dtypes(include='float64').columns
    cleaned[float_cols] = cleaned[float_cols].replace([np.inf, -np.inf], np.nan)
    cleaned = cleaned.dropna(subset=float_cols)

    if cleaned.empty:
        continue

    norm_df = pd.DataFrame(index=cleaned.index)
    for col in float_cols:
        scaler = MinMaxScaler(feature_range=(0, 5))
        norm_col = scaler.fit_transform(cleaned[[col]])
        # norm_df[col] = 5 - norm_col.ravel() if col in reverse_columns else norm_col.ravel()
        norm_df[col] = norm_col.ravel() if col in reverse_columns else norm_col.ravel()

    # ID 및 이름 붙이기
    norm_df['acnt_id'] = cleaned['acnt_id'].values
    norm_df['acnt_nm'] = cleaned['acnt_nm'].values
    norm_df['influencer_scale_type'] = name

    # 딕셔너리에 저장
    normalized_df_dict[name] = norm_df

normalized_all_df = pd.concat(normalized_df_dict, ignore_index=True)
normalized_all_dic = normalized_all_df.to_dict(orient='index')

# %%
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
import numpy as np

def normalize_influencer_scores(influencer_scale_names, influencer_scale_df_list, reverse_columns=None, feature_range=(0, 5)):

    if reverse_columns is None:
        reverse_columns = []

    normalized_df_dict = {}

    for name, df in zip(influencer_scale_names, influencer_scale_df_list):
        cleaned = df.copy()

        # 무한대 및 NaN 제거
        float_cols = cleaned.select_dtypes(include='float64').columns
        cleaned[float_cols] = cleaned[float_cols].replace([np.inf, -np.inf], np.nan)
        cleaned = cleaned.dropna(subset=float_cols)

        if cleaned.empty:
            continue

        norm_df = pd.DataFrame(index=cleaned.index)
        for col in float_cols:
            scaler = MinMaxScaler(feature_range=feature_range)
            norm_col = scaler.fit_transform(cleaned[[col]])
            if col in reverse_columns:
                norm_df[col] = feature_range[1] - norm_col.ravel()
            else:
                norm_df[col] = norm_col.ravel()

        # ID 및 이름, 스케일 타입 추가
        norm_df['acnt_id'] = cleaned['acnt_id'].values
        norm_df['acnt_nm'] = cleaned['acnt_nm'].values
        norm_df['influencer_scale_type'] = name

        normalized_df_dict[name] = norm_df

    normalized_all_df = pd.concat(normalized_df_dict.values(), ignore_index=True)
    normalized_all_dic = normalized_all_df.to_dict(orient='index')

    return normalized_all_df, normalized_all_dic

# %%
influencer_scale_names=['nano', 'micro', 'mid', 'macro', 'mega']
influencer_scale_df_list=[nano, micro, mid, macro, mega]

normalized_df, normalized_dic = normalize_influencer_scores(influencer_scale_names, influencer_scale_df_list)

# %%
normalized_all_dic
# Out:
# {0: {'activity_score': 0.18618008163528707,
#   'trend_score': 1.2384506112322682,
#   'follower_total_engagement': 0.9006925508419993,
#   'follower_retention_rate': 4.84593837535013,
#   'avg_post_efficiency': 1.4776093002849746,
#   'acnt_id': '17841400070132367',
#   'acnt_nm': 'gnuoyeatt',
#   'influencer_scale_type': 'nano'},
#  1: {'activity_score': 4.442126007071234,
#   'trend_score': 1.2041673155386674,
#   'follower_total_engagement': 0.6477789738723821,
#   'follower_retention_rate': 4.70588235294116,
#   'avg_post_efficiency': 0.07223635090475532,
#   'acnt_id': '17841400111322589',
#   'acnt_nm': 'seon4123',
#   'influencer_scale_type': 'nano'},
#  2: {'activity_score': 0.7667208771875991,
#   'trend_score': 1.338593886015669,
#   'follower_total_engagement': 3.2795727597981803,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.3240928471358846,
#   'acnt_id': '17841400204233993',
#   'acnt_nm': 'j_solha',
#   'influencer_scale_type': 'nano'},
#  3: {'activity_score': 0.20735524256651017,
#   'trend_score': 1.3576393327905583,
#   'follower_total_engagement': 0.5473126184561684,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.28150269170720965,
#   'acnt_id': '17841400297953515',
#   'acnt_nm': 'j.yyyyyul',
#   'influencer_scale_type': 'nano'},
#  4: {'activity_score': 1.0090552813557507,
#   'trend_score': 1.4029135262319354,
#   'follower_total_engagement': 2.127321298024773,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.23500388611512982,
#   'acnt_id': '17841400483419781',
#   'acnt_nm': 'hyeryeon_yoon',
#   'influencer_scale_type': 'nano'},
#  5: {'activity_score': 0.09762057541358718,
#   'trend_score': 1.3462327898341826,
#   'follower_total_engagement': 0.5942819963246702,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.3272085001864806,
#   'acnt_id': '17841400532714000',
#   'acnt_nm': '2sarada90',
#   'influencer_scale_type': 'nano'},
#  6: {'activity_score': 0.13186002368244107,
#   'trend_score': 1.0433064236541032,
#   'follower_total_engagement': 0.1767776121910973,
#   'follower_retention_rate': 4.0756302521008365,
#   'avg_post_efficiency': 0.6074209287956516,
#   'acnt_id': '17841400587197476',
#   'acnt_nm': 'sm1112',
#   'influencer_scale_type': 'nano'},
#  7: {'activity_score': 0.06819598712419048,
#   'trend_score': 1.2779456193353473,
#   'follower_total_engagement': 2.9331246459236895,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.6173305278984749,
#   'acnt_id': '17841400588709226',
#   'acnt_nm': 'seul90',
#   'influencer_scale_type': 'nano'},
#  8: {'activity_score': 0.007580896141722859,
#   'trend_score': 1.207229260953154,
#   'follower_total_engagement': 1.5451003578418703,
#   'follower_retention_rate': 4.71988795518206,
#   'avg_post_efficiency': 1.2671307820584667,
#   'acnt_id': '17841400590387514',
#   'acnt_nm': 'kay.kwon.kr',
#   'influencer_scale_type': 'nano'},
#  9: {'activity_score': 0.21541010770505387,
#   'trend_score': 1.2779456193353473,
#   'follower_total_engagement': 0.18389511720472662,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.0916592854593965,
#   'acnt_id': '17841400593366620',
#   'acnt_nm': 'attraction_sa',
#   'influencer_scale_type': 'nano'},
#  10: {'activity_score': 0.06477783227835782,
#   'trend_score': 1.2779456193353473,
#   'follower_total_engagement': 4.435015345986951,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 2.1341230920437075,
#   'acnt_id': '17841400718160676',
#   'acnt_nm': 'bbongslim',
#   'influencer_scale_type': 'nano'},
#  11: {'activity_score': 0.9354894800904191,
#   'trend_score': 1.3578172205438066,
#   'follower_total_engagement': 5.0,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.7281968354262629,
#   'acnt_id': '17841400802104441',
#   'acnt_nm': 'huizhenzhen_',
#   'influencer_scale_type': 'nano'},
#  12: {'activity_score': 5.0,
#   'trend_score': 1.4188215143801888,
#   'follower_total_engagement': 1.322737225351321,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.08373425359856503,
#   'acnt_id': '17841401028212046',
#   'acnt_nm': 'kevinkim911',
#   'influencer_scale_type': 'nano'},
#  13: {'activity_score': 0.11908851482881022,
#   'trend_score': 1.2779456193353473,
#   'follower_total_engagement': 3.184458754837271,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.3024257666918446,
#   'acnt_id': '17841401032620068',
#   'acnt_nm': 'insunkwak',
#   'influencer_scale_type': 'nano'},
#  14: {'activity_score': 0.0,
#   'trend_score': 1.1866637893828225,
#   'follower_total_engagement': 0.2379724964581205,
#   'follower_retention_rate': 4.6358543417366604,
#   'avg_post_efficiency': 1.3357883971406754,
#   'acnt_id': '17841401293139137',
#   'acnt_nm': '_movingday',
#   'influencer_scale_type': 'nano'},
#  15: {'activity_score': 0.3004694835680751,
#   'trend_score': 1.2354990269968067,
#   'follower_total_engagement': 0.45015935107069405,
#   'follower_retention_rate': 4.83193277310923,
#   'avg_post_efficiency': 0.18515792039872453,
#   'acnt_id': '17841401374507119',
#   'acnt_nm': 'yeeeee_jini',
#   'influencer_scale_type': 'nano'},
#  16: {'activity_score': 0.0882833231271688,
#   'trend_score': 1.2779456193353473,
#   'follower_total_engagement': 0.9726397784595547,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.19376638718308317,
#   'acnt_id': '17841401443052146',
#   'acnt_nm': 'kyounghye0517',
#   'influencer_scale_type': 'nano'},
#  17: {'activity_score': 0.06919443918117574,
#   'trend_score': 1.2779456193353473,
#   'follower_total_engagement': 1.7593372457158274,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.8780664133903275,
#   'acnt_id': '17841401486674215',
#   'acnt_nm': 'minhee0216',
#   'influencer_scale_type': 'nano'},
#  18: {'activity_score': 0.09975546751759584,
#   'trend_score': 1.398021046655447,
#   'follower_total_engagement': 0.4751437944291725,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.32276686038471136,
#   'acnt_id': '17841401530775838',
#   'acnt_nm': 'touritst_genie',
#   'influencer_scale_type': 'nano'},
#  19: {'activity_score': 1.4136671883150755,
#   'trend_score': 1.2779456193353473,
#   'follower_total_engagement': 0.11228991951840198,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.023851176320975775,
#   'acnt_id': '17841401615883791',
#   'acnt_nm': 'rinaseong',
#   'influencer_scale_type': 'nano'},
#  20: {'activity_score': 0.048627017777561184,
#   'trend_score': 1.2779456193353473,
#   'follower_total_engagement': 0.3466894656118996,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.0879632347545671,
#   'acnt_id': '17841401629705047',
#   'acnt_nm': 'soulvoice1987',
#   'influencer_scale_type': 'nano'},
#  21: {'activity_score': 0.050732864872605275,
#   'trend_score': 1.3506742318178468,
#   'follower_total_engagement': 0.5830577323621743,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.300241485787321,
#   'acnt_id': '17841401639140025',
#   'acnt_nm': 'summerkim__',
#   'influencer_scale_type': 'nano'},
#  22: {'activity_score': 0.012550808641830648,
#   'trend_score': 1.2779456193353473,
#   'follower_total_engagement': 0.5223724026753216,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 2.4840931173160894,
#   'acnt_id': '17841401738522234',
#   'acnt_nm': 'eunchong326',
#   'influencer_scale_type': 'nano'},
#  23: {'activity_score': 0.2723233153992895,
#   'trend_score': 1.2779456193353473,
#   'follower_total_engagement': 1.45342764931814,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.19858652503971727,
#   'acnt_id': '17841401784692335',
#   'acnt_nm': 'totoro0550',
#   'influencer_scale_type': 'nano'},
#  24: {'activity_score': 0.013760725271167229,
#   'trend_score': 1.2779456193353473,
#   'follower_total_engagement': 0.736062368439967,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.9127516859323491,
#   'acnt_id': '17841401850643757',
#   'acnt_nm': 'michelle_ynoh',
#   'influencer_scale_type': 'nano'},
#  25: {'activity_score': 2.489567031820553,
#   'trend_score': 1.3754455575952649,
#   'follower_total_engagement': 0.8503838171845242,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.01575443709900068,
#   'acnt_id': '17841401921070593',
#   'acnt_nm': 'hi_angsoo',
#   'influencer_scale_type': 'nano'},
#  26: {'activity_score': 0.03944476557935087,
#   'trend_score': 1.37960038450975,
#   'follower_total_engagement': 0.430219318701651,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.10905174971199835,
#   'acnt_id': '17841402048303273',
#   'acnt_nm': 'vvipsvip',
#   'influencer_scale_type': 'nano'},
#  27: {'activity_score': 0.062295404201915726,
#   'trend_score': 1.2779456193353473,
#   'follower_total_engagement': 0.3510870793496411,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.1008310637408445,
#   'acnt_id': '17841402265949784',
#   'acnt_nm': 'soro_1217',
#   'influencer_scale_type': 'nano'},
#  28: {'activity_score': 0.04541612220689987,
#   'trend_score': 1.3695780837179075,
#   'follower_total_engagement': 3.355584763280457,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.39079960871452346,
#   'acnt_id': '17841402652660371',
#   'acnt_nm': 'ykl0422',
#   'influencer_scale_type': 'nano'},
#  29: {'activity_score': 0.13186002368244107,
#   'trend_score': 1.242091433622532,
#   'follower_total_engagement': 0.49468785913777,
#   'follower_retention_rate': 4.85994397759103,
#   'avg_post_efficiency': 0.0976211415742794,
#   'acnt_id': '17841403245207523',
#   'acnt_nm': 'soulruka',
#   'influencer_scale_type': 'nano'},
#  30: {'activity_score': 0.09389671361502347,
#   'trend_score': 0.9128182995252481,
#   'follower_total_engagement': 1.3259170570403596,
#   'follower_retention_rate': 3.571428571428555,
#   'avg_post_efficiency': 0.8365683887043333,
#   'acnt_id': '17841403690842921',
#   'acnt_nm': 'jisoocori',
#   'influencer_scale_type': 'nano'},
#  31: {'activity_score': 0.018903298780582285,
#   'trend_score': 1.2779456193353473,
#   'follower_total_engagement': 0.023701145722757014,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.11782221412026853,
#   'acnt_id': '17841403918276288',
#   'acnt_nm': 'suhhahi',
#   'influencer_scale_type': 'nano'},
#  32: {'activity_score': 1.4136671883150755,
#   'trend_score': 1.125679758308157,
#   'follower_total_engagement': 0.09847946481379935,
#   'follower_retention_rate': 4.39775910364142,
#   'avg_post_efficiency': 0.0,
#   'acnt_id': '17841404867713313',
#   'acnt_nm': 'znzl5689',
#   'influencer_scale_type': 'nano'},
#  33: {'activity_score': 0.04985048527996356,
#   'trend_score': 1.2779456193353473,
#   'follower_total_engagement': 2.4565525175193095,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.7289311557821498,
#   'acnt_id': '17841405446581360',
#   'acnt_nm': 'imsujini88',
#   'influencer_scale_type': 'nano'},
#  34: {'activity_score': 0.03434633510622088,
#   'trend_score': 1.2779456193353473,
#   'follower_total_engagement': 0.0064260571910038,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.07618833891091574,
#   'acnt_id': '17841405735233010',
#   'acnt_nm': 'flex_h.y',
#   'influencer_scale_type': 'nano'},
#  35: {'activity_score': 0.03319453132733894,
#   'trend_score': 1.3635496321137917,
#   'follower_total_engagement': 0.7191842871684775,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.20302166589718923,
#   'acnt_id': '17841405960290513',
#   'acnt_nm': 'kjnon1026',
#   'influencer_scale_type': 'nano'},
#  36: {'activity_score': 0.05622989375794112,
#   'trend_score': 1.2779456193353473,
#   'follower_total_engagement': 0.6009661543953242,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.5466525451647628,
#   'acnt_id': '17841406001951671',
#   'acnt_nm': 'gukja98',
#   'influencer_scale_type': 'nano'},
#  37: {'activity_score': 1.094882049498638,
#   'trend_score': 1.3209534046014408,
#   'follower_total_engagement': 4.648501239674523,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.3168928085735826,
#   'acnt_id': '17841406919372473',
#   'acnt_nm': '12styles',
#   'influencer_scale_type': 'nano'},
#  38: {'activity_score': 0.062295404201915726,
#   'trend_score': 1.2779456193353473,
#   'follower_total_engagement': 0.15316863249851462,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.3419743986784016,
#   'acnt_id': '17841407376200009',
#   'acnt_nm': 'sh851029',
#   'influencer_scale_type': 'nano'},
#  39: {'activity_score': 0.07758241533441754,
#   'trend_score': 1.2189959037811633,
#   'follower_total_engagement': 1.2410382136653038,
#   'follower_retention_rate': 4.775910364145659,
#   'avg_post_efficiency': 0.44564910421064197,
#   'acnt_id': '17841408084939632',
#   'acnt_nm': 'sweet_potato36',
#   'influencer_scale_type': 'nano'},
#  40: {'activity_score': 0.10310606206972056,
#   'trend_score': 1.103962747335073,
#   'follower_total_engagement': 0.15296324191139596,
#   'follower_retention_rate': 4.313725490196077,
#   'avg_post_efficiency': 0.4178368552606476,
#   'acnt_id': '17841411461566186',
#   'acnt_nm': 'dbbibbi',
#   'influencer_scale_type': 'nano'},
#  41: {'activity_score': 0.01601829457854497,
#   'trend_score': 1.2779456193353473,
#   'follower_total_engagement': 0.6024516600557742,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.821161546478074,
#   'acnt_id': '17841411649994165',
#   'acnt_nm': 'seungje69',
#   'influencer_scale_type': 'nano'},
#  42: {'activity_score': 1.7255222154181125,
#   'trend_score': 1.6733321092954547,
#   'follower_total_engagement': 0.18358013035228582,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.28271182797457517,
#   'acnt_id': '17841412336851729',
#   'acnt_nm': 'naegyeong2',
#   'influencer_scale_type': 'nano'},
#  43: {'activity_score': 0.29726055547651786,
#   'trend_score': 1.0417576500852501,
#   'follower_total_engagement': 0.0633093277176063,
#   'follower_retention_rate': 4.0756302521008365,
#   'avg_post_efficiency': 0.45861533659398823,
#   'acnt_id': '17841415107014253',
#   'acnt_nm': 'hongsyn',
#   'influencer_scale_type': 'nano'},
#  44: {'activity_score': 0.737000620072637,
#   'trend_score': 1.3527261362452527,
#   'follower_total_engagement': 0.3187969650003888,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.009116243115767697,
#   'acnt_id': '17841418240434019',
#   'acnt_nm': '1209_1124',
#   'influencer_scale_type': 'nano'},
#  45: {'activity_score': 0.4019438267029075,
#   'trend_score': 1.4061982262937334,
#   'follower_total_engagement': 0.29118989152163405,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.4337623468244147,
#   'acnt_id': '17841423147019767',
#   'acnt_nm': 'haeneul_woojoo',
#   'influencer_scale_type': 'nano'},
#  46: {'activity_score': 0.175070295303892,
#   'trend_score': 0.9658891308929951,
#   'follower_total_engagement': 0.13952856750628037,
#   'follower_retention_rate': 3.7815126050419963,
#   'avg_post_efficiency': 0.3579672988887088,
#   'acnt_id': '17841430430382691',
#   'acnt_nm': 'b_ri_27',
#   'influencer_scale_type': 'nano'},
#  47: {'activity_score': 0.18618008163528707,
#   'trend_score': 1.3860497804875822,
#   'follower_total_engagement': 0.2865187748066536,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.2615111820993997,
#   'acnt_id': '17841436609182687',
#   'acnt_nm': 'lovesome_nini',
#   'influencer_scale_type': 'nano'},
#  48: {'activity_score': 0.053517262698274705,
#   'trend_score': 1.2048455634795971,
#   'follower_total_engagement': 0.12147230074215268,
#   'follower_retention_rate': 4.71988795518206,
#   'avg_post_efficiency': 0.1679407187133127,
#   'acnt_id': '17841438292231131',
#   'acnt_nm': 'charmin.grl',
#   'influencer_scale_type': 'nano'},
#  49: {'activity_score': 0.006001573668444459,
#   'trend_score': 1.2779456193353473,
#   'follower_total_engagement': 0.08826738057684844,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.27235901290216713,
#   'acnt_id': '17841439225730933',
#   'acnt_nm': 'review_ddook',
#   'influencer_scale_type': 'nano'},
#  50: {'activity_score': 0.01699167673335014,
#   'trend_score': 1.2779456193353473,
#   'follower_total_engagement': 0.2571703937394957,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.4027523450630257,
#   'acnt_id': '17841439791628421',
#   'acnt_nm': 'kkochang_cos',
#   'influencer_scale_type': 'nano'},
#  51: {'activity_score': 1.9874804381846634,
#   'trend_score': 1.539131585330893,
#   'follower_total_engagement': 0.6885336885386285,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.0204137677732528,
#   'acnt_id': '17841443737382400',
#   'acnt_nm': 'kan__jung',
#   'influencer_scale_type': 'nano'},
#  52: {'activity_score': 0.1974325826132317,
#   'trend_score': 1.8693915258045992,
#   'follower_total_engagement': 0.269294345446564,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.2998920978630826,
#   'acnt_id': '17841444317992419',
#   'acnt_nm': 'sayhello_0123',
#   'influencer_scale_type': 'nano'},
#  53: {'activity_score': 0.5146930968527212,
#   'trend_score': 1.4094988448551624,
#   'follower_total_engagement': 0.9658531255966201,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.7196719050919862,
#   'acnt_id': '17841445132536071',
#   'acnt_nm': 'smh_pomy1004',
#   'influencer_scale_type': 'nano'},
#  54: {'activity_score': 0.03926419461546391,
#   'trend_score': 1.2779456193353473,
#   'follower_total_engagement': 0.7829515504932633,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.5841620077350143,
#   'acnt_id': '17841445316242409',
#   'acnt_nm': 'cafe_mjj',
#   'influencer_scale_type': 'nano'},
#  55: {'activity_score': 0.04709840795730074,
#   'trend_score': 1.2779456193353473,
#   'follower_total_engagement': 1.0238300582989686,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.747879997149576,
#   'acnt_id': '17841445530983804',
#   'acnt_nm': 'lucystory03',
#   'influencer_scale_type': 'nano'},
#  56: {'activity_score': 0.07276326525152815,
#   'trend_score': 1.2779456193353473,
#   'follower_total_engagement': 0.050342458275128815,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.08370950757437563,
#   'acnt_id': '17841445643835132',
#   'acnt_nm': 'zeppetto81',
#   'influencer_scale_type': 'nano'},
#  57: {'activity_score': 0.01118510903001918,
#   'trend_score': 1.2779456193353473,
#   'follower_total_engagement': 0.1880958224132597,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.4249852620122698,
#   'acnt_id': '17841445666937156',
#   'acnt_nm': '__moggu__',
#   'influencer_scale_type': 'nano'},
#  58: {'activity_score': 0.056378154969704254,
#   'trend_score': 1.066214984179195,
#   'follower_total_engagement': 0.36244323947358537,
#   'follower_retention_rate': 4.173669467787107,
#   'avg_post_efficiency': 0.9892972594283788,
#   'acnt_id': '17841445706534901',
#   'acnt_nm': 'gimpo_market',
#   'influencer_scale_type': 'nano'},
#  59: {'activity_score': 2.21063003535617,
#   'trend_score': 1.6148099457710248,
#   'follower_total_engagement': 0.7451634686961548,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.5436330869242706,
#   'acnt_id': '17841445825421303',
#   'acnt_nm': 'seol1112',
#   'influencer_scale_type': 'nano'},
#  60: {'activity_score': 0.14719652176190567,
#   'trend_score': 1.3639611898675341,
#   'follower_total_engagement': 1.5022757132260727,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.351781051270487,
#   'acnt_id': '17841448271359564',
#   'acnt_nm': 'soulmate.0817',
#   'influencer_scale_type': 'nano'},
#  61: {'activity_score': 1.1267605633802815,
#   'trend_score': 0.9994827606474895,
#   'follower_total_engagement': 0.4814569358747132,
#   'follower_retention_rate': 3.9075630252100666,
#   'avg_post_efficiency': 0.15441714735815615,
#   'acnt_id': '17841449913495321',
#   'acnt_nm': 'goneemama',
#   'influencer_scale_type': 'nano'},
#  62: {'activity_score': 0.04027093957850491,
#   'trend_score': 1.2779456193353473,
#   'follower_total_engagement': 0.7010575998217279,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 2.516506940966639,
#   'acnt_id': '17841449982443435',
#   'acnt_nm': 'soli_beem',
#   'influencer_scale_type': 'nano'},
#  63: {'activity_score': 0.046641504802233884,
#   'trend_score': 1.1777145903678692,
#   'follower_total_engagement': 3.1818244013183086,
#   'follower_retention_rate': 4.607843137254889,
#   'avg_post_efficiency': 2.6769359208525474,
#   'acnt_id': '17841450345136721',
#   'acnt_nm': '____yulbro____',
#   'influencer_scale_type': 'nano'},
#  64: {'activity_score': 0.10954616588419405,
#   'trend_score': 1.1681834189016365,
#   'follower_total_engagement': 0.4863037496882982,
#   'follower_retention_rate': 4.56582633053219,
#   'avg_post_efficiency': 0.42221646378989774,
#   'acnt_id': '17841451635925488',
#   'acnt_nm': 'nanangmanssi',
#   'influencer_scale_type': 'nano'},
#  65: {'activity_score': 0.11302382194400973,
#   'trend_score': 1.1554028887141496,
#   'follower_total_engagement': 1.27448123996718,
#   'follower_retention_rate': 4.523809523809518,
#   'avg_post_efficiency': 4.174455632796466,
#   'acnt_id': '17841452448927260',
#   'acnt_nm': 'daylog_c',
#   'influencer_scale_type': 'nano'},
#  66: {'activity_score': 0.2660406885758998,
#   'trend_score': 0.7739670652312666,
#   'follower_total_engagement': 0.11372307812305993,
#   'follower_retention_rate': 3.0252100840336027,
#   'avg_post_efficiency': 2.9910063570007983,
#   'acnt_id': '17841453655907894',
#   'acnt_nm': 'ninetys_90z',
#   'influencer_scale_type': 'nano'},
#  67: {'activity_score': 0.12680659118107335,
#   'trend_score': 1.4935027117533577,
#   'follower_total_engagement': 0.2669445762664186,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.37552959097385386,
#   'acnt_id': '17841454351752346',
#   'acnt_nm': 'rareyul',
#   'influencer_scale_type': 'nano'},
#  68: {'activity_score': 0.12957199431852595,
#   'trend_score': 2.1758747872497697,
#   'follower_total_engagement': 0.0372931853999459,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.1554701002788964,
#   'acnt_id': '17841455388870972',
#   'acnt_nm': 'elie0723',
#   'influencer_scale_type': 'nano'},
#  69: {'activity_score': 0.13421872576802155,
#   'trend_score': 1.4413359268302777,
#   'follower_total_engagement': 0.30528497127030374,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.6789751194498445,
#   'acnt_id': '17841457700514314',
#   'acnt_nm': 'hi_kooing',
#   'influencer_scale_type': 'nano'},
#  70: {'activity_score': 0.23335512370991068,
#   'trend_score': 1.2779456193353473,
#   'follower_total_engagement': 0.5731134539727142,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.968617375522786,
#   'acnt_id': '17841458346986749',
#   'acnt_nm': 'meok_santa',
#   'influencer_scale_type': 'nano'},
#  71: {'activity_score': 0.040085395190227524,
#   'trend_score': 1.0211335810000144,
#   'follower_total_engagement': 0.5883034475406871,
#   'follower_retention_rate': 3.9915966386554373,
#   'avg_post_efficiency': 2.5247242671378034,
#   'acnt_id': '17841459150352271',
#   'acnt_nm': '_jj__99__',
#   'influencer_scale_type': 'nano'},
#  72: {'activity_score': 0.042289610010400165,
#   'trend_score': 0.0,
#   'follower_total_engagement': 0.34928565407255785,
#   'follower_retention_rate': 0.0,
#   'avg_post_efficiency': 2.043700023105709,
#   'acnt_id': '17841459626202227',
#   'acnt_nm': 'meowmoue',
#   'influencer_scale_type': 'nano'},
#  73: {'activity_score': 0.10746290546497539,
#   'trend_score': 1.1708124536425637,
#   'follower_total_engagement': 0.630918005363297,
#   'follower_retention_rate': 4.579831932773089,
#   'avg_post_efficiency': 2.9273267942832537,
#   'acnt_id': '17841460040181185',
#   'acnt_nm': 'kkudam_',
#   'influencer_scale_type': 'nano'},
#  74: {'activity_score': 0.3476379855757036,
#   'trend_score': 1.4199395770392749,
#   'follower_total_engagement': 0.46242532045568996,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.5677686385709737,
#   'acnt_id': '17841460588103672',
#   'acnt_nm': 'yujiwon628',
#   'influencer_scale_type': 'nano'},
#  75: {'activity_score': 0.05622989375794112,
#   'trend_score': 1.2779456193353473,
#   'follower_total_engagement': 0.07880158861488679,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.45137880476978265,
#   'acnt_id': '17841463893430301',
#   'acnt_nm': 'mukyuding_',
#   'influencer_scale_type': 'nano'},
#  76: {'activity_score': 0.10348987630634165,
#   'trend_score': 1.2779456193353473,
#   'follower_total_engagement': 0.09116805163188499,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.3099879189806798,
#   'acnt_id': '17841464003665583',
#   'acnt_nm': 'velyoung2m',
#   'influencer_scale_type': 'nano'},
#  77: {'activity_score': 1.094882049498638,
#   'trend_score': 1.348942598187311,
#   'follower_total_engagement': 0.0,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.06220531755815277,
#   'acnt_id': '17841464134128386',
#   'acnt_nm': 'it.tem___',
#   'influencer_scale_type': 'nano'},
#  78: {'activity_score': 0.39322609962946825,
#   'trend_score': 1.2779456193353473,
#   'follower_total_engagement': 0.7535117070690898,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.9644381842058746,
#   'acnt_id': '17841464778435646',
#   'acnt_nm': 'hastar3_3',
#   'influencer_scale_type': 'nano'},
#  79: {'activity_score': 0.5278625812759578,
#   'trend_score': 2.6541947478503367,
#   'follower_total_engagement': 0.3160238256985688,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 3.167543439402628,
#   'acnt_id': '17841465388966562',
#   'acnt_nm': 'iam.lovemom',
#   'influencer_scale_type': 'nano'},
#  80: {'activity_score': 0.10828817132879448,
#   'trend_score': 1.1067375937784587,
#   'follower_total_engagement': 0.15473449284328014,
#   'follower_retention_rate': 4.327731092436949,
#   'avg_post_efficiency': 0.6063467281667237,
#   'acnt_id': '17841465775699880',
#   'acnt_nm': 'beauty_dohyi',
#   'influencer_scale_type': 'nano'},
#  81: {'activity_score': 3.6306729264475743,
#   'trend_score': 1.2779456193353473,
#   'follower_total_engagement': 0.4088897932391157,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.5356529738344034,
#   'acnt_id': '17841466835485122',
#   'acnt_nm': 'kikikiki_eun',
#   'influencer_scale_type': 'nano'},
#  82: {'activity_score': 0.0628151625804208,
#   'trend_score': 1.032860158092952,
#   'follower_total_engagement': 0.03955181033386666,
#   'follower_retention_rate': 4.047619047619037,
#   'avg_post_efficiency': 5.000000000000001,
#   'acnt_id': '17841466979796967',
#   'acnt_nm': 'iseolriem',
#   'influencer_scale_type': 'nano'},
#  83: {'activity_score': 0.056856446556878236,
#   'trend_score': 1.174077760579499,
#   'follower_total_engagement': 0.17199443639052414,
#   'follower_retention_rate': 4.593837535013989,
#   'avg_post_efficiency': 2.9761492766143838,
#   'acnt_id': '17841466998593596',
#   'acnt_nm': 'nao_yim',
#   'influencer_scale_type': 'nano'},
#  84: {'activity_score': 0.6167043412739813,
#   'trend_score': 1.2010767099016422,
#   'follower_total_engagement': 0.1663848644389226,
#   'follower_retention_rate': 4.70588235294116,
#   'avg_post_efficiency': 0.5695773150209514,
#   'acnt_id': '17841467078397304',
#   'acnt_nm': 'hyunnn138_',
#   'influencer_scale_type': 'nano'},
#  85: {'activity_score': 0.4940946724984283,
#   'trend_score': 1.2370980424616147,
#   'follower_total_engagement': 0.24053758255185623,
#   'follower_retention_rate': 4.84593837535013,
#   'avg_post_efficiency': 0.1043037145281854,
#   'acnt_id': '17841467085828788',
#   'acnt_nm': 'ingyuking2',
#   'influencer_scale_type': 'nano'},
#  86: {'activity_score': 0.5007824726134585,
#   'trend_score': 0.9911121336328245,
#   'follower_total_engagement': 0.11642050201139785,
#   'follower_retention_rate': 3.879551820728267,
#   'avg_post_efficiency': 0.17808259515793054,
#   'acnt_id': '17841467436798662',
#   'acnt_nm': 'i_am_foodist',
#   'influencer_scale_type': 'nano'},
#  87: {'activity_score': 0.29050559457809155,
#   'trend_score': 1.3143469187670764,
#   'follower_total_engagement': 0.7647563712920508,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.6864888322315327,
#   'acnt_id': '17841467581724114',
#   'acnt_nm': 'kooney2024',
#   'influencer_scale_type': 'nano'},
#  88: {'activity_score': 0.5612634475667747,
#   'trend_score': 1.1653040327412558,
#   'follower_total_engagement': 0.29163412357087287,
#   'follower_retention_rate': 4.56582633053219,
#   'avg_post_efficiency': 2.3339817934281353,
#   'acnt_id': '17841469380767019',
#   'acnt_nm': '_bbo_iing',
#   'influencer_scale_type': 'nano'},
#  89: {'activity_score': 3.995826812728221,
#   'trend_score': 1.452069596665711,
#   'follower_total_engagement': 0.1314609302088606,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.1458849419105329,
#   'acnt_id': '17841469588134780',
#   'acnt_nm': 'review.cat',
#   'influencer_scale_type': 'nano'},
#  90: {'activity_score': 0.2022836608126123,
#   'trend_score': 1.2779456193353473,
#   'follower_total_engagement': 0.0046892525521677,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 2.8423171780632472,
#   'acnt_id': '17841470993682107',
#   'acnt_nm': 'hi_losy',
#   'influencer_scale_type': 'nano'},
#  91: {'activity_score': 1.2343505477308294,
#   'trend_score': 5.0,
#   'follower_total_engagement': 0.5158914180229788,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.7684232060081522,
#   'acnt_id': '17841472222414158',
#   'acnt_nm': 'elmom.home',
#   'influencer_scale_type': 'nano'},
#  92: {'activity_score': 0.4573117718657625,
#   'trend_score': 1.2779456193353473,
#   'follower_total_engagement': 0.0050325743993794875,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.0586409955753646,
#   'acnt_id': '17841474152637635',
#   'acnt_nm': '_samelee47',
#   'influencer_scale_type': 'nano'},
#  93: {'activity_score': 0.20129297678518954,
#   'trend_score': 0.8616236107204981,
#   'follower_total_engagement': 0.1381377416481208,
#   'follower_retention_rate': 4.9336550060313655,
#   'avg_post_efficiency': 0.07427983269875288,
#   'acnt_id': '17841400079187566',
#   'acnt_nm': 'jjjjeong_2',
#   'influencer_scale_type': 'micro'},
#  94: {'activity_score': 1.4948574786952689,
#   'trend_score': 0.8608903104789853,
#   'follower_total_engagement': 0.7156064274364007,
#   'follower_retention_rate': 4.927623642943303,
#   'avg_post_efficiency': 0.33189385910660396,
#   'acnt_id': '17841400098010697',
#   'acnt_nm': 'hyyye.r',
#   'influencer_scale_type': 'micro'},
#  95: {'activity_score': 0.04436451991585839,
#   'trend_score': 0.8761378112421685,
#   'follower_total_engagement': 0.020074200243479477,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.03887069860219596,
#   'acnt_id': '17841400157522436',
#   'acnt_nm': 'eknaremo',
#   'influencer_scale_type': 'micro'},
#  96: {'activity_score': 0.16631873610330225,
#   'trend_score': 0.8534789530879964,
#   'follower_total_engagement': 0.2973253727762596,
#   'follower_retention_rate': 4.885404101326898,
#   'avg_post_efficiency': 0.19334604114596468,
#   'acnt_id': '17841400187194180',
#   'acnt_nm': 'j.o.a.r.a',
#   'influencer_scale_type': 'micro'},
#  97: {'activity_score': 1.9955921245959447,
#   'trend_score': 1.1428494408003418,
#   'follower_total_engagement': 1.3683100810894042,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.22937033264921033,
#   'acnt_id': '17841400207803324',
#   'acnt_nm': 'ssobebe__',
#   'influencer_scale_type': 'micro'},
#  98: {'activity_score': 0.903080169903561,
#   'trend_score': 0.8822978594511037,
#   'follower_total_engagement': 1.976339227226724,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.20029416811098238,
#   'acnt_id': '17841400228562323',
#   'acnt_nm': 'subin_mam',
#   'influencer_scale_type': 'micro'},
#  99: {'activity_score': 0.44107262687444354,
#   'trend_score': 0.8732117883429243,
#   'follower_total_engagement': 0.3667824677220977,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.10694293549422257,
#   'acnt_id': '17841400286702933',
#   'acnt_nm': 'hwasu0220',
#   'influencer_scale_type': 'micro'},
#  100: {'activity_score': 0.05853967861175124,
#   'trend_score': 0.8672521072934734,
#   'follower_total_engagement': 0.22728492147387824,
#   'follower_retention_rate': 4.963811821471651,
#   'avg_post_efficiency': 0.03571855896524369,
#   'acnt_id': '17841400290385517',
#   'acnt_nm': 'mchan_lee',
#   'influencer_scale_type': 'micro'},
#  101: {'activity_score': 4.999999999999999,
#   'trend_score': 0.8624320192627934,
#   'follower_total_engagement': 0.07987222017343522,
#   'follower_retention_rate': 4.939686369119421,
#   'avg_post_efficiency': 0.004686177511324547,
#   'acnt_id': '17841400321488131',
#   'acnt_nm': 'hello_minvely',
#   'influencer_scale_type': 'micro'},
#  102: {'activity_score': 0.691353046901161,
#   'trend_score': 0.8793148056795688,
#   'follower_total_engagement': 0.20054877005902763,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.0458194896113943,
#   'acnt_id': '17841400331610291',
#   'acnt_nm': 'ssong_e.y',
#   'influencer_scale_type': 'micro'},
#  103: {'activity_score': 1.3582934843587209,
#   'trend_score': 0.8901259489827892,
#   'follower_total_engagement': 1.8480241432674833,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.2787730246208732,
#   'acnt_id': '17841400385794614',
#   'acnt_nm': '76minary',
#   'influencer_scale_type': 'micro'},
#  104: {'activity_score': 1.2989178346471781,
#   'trend_score': 0.8952273069792586,
#   'follower_total_engagement': 0.27918995250915135,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.22457060934847345,
#   'acnt_id': '17841400393557813',
#   'acnt_nm': 'sonhilook',
#   'influencer_scale_type': 'micro'},
#  105: {'activity_score': 0.9410146127748241,
#   'trend_score': 0.8732117883429243,
#   'follower_total_engagement': 0.4978291170137543,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.18037958792539727,
#   'acnt_id': '17841400397474567',
#   'acnt_nm': 'yoomyang',
#   'influencer_scale_type': 'micro'},
#  106: {'activity_score': 3.74816338524831,
#   'trend_score': 0.8766595968383014,
#   'follower_total_engagement': 0.48163420020359105,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.016337911927075413,
#   'acnt_id': '17841400475050030',
#   'acnt_nm': '49lauren',
#   'influencer_scale_type': 'micro'},
#  107: {'activity_score': 0.6602997355274757,
#   'trend_score': 0.8679894940635393,
#   'follower_total_engagement': 0.10209860256037027,
#   'follower_retention_rate': 4.969843184559714,
#   'avg_post_efficiency': 0.022885782780035818,
#   'acnt_id': '17841400611875418',
#   'acnt_nm': 'cafe.flex',
#   'influencer_scale_type': 'micro'},
#  108: {'activity_score': 0.07541959816690669,
#   'trend_score': 0.8744825445169777,
#   'follower_total_engagement': 0.024711818918792445,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.017589637124828982,
#   'acnt_id': '17841400641430079',
#   'acnt_nm': 'bom_lael',
#   'influencer_scale_type': 'micro'},
#  109: {'activity_score': 0.09554422165776369,
#   'trend_score': 0.8890475122743227,
#   'follower_total_engagement': 0.7085718092896859,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.6603466587680299,
#   'acnt_id': '17841400679881569',
#   'acnt_nm': 'l10000000ll',
#   'influencer_scale_type': 'micro'},
#  110: {'activity_score': 1.1944166911548633,
#   'trend_score': 0.8306958568356132,
#   'follower_total_engagement': 0.015424265931477712,
#   'follower_retention_rate': 4.758745476477678,
#   'avg_post_efficiency': 0.0018367940525660102,
#   'acnt_id': '17841400685492264',
#   'acnt_nm': 'oli_park',
#   'influencer_scale_type': 'micro'},
#  111: {'activity_score': 0.06910157853532917,
#   'trend_score': 0.8581570972573205,
#   'follower_total_engagement': 0.3189537729991985,
#   'follower_retention_rate': 4.915560916767191,
#   'avg_post_efficiency': 0.15416024941114492,
#   'acnt_id': '17841400700913085',
#   'acnt_nm': 'cokingsat7',
#   'influencer_scale_type': 'micro'},
#  112: {'activity_score': 0.06172038870367932,
#   'trend_score': 0.8732117883429243,
#   'follower_total_engagement': 0.28032751978778714,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 2.1769337595016283,
#   'acnt_id': '17841400803055966',
#   'acnt_nm': 'j__eunvely__',
#   'influencer_scale_type': 'micro'},
#  113: {'activity_score': 0.2682872910303105,
#   'trend_score': 0.8764341740266391,
#   'follower_total_engagement': 0.5864873478026886,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.07958323615218335,
#   'acnt_id': '17841400847520703',
#   'acnt_nm': 'soulrain0477',
#   'influencer_scale_type': 'micro'},
#  114: {'activity_score': 0.1323934421748252,
#   'trend_score': 0.8649002205336269,
#   'follower_total_engagement': 0.20751186200840582,
#   'follower_retention_rate': 4.95174909529554,
#   'avg_post_efficiency': 0.23455327024322356,
#   'acnt_id': '17841400875316568',
#   'acnt_nm': 'lim_nayoung',
#   'influencer_scale_type': 'micro'},
#  115: {'activity_score': 1.7599522912309205,
#   'trend_score': 0.8811356080678151,
#   'follower_total_engagement': 5.0,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.23740526675747434,
#   'acnt_id': '17841400987507569',
#   'acnt_nm': 'shannon_byoun',
#   'influencer_scale_type': 'micro'},
#  116: {'activity_score': 0.12500631083482958,
#   'trend_score': 0.8666898500185768,
#   'follower_total_engagement': 0.3239805262392067,
#   'follower_retention_rate': 4.963811821471651,
#   'avg_post_efficiency': 0.04057328697603091,
#   'acnt_id': '17841401063748301',
#   'acnt_nm': 'chae_yeon__',
#   'influencer_scale_type': 'micro'},
#  117: {'activity_score': 0.03162121771702926,
#   'trend_score': 0.8541066424532656,
#   'follower_total_engagement': 0.05430849974615344,
#   'follower_retention_rate': 4.891435464414954,
#   'avg_post_efficiency': 0.12783281466460977,
#   'acnt_id': '17841401130847234',
#   'acnt_nm': 'taehun.gim',
#   'influencer_scale_type': 'micro'},
#  118: {'activity_score': 1.1944166911548633,
#   'trend_score': 0.8580813911958268,
#   'follower_total_engagement': 0.9498175126524601,
#   'follower_retention_rate': 4.915560916767191,
#   'avg_post_efficiency': 0.08801050426523463,
#   'acnt_id': '17841401207230048',
#   'acnt_nm': 'wldms83',
#   'influencer_scale_type': 'micro'},
#  119: {'activity_score': 0.21520227250465276,
#   'trend_score': 0.8311545913415809,
#   'follower_total_engagement': 0.33742015233502115,
#   'follower_retention_rate': 4.758745476477678,
#   'avg_post_efficiency': 1.0713718996134813,
#   'acnt_id': '17841401222824388',
#   'acnt_nm': 'hyoniii_ee',
#   'influencer_scale_type': 'micro'},
#  120: {'activity_score': 0.1633585339139262,
#   'trend_score': 1.019384025838843,
#   'follower_total_engagement': 1.672061924847194,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.0279867311543076,
#   'acnt_id': '17841401228916385',
#   'acnt_nm': '14k._.zero',
#   'influencer_scale_type': 'micro'},
#  121: {'activity_score': 0.20129297678518954,
#   'trend_score': 0.8732117883429243,
#   'follower_total_engagement': 1.1279256243286546,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.220472397130165,
#   'acnt_id': '17841401329551671',
#   'acnt_nm': 'angelkkang',
#   'influencer_scale_type': 'micro'},
#  122: {'activity_score': 0.29309432853364675,
#   'trend_score': 0.8188093566819213,
#   'follower_total_engagement': 0.24982722143303776,
#   'follower_retention_rate': 4.686369119420988,
#   'avg_post_efficiency': 0.31820130302424576,
#   'acnt_id': '17841401344565922',
#   'acnt_nm': 'it_chelin',
#   'influencer_scale_type': 'micro'},
#  123: {'activity_score': 0.2815389136282466,
#   'trend_score': 0.8254231546712143,
#   'follower_total_engagement': 0.10770000991678966,
#   'follower_retention_rate': 4.728588661037392,
#   'avg_post_efficiency': 0.014254066815344345,
#   'acnt_id': '17841401488267197',
#   'acnt_nm': 'ranmong_life',
#   'influencer_scale_type': 'micro'},
#  124: {'activity_score': 0.1840170999361747,
#   'trend_score': 0.8816028293105577,
#   'follower_total_engagement': 0.5335213559328156,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.22036800276833146,
#   'acnt_id': '17841401528132591',
#   'acnt_nm': 'ji___h2',
#   'influencer_scale_type': 'micro'},
#  125: {'activity_score': 0.10955657116460525,
#   'trend_score': 0.8821475171629327,
#   'follower_total_engagement': 0.31976826184316115,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.06701617119563992,
#   'acnt_id': '17841401565515438',
#   'acnt_nm': 'keikokim720',
#   'influencer_scale_type': 'micro'},
#  126: {'activity_score': 1.4233239578523151,
#   'trend_score': 0.8732117883429243,
#   'follower_total_engagement': 0.0118940612110582,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.0170083745629682,
#   'acnt_id': '17841401622874029',
#   'acnt_nm': 'pkasset_hawon',
#   'influencer_scale_type': 'micro'},
#  127: {'activity_score': 1.1053971985502986,
#   'trend_score': 0.863124856911526,
#   'follower_total_engagement': 0.029975345253202373,
#   'follower_retention_rate': 4.939686369119421,
#   'avg_post_efficiency': 0.025802348173247985,
#   'acnt_id': '17841401764081337',
#   'acnt_nm': 'hey.trafoli',
#   'influencer_scale_type': 'micro'},
#  128: {'activity_score': 0.14065392894417994,
#   'trend_score': 0.8732117883429243,
#   'follower_total_engagement': 0.579823424166879,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.30502326535655566,
#   'acnt_id': '17841401866805925',
#   'acnt_nm': 'smileminsun',
#   'influencer_scale_type': 'micro'},
#  129: {'activity_score': 0.4099324125771378,
#   'trend_score': 0.8718359382757203,
#   'follower_total_engagement': 0.14619523915344065,
#   'follower_retention_rate': 4.993968636911937,
#   'avg_post_efficiency': 0.030382056919393816,
#   'acnt_id': '17841401871948688',
#   'acnt_nm': 'kaznyx',
#   'influencer_scale_type': 'micro'},
#  130: {'activity_score': 1.573920843837481,
#   'trend_score': 0.8752888606140052,
#   'follower_total_engagement': 0.41992026828415474,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.030743175197908527,
#   'acnt_id': '17841401888467270',
#   'acnt_nm': 'joheeyeon88',
#   'influencer_scale_type': 'micro'},
#  131: {'activity_score': 0.903080169903561,
#   'trend_score': 0.8561441118204286,
#   'follower_total_engagement': 1.1044458955495293,
#   'follower_retention_rate': 4.903498190591073,
#   'avg_post_efficiency': 0.1434100819874824,
#   'acnt_id': '17841401894015818',
#   'acnt_nm': 'ideal_piano',
#   'influencer_scale_type': 'micro'},
#  132: {'activity_score': 0.39865460523703244,
#   'trend_score': 0.8705349310947342,
#   'follower_total_engagement': 0.1574605524393391,
#   'follower_retention_rate': 4.981905910735826,
#   'avg_post_efficiency': 0.032595128776680936,
#   'acnt_id': '17841402073082603',
#   'acnt_nm': 'seolaj',
#   'influencer_scale_type': 'micro'},
#  133: {'activity_score': 0.23891648160013101,
#   'trend_score': 0.46726875243696836,
#   'follower_total_engagement': 0.07510296452301599,
#   'follower_retention_rate': 2.6779252110977154,
#   'avg_post_efficiency': 0.019235906385913423,
#   'acnt_id': '17841402090832266',
#   'acnt_nm': 'aldw_beauty',
#   'influencer_scale_type': 'micro'},
#  134: {'activity_score': 0.04902141858055937,
#   'trend_score': 0.8759002633019184,
#   'follower_total_engagement': 1.9233249502417302,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.6377801599530784,
#   'acnt_id': '17841402099382155',
#   'acnt_nm': 'pooh_chobap',
#   'influencer_scale_type': 'micro'},
#  135: {'activity_score': 0.05226480836236934,
#   'trend_score': 0.8769593884903905,
#   'follower_total_engagement': 0.676729007155835,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.27040353011005713,
#   'acnt_id': '17841402102624080',
#   'acnt_nm': 'sun_yu1173',
#   'influencer_scale_type': 'micro'},
#  136: {'activity_score': 0.3157081512517418,
#   'trend_score': 0.8816532764506437,
#   'follower_total_engagement': 0.08604714795389505,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.050611460351283645,
#   'acnt_id': '17841402104848113',
#   'acnt_nm': 'ehgl55',
#   'influencer_scale_type': 'micro'},
#  137: {'activity_score': 0.4772354563809921,
#   'trend_score': 0.8787630568797614,
#   'follower_total_engagement': 2.4443603953975432,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.145915977730539,
#   'acnt_id': '17841402108414803',
#   'acnt_nm': 'junyoujini',
#   'influencer_scale_type': 'micro'},
#  138: {'activity_score': 0.5490253697717699,
#   'trend_score': 0.8658834957789857,
#   'follower_total_engagement': 0.034346941905024714,
#   'follower_retention_rate': 4.957780458383596,
#   'avg_post_efficiency': 0.016708405378542086,
#   'acnt_id': '17841402240386451',
#   'acnt_nm': 'leeja5139',
#   'influencer_scale_type': 'micro'},
#  139: {'activity_score': 0.11578501129668613,
#   'trend_score': 0.8564082836127825,
#   'follower_total_engagement': 0.40127405048164505,
#   'follower_retention_rate': 4.903498190591073,
#   'avg_post_efficiency': 0.7723743021124867,
#   'acnt_id': '17841402258091857',
#   'acnt_nm': 'great_pocha',
#   'influencer_scale_type': 'micro'},
#  140: {'activity_score': 0.02231205901302462,
#   'trend_score': 0.8641725124507528,
#   'follower_total_engagement': 0.09057136720018591,
#   'follower_retention_rate': 4.945717732207477,
#   'avg_post_efficiency': 0.09074162917148056,
#   'acnt_id': '17841402265250392',
#   'acnt_nm': 'misuk8128',
#   'influencer_scale_type': 'micro'},
#  141: {'activity_score': 1.1053971985502986,
#   'trend_score': 0.8816431385545975,
#   'follower_total_engagement': 0.5645170998703513,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.08095624944126412,
#   'acnt_id': '17841402271528903',
#   'acnt_nm': 'cutehyuny',
#   'influencer_scale_type': 'micro'},
#  142: {'activity_score': 0.1828059381707131,
#   'trend_score': 0.8652600467765665,
#   'follower_total_engagement': 0.17453867515045843,
#   'follower_retention_rate': 4.95174909529554,
#   'avg_post_efficiency': 0.08532192072930865,
#   'acnt_id': '17841402288409708',
#   'acnt_nm': 'aj.alice0_0',
#   'influencer_scale_type': 'micro'},
#  143: {'activity_score': 0.027147316830256816,
#   'trend_score': 0.9089577367963523,
#   'follower_total_engagement': 0.17467070146929317,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.2711838769986026,
#   'acnt_id': '17841402296091558',
#   'acnt_nm': 'fastlane_sy',
#   'influencer_scale_type': 'micro'},
#  144: {'activity_score': 0.8046556694808236,
#   'trend_score': 0.860875876885236,
#   'follower_total_engagement': 0.3725723447356365,
#   'follower_retention_rate': 4.927623642943303,
#   'avg_post_efficiency': 0.20040519034080587,
#   'acnt_id': '17841402420507604',
#   'acnt_nm': 'bichu1004',
#   'influencer_scale_type': 'micro'},
#  145: {'activity_score': 0.2682872910303105,
#   'trend_score': 0.8688129761397582,
#   'follower_total_engagement': 0.5454531101606487,
#   'follower_retention_rate': 4.975874547647763,
#   'avg_post_efficiency': 0.5284900632736286,
#   'acnt_id': '17841402762469232',
#   'acnt_nm': '__h.j__91',
#   'influencer_scale_type': 'micro'},
#  146: {'activity_score': 0.5291549473153938,
#   'trend_score': 0.7649010631833371,
#   'follower_total_engagement': 0.16310985107757228,
#   'follower_retention_rate': 4.378769601930031,
#   'avg_post_efficiency': 0.07559752970582309,
#   'acnt_id': '17841402932403601',
#   'acnt_nm': 'ryu_mj3',
#   'influencer_scale_type': 'micro'},
#  147: {'activity_score': 0.10270511152086233,
#   'trend_score': 0.8534789530879964,
#   'follower_total_engagement': 0.28783401271037934,
#   'follower_retention_rate': 4.885404101326898,
#   'avg_post_efficiency': 0.2007794775202458,
#   'acnt_id': '17841402954779102',
#   'acnt_nm': 'boram_8916',
#   'influencer_scale_type': 'micro'},
#  148: {'activity_score': 0.06557606224091247,
#   'trend_score': 0.8981268271782079,
#   'follower_total_engagement': 0.08428605228005823,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.2320605396841069,
#   'acnt_id': '17841402992067481',
#   'acnt_nm': 't__e9608',
#   'influencer_scale_type': 'micro'},
#  149: {'activity_score': 0.4280749722112202,
#   'trend_score': 0.8959891994771274,
#   'follower_total_engagement': 0.4434000155065446,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.13871545333108626,
#   'acnt_id': '17841403193273551',
#   'acnt_nm': 'sia_flower',
#   'influencer_scale_type': 'micro'},
#  150: {'activity_score': 0.8272112841610343,
#   'trend_score': 0.838122263082125,
#   'follower_total_engagement': 0.2745705949779732,
#   'follower_retention_rate': 4.8009650180940895,
#   'avg_post_efficiency': 0.20601123239288247,
#   'acnt_id': '17841403197617390',
#   'acnt_nm': 'k._._.b',
#   'influencer_scale_type': 'micro'},
#  151: {'activity_score': 0.8763029161120808,
#   'trend_score': 0.857166958864438,
#   'follower_total_engagement': 0.48231211566145304,
#   'follower_retention_rate': 4.909529553679128,
#   'avg_post_efficiency': 0.06368039339950694,
#   'acnt_id': '17841403212163423',
#   'acnt_nm': 'pompous33',
#   'influencer_scale_type': 'micro'},
#  152: {'activity_score': 0.6057980053614157,
#   'trend_score': 0.8811130161448301,
#   'follower_total_engagement': 1.2446069291966735,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.21861136512849086,
# ...
#   'follower_retention_rate': 4.918397626112764,
#   'avg_post_efficiency': 2.275135297586742,
#   'acnt_id': '17841408675527763',
#   'acnt_nm': 'alema.2',
#   'influencer_scale_type': 'mid'},
#  310: {'activity_score': 0.11164115815278608,
#   'trend_score': 2.043589212600526,
#   'follower_total_engagement': 0.11451882715790104,
#   'follower_retention_rate': 4.6995548961424305,
#   'avg_post_efficiency': 0.2743876974793415,
#   'acnt_id': '17841409132515581',
#   'acnt_nm': 'wony.life',
#   'influencer_scale_type': 'mid'},
#  311: {'activity_score': 0.05703867843785539,
#   'trend_score': 2.212761871742501,
#   'follower_total_engagement': 0.047916433845831594,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.9013752471012797,
#   'acnt_id': '17841412847710660',
#   'acnt_nm': 'key_ssam_',
#   'influencer_scale_type': 'mid'},
#  312: {'activity_score': 0.1305151305151305,
#   'trend_score': 2.030341015554379,
#   'follower_total_engagement': 0.22231158530822698,
#   'follower_retention_rate': 4.666172106824924,
#   'avg_post_efficiency': 0.29056983834437716,
#   'acnt_id': '17841413125170679',
#   'acnt_nm': '4_u_n_me_',
#   'influencer_scale_type': 'mid'},
#  313: {'activity_score': 1.2464387464387465,
#   'trend_score': 1.8995125102650299,
#   'follower_total_engagement': 0.8016001901263211,
#   'follower_retention_rate': 4.365727002967361,
#   'avg_post_efficiency': 0.8804185109437458,
#   'acnt_id': '17841417756851455',
#   'acnt_nm': 'hihellocongcong',
#   'influencer_scale_type': 'mid'},
#  314: {'activity_score': 0.05085997678590272,
#   'trend_score': 2.172332165169782,
#   'follower_total_engagement': 0.03334942152671602,
#   'follower_retention_rate': 4.992581602373889,
#   'avg_post_efficiency': 0.05315484340568289,
#   'acnt_id': '17841418505172230',
#   'acnt_nm': 'ko_a.ra',
#   'influencer_scale_type': 'mid'},
#  315: {'activity_score': 0.10405053883314754,
#   'trend_score': 1.673333850200709,
#   'follower_total_engagement': 0.03827928303482509,
#   'follower_retention_rate': 3.8464391691394653,
#   'avg_post_efficiency': 0.37124997383469016,
#   'acnt_id': '17841418684451303',
#   'acnt_nm': 'drh_zzz',
#   'influencer_scale_type': 'mid'},
#  316: {'activity_score': 0.0879321866976188,
#   'trend_score': 2.172587005589834,
#   'follower_total_engagement': 0.11622951270279819,
#   'follower_retention_rate': 4.9962908011869445,
#   'avg_post_efficiency': 0.27469925800924094,
#   'acnt_id': '17841421762463040',
#   'acnt_nm': 'doramg_97',
#   'influencer_scale_type': 'mid'},
#  317: {'activity_score': 0.21284941574796648,
#   'trend_score': 1.4723078301500485,
#   'follower_total_engagement': 0.45668876599116737,
#   'follower_retention_rate': 3.3864985163204793,
#   'avg_post_efficiency': 0.7698221677244386,
#   'acnt_id': '17841424856575341',
#   'acnt_nm': 'code.bin',
#   'influencer_scale_type': 'mid'},
#  318: {'activity_score': 0.23357301135078917,
#   'trend_score': 2.1373711838996647,
#   'follower_total_engagement': 0.10867147022618412,
#   'follower_retention_rate': 4.914688427299701,
#   'avg_post_efficiency': 0.12450117735586579,
#   'acnt_id': '17841428708203878',
#   'acnt_nm': 'kalkaluniv',
#   'influencer_scale_type': 'mid'},
#  319: {'activity_score': 0.11441233663455888,
#   'trend_score': 2.2156326804731785,
#   'follower_total_engagement': 0.05965598005194846,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.2480331798512099,
#   'acnt_id': '17841438518782201',
#   'acnt_nm': 'seandy.zip',
#   'influencer_scale_type': 'mid'},
#  320: {'activity_score': 0.41231402342513457,
#   'trend_score': 2.164843227005604,
#   'follower_total_engagement': 0.09521234201893161,
#   'follower_retention_rate': 4.97774480712166,
#   'avg_post_efficiency': 0.09848043293512537,
#   'acnt_id': '17841439373155133',
#   'acnt_nm': 'daha_home',
#   'influencer_scale_type': 'mid'},
#  321: {'activity_score': 0.1566951566951567,
#   'trend_score': 2.1710833494577546,
#   'follower_total_engagement': 0.5229838946796884,
#   'follower_retention_rate': 4.992581602373889,
#   'avg_post_efficiency': 0.9905560732660309,
#   'acnt_id': '17841440764386735',
#   'acnt_nm': 'kwon.elly',
#   'influencer_scale_type': 'mid'},
#  322: {'activity_score': 0.13824447157780492,
#   'trend_score': 2.14464273491291,
#   'follower_total_engagement': 0.24541907269350802,
#   'follower_retention_rate': 4.929525222551931,
#   'avg_post_efficiency': 0.6604576791729876,
#   'acnt_id': '17841440860421887',
#   'acnt_nm': 'nyong_zzi',
#   'influencer_scale_type': 'mid'},
#  323: {'activity_score': 0.49572649572649574,
#   'trend_score': 2.1510871618819514,
#   'follower_total_engagement': 0.1583042492252058,
#   'follower_retention_rate': 4.944362017804153,
#   'avg_post_efficiency': 0.4592397609163771,
#   'acnt_id': '17841442322452711',
#   'acnt_nm': 'piny_biny_20',
#   'influencer_scale_type': 'mid'},
#  324: {'activity_score': 0.9962013295346629,
#   'trend_score': 2.1440278208017407,
#   'follower_total_engagement': 0.01155840465474839,
#   'follower_retention_rate': 4.929525222551931,
#   'avg_post_efficiency': 0.0071892670648205995,
#   'acnt_id': '17841443943990104',
#   'acnt_nm': 'wearestars.1',
#   'influencer_scale_type': 'mid'},
#  325: {'activity_score': 0.04738445710667933,
#   'trend_score': 1.8307259517410115,
#   'follower_total_engagement': 0.00994108051827961,
#   'follower_retention_rate': 4.209940652818993,
#   'avg_post_efficiency': 0.06448622698910265,
#   'acnt_id': '17841445010987146',
#   'acnt_nm': 'flore_scence97',
#   'influencer_scale_type': 'mid'},
#  326: {'activity_score': 5.000000000000001,
#   'trend_score': 2.1530946111289877,
#   'follower_total_engagement': 1.0075557539995914,
#   'follower_retention_rate': 4.948071216617208,
#   'avg_post_efficiency': 1.0233167024812853,
#   'acnt_id': '17841445592295805',
#   'acnt_nm': 'zzzz_03081207',
#   'influencer_scale_type': 'mid'},
#  327: {'activity_score': 0.7102157102157103,
#   'trend_score': 2.44300747783423,
#   'follower_total_engagement': 0.25847158916216934,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.41011852092827555,
#   'acnt_id': '17841445794356996',
#   'acnt_nm': '_peach.kong',
#   'influencer_scale_type': 'mid'},
#  328: {'activity_score': 0.014575014575014577,
#   'trend_score': 2.145765556277363,
#   'follower_total_engagement': 0.018597824316188963,
#   'follower_retention_rate': 4.933234421364986,
#   'avg_post_efficiency': 0.2642466645855458,
#   'acnt_id': '17841446055101990',
#   'acnt_nm': 'ohwonee',
#   'influencer_scale_type': 'mid'},
#  329: {'activity_score': 0.009971509971509973,
#   'trend_score': 1.5288468251305096,
#   'follower_total_engagement': 0.012518452365577143,
#   'follower_retention_rate': 3.5163204747774515,
#   'avg_post_efficiency': 0.23874133490385374,
#   'acnt_id': '17841447339033115',
#   'acnt_nm': 'ijingwang84',
#   'influencer_scale_type': 'mid'},
#  330: {'activity_score': 0.07729671664097895,
#   'trend_score': 3.849637549433022,
#   'follower_total_engagement': 0.024170410002930843,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.2261720053450659,
#   'acnt_id': '17841449365835250',
#   'acnt_nm': 'by_yangna',
#   'influencer_scale_type': 'mid'},
#  331: {'activity_score': 0.13427244908726393,
#   'trend_score': 2.16719076337713,
#   'follower_total_engagement': 0.2298944777028655,
#   'follower_retention_rate': 4.981454005934722,
#   'avg_post_efficiency': 0.4169232872088424,
#   'acnt_id': '17841450009911070',
#   'acnt_nm': 'l.m.y_lovelybaby',
#   'influencer_scale_type': 'mid'},
#  332: {'activity_score': 0.07469211172914877,
#   'trend_score': 2.1433068986842474,
#   'follower_total_engagement': 0.08714736990612294,
#   'follower_retention_rate': 4.925816023738875,
#   'avg_post_efficiency': 0.24789454696655636,
#   'acnt_id': '17841450480769814',
#   'acnt_nm': 'haeun.fit',
#   'influencer_scale_type': 'mid'},
#  333: {'activity_score': 0.07469211172914877,
#   'trend_score': 2.0367699244958986,
#   'follower_total_engagement': 0.011266307355675369,
#   'follower_retention_rate': 4.681008902077153,
#   'avg_post_efficiency': 0.0392735102259576,
#   'acnt_id': '17841452125837312',
#   'acnt_nm': 'kbeautysun',
#   'influencer_scale_type': 'mid'},
#  334: {'activity_score': 0.20378284267173158,
#   'trend_score': 2.3172457031953138,
#   'follower_total_engagement': 0.5657717053697151,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 1.0706538481400347,
#   'acnt_id': '17841453615191128',
#   'acnt_nm': 'bong_camper83',
#   'influencer_scale_type': 'mid'},
#  335: {'activity_score': 0.21284941574796648,
#   'trend_score': 2.1732157646681625,
#   'follower_total_engagement': 0.6666322709132567,
#   'follower_retention_rate': 4.9962908011869445,
#   'avg_post_efficiency': 2.6592945834760364,
#   'acnt_id': '17841454076298818',
#   'acnt_nm': 'ipsae_camping',
#   'influencer_scale_type': 'mid'},
#  336: {'activity_score': 0.14691070246625806,
#   'trend_score': 2.1752317460744903,
#   'follower_total_engagement': 0.24632760236409537,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.6930542831993284,
#   'acnt_id': '17841456831877987',
#   'acnt_nm': 'so1jii',
#   'influencer_scale_type': 'mid'},
#  337: {'activity_score': 0.023687732021065354,
#   'trend_score': 0.0,
#   'follower_total_engagement': 0.0555122596739778,
#   'follower_retention_rate': 0.0,
#   'avg_post_efficiency': 0.5597727760394197,
#   'acnt_id': '17841457190973321',
#   'acnt_nm': 'jjoy119',
#   'influencer_scale_type': 'mid'},
#  338: {'activity_score': 0.3080484330484331,
#   'trend_score': 2.159085980197127,
#   'follower_total_engagement': 0.85305462724522,
#   'follower_retention_rate': 4.9629080118694375,
#   'avg_post_efficiency': 1.3316744502306115,
#   'acnt_id': '17841458331410873',
#   'acnt_nm': 'semo.jung',
#   'influencer_scale_type': 'mid'},
#  339: {'activity_score': 0.15165004748338085,
#   'trend_score': 2.265055798549896,
#   'follower_total_engagement': 0.033272542763906024,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.17450110240604763,
#   'acnt_id': '17841459094129560',
#   'acnt_nm': 'witty_sunday',
#   'influencer_scale_type': 'mid'},
#  340: {'activity_score': 0.14691070246625806,
#   'trend_score': 1.6491116675417308,
#   'follower_total_engagement': 0.11788948648736902,
#   'follower_retention_rate': 3.790801186943618,
#   'avg_post_efficiency': 1.1615732994275862,
#   'acnt_id': '17841461230983239',
#   'acnt_nm': 's2unniverse',
#   'influencer_scale_type': 'mid'},
#  341: {'activity_score': 0.09534662867996202,
#   'trend_score': 2.0825780860106127,
#   'follower_total_engagement': 0.0,
#   'follower_retention_rate': 4.788575667655792,
#   'avg_post_efficiency': 0.0030420660679860686,
#   'acnt_id': '17841467159743263',
#   'acnt_nm': 'thirty_life_93',
#   'influencer_scale_type': 'mid'},
#  342: {'activity_score': 0.06778424652820789,
#   'trend_score': 1.7872010733445163,
#   'follower_total_engagement': 0.01507386924918853,
#   'follower_retention_rate': 4.109792284866465,
#   'avg_post_efficiency': 1.7619454720294647,
#   'acnt_id': '17841469363262587',
#   'acnt_nm': 'comet_life_all',
#   'influencer_scale_type': 'mid'},
#  343: {'activity_score': 0.41231402342513457,
#   'trend_score': 5.0,
#   'follower_total_engagement': 0.11892081046746758,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 5.0,
#   'acnt_id': '17841473211163104',
#   'acnt_nm': 'mom._.room',
#   'influencer_scale_type': 'mid'},
#  344: {'activity_score': 3.9960493827160497,
#   'trend_score': 5.0,
#   'follower_total_engagement': 0.04671666767214156,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 0.004614317039442518,
#   'acnt_id': '17841400417546279',
#   'acnt_nm': 'yooojung4',
#   'influencer_scale_type': 'macro'},
#  345: {'activity_score': 5.000000000000001,
#   'trend_score': 4.327076014144086,
#   'follower_total_engagement': 5.0,
#   'follower_retention_rate': 4.52986022871665,
#   'avg_post_efficiency': 0.9081883224759456,
#   'acnt_id': '17841400580612199',
#   'acnt_nm': 'jogood72',
#   'influencer_scale_type': 'macro'},
#  346: {'activity_score': 1.5865679012345681,
#   'trend_score': 4.240317872579836,
#   'follower_total_engagement': 2.860263948122396,
#   'follower_retention_rate': 4.440914866581963,
#   'avg_post_efficiency': 1.1579574832756026,
#   'acnt_id': '17841401272625523',
#   'acnt_nm': 'oing0307',
#   'influencer_scale_type': 'macro'},
#  347: {'activity_score': 0.0,
#   'trend_score': 4.839334252676368,
#   'follower_total_engagement': 0.03682467969736509,
#   'follower_retention_rate': 5.0,
#   'avg_post_efficiency': 3.3579366970008526,
#   'acnt_id': '17841401400610794',
#   'acnt_nm': 'sun',
#   'influencer_scale_type': 'macro'},
#  348: {'activity_score': 0.5708061002178649,
#   'trend_score': 4.407679557964084,
#   'follower_total_engagement': 3.4902074249397237,
#   'follower_retention_rate': 4.6124523506988595,
#   'avg_post_efficiency': 1.3221559201810855,
#   'acnt_id': '17841401844782267',
#   'acnt_nm': 'real2sseul',
#   'influencer_scale_type': 'macro'},
#  349: {'activity_score': 0.5539329805996474,
#   'trend_score': 4.4982274080010995,
#   'follower_total_engagement': 0.24758535955778732,
#   'follower_retention_rate': 4.707750952986025,
#   'avg_post_efficiency': 1.2842124759405977,
#   'acnt_id': '17841401942858884',
#   'acnt_nm': 'my_floria_',
#   'influencer_scale_type': 'macro'},
#  350: {'activity_score': 0.8532474503488997,
#   'trend_score': 4.42081590468315,
#   'follower_total_engagement': 1.0266127775303084,
#   'follower_retention_rate': 4.625158831003809,
#   'avg_post_efficiency': 0.9576080212200311,
#   'acnt_id': '17841402244880241',
#   'acnt_nm': 'hyunju2469',
#   'influencer_scale_type': 'macro'},
#  351: {'activity_score': 0.22362888140665918,
#   'trend_score': 0.0,
#   'follower_total_engagement': 0.3740082011113628,
#   'follower_retention_rate': 0.0,
#   'avg_post_efficiency': 0.8378779337823417,
#   'acnt_id': '17841402308230240',
#   'acnt_nm': 'changmibaek',
#   'influencer_scale_type': 'macro'},
#  352: {'activity_score': 1.892533803644915,
#   'trend_score': 4.740776182105638,
#   'follower_total_engagement': 1.546438232489323,
#   'follower_retention_rate': 4.961880559085131,
#   'avg_post_efficiency': 0.6723684617501456,
#   'acnt_id': '17841404452754986',
#   'acnt_nm': 'sylove7100',
#   'influencer_scale_type': 'macro'},
#  353: {'activity_score': 1.7262479871175525,
#   'trend_score': 4.457476403094674,
#   'follower_total_engagement': 2.2261750329428724,
#   'follower_retention_rate': 4.663278271918678,
#   'avg_post_efficiency': 2.199254415750361,
#   'acnt_id': '17841404754372434',
#   'acnt_nm': 'bora_sunny_',
#   'influencer_scale_type': 'macro'},
#  354: {'activity_score': 0.34866915845509117,
#   'trend_score': 4.242411673468721,
#   'follower_total_engagement': 0.6228912881306672,
#   'follower_retention_rate': 4.440914866581963,
#   'avg_post_efficiency': 1.33738922561317,
#   'acnt_id': '17841416105095031',
#   'acnt_nm': 'best_namnam',
#   'influencer_scale_type': 'macro'},
#  355: {'activity_score': 0.1961502721359352,
#   'trend_score': 4.510979786012517,
#   'follower_total_engagement': 0.30032910413639136,
#   'follower_retention_rate': 4.720457433290981,
#   'avg_post_efficiency': 2.1407932790425863,
#   'acnt_id': '17841423469631536',
#   'acnt_nm': 'goodlovelov',
#   'influencer_scale_type': 'macro'},
#  356: {'activity_score': 5.000000000000001,
#   'trend_score': 4.7719801232847985,
#   'follower_total_engagement': 0.0,
#   'follower_retention_rate': 4.993646759847522,
#   'avg_post_efficiency': 0.0,
#   'acnt_id': '17841437781952670',
#   'acnt_nm': 'neuel_s',
#   'influencer_scale_type': 'macro'},
#  357: {'activity_score': 0.14152412117606228,
#   'trend_score': 3.6441807662065218,
#   'follower_total_engagement': 0.2554322892023362,
#   'follower_retention_rate': 3.8119440914866587,
#   'avg_post_efficiency': 2.190446850299484,
#   'acnt_id': '17841448810667457',
#   'acnt_nm': 'gum0070',
#   'influencer_scale_type': 'macro'},
#  358: {'activity_score': 0.8168724279835392,
#   'trend_score': 4.629324383253161,
#   'follower_total_engagement': 1.693943929284078,
#   'follower_retention_rate': 4.847522236340538,
#   'avg_post_efficiency': 5.000000000000001,
#   'acnt_id': '17841462888085401',
#   'acnt_nm': 'mr___choon',
#   'influencer_scale_type': 'macro'},
#  359: {'activity_score': 0.0,
#   'trend_score': 0.0,
#   'follower_total_engagement': 0.0,
#   'follower_retention_rate': 0.0,
#   'avg_post_efficiency': 0.0,
#   'acnt_id': '17841400290105756',
#   'acnt_nm': 'reel',
#   'influencer_scale_type': 'mega'}}

# %% [markdown]
# ##### 크리에이터 광고 효율성

# %%
revenue_dic = {
    'acnt_nm' : ['s_h_j_', 'siwolbubu_hyun', 'bong_camper83', 'binwoos', 'seojinii_', 'tingkerhee'],
    'sell_type' : ['flexmatch', 'other', 'flexmatch', 'flexmatch', 'other', 'other'],
    'total_revenue' : [6906000, 10937105, 7233100, 8759000, 7939664, 38449720],
    'total_order_cnt' : [84, 132, 122, 88, 89, 471]
    }

revenue_df = pd.DataFrame(revenue_dic)
revenue_merged_df = pd.merge(media_engagement_merged_df, revenue_df, on='acnt_nm', how='left')
revenue_merged_df = revenue_merged_df[['acnt_id', 'acnt_nm', 'follower_cnt', 'follow_cnt', 'media_cnt', 'sell_type', 'total_revenue', 'total_order_cnt', 'media_id', 'like_cnt', 'cmnt_cnt']]
revenue_merged_df

revenue_merged_df['post_efficiency'] = ((revenue_merged_df['like_cnt'] + revenue_merged_df['cmnt_cnt']) / revenue_merged_df['follower_cnt']) * 100
revenue_df_total = revenue_merged_df.groupby(['acnt_id', 'acnt_nm']).agg({
    'post_efficiency' : 'mean',
    'total_order_cnt' : 'first'
}).dropna()

revenue_df_total['advertisement_efficiency'] = (revenue_df_total['total_order_cnt'] / revenue_df_total['post_efficiency']) 
revenue_df_total.sort_values(by='advertisement_efficiency', ascending=False)

revenue_merged_df['engagement_per_post'] = ((revenue_merged_df['like_cnt'] + revenue_merged_df['cmnt_cnt']) / 25)
revenue_df_total = revenue_merged_df.groupby(['acnt_id', 'acnt_nm']).agg({
    'engagement_per_post' : 'mean',
    'total_revenue' : 'first',
    'total_order_cnt' : 'first'
}).dropna()

# 팔로워를 생각하지 않고, 25개의 콘텐츠 단위당 반응 비율을 계산
revenue_df_total['advertisement_efficiency'] = (revenue_df_total['total_order_cnt'] / revenue_df_total['engagement_per_post'] * 25) * 100
revenue_df_total.sort_values(by='advertisement_efficiency', ascending=False)
# Out:
#           acnt_nm  sell_type  total_revenue  total_order_cnt
# 0          s_h_j_  flexmatch        6906000               84
# 1  siwolbubu_hyun      other       10937105              132
# 2   bong_camper83  flexmatch        7233100              122
# 3         binwoos  flexmatch        8759000               88
# 4       seojinii_      other        7939664               89
# 5      tingkerhee      other       38449720              471

# %% [markdown]
# 콘텐츠 효율성이 아닌 팔로워 참여도를 기준으로 계산했을 때

# %%
engaged_df_2 = engaged_df.copy()
revenue_merged_df_2 = revenue_merged_df.groupby(['acnt_id', 'acnt_nm'])[['total_revenue', 'total_order_cnt']].first().dropna().reset_index()
revenue_df_total_2 = pd.merge(engaged_df_2, revenue_merged_df_2, on='acnt_id')

revenue_df_total_2['advertisement_efficiency'] = revenue_df_total_2['total_order_cnt'] / revenue_df_total_2['follower_total_engagement']
revenue_df_total_2[['acnt_id', 'acnt_nm', 'total_revenue', 'total_order_cnt', 'follower_total_engagement', 'advertisement_efficiency']].sort_values(by='advertisement_efficiency', ascending=False)

# %% [markdown]
# table merged

# %%
# 크리에이터 활동성
creator_activity_score = activity_df[['acnt_id', 'avg_upload_interval']]

# %%
# 트렌드지수
creator_trend_score = time_series_merged_df[['acnt_id', 'trend_score']]

# %%
# 팔로워 참여도
follower_engagement = engaged_df[['acnt_id', 'follower_total_engagement']]

# %%
# 팔로워 충성도
follower_loyalty = time_series_merged_df_copy[['acnt_id', 'follower_retention_rate']]

# %%
# 콘텐츠 효율성
post_efficiency = post_efficiency_df.copy()

# %%
# 광고효율성
revenue_df_total = revenue_df_total.reset_index()
advertisement_efficiency = revenue_df_total[['acnt_id', 'advertisement_efficiency']]

# %%
df_list = [creator_activity_score, creator_trend_score, follower_engagement, follower_loyalty, post_efficiency, advertisement_efficiency]

# %%
from functools import reduce

flexmatch_score = reduce(lambda left, right: pd.merge(left, right, on='acnt_id', how='left'), df_list)

# %%
user_info_nm = user_info_2[['acnt_id', 'acnt_nm']]
flexmatch_score = pd.merge(flexmatch_score, user_info_nm, on='acnt_id')

# %%
flexmatch_score = flexmatch_score[['acnt_id', 'acnt_nm', 'avg_upload_interval', 'trend_score', 'follower_total_engagement', 'follower_retention_rate', 'avg_post_efficiency', 'advertisement_efficiency']]
flexmatch_score.rename(columns={
    'avg_upload_interval' : '크리에이터 활동성',
    'trend_score' : '트렌드지수(팔로워순증가량)', 
    'follower_total_engagement' : '콘텐츠 참여도' ,
    'follower_retention_rate' : '팔로워 충성도',
    'avg_post_efficiency' : '콘텐츠 효율성',
    'advertisement_efficiency' : '광고 효율성'
}, inplace=True)

# %%
flexmatch_score_2 = flexmatch_score.copy()
flexmatch_score_2.dropna(inplace=True)

# %%
flexmatch_score_2
# Out:
#               acnt_id         acnt_nm  크리에이터 활동성  트렌드지수(팔로워순증가량)      콘텐츠 참여도  \
# 0   17841400361359004          s_h_j_   1.166667        0.057866   110.188904
# 1   17841400561503844         binwoos   0.500000       -0.014956   626.642600
# 2   17841400591698216      tingkerhee   2.416667       -0.018509  2065.579146
# 4   17841401506106699  siwolbubu_hyun   0.958333       -0.075045  2094.996055
# 6   17841402936102997       seojinii_   2.875000       -0.002312   166.809026
# 10  17841453615191128   bong_camper83   1.500000        0.281793  2526.578680
#
#     팔로워 충성도   콘텐츠 효율성       광고 효율성
# 0    100.00  0.045178  1859.316062
# 1     99.99  0.169730   518.470975
# 2     99.98  0.483403   974.343202
# 4     99.92  0.556736   237.096389
# 6    100.00  0.240359   370.279723
# 10   100.00  2.506526    48.672935

# %%
# from sklearn.preprocessing import MinMaxScaler

# columns = flexmatch_score_2.select_dtypes(include='float64').columns
# minmax = MinMaxScaler(feature_range=(0, 5))
# flexmatch_score_norm = minmax.fit_transform(flexmatch_score_2[columns])

# flexmatch_score_norm_df = pd.DataFrame(flexmatch_score_norm, columns=columns, index=flexmatch_score_2.index)
# flexmatch_score_norm_df['acnt_id'] = flexmatch_score_2['acnt_id']
# flexmatch_score_norm_df['acnt_nm'] = flexmatch_score_2['acnt_nm']

# flexmatch_score_norm_df['avg_upload_interval'] = 5 - flexmatch_score_norm_df['avg_upload_interval']
# flexmatch_score_norm_df

# %%
from sklearn.preprocessing import MinMaxScaler

columns = flexmatch_score_2.select_dtypes(include='float64').columns
minmax = MinMaxScaler(feature_range=(0, 5))
flexmatch_score_norm = minmax.fit_transform(flexmatch_score_2[columns])

flexmatch_score_norm_df = pd.DataFrame(flexmatch_score_norm, columns=columns, index=flexmatch_score_2.index)
flexmatch_score_norm_df['acnt_id'] = flexmatch_score_2['acnt_id']
flexmatch_score_norm_df['acnt_nm'] = flexmatch_score_2['acnt_nm']

flexmatch_score_norm_df['크리에이터 활동성'] = 5 - flexmatch_score_norm_df['크리에이터 활동성']
flexmatch_score_norm_df

# 지금 이거 정규화 할 때는 그냥 이사람들을 전부 다 합쳐서 함께 정규화를 진행해서 그런데, 원래라면은 팔로워를 기준으로 뭐 메가 인플루언서, 마이크로 인플루언서 이런식으로 기준을 나눠서 정규화를 해야 조금 더 정확한 값이 될 것 같음.
# Out:
#     크리에이터 활동성  트렌드지수(팔로워순증가량)   콘텐츠 참여도  팔로워 충성도   콘텐츠 효율성    광고 효율성  \
# 0    3.596491        1.862339  0.000000    5.000  0.000000  5.000000
# 1    5.000000        0.841960  1.068647    4.375  0.253016  1.297324
# 2    0.964912        0.792182  4.046099    3.750  0.890213  2.556192
# 4    4.035088        0.000000  4.106968    0.000  1.039182  0.520322
# 6    0.000000        1.019133  0.117159    5.000  0.396492  0.888101
# 10   2.894737        5.000000  5.000000    5.000  5.000000  0.000000
#
#               acnt_id         acnt_nm
# 0   17841400361359004          s_h_j_
# 1   17841400561503844         binwoos
# 2   17841400591698216      tingkerhee
# 4   17841401506106699  siwolbubu_hyun
# 6   17841402936102997       seojinii_
# 10  17841453615191128   bong_camper83

# %%
# flexmatch_score_norm_df.to_csv("flexmatch_score_test.csv")
